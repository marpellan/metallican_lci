# %%
import pandas as pd

# %% [markdown]
# # Mappings

# %%
substances_table = pd.read_csv('data/MetalliCan/substances_table.csv')

# %%
substances_table
# Out:
#       substance_id                  substance_name
# 0    SUB07971a0766          1,2,4-Trimethylbenzene
# 1    SUBbdfdffeb95                   1-Nitropyrene
# 2    SUB0f01e7c1d0                 2-Butoxyethanol
# 3    SUB324959500a  7,12-Dimethylbenz[a]anthracene
# 4    SUBfee6b26acd        7H-Dibenzo[c,g]carbazole
# ..             ...                             ...
# 169  SUB787e5ac1a2    Vanadium (and its compounds)
# 170  SUBe849a2ff09            Xylene (all isomers)
# 171  SUBae95939c3f        Zinc (and its compounds)
# 172  SUB090a1237c1                 i-Butyl alcohol
# 173  SUBd049575022                        n-Hexane
#
# [174 rows x 2 columns]

# %%
# Create mapping NPRI-EI through IW+ mapping
# Import existing concordances 
mapping_npri_iw = pd.read_excel(r'data/Mappings/openIO_IW_EI_concordance.xlsx', sheet_name='NPRI_to_IW21')
mapping_ei_iw = pd.read_excel(r'data/Mappings/openIO_IW_EI_concordance.xlsx', sheet_name='EI_to_IW+')

# %%
# Standardize column names for merging
mapping_npri_iw.rename(columns={'IMPACT World+ flows': 'iw_name'}, inplace=True)
mapping_ei_iw.rename(columns={'iw name': 'iw_name'}, inplace=True)

# %%
# Add the 'EI' column to df_npri_iw based on matching iw_name with df_ei_iw
mapping_npri_iw['EI'] = mapping_npri_iw['iw_name'].map(
    lambda iw: mapping_ei_iw[mapping_ei_iw['iw_name'] == iw]['ecoinvent name'].iloc[0]
    if iw in mapping_ei_iw['iw_name'].values else 'No match found'
)

# %%
mapping_npri_iw
# Out:
#               OpenIO flows                        iw_name  \
# 0           Carbon dioxide         Carbon dioxide, fossil
# 1                  Methane                Methane, fossil
# 2      Dinitrogen monoxide            Dinitrogen monoxide
# 3                      CF4  Methane, tetrafluoro-, CFC-14
# 4                     C2F6   Ethane, hexafluoro-, HFC-116
# ..                     ...                            ...
# 348        Propylene oxide                Propylene oxide
# 349               Thiourea                       Thiourea
# 350  2-Ethoxyethyl acetate          2-Ethoxyethyl acetate
# 351      Azo disperse dyes                            NaN
# 352        Propionaldehyde                       Propanal
#
#                                EI
# 0          Carbon dioxide, fossil
# 1                         Methane
# 2             Dinitrogen monoxide
# 3     Methane, tetrafluoro-, R-14
# 4    Ethane, hexafluoro-, HFC-116
# ..                            ...
# 348               Propylene oxide
# 349                No match found
# 350                No match found
# 351                No match found
# 352                      Propanal
#
# [353 rows x 3 columns]

# %%
mapping_npri_iw.rename(columns={'OpenIO flows': 'substance_name'}, inplace=True)

# %%
substances_table
# Out:
#       substance_id                  substance_name
# 0    SUB07971a0766          1,2,4-Trimethylbenzene
# 1    SUBbdfdffeb95                   1-Nitropyrene
# 2    SUB0f01e7c1d0                 2-Butoxyethanol
# 3    SUB324959500a  7,12-Dimethylbenz[a]anthracene
# 4    SUBfee6b26acd        7H-Dibenzo[c,g]carbazole
# ..             ...                             ...
# 169  SUB787e5ac1a2    Vanadium (and its compounds)
# 170  SUBe849a2ff09            Xylene (all isomers)
# 171  SUBae95939c3f        Zinc (and its compounds)
# 172  SUB090a1237c1                 i-Butyl alcohol
# 173  SUBd049575022                        n-Hexane
#
# [174 rows x 2 columns]

# %%
substances_table_df = substances_table.merge(mapping_npri_iw[['substance_name', 'EI']],
              on='substance_name',
              how='left')

# %%
substances_table_df
# Out:
#       substance_id                  substance_name                   EI
# 0    SUB07971a0766          1,2,4-Trimethylbenzene       No match found
# 1    SUBbdfdffeb95                   1-Nitropyrene       No match found
# 2    SUB0f01e7c1d0                 2-Butoxyethanol       No match found
# 3    SUB324959500a  7,12-Dimethylbenz[a]anthracene       No match found
# 4    SUBfee6b26acd        7H-Dibenzo[c,g]carbazole       No match found
# ..             ...                             ...                  ...
# 169  SUB787e5ac1a2    Vanadium (and its compounds)             Vanadium
# 170  SUBe849a2ff09            Xylene (all isomers)               Xylene
# 171  SUBae95939c3f        Zinc (and its compounds)                 Zinc
# 172  SUB090a1237c1                 i-Butyl alcohol  2-Methyl-1-propanol
# 173  SUBd049575022                        n-Hexane               Hexane
#
# [174 rows x 3 columns]

# %% [markdown]
# # Data coverage statistics

# %%
data_coverage = pd.read_csv('data/MetalliCan/data_coverage_per_table.csv')

# %%
data_coverage
# Out:
#               main_id     facility_type      facility_name  \
# 0    QC-MAIN-5801b453  advanced project     Abcourt-Barvue
# 1    QC-MAIN-d29e0839            mining     Sleeping Giant
# 2    QC-MAIN-f1ff4920  advanced project       Akasaba West
# 3    NU-MAIN-4ea8ac9d            mining             Amaruq
# 4    QC-MAIN-e7e6a960            mining  Canadian Malartic
# ..                ...               ...                ...
# 265  ON-MAIN-c5fefb01            mining              Mishi
# 266  BC-MAIN-feb13c30  advanced project       Record Ridge
# 267  YT-MAIN-5e0d8b48  advanced project             Casino
# 268  ON-MAIN-12c68d49  advanced project       Eagle's Nest
# 269  BC-MAIN-891d3cb5  advanced project               Akie
#
#                                    commodities  Archetype table  \
# 0                                 Zinc, silver                0
# 1                                 Gold, silver                1
# 2                                 Gold, copper                0
# 3                                         Gold                1
# 4                                 Gold, silver                1
# ..                                         ...              ...
# 265                                       Gold                1
# 266                                  Magnesium                0
# 267           Copper, gold, molybdenum, silver                0
# 268  Nickel, copper, gold, platinum, palladium                0
# 269                         Zinc, lead, silver                0
#
#      By-product ratios table  Climate category table  Conflict table  \
# 0                          0                       9               0
# 1                          0                       9               0
# 2                          0                       9               0
# 3                          0                       9               0
# 4                          0                       9               0
# ..                       ...                     ...             ...
# 265                        0                       9               0
# 266                        0                       9               0
# 267                        0                       9               0
# 268                        0                       9               0
# 269                        0                       9               0
#
#      Energy table  Environmental intensity table  ...  Land occupation table  \
# 0               0                              0  ...                      2
# 1               0                              0  ...                      6
# 2               0                              0  ...                     10
# 3               8                              2  ...                      0
# 4               8                              2  ...                      6
# ..            ...                            ...  ...                    ...
# 265             8                              6  ...                      4
# 266             0                              0  ...                      0
# 267             0                              0  ...                      0
# 268             0                              0  ...                      0
# 269             0                              0  ...                      0
#
#      Peatland table  Population table  Prioritize conservation areas table  \
# 0                 1                 4                                    1
# 1                 1                 4                                    1
# 2                 1                 4                                    1
# 3                 1                 4                                    1
# 4                 1                 4                                    1
# ..              ...               ...                                  ...
# 265               1                 4                                    1
# 266               1                 4                                    1
# 267               1                 4                                    1
# 268               1                 4                                    1
# 269               1                 4                                    1
#
#      Production table  Protected & Indigenous land table  Reserves table  \
# 0                   0                                 30               0
# 1                   0                                 44               2
# 2                   0                                 46               0
# 3                   5                                  1               4
# 4                   1                                 41               5
# ..                ...                                ...             ...
# 265                 5                                 11               5
# 266                 0                                 24               0
# 267                 0                                  2               0
# 268                 0                                  1               0
# 269                 0                                  9               0
#
#      Tailings table  Water risk table  Weather table
# 0                 0                32            128
# 1                 0                32            128
# 2                 0                32            128
# 3                 0                32            128
# 4                 2                32            128
# ..              ...               ...            ...
# 265               0                32            128
# 266               0                32            128
# 267               0                32            128
# 268               0                32            128
# 269               0                32            128
#
# [270 rows x 22 columns]

# %%
col_of_interest = ['Energy table', 'Environmental intensity table', 'Production table', 'Environmental flows table', 'Tailings table']
stat_data_coverage = data_coverage[col_of_interest].describe()

# %%
stat_data_coverage
# Out:
#        Energy table  Environmental intensity table  Production table  \
# count    270.000000                     270.000000        270.000000
# mean       0.655556                       0.218519          1.177778
# std        2.035892                       0.990864          2.724982
# min        0.000000                       0.000000          0.000000
# 25%        0.000000                       0.000000          0.000000
# 50%        0.000000                       0.000000          0.000000
# 75%        0.000000                       0.000000          1.000000
# max        9.000000                       8.000000         21.000000
#
#        Environmental flows table  Tailings table
# count                 270.000000      270.000000
# mean                   52.762963        0.318519
# std                   102.823067        1.268151
# min                     0.000000        0.000000
# 25%                     0.000000        0.000000
# 50%                     0.000000        0.000000
# 75%                    48.750000        0.000000
# max                   758.000000       15.000000

# %%
data_coverage
