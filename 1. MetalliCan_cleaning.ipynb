# %%
import pandas as pd

# %%
from utils.data_manipulations import *

# %%
metallican_path = r'C:\Users\mp_ma\OneDrive - polymtl\POST_DOC\CODE\metallican_db'

# %% [markdown]
# # Import MetalliCan tables

# %%
main_table = pd.read_csv(metallican_path + r'\database\CSV\main_table.csv')
production_table = pd.read_csv(metallican_path + r'\database\CSV\production_table.csv')
tech_attributes_table = pd.read_csv(metallican_path + r'\database\CSV\tech_attributes_table.csv')
env_table = pd.read_csv(metallican_path + r'\database\CSV\environmental_flows_table.csv')
technosphere_table = pd.read_csv(metallican_path + r'\database\CSV\materials_energy_table.csv')
archetypes_table = pd.read_csv(metallican_path + r'\database\CSV\archetypes_table.csv')
land_table = pd.read_csv(metallican_path + r'\database\CSV\land_occupation_table.csv')
intensity_table = pd.read_csv(metallican_path + r'\database\CSV\intensity_table.csv')
waste_table = pd.read_table(metallican_path + r'\database\CSV\waste_table.csv', sep=',')
substances_table = pd.read_csv(metallican_path + r'\database\CSV\substances_table.csv')
#npv_table = pd.read_csv(metallican_path + r'\database\CSV\npv_table.csv')

# %%
intensity_table_nrj = intensity_table[intensity_table['type'] == 'Energy']
intensity_table_nrj = intensity_table_nrj[~intensity_table_nrj['intensity_id'].str.startswith('INT-CMP')]

# %%
# Let's remove ClimateTRACE data from production and env tables
production_table = production_table[~production_table['source_id'].str.startswith('Jolleys, M. et al (2024). Mineral Extraction sector: Mining and Quarrying Emissions from Copper, Iron, Bauxite, Rock and Sand, Hypervine, UK, Climate TRACE Emissions Inventory')]
env_table = env_table[~env_table['source_id'].str.startswith('Jolleys, M. et al (2024). Mineral Extraction sector: Mining and Quarrying Emissions from Copper, Iron, Bauxite, Rock and Sand, Hypervine, UK, Climate TRACE Emissions Inventory')]

# %%
production_table = merge_main_and_group(production_table, main_table, cols_to_add=['facility_name', 'facility_group_name'])
ta_table = merge_main_and_group(tech_attributes_table, main_table, cols_to_add=['facility_name', 'facility_group_name'])

# %%
ta_table = add_site_id(ta_table)

# %%
ta_table
# Out:
#            tech_attr_id  year commodity reference_point       material_type  \
# 0    TA-089f3c60-2022-1  2022      Iron      Usable ore   Concentrate grade
# 1    TA-857b7b89-2023-1  2023       Ore       Crude ore      Mill ore grade
# 2    TA-857b7b89-2023-2  2023       Ore       Crude ore  Mill recovery rate
# 3    TA-e7e6a960-2023-1  2023       Ore       Crude ore         Strip ratio
# 4    TA-e7e6a960-2023-2  2023      Gold       Crude ore          Head grade
# ..                  ...   ...       ...             ...                 ...
# 145  TA-02884fb5-2023-4  2023       Ore       Crude ore       Recovery rate
# 146  TA-7607a50e-2023-1  2023       Ore       Crude ore         Strip ratio
# 147  TA-7607a50e-2023-2  2023      Gold       Crude ore          Mill grade
# 148  TA-7607a50e-2023-3  2023      Gold       Crude ore  Mill recovery rate
# 149  TA-7607a50e-2023-4  2023      Gold       Crude ore           Ore grade
#
#          method       unit      value  \
# 0      Reported          %  66.200000
# 1      Reported        g/t   5.685000
# 2      Reported          %  96.000000
# 3    Calculated  waste/ore   1.000141
# 4      Reported        g/t   1.170000
# ..          ...        ...        ...
# 145    Reported          %  93.000000
# 146  Calculated  waste/ore   0.156803
# 147    Reported        g/t   2.200000
# 148    Reported          %  90.000000
# 149    Reported        g/t   2.200000
#
#                                               comment           main_id  \
# 0                                                 NaN  QC-MAIN-089f3c60
# 1                                                 NaN  BC-MAIN-857b7b89
# 2                                                 NaN  BC-MAIN-857b7b89
# 3         Total waste generated taken for calculation  QC-MAIN-e7e6a960
# 4                                                 NaN  QC-MAIN-e7e6a960
# ..                                                ...               ...
# 145                                               NaN  QC-MAIN-02884fb5
# 146  Total waste rock generated taken for calculation  ON-MAIN-7607a50e
# 147                                       Assumed g/t  ON-MAIN-7607a50e
# 148                                               NaN  ON-MAIN-7607a50e
# 149                                       Assumed g/t  ON-MAIN-7607a50e
#
#     facility_group_id    company_id  \
# 0                <NA>  CMP-c08ac7d7
# 1                <NA>  CMP-4a434d72
# 2                <NA>  CMP-4a434d72
# 3                <NA>  CMP-6265c407
# 4                <NA>  CMP-6265c407
# ..                ...           ...
# 145              <NA>  CMP-3d0a95b7
# 146              <NA>  CMP-3a4ccc7f
# 147              <NA>  CMP-3a4ccc7f
# 148              <NA>  CMP-3a4ccc7f
# 149              <NA>  CMP-3a4ccc7f
#
#                                              source_id      facility_name  \
# 0                   ChampionIronLtd_TR_Bloom_Lake_2023         Bloom Lake
# 1         NewmontCorporation_Operating_statistics_2023          Brucejack
# 2         NewmontCorporation_Operating_statistics_2023          Brucejack
# 3    AgnicoEagleMinesLimited_2023-Sustainability-Pe...  Canadian Malartic
# 4             AgnicoEagleMinesLimited_operational_data  Canadian Malartic
# ..                                                 ...                ...
# 145                IAMGOLDCorporation_operational_data     Westwood-Doyon
# 146                            AlamosGoldInc_Data_2023     Young-Davidson
# 147                            AlamosGoldInc_Data_2023     Young-Davidson
# 148                            AlamosGoldInc_Data_2023     Young-Davidson
# 149                            AlamosGoldInc_Data_2023     Young-Davidson
#
#     facility_group_name           site_id
# 0                   NaN  QC-MAIN-089f3c60
# 1                   NaN  BC-MAIN-857b7b89
# 2                   NaN  BC-MAIN-857b7b89
# 3                   NaN  QC-MAIN-e7e6a960
# 4                   NaN  QC-MAIN-e7e6a960
# ..                  ...               ...
# 145                 NaN  QC-MAIN-02884fb5
# 146                 NaN  ON-MAIN-7607a50e
# 147                 NaN  ON-MAIN-7607a50e
# 148                 NaN  ON-MAIN-7607a50e
# 149                 NaN  ON-MAIN-7607a50e
#
# [150 rows x 16 columns]

# %%
production_table.to_csv(r'data\MetalliCan\pre_cleaned_data\production_table.csv', index=False, encoding='utf-8-sig')
ta_table.to_csv(r'data\MetalliCan\pre_cleaned_data\ta_table.csv', index=False, encoding='utf-8-sig')

# %%
# Let's remove ClimateTRACE data
env_table = env_table[~env_table['source_id'].str.startswith('Jolleys, M. et al (2024). Mineral Extraction sector: Mining and Quarrying Emissions from Copper, Iron, Bauxite, Rock and Sand, Hypervine, UK, Climate TRACE Emissions Inventory')]

# %%
#ids_energy = set(energy_table[['main_id', 'facility_group_id']].apply(tuple, axis=1))
#ids_material = set(material_table[['main_id', 'facility_group_id']].apply(tuple, axis=1))
#ids_biosphere = set(biosphere_table[['main_id', 'facility_group_id']].apply(tuple, axis=1))
#ids_land = set(land_table[['main_id', 'facility_group_id']].apply(tuple, axis=1))

# %%
# Facilities with at least technosphere and biosphere flows
#best_ids = ids_energy & ids_material & ids_biosphere
#best_ids

# %% [markdown]
# ## Harmonize units for the same substance_id

# %%
unit_mapping = {
'7732-18-5' : 'm3',
'NA - M10' : 'tonnes',
'NA - M09' : 'tonnes',
'NA - M16' : 'tonnes',
'630-08-0' : 'tonnes',
'NA - NOx' : 'tonnes',
'NA - 08' : 'kg',
'NA - 10' : 'tonnes',
'NA - 02' : 'kg',
'NA - M08' : 'tonnes',
'NA - GHG' : 'tCO2eq',
'NA - 12': 'kg',
'NA - SOx': 'tonnes'
}

# %%
conversion_factors = {
    ('kg', 'tonnes'): 1/1000,
    ('kg', 't'): 1/1000,
    ('tonnes', 'kg'): 1000,
    ('t', 'kg'): 1000,
    ('tonnes', 't'): 1,
    ('t', 'tonnes'): 1,
    ('ML', 'm3'): 1000,
    ('m3', 'ML'): 1/1000,
    ('L', 'm3'): 1/1000,
    ('m3', 'L'): 1000,
    ('Mm3', 'm3'): 1000000,
    ('km3', 'm3'): 1000,
    ('ktCO2eq', 'tCO2eq'): 1000,
    ('tCO2eq', 'ktCO2eq'): 1/1000
}

# %%
def update_units_and_values(row):
    substance_id = row['substance_id']
    current_unit = row['unit']
    value = row['value']

    if substance_id in unit_mapping:
        target_unit = unit_mapping[substance_id]

        if current_unit != target_unit:
            conversion_key = (current_unit, target_unit)
            if conversion_key in conversion_factors:
                value = value * conversion_factors[conversion_key]
            # Si la conversion n'est pas définie, la valeur reste inchangée

        current_unit = target_unit  # Mettre à jour l'unité

    return pd.Series({'unit': current_unit, 'value': value})


env_table['value'] = pd.to_numeric(env_table['value'], errors='coerce')
mask = env_table['substance_id'].isin(unit_mapping.keys())
env_table.loc[mask, ['unit', 'value']] = env_table.loc[mask].apply(update_units_and_values, axis=1)

# %%
env_table
# Out:
#                     env_id  year compartment_name substance_id flow_direction  \
# 0                  1754055  2023              Air     NA - GHG            NaN
# 1                  1754056  2023              Air     NA - GHG            NaN
# 2                  1754057  2023              Air     NA - GHG            NaN
# 3                  1754058  2023              Air     NA - GHG            NaN
# 4                  1754060  2023              Air     NA - GHG            NaN
# ...                    ...   ...              ...          ...            ...
# 5339  ENV-9de9bb0d-2023-12  2023              Air     NA - M16       Emission
# 5340  ENV-02884fb5-2023-12  2023            Water    7732-18-5     Withdrawal
# 5341  ENV-7607a50e-2023-14  2023            Water    7732-18-5     Withdrawal
# 5342  ENV-7607a50e-2023-15  2023            Water    7732-18-5     Discharged
# 5343  ENV-7607a50e-2023-16  2023            Water    7732-18-5    Consumption
#
#      release_pathway    unit         value                 comment  \
# 0                NaN  tCO2eq  5.610000e+03                     NaN
# 1                NaN  tCO2eq  6.403000e+03                     NaN
# 2                NaN  tCO2eq  2.299160e+05                     NaN
# 3                NaN  tCO2eq  2.639000e+03                     NaN
# 4                NaN  tCO2eq  4.225000e+03                     NaN
# ...              ...     ...           ...                     ...
# 5339             NaN  tonnes  9.900000e-01                     NaN
# 5340             NaN      m3  5.145100e+06   Withdrawal|Freshwater
# 5341             NaN      m3  2.879300e+06  Total water withdrawal
# 5342             NaN      m3  1.088500e+06   Total water discharge
# 5343             NaN      m3  1.790810e+06       Total consumption
#
#                main_id facility_group_id    company_id  \
# 0     ON-MAIN-6e9b2449      GRP-dc07540b  CMP-9617aef4
# 1     ON-MAIN-f080c409      GRP-dc07540b  CMP-9617aef4
# 2     BC-MAIN-599152a0               NaN  CMP-12afc634
# 3     ON-MAIN-52224e1e      GRP-dc07540b  CMP-9617aef4
# 4     ON-MAIN-48fe2205      GRP-dc07540b  CMP-9617aef4
# ...                ...               ...           ...
# 5339  QC-MAIN-9de9bb0d               NaN  CMP-3d2c4955
# 5340  QC-MAIN-02884fb5               NaN  CMP-3d0a95b7
# 5341  ON-MAIN-7607a50e               NaN  CMP-3a4ccc7f
# 5342  ON-MAIN-7607a50e               NaN  CMP-3a4ccc7f
# 5343  ON-MAIN-7607a50e               NaN  CMP-3a4ccc7f
#
#                                               source_id
# 0     https://github.com/climatetracecoalition/metho...
# 1     https://github.com/climatetracecoalition/metho...
# 2     https://github.com/climatetracecoalition/metho...
# 3     https://github.com/climatetracecoalition/metho...
# 4     https://github.com/climatetracecoalition/metho...
# ...                                                 ...
# 5339           WesdomeGoldMinesLtd_2023-ESG-Data-Tables
# 5340  IAMGOLDCorporation_2023_iamgold-esg-performanc...
# 5341                            AlamosGoldInc_Data_2023
# 5342                            AlamosGoldInc_Data_2023
# 5343                            AlamosGoldInc_Data_2023
#
# [5344 rows x 13 columns]

# %% [markdown]
# ## Aggregate data at facility-group level

# %%
biosphere_df = aggregate_biosphere_facility_groups(env_table, remove_individuals='True')

# %%
biosphere_df
# Out:
#        env_id  year compartment_name substance_id flow_direction  \
# 0     1754057  2023              Air     NA - GHG            NaN
# 1     1754061  2023              Air     NA - GHG            NaN
# 2     1754066  2023              Air     NA - GHG            NaN
# 3     1754071  2023              Air     NA - GHG            NaN
# 4     1754077  2023              Air     NA - GHG            NaN
# ...       ...   ...              ...          ...            ...
# 4412      NaN  2023            Water      NA - 17       Emission
# 4413      NaN  2023            Water      NA - 37       Emission
# 4414      NaN  2023            Water      NA - 37       Emission
# 4415      NaN  2023            Water      NA - 40       Emission
# 4416      NaN  2023            Water      NA - 40       Emission
#
#        release_pathway    unit         value  \
# 0                  NaN  tCO2eq  2.299160e+05
# 1                  NaN  tCO2eq  1.316380e+05
# 2                  NaN  tCO2eq  2.412130e+06
# 3                  NaN  tCO2eq  0.000000e+00
# 4                  NaN  tCO2eq  6.711600e+04
# ...                ...     ...           ...
# 4412         Waterbody  tonnes  0.000000e+00
# 4413  Direct Discharge      kg  2.100000e-03
# 4414         Waterbody      kg  0.000000e+00
# 4415  Direct Discharge  tonnes  7.037000e-03
# 4416         Waterbody  tonnes  0.000000e+00
#
#                                         comment           main_id  \
# 0                                           NaN  BC-MAIN-599152a0
# 1                                           NaN  BC-MAIN-6b4800fe
# 2                                           NaN  BC-MAIN-bf503b6b
# 3                                           NaN  BC-MAIN-e34feb4d
# 4                                           NaN  QC-MAIN-e51eda66
# ...                                         ...               ...
# 4412  Aggregated value from multiple facilities              None
# 4413  Aggregated value from multiple facilities              None
# 4414  Aggregated value from multiple facilities              None
# 4415  Aggregated value from multiple facilities              None
# 4416  Aggregated value from multiple facilities              None
#
#      facility_group_id    company_id  \
# 0                  NaN  CMP-12afc634
# 1                  NaN  CMP-e35f138c
# 2                  NaN  CMP-06e20c6e
# 3                  NaN  CMP-fa032e20
# 4                  NaN  CMP-6265c407
# ...                ...           ...
# 4412      GRP-de097f20  CMP-d5f1c66b
# 4413      GRP-de097f20  CMP-d5f1c66b
# 4414      GRP-de097f20  CMP-d5f1c66b
# 4415      GRP-de097f20  CMP-d5f1c66b
# 4416      GRP-de097f20  CMP-d5f1c66b
#
#                                               source_id
# 0     https://github.com/climatetracecoalition/metho...
# 1     https://github.com/climatetracecoalition/metho...
# 2     https://github.com/climatetracecoalition/metho...
# 3     https://github.com/climatetracecoalition/metho...
# 4     https://github.com/climatetracecoalition/metho...
# ...                                                 ...
# 4412  https://www.canada.ca/en/environment-climate-c...
# 4413  https://www.canada.ca/en/environment-climate-c...
# 4414  https://www.canada.ca/en/environment-climate-c...
# 4415  https://www.canada.ca/en/environment-climate-c...
# 4416  https://www.canada.ca/en/environment-climate-c...
#
# [4417 rows x 13 columns]

# %%
# To have the substance names
biosphere_df = biosphere_df.merge(substances_table[['substance_id', 'substance_name']], how='left',
                                        on='substance_id')

# %%
biosphere_df.to_excel(r'data/MetalliCan/pre_cleaned_data/biosphere_df.xlsx', index=False)

# %% [markdown]
# # Harmonization of technosphere units

# %%
# Separe energy and material
energy_df = technosphere_table[technosphere_table['flow_type'] == 'Energy']
material_df = technosphere_table[technosphere_table['flow_type'] == 'Material use']

# %% [markdown]
# ## Energy flows

# %%
from utils.conversion_functions import standardize_energy_to_MJ

# %%
# Replace the unit 'kl' to 'm3' for Natural gas to avoid issues during conversion
energy_df.loc[(energy_df['subflow_type'] == 'Natural gas') & (energy_df['unit'] == 'kl'), 'unit'] = 'm3'

# %%
energy_df_sd = standardize_energy_to_MJ(energy_df)

# %%
energy_df_sd[energy_df_sd['value_MJ'].isna()]
# Out:
# Empty DataFrame
# Columns: [technosphere_id, year, flow_type, subflow_type, unit, value, comment, main_id, facility_group_id, company_id, source_id, value_MJ, unit_source, assumption_note, unit_standard, needs_factor]
# Index: []

# %%
# Check the rows where needs_factor is TRUE
energy_df_sd[energy_df_sd['value_MJ'].isna()]
# Out:
# Empty DataFrame
# Columns: [technosphere_id, year, flow_type, subflow_type, unit, value, comment, main_id, facility_group_id, company_id, source_id, value_MJ, unit_source, assumption_note, unit_standard, needs_factor]
# Index: []

# %%
energy_df_sd.to_excel(r'data/MetalliCan/pre_cleaned_data/energy_df.xlsx', index=False)

# %% [markdown]
# ## Material flows

# %%
from utils.conversion_functions import standardize_materials_to_t

# %%
material_df_sd = standardize_materials_to_t(material_df)

# %%
# Check the rows where mass_t is NaN
material_df_sd[material_df_sd['mass_t'].isna()]
# Out:
# Empty DataFrame
# Columns: [technosphere_id, year, flow_type, subflow_type, unit, value, comment, main_id, facility_group_id, company_id, source_id, mass_t, mass_source, mass_note, needs_density]
# Index: []

# %%
material_df_sd.to_excel(r'data/MetalliCan/pre_cleaned_data/material_df.xlsx', index=False)

# %% [markdown]
# # Harmonization of land flows

# %%
# Step 1: Find main_id that have more than one unique source_id
multi_source_main_ids = land_table.groupby('main_id')['source_id'].nunique()
multi_source_main_ids = multi_source_main_ids[multi_source_main_ids > 1].index

# Step 2: Filter the dataframe
land_table = land_table[
    ~land_table['main_id'].isin(multi_source_main_ids) |
    (land_table['source_id'] == "https://www.nature.com/articles/s41597-025-05296-y")
]

# %%
# For each main_id, give the sum of area_km2 associated
land_table = land_table.groupby('main_id')['area_km2'].sum().reset_index()

# %%
land_table = land_table.merge(main_table[['main_id', 'facility_group_id', 'facility_name', 'facility_group_name', 'province', 'facility_type', 'mining_processing_type', 'commodities', 'operation_periods']], on='main_id', how='left')

# %%
land_table_mining = land_table[land_table['facility_type'] == 'mining']

# %%
# Add a column with area in m2 and
land_table_mining['area_m2'] = land_table_mining['area_km2'] * 1e6
land_table_mining.drop(columns=['area_km2'], inplace=True)
# Out:
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_12308\2199434072.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   land_table_mining['area_m2'] = land_table_mining['area_km2'] * 1e6
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_12308\2199434072.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   land_table_mining.drop(columns=['area_km2'], inplace=True)

# %%
land_table_mining
# Out:
#               main_id facility_group_id              facility_name  \
# 0    BC-MAIN-23155c25               NaN                 Myra Falls
# 2    BC-MAIN-3f490561               NaN               Mount Polley
# 3    BC-MAIN-4724f4ba               NaN                        Elk
# 4    BC-MAIN-599152a0               NaN            Copper Mountain
# 5    BC-MAIN-6b4800fe               NaN                  Gibraltar
# ..                ...               ...                        ...
# 110  SK-MAIN-91cf5448               NaN                 Cigar Lake
# 112  SK-MAIN-bb89158f      GRP-21eee27d                   Key Lake
# 113  SK-MAIN-d3c471e8      GRP-21eee27d             McArthur River
# 114  YT-MAIN-44857446               NaN  Keno Hill Silver District
# 115  YT-MAIN-752fbcae               NaN                      Minto
#
#            facility_group_name          province facility_type  \
# 0                          NaN  British Columbia        mining
# 2                          NaN  British Columbia        mining
# 3                          NaN  British Columbia        mining
# 4                          NaN  British Columbia        mining
# 5                          NaN  British Columbia        mining
# ..                         ...               ...           ...
# 110                        NaN      Saskatchewan        mining
# 112  Key Lake + McArthur River      Saskatchewan        mining
# 113  Key Lake + McArthur River      Saskatchewan        mining
# 114                        NaN             Yukon        mining
# 115                        NaN             Yukon        mining
#
#                   mining_processing_type                       commodities  \
# 0                            Underground  Zinc, copper, silver, gold, lead
# 2                 Open-pit, concentrator              Gold, copper, silver
# 3                               Open-pit                              Gold
# 4                 Open-pit, concentrator              Copper, gold, silver
# 5                 Open-pit, concentrator        Copper, molybdenum, silver
# ..                                   ...                               ...
# 110                          Underground                           Uranium
# 112                         Concentrator                           Uranium
# 113                          Underground                           Uranium
# 114            Underground, concentrator                Silver, zinc, lead
# 115  Open-pit, underground, concentrator              Copper, gold, silver
#
#                    operation_periods       area_m2
# 0    1966–1985; 2002–2015; 2019–open  1.499690e+06
# 2                                NaN  7.967835e+06
# 3                                NaN  4.167369e+05
# 4               1884–1958; 2011–open  1.323321e+07
# 5               1972–1998; 2004–open  2.252800e+07
# ..                               ...           ...
# 110                        2015–open  1.600590e+06
# 112                              NaN  1.023565e+07
# 113                              NaN  1.973892e+06
# 114                              NaN  5.293594e+06
# 115                              NaN  3.418676e+06
#
# [77 rows x 10 columns]

# %%
land_table_mining.columns
# Out:
# Index(['main_id', 'facility_group_id', 'facility_name', 'facility_group_name',
#        'province', 'facility_type', 'mining_processing_type', 'commodities',
#        'operation_periods', 'area_m2'],
#       dtype='object')

# %%
import pandas as pd

def aggregate_land_facility_groups(
    df: pd.DataFrame,
    by=("facility_group_id",),                    # -> 1 ligne par facility_group_id
    sum_cols=("area_m2",),                        # colonnes à sommer
    concat_cols=("operation_periods", "commodities", "mining_processing_type"),  # concat unique
    first_cols=("province", "facility_type", "company_id"),  # on prend la 1ère valeur non-nulle
    remove_individuals: bool=False
) -> pd.DataFrame:
    """
    Agrège les enregistrements par facility_group_id (1 ligne par groupe).
    - Somme les colonnes numériques définies dans `sum_cols`
    - Concatène de façon unique et nettoyée les colonnes de `concat_cols`
    - Recopie la première valeur non-nulle pour `first_cols`
    - Crée de nouvelles lignes agrégées (main_id=None, facility_name="")
    - Optionnellement supprime les lignes individuelles du groupe (remove_individuals=True)

    Paramètres
    ----------
    df : pd.DataFrame
    by : tuple[str]
        Clés d'agrégation. Par défaut uniquement ("facility_group_id",)
        -> garantit 1 ligne par facility group ID.
    sum_cols : tuple[str]
        Colonnes à sommer.
    concat_cols : tuple[str]
        Colonnes à concaténer (valeurs uniques, trim, dédoublonnées).
    first_cols : tuple[str]
        Colonnes pour lesquelles on prend la première valeur non-nulle.
    remove_individuals : bool
        Si True, supprime les enregistrements individuels des groupes agrégés.

    Retour
    ------
    pd.DataFrame
        DataFrame combinant les lignes d'origine (ou non) et les lignes agrégées.
    """

    df = df.copy()

    # --- Helpers -------------------------------------------------------------
    def first_non_null(series: pd.Series):
        s = series.dropna()
        if not s.empty:
            # Evite les chaînes vides considérées comme "non-informatives"
            for v in s:
                if isinstance(v, str) and v.strip() == "":
                    continue
                return v
            # si tout est vide/"" -> retourner NaN
            return pd.NA
        return pd.NA

    def concat_unique(series: pd.Series):
        """Concatène des valeurs uniques en nettoyant les séparateurs et espaces.
        Gère des entrées déjà séparées par des virgules.
        """
        if series.isna().all():
            return pd.NA
        tokens = []
        for v in series.dropna().astype(str):
            # scinder sur virgule si présent
            parts = [p.strip() for p in v.split(",") if p.strip() != ""]
            tokens.extend(parts)
        # unicité en préservant l'ordre d'apparition
        seen = set()
        uniq = []
        for t in tokens:
            key = t.lower()  # unicité case-insensitive
            if key not in seen:
                seen.add(key)
                uniq.append(t)
        return ", ".join(uniq) if uniq else pd.NA

    # S'assurer que la colonne facility_group_id existe et filtrer les groupes valides
    if "facility_group_id" not in df.columns:
        raise KeyError("La colonne 'facility_group_id' est absente du DataFrame.")

    df_groups = df[df["facility_group_id"].notna()].copy()
    if df_groups.empty:
        # rien à agréger : retourner df tel quel
        return df

    # Construire le dict d'aggregations
    agg_dict = {}

    for c in sum_cols:
        if c in df_groups.columns:
            agg_dict[c] = "sum"

    for c in concat_cols:
        if c in df_groups.columns:
            agg_dict[c] = concat_unique

    for c in first_cols:
        if c in df_groups.columns:
            agg_dict[c] = first_non_null

    # Groupby UNIQUEMENT par les clés "by" (par défaut: facility_group_id)
    grouped = (
        df_groups
        .groupby(list(by), dropna=False)
        .agg(agg_dict)
        .reset_index()
    )

    # Ajouter/forcer les champs des lignes agrégées
    grouped["main_id"] = None
    grouped["facility_name"] = ""  # vide pour les lignes agrégées
    grouped["comment"] = grouped.get("comment", pd.Series(index=grouped.index, dtype="object"))
    grouped["comment"] = grouped["comment"].fillna("Aggregated value from multiple facilities")

    # Réordonner/réaligner les colonnes sur le df original
    # (on garde toutes les colonnes d'origine ; s'il en manque, on les crée)
    for col in df.columns:
        if col not in grouped.columns:
            grouped[col] = pd.NA
    grouped = grouped[df.columns]

    # Optionnellement supprimer les indiv. des groupes agrégés
    if remove_individuals:
        to_remove = df_groups["facility_group_id"].unique()
        base = df[~df["facility_group_id"].isin(to_remove)].copy()
    else:
        base = df

    # Combiner
    combined = pd.concat([base, grouped], ignore_index=True)

    # (Optionnel) garantir au maximum 1 ligne agrégée par group_id
    # -> si jamais des duplications surviennent, on garde la première.
    mask_agg = (combined["main_id"].isna()) & (combined["facility_name"] == "")
    dupe_mask = mask_agg & combined.duplicated(subset=list(by) + ["main_id", "facility_name"], keep="first")
    if dupe_mask.any():
        combined = combined.loc[~dupe_mask].copy()

    return combined

# %%
land_table_mining = aggregate_land_facility_groups(land_table_mining)

# %%
land_table_mining
# Out:
#              main_id facility_group_id    facility_name facility_group_name  \
# 0   BC-MAIN-23155c25               NaN       Myra Falls                 NaN
# 1   BC-MAIN-3f490561               NaN     Mount Polley                 NaN
# 2   BC-MAIN-4724f4ba               NaN              Elk                 NaN
# 3   BC-MAIN-599152a0               NaN  Copper Mountain                 NaN
# 4   BC-MAIN-6b4800fe               NaN        Gibraltar                 NaN
# ..               ...               ...              ...                 ...
# 83              None      GRP-25483238                                  NaN
# 84              None      GRP-2a663492                                  NaN
# 85              None      GRP-a13779f8                                  NaN
# 86              None      GRP-dc07540b                                  NaN
# 87              None      GRP-de097f20                                  NaN
#
#                      province facility_type     mining_processing_type  \
# 0            British Columbia        mining                Underground
# 1            British Columbia        mining     Open-pit, concentrator
# 2            British Columbia        mining                   Open-pit
# 3            British Columbia        mining     Open-pit, concentrator
# 4            British Columbia        mining     Open-pit, concentrator
# ..                        ...           ...                        ...
# 83                     Quebec        mining                   Open-pit
# 84  Newfoundland and Labrador        mining                   Open-pit
# 85                   Manitoba        mining  Concentrator, Underground
# 86                    Ontario        mining  Underground, Concentrator
# 87                    Ontario        mining  Underground, Concentrator
#
#                                           commodities  \
# 0                    Zinc, copper, silver, gold, lead
# 1                                Gold, copper, silver
# 2                                                Gold
# 3                                Copper, gold, silver
# 4                          Copper, molybdenum, silver
# ..                                                ...
# 83                                           Ilmenite
# 84                                               Iron
# 85                         Gold, zinc, copper, silver
# 86  Nickel, copper, platinum group metals, gold, s...
# 87  Nickel, copper, platinum group metals, gold, c...
#
#                   operation_periods       area_m2
# 0   1966–1985; 2002–2015; 2019–open  1.499690e+06
# 1                               NaN  7.967835e+06
# 2                               NaN  4.167369e+05
# 3              1884–1958; 2011–open  1.323321e+07
# 4              1972–1998; 2004–open  2.252800e+07
# ..                              ...           ...
# 83                        1948–open  2.331099e+06
# 84                             <NA>  1.034080e+07
# 85  2013–open, 1949–2000; 2021–open  3.104131e+06
# 86                        2014–open  2.941696e+07
# 87  1962–1991; 2007–2009; 2010–open  4.589124e+06
#
# [88 rows x 10 columns]

# %%
land_table_mining.to_excel(r'data/MetalliCan/pre_cleaned_data/land_table_mining.xlsx', index=False)

# %%
# Which ones do not have operation periods?
land_table_mining[land_table_mining['operation_periods'].isna()]
# Out:
#              main_id facility_group_id              facility_name  \
# 1   BC-MAIN-3f490561               NaN               Mount Polley
# 2   BC-MAIN-4724f4ba               NaN                        Elk
# 7   BC-MAIN-bf503b6b               NaN            Highland Valley
# 9   MB-MAIN-0898e255      GRP-a13779f8                 Stall Lake
# 10  MB-MAIN-915d9faa               NaN                      Tanco
# 13  MB-MAIN-e0a6250e               NaN     Thompson (T-1 and T-3)
# 15  NL-MAIN-842ba1b4               NaN                Nugget Pond
# 16  NL-MAIN-b64bae7a               NaN                     Scully
# 17  NL-MAIN-c139de6d               NaN                       Ming
# 18  NL-MAIN-dd723db4               NaN                 Carol Lake
# 19  NL-MAIN-e09881ff      GRP-2a663492              DSO (3 and 4)
# 20  NL-MAIN-f021107e               NaN               Point Rousse
# 22  NT-MAIN-0ec39ce0               NaN                     Diavik
# 30  ON-MAIN-3b3e5365               NaN                  Porcupine
# 31  ON-MAIN-48fe2205      GRP-dc07540b                     Garson
# 33  ON-MAIN-52224e1e      GRP-dc07540b                  Creighton
# 35  ON-MAIN-6e9b2449      GRP-dc07540b                    Coleman
# 37  ON-MAIN-7001a391               NaN              McCreedy West
# 40  ON-MAIN-8629a493      GRP-0d911886                  Hollinger
# 41  ON-MAIN-8825d90d               NaN                     Magino
# 46  ON-MAIN-de2f9639      GRP-dc07540b                 Clarabelle
# 48  ON-MAIN-f080c409      GRP-dc07540b       Copper Cliff Complex
# 51  ON-MAIN-fcb287a4      GRP-de097f20           Nickel Rim South
# 55  QC-MAIN-089f3c60               NaN                 Bloom Lake
# 57  QC-MAIN-33c09b8b      GRP-1402249f                  Fire Lake
# 65  QC-MAIN-dc1a16f9               NaN     North American Lithium
# 69  QC-MAIN-f9e41c2a               NaN                    Lamaque
# 70  SK-MAIN-29afbdb5      GRP-14bfbb82                     Seabee
# 71  SK-MAIN-60ba74c4               NaN               McClean Lake
# 73  SK-MAIN-bb89158f      GRP-21eee27d                   Key Lake
# 74  SK-MAIN-d3c471e8      GRP-21eee27d             McArthur River
# 75  YT-MAIN-44857446               NaN  Keno Hill Silver District
# 76  YT-MAIN-752fbcae               NaN                      Minto
# 81              None      GRP-14bfbb82
# 82              None      GRP-21eee27d
# 84              None      GRP-2a663492
#
#              facility_group_name                   province facility_type  \
# 1                            NaN           British Columbia        mining
# 2                            NaN           British Columbia        mining
# 7                            NaN           British Columbia        mining
# 9                      Snow Lake                   Manitoba        mining
# 10                           NaN                   Manitoba        mining
# 13                           NaN                   Manitoba        mining
# 15                           NaN  Newfoundland and Labrador        mining
# 16                           NaN  Newfoundland and Labrador        mining
# 17                           NaN  Newfoundland and Labrador        mining
# 18                           NaN  Newfoundland and Labrador        mining
# 19                           DSO  Newfoundland and Labrador        mining
# 20                           NaN  Newfoundland and Labrador        mining
# 22                           NaN      Northwest Territories        mining
# 30                           NaN                    Ontario        mining
# 31             Sudbury Operation                    Ontario        mining
# 33             Sudbury Operation                    Ontario        mining
# 35             Sudbury Operation                    Ontario        mining
# 37                           NaN                    Ontario        mining
# 40             Porcupine complex                    Ontario        mining
# 41                           NaN                    Ontario        mining
# 46             Sudbury Operation                    Ontario        mining
# 48             Sudbury Operation                    Ontario        mining
# 51  Integrated Nickel Operations                    Ontario        mining
# 55                           NaN                     Quebec        mining
# 57                          AMMC                     Quebec        mining
# 65                           NaN                     Quebec        mining
# 69                           NaN                     Quebec        mining
# 70         Seabee Gold Operation               Saskatchewan        mining
# 71                           NaN               Saskatchewan        mining
# 73     Key Lake + McArthur River               Saskatchewan        mining
# 74     Key Lake + McArthur River               Saskatchewan        mining
# 75                           NaN                      Yukon        mining
# 76                           NaN                      Yukon        mining
# 81                           NaN               Saskatchewan        mining
# 82                           NaN               Saskatchewan        mining
# 84                           NaN  Newfoundland and Labrador        mining
#
#                  mining_processing_type  \
# 1                Open-pit, concentrator
# 2                              Open-pit
# 7                Open-pit, concentrator
# 9                          Concentrator
# 10     Underground, concentrator, plant
# 13  Open-pit, underground, concentrator
# 15                         Concentrator
# 16               Open-pit, concentrator
# 17                          Underground
# 18               Open-pit, concentrator
# 19                             Open-pit
# 20               Open-pit, concentrator
# 22                   Underground, plant
# 30                         Concentrator
# 31                          Underground
# 33                          Underground
# 35                          Underground
# 37                          Underground
# 40                             Open-pit
# 41               Open-pit, concentrator
# 46                         Concentrator
# 48                          Underground
# 51                          Underground
# 55                             Open-pit
# 57                             Open-pit
# 65                Open-pit, underground
# 69            Underground, concentrator
# 70                         Concentrator
# 71                         Concentrator
# 73                         Concentrator
# 74                          Underground
# 75            Underground, concentrator
# 76  Open-pit, underground, concentrator
# 81                         Concentrator
# 82            Concentrator, Underground
# 84                             Open-pit
#
#                                           commodities operation_periods  \
# 1                                Gold, copper, silver               NaN
# 2                                                Gold               NaN
# 7                          Copper, silver, molybdenum               NaN
# 9                                          Gold, zinc               NaN
# 10                                    Cesium, lithium               NaN
# 13  Nickel, cobalt, copper, platinum group metals,...               NaN
# 15                                             Copper               NaN
# 16                                               Iron               NaN
# 17                               Copper, gold, silver               NaN
# 18                                               Iron               NaN
# 19                                               Iron               NaN
# 20                                               Gold               NaN
# 22                                           Diamonds               NaN
# 30                                               Gold               NaN
# 31  Nickel, copper, platinum group metals, gold, s...               NaN
# 33  Nickel, copper, platinum group metals, gold, s...               NaN
# 35  Nickel, copper, platinum group metals, gold, s...               NaN
# 37  Copper, nickel, platinum group metals, gold, s...               NaN
# 40                                               Gold               NaN
# 41                                       Gold, silver               NaN
# 46  Nickel, copper, platinum group metals, gold, s...               NaN
# 48  Nickel, copper, platinum group metals, gold, s...               NaN
# 51  Nickel, copper, cobalt, platinum group metals,...               NaN
# 55                                               Iron               NaN
# 57                                               Iron               NaN
# 65                                            Lithium               NaN
# 69                                               Gold               NaN
# 70                                               Gold               NaN
# 71                                            Uranium               NaN
# 73                                            Uranium               NaN
# 74                                            Uranium               NaN
# 75                                 Silver, zinc, lead               NaN
# 76                               Copper, gold, silver               NaN
# 81                                               Gold              <NA>
# 82                                            Uranium              <NA>
# 84                                               Iron              <NA>
#
#          area_m2
# 1   7.967835e+06
# 2   4.167369e+05
# 7   6.392426e+07
# 9   3.300033e+05
# 10  1.058100e+06
# 13  7.481998e+06
# 15  1.632546e+05
# 16  1.057219e+07
# 17  1.510729e+06
# 18  2.610465e+07
# 19  1.034080e+07
# 20  4.354811e+06
# 22  9.992992e+06
# 30  3.512632e+06
# 31  2.161806e+06
# 33  1.929968e+06
# 35  1.108039e+05
# 37  9.891461e+05
# 40  1.141146e+06
# 41  2.404687e+05
# 46  3.063893e+06
# 48  2.159125e+07
# 51  1.788408e+06
# 55  1.570269e+07
# 57  3.714363e+06
# 65  2.689687e+06
# 69  1.190408e+07
# 70  5.170040e+05
# 71  4.412887e+06
# 73  1.023565e+07
# 74  1.973892e+06
# 75  5.293594e+06
# 76  3.418676e+06
# 81  5.170040e+05
# 82  1.220954e+07
# 84  1.034080e+07

# %% [markdown]
# # Normalization

# %% [markdown]
# ## Prepare data for normalization

# %%
from utils.data_manipulations import build_activity_name, add_site_id

# %%
# Load prices and production data
price_df = pd.read_excel(r'data/Prices/Prices_data.xlsx', sheet_name='data')
production_df = pd.read_excel(r'data/MetalliCan/sites_for_lci.xlsx', sheet_name='prod_data')

# %%
# Keep only relevant columns
energy_df_sd = energy_df_sd[['main_id', 'facility_group_id', 'flow_type', 'subflow_type', 'value_MJ']]
material_df_sd = material_df_sd[['main_id', 'facility_group_id', 'flow_type', 'subflow_type', 'mass_t']]
biosphere_df = biosphere_df[['main_id', 'facility_group_id', 'compartment_name', 'substance_name', 'flow_direction', 'release_pathway', 'unit', 'value']]

# %%
# Add activitiy_name to production_df
production_df['activity_name'] = production_df.apply(lambda row: build_activity_name(row, production_df), axis=1)

# %%
production_df = add_site_id(production_df)
energy_df_sd = add_site_id(energy_df_sd)
material_df_sd = add_site_id(material_df_sd)
biosphere_df = add_site_id(biosphere_df)

# %%
energy_df_sd = energy_df_sd.merge(production_df[['site_id', 'activity_name']], on='site_id', how='left')
material_df_sd = material_df_sd.merge(production_df[['site_id', 'activity_name']], on='site_id', how='left')
biosphere_df = biosphere_df.merge(production_df[['site_id', 'activity_name']], on='site_id', how='left')

# %%
# Replace column name mass_t to mass for normalization function
material_df_sd = material_df_sd.rename(columns={'mass_t': 'mass'})

# %% [markdown]
# ## Normalize flows

# %%
from core.lci_database_builder import normalize_flows

# %%
energy_df_sd
# Out:
#               main_id facility_group_id flow_type  \
# 0    BC-MAIN-857b7b89              <NA>    Energy
# 1    BC-MAIN-857b7b89              <NA>    Energy
# 2    BC-MAIN-857b7b89              <NA>    Energy
# 3    BC-MAIN-857b7b89              <NA>    Energy
# 4    BC-MAIN-857b7b89              <NA>    Energy
# ..                ...               ...       ...
# 169  ON-MAIN-7607a50e              <NA>    Energy
# 170  ON-MAIN-7607a50e              <NA>    Energy
# 171  ON-MAIN-7607a50e              <NA>    Energy
# 172  ON-MAIN-7607a50e              <NA>    Energy
# 173  ON-MAIN-7607a50e              <NA>    Energy
#
#                                   subflow_type      value_MJ  \
# 0                                    Acetylene  1.847565e+04
# 1                                Aviation fuel  7.267611e+07
# 2                                       Diesel  2.870424e+08
# 3    Electricity consumption|Generated on-site  8.622512e+07
# 4     Electricity consumption|Grid electricity  5.690096e+08
# ..                                         ...           ...
# 169  Electricity consumption|Generated on-site  4.750000e+05
# 170   Electricity consumption|Grid electricity  9.607480e+08
# 171                                   Gasoline  2.124000e+06
# 172                                     Naphta  6.344000e+06
# 173                                Natural gas  2.216120e+08
#
#               site_id                                      activity_name
# 0    BC-MAIN-857b7b89  Au, Underground mining and beneficiation at Br...
# 1    BC-MAIN-857b7b89  Au, Underground mining and beneficiation at Br...
# 2    BC-MAIN-857b7b89  Au, Underground mining and beneficiation at Br...
# 3    BC-MAIN-857b7b89  Au, Underground mining and beneficiation at Br...
# 4    BC-MAIN-857b7b89  Au, Underground mining and beneficiation at Br...
# ..                ...                                                ...
# 169  ON-MAIN-7607a50e  Au, Underground mining and beneficiation at Yo...
# 170  ON-MAIN-7607a50e  Au, Underground mining and beneficiation at Yo...
# 171  ON-MAIN-7607a50e  Au, Underground mining and beneficiation at Yo...
# 172  ON-MAIN-7607a50e  Au, Underground mining and beneficiation at Yo...
# 173  ON-MAIN-7607a50e  Au, Underground mining and beneficiation at Yo...
#
# [174 rows x 7 columns]

# %%
energy_norm_ore = normalize_flows(energy_df_sd, production_df, mode='ore', value_col='value_MJ')
energy_norm_mass = normalize_flows(energy_df_sd, production_df, mode='metal', allocation='mass', value_col='value_MJ')
energy_norm_econ = normalize_flows(energy_df_sd, production_df, price_df=price_df, mode='metal', allocation='economic', value_col='value_MJ')

# %%
energy_norm_ore
# Out:
#               main_id facility_group_id flow_type  \
# 0    BC-MAIN-857b7b89              <NA>    Energy
# 1    BC-MAIN-857b7b89              <NA>    Energy
# 2    BC-MAIN-857b7b89              <NA>    Energy
# 3    BC-MAIN-857b7b89              <NA>    Energy
# 4    BC-MAIN-857b7b89              <NA>    Energy
# ..                ...               ...       ...
# 169  ON-MAIN-7607a50e              <NA>    Energy
# 170  ON-MAIN-7607a50e              <NA>    Energy
# 171  ON-MAIN-7607a50e              <NA>    Energy
# 172  ON-MAIN-7607a50e              <NA>    Energy
# 173  ON-MAIN-7607a50e              <NA>    Energy
#
#                                   subflow_type      value_MJ  \
# 0                                    Acetylene  1.847565e+04
# 1                                Aviation fuel  7.267611e+07
# 2                                       Diesel  2.870424e+08
# 3    Electricity consumption|Generated on-site  8.622512e+07
# 4     Electricity consumption|Grid electricity  5.690096e+08
# ..                                         ...           ...
# 169  Electricity consumption|Generated on-site  4.750000e+05
# 170   Electricity consumption|Grid electricity  9.607480e+08
# 171                                   Gasoline  2.124000e+06
# 172                                     Naphta  6.344000e+06
# 173                                Natural gas  2.216120e+08
#
#               site_id                                      activity_name  \
# 0    BC-MAIN-857b7b89  Au, Underground mining and beneficiation at Br...
# 1    BC-MAIN-857b7b89  Au, Underground mining and beneficiation at Br...
# 2    BC-MAIN-857b7b89  Au, Underground mining and beneficiation at Br...
# 3    BC-MAIN-857b7b89  Au, Underground mining and beneficiation at Br...
# 4    BC-MAIN-857b7b89  Au, Underground mining and beneficiation at Br...
# ..                ...                                                ...
# 169  ON-MAIN-7607a50e  Au, Underground mining and beneficiation at Yo...
# 170  ON-MAIN-7607a50e  Au, Underground mining and beneficiation at Yo...
# 171  ON-MAIN-7607a50e  Au, Underground mining and beneficiation at Yo...
# 172  ON-MAIN-7607a50e  Au, Underground mining and beneficiation at Yo...
# 173  ON-MAIN-7607a50e  Au, Underground mining and beneficiation at Yo...
#
#      ore_processed_t  value_normalized functional_unit  allocation_factor  \
# 0           166000.0          0.111299   Ore processed                  1
# 1           166000.0        437.807896   Ore processed                  1
# 2           166000.0       1729.171369   Ore processed                  1
# 3           166000.0        519.428418   Ore processed                  1
# 4           166000.0       3427.768583   Ore processed                  1
# ..               ...               ...             ...                ...
# 169        2878047.0          0.165042   Ore processed                  1
# 170        2878047.0        333.819427   Ore processed                  1
# 171        2878047.0          0.738000   Ore processed                  1
# 172        2878047.0          2.204273   Ore processed                  1
# 173        2878047.0         77.000827   Ore processed                  1
#
#     normalization_key
# 0                 ore
# 1                 ore
# 2                 ore
# 3                 ore
# 4                 ore
# ..                ...
# 169               ore
# 170               ore
# 171               ore
# 172               ore
# 173               ore
#
# [174 rows x 12 columns]

# %%
energy_norm_econ
# Out:
#               main_id facility_group_id flow_type  \
# 0    BC-MAIN-857b7b89              <NA>    Energy
# 1    BC-MAIN-857b7b89              <NA>    Energy
# 2    BC-MAIN-857b7b89              <NA>    Energy
# 3    BC-MAIN-857b7b89              <NA>    Energy
# 4    BC-MAIN-857b7b89              <NA>    Energy
# ..                ...               ...       ...
# 286  ON-MAIN-7607a50e              <NA>    Energy
# 287  ON-MAIN-7607a50e              <NA>    Energy
# 288  ON-MAIN-7607a50e              <NA>    Energy
# 289  ON-MAIN-7607a50e              <NA>    Energy
# 290  ON-MAIN-7607a50e              <NA>    Energy
#
#                                   subflow_type      value_MJ  \
# 0                                    Acetylene  1.847565e+04
# 1                                Aviation fuel  7.267611e+07
# 2                                       Diesel  2.870424e+08
# 3    Electricity consumption|Generated on-site  8.622512e+07
# 4     Electricity consumption|Grid electricity  5.690096e+08
# ..                                         ...           ...
# 286  Electricity consumption|Generated on-site  4.750000e+05
# 287   Electricity consumption|Grid electricity  9.607480e+08
# 288                                   Gasoline  2.124000e+06
# 289                                     Naphta  6.344000e+06
# 290                                Natural gas  2.216120e+08
#
#               site_id                                      activity_name  \
# 0    BC-MAIN-857b7b89  Au, Underground mining and beneficiation at Br...
# 1    BC-MAIN-857b7b89  Au, Underground mining and beneficiation at Br...
# 2    BC-MAIN-857b7b89  Au, Underground mining and beneficiation at Br...
# 3    BC-MAIN-857b7b89  Au, Underground mining and beneficiation at Br...
# 4    BC-MAIN-857b7b89  Au, Underground mining and beneficiation at Br...
# ..                ...                                                ...
# 286  ON-MAIN-7607a50e  Au, Underground mining and beneficiation at Yo...
# 287  ON-MAIN-7607a50e  Au, Underground mining and beneficiation at Yo...
# 288  ON-MAIN-7607a50e  Au, Underground mining and beneficiation at Yo...
# 289  ON-MAIN-7607a50e  Au, Underground mining and beneficiation at Yo...
# 290  ON-MAIN-7607a50e  Au, Underground mining and beneficiation at Yo...
#
#     metal    mass_t  allocation_factor  value_normalized facility_type  \
# 0      Au  0.902002                1.0      2.048295e+04        mining
# 1      Au  0.902002                1.0      8.057205e+07        mining
# 2      Au  0.902002                1.0      3.182283e+08        mining
# 3      Au  0.902002                1.0      9.559310e+07        mining
# 4      Au  0.902002                1.0      6.308300e+08        mining
# ..    ...       ...                ...               ...           ...
# 286    Au  5.757258                1.0      8.250456e+04        mining
# 287    Au  5.757258                1.0      1.668760e+08        mining
# 288    Au  5.757258                1.0      3.689256e+05        mining
# 289    Au  5.757258                1.0      1.101913e+06        mining
# 290    Au  5.757258                1.0      3.849263e+07        mining
#
#     functional_unit normalization_key
# 0    Au, usable ore    metal_economic
# 1    Au, usable ore    metal_economic
# 2    Au, usable ore    metal_economic
# 3    Au, usable ore    metal_economic
# 4    Au, usable ore    metal_economic
# ..              ...               ...
# 286  Au, usable ore    metal_economic
# 287  Au, usable ore    metal_economic
# 288  Au, usable ore    metal_economic
# 289  Au, usable ore    metal_economic
# 290  Au, usable ore    metal_economic
#
# [291 rows x 14 columns]

# %%
material_norm_ore = normalize_flows(material_df_sd, production_df, mode='ore', value_col='mass')
material_norm_mass = normalize_flows(material_df_sd, production_df, mode='metal', allocation='mass', value_col='mass')
material_norm_econ = normalize_flows(material_df_sd, production_df, price_df=price_df, mode='metal', allocation='economic', value_col='mass')

# %%
biosphere_norm_ore = normalize_flows(biosphere_df, production_df, mode='ore', value_col='value')
biosphere_norm_mass = normalize_flows(biosphere_df, production_df, mode='metal', allocation='mass', value_col='value')
biosphere_norm_econ = normalize_flows(biosphere_df, production_df, price_df=price_df, mode='metal', allocation='economic', value_col='value')

# %%
# Only where activity name is not null
#biosphere_norm_ore = biosphere_norm_ore[~biosphere_norm_ore['activity_name'].isna()]
#biosphere_norm_ore

# %% [markdown]
# # Exports normalized dataframes

# %%
energy_norm_ore.to_csv(r'data/MetalliCan/data_for_lci_initialization/ore_normalization/energy_df.csv', index=False)
material_norm_ore.to_csv(r'data/MetalliCan/data_for_lci_initialization/ore_normalization/material_df.csv', index=False)
biosphere_norm_ore.to_csv(r'data/MetalliCan/data_for_lci_initialization/ore_normalization/biosphere_df.csv', index=False)

# %%
energy_norm_econ.to_csv(r'data/MetalliCan/data_for_lci_initialization/economic_allocation/energy_df.csv', index=False)
material_norm_econ.to_csv(r'data/MetalliCan/data_for_lci_initialization/economic_allocation/material_df.csv', index=False)
biosphere_norm_econ.to_csv(r'data/MetalliCan/data_for_lci_initialization/economic_allocation/biosphere_df.csv', index=False)
