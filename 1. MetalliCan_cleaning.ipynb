# %%
import pandas as pd

# %%
from utils.data_manipulations import *

# %%
metallican_path = r'C:\Users\mp_ma\OneDrive - polymtl\POST_DOC\CODE\metallican_db'

# %% [markdown]
# # Import MetalliCan tables

# %%
main_table = pd.read_csv(metallican_path + r'\database\CSV\main_table.csv')
production_table = pd.read_csv(metallican_path + r'\database\CSV\production_table.csv')
tech_attributes_table = pd.read_csv(metallican_path + r'\database\CSV\tech_attributes_table.csv')
env_table = pd.read_csv(metallican_path + r'\database\CSV\environmental_flows_table.csv')
technosphere_table = pd.read_csv(metallican_path + r'\database\CSV\materials_energy_table.csv')
archetypes_table = pd.read_csv(metallican_path + r'\database\CSV\archetypes_table.csv')
land_table = pd.read_csv(metallican_path + r'\database\CSV\land_occupation_table.csv')
intensity_table = pd.read_csv(metallican_path + r'\database\CSV\intensity_table.csv')
waste_table = pd.read_table(metallican_path + r'\database\CSV\waste_table.csv', sep=',')
substances_table = pd.read_csv(metallican_path + r'\database\CSV\substances_table.csv')
#npv_table = pd.read_csv(metallican_path + r'\database\CSV\npv_table.csv')
carbon_stock_table = pd.read_csv(metallican_path + r'\database\CSV\carbon_stock_ecosystems_table.csv')

# %%
intensity_table_nrj = intensity_table[intensity_table['type'] == 'Energy']
intensity_table_nrj = intensity_table_nrj[~intensity_table_nrj['intensity_id'].str.startswith('INT-CMP')]

# %%
# Let's remove ClimateTRACE data from production and env tables
production_table = production_table[~production_table['source_id'].str.startswith('https://github.com/climatetracecoalition/methodology-documents/tree/main/2024/Mineral%20Extraction')]
env_table = env_table[~env_table['source_id'].str.startswith('https://github.com/climatetracecoalition/methodology-documents/tree/main/2024/Mineral%20Extraction')]

# %%
production_table = merge_main_and_group(production_table, main_table, cols_to_add=['facility_name', 'facility_group_name'])
ta_table = merge_main_and_group(tech_attributes_table, main_table, cols_to_add=['facility_name', 'facility_group_name'])

# %%
ta_table = add_site_id(ta_table)

# %%
#production_table.to_csv(r'data\MetalliCan\pre_cleaned_data\production_table.csv', index=False, encoding='utf-8-sig')
ta_table.to_csv(r'data\MetalliCan\pre_cleaned_data\ta_table.csv', index=False, encoding='utf-8-sig')

# %%
ghg_table = env_table[env_table['substance_id'].isin(['NA - GHG', '124-38-9', '74-82-8', '10024-97-2'])]
# Remove scope 2 and scope 3 emissions from ghg_table, they are in the comment column
ghg_table = ghg_table[~ghg_table['comment'].str.contains('scope1+2', case=False, na=False)]
ghg_table = ghg_table[~ghg_table['comment'].str.contains('scope2', case=False, na=False)]
ghg_table = ghg_table[~ghg_table['comment'].str.contains('scope3', case=False, na=False)]

# %%
#ids_energy = set(energy_table[['main_id', 'facility_group_id']].apply(tuple, axis=1))
#ids_material = set(material_table[['main_id', 'facility_group_id']].apply(tuple, axis=1))
#ids_biosphere = set(biosphere_table[['main_id', 'facility_group_id']].apply(tuple, axis=1))
#ids_land = set(land_table[['main_id', 'facility_group_id']].apply(tuple, axis=1))

# %%
# Facilities with at least technosphere and biosphere flows
#best_ids = ids_energy & ids_material & ids_biosphere
#best_ids

# %% [markdown]
# ## Harmonize units for the same substance_id

# %%
unit_mapping = {
'7732-18-5' : 'm3',
'NA - M10' : 'tonnes',
'NA - M09' : 'tonnes',
'NA - M16' : 'tonnes',
'630-08-0' : 'tonnes',
'NA - NOx' : 'tonnes',
'NA - 08' : 'kg',
'NA - 10' : 'tonnes',
'NA - 02' : 'kg',
'NA - M08' : 'tonnes',
'NA - GHG' : 'tonnes',
'124-38-9' : 'tonnes',
'74-82-8' : 'tonnes',
'10024-97-2' : 'tonnes',
'NA - 12': 'kg',
'NA - SOx': 'tonnes'
}

# %%
conversion_factors = {
    ('kg', 'tonnes'): 1/1000,
    ('kg', 't'): 1/1000,
    ('tonnes', 'kg'): 1000,
    ('t', 'kg'): 1000,
    ('tonnes', 't'): 1,
    ('t', 'tonnes'): 1,
    ('ML', 'm3'): 1000,
    ('m3', 'ML'): 1/1000,
    ('L', 'm3'): 1/1000,
    ('m3', 'L'): 1000,
    ('Mm3', 'm3'): 1000000,
    ('km3', 'm3'): 1000,
    ('ktCO2eq', 'tCO2eq'): 1000,
    ('tCO2eq', 'ktCO2eq'): 1/1000
}

# %%
def update_units_and_values(row):
    substance_id = row['substance_id']
    current_unit = row['unit']
    value = row['value']

    if substance_id in unit_mapping:
        target_unit = unit_mapping[substance_id]

        if current_unit != target_unit:
            conversion_key = (current_unit, target_unit)
            if conversion_key in conversion_factors:
                value = value * conversion_factors[conversion_key]
            # Si la conversion n'est pas définie, la valeur reste inchangée

        current_unit = target_unit  # Mettre à jour l'unité

    return pd.Series({'unit': current_unit, 'value': value})

# %%
env_table['value'] = pd.to_numeric(env_table['value'], errors='coerce')
mask = env_table['substance_id'].isin(unit_mapping.keys())
env_table.loc[mask, ['unit', 'value']] = env_table.loc[mask].apply(update_units_and_values, axis=1)

# %%
ghg_table['value'] = pd.to_numeric(ghg_table['value'], errors='coerce')
mask = ghg_table['substance_id'].isin(unit_mapping.keys())
ghg_table.loc[mask, ['unit', 'value']] = ghg_table.loc[mask].apply(update_units_and_values, axis=1)

# %%
ghg_table
# Out:
#                        env_id  year compartment_name substance_id  \
# 5035         GHG-10011-2023-1  2023              Air     124-38-9
# 5036         GHG-10011-2023-2  2023              Air     124-38-9
# 5037         GHG-10011-2023-3  2023              Air     124-38-9
# 5038         GHG-10011-2023-4  2023              Air     124-38-9
# 5039         GHG-10012-2023-1  2023              Air     124-38-9
# ...                       ...   ...              ...          ...
# 6408  ENV-GRP-a13779f8-2023-1  2023              Air     NA - GHG
# 6415  ENV-GRP-147b3123-2023-2  2023              Air     NA - GHG
# 6435      ENV-02884fb5-2023-2  2023              Air     NA - GHG
# 6447      ENV-7607a50e-2023-2  2023              Air     NA - GHG
# 6450      ENV-7607a50e-2023-5  2023              Air   10024-97-2
#
#      flow_direction             release_pathway    unit         value comment  \
# 5035       Emission          Flaring / Torchage  tonnes  4.022000e+02     NaN
# 5036       Emission  Stationary Fuel Combustion  tonnes  9.771639e+05     NaN
# 5037       Emission        Industrial Processes  tonnes  3.276798e+06     NaN
# 5038       Emission      On-site Transportation  tonnes  2.247158e+04     NaN
# 5039       Emission  Stationary Fuel Combustion  tonnes  4.990020e+04     NaN
# ...             ...                         ...     ...           ...     ...
# 6408       Emission                         NaN  tonnes  2.800000e+01  scope1
# 6415       Emission                         NaN  tonnes  3.561737e+04  scope1
# 6435       Emission                         NaN  tonnes  1.852110e+04  scope1
# 6447       Emission                         NaN  tonnes  2.163400e+04  scope1
# 6450       Emission                         NaN  tonnes  7.300000e+01  scope1
#
#                main_id facility_group_id    company_id  \
# 5035  ON-MAIN-eab8c362               NaN  CMP-0f9c0b53
# 5036  ON-MAIN-eab8c362               NaN  CMP-0f9c0b53
# 5037  ON-MAIN-eab8c362               NaN  CMP-0f9c0b53
# 5038  ON-MAIN-eab8c362               NaN  CMP-0f9c0b53
# 5039  QC-MAIN-8d6616b4      GRP-677b5973  CMP-7a096012
# ...                ...               ...           ...
# 6408               NaN      GRP-a13779f8  CMP-12afc634
# 6415               NaN      GRP-147b3123  CMP-48a36546
# 6435  QC-MAIN-02884fb5               NaN  CMP-3d0a95b7
# 6447  ON-MAIN-7607a50e               NaN  CMP-3a4ccc7f
# 6450  ON-MAIN-7607a50e               NaN  CMP-3a4ccc7f
#
#                                               source_id
# 5035  https://www.canada.ca/en/environment-climate-c...
# 5036  https://www.canada.ca/en/environment-climate-c...
# 5037  https://www.canada.ca/en/environment-climate-c...
# 5038  https://www.canada.ca/en/environment-climate-c...
# 5039  https://www.canada.ca/en/environment-climate-c...
# ...                                                 ...
# 6408  HudbayMineralsInc_Hudbay-2023-Integrated-Annua...
# 6415  PanAmericanSilverCorp_PAS-2023-Sustainability-...
# 6435  IAMGOLDCorporation_2023_iamgold-esg-performanc...
# 6447                            AlamosGoldInc_Data_2023
# 6450                            AlamosGoldInc_Data_2023
#
# [1162 rows x 13 columns]

# %% [markdown]
# ## Aggregate data at facility-group level

# %%
biosphere_df = aggregate_biosphere_facility_groups(env_table, remove_individuals='False')

# %%
ghg_df = aggregate_biosphere_facility_groups(ghg_table, remove_individuals='False')

# %%
# To have the substance names
biosphere_df = biosphere_df.merge(substances_table[['substance_id', 'substance_name']], how='left',on='substance_id')

# %%
biosphere_df.to_excel(r'data/MetalliCan/pre_cleaned_data/biosphere_df.xlsx', index=False)

# %%
ghg_df
# Out:
#                env_id  year compartment_name substance_id flow_direction  \
# 0    GHG-10011-2023-1  2023              Air     124-38-9       Emission
# 1    GHG-10011-2023-2  2023              Air     124-38-9       Emission
# 2    GHG-10011-2023-3  2023              Air     124-38-9       Emission
# 3    GHG-10011-2023-4  2023              Air     124-38-9       Emission
# 4    GHG-10013-2023-1  2023              Air     124-38-9       Emission
# ..                ...   ...              ...          ...            ...
# 967               NaN  2023              Air     NA - GHG       Emission
# 968               NaN  2023              Air     NA - GHG       Emission
# 969               NaN  2023              Air     NA - GHG       Emission
# 970               NaN  2023              Air     NA - GHG       Emission
# 971               NaN  2023              Air     NA - GHG       Emission
#
#                 release_pathway    unit         value  \
# 0            Flaring / Torchage  tonnes  4.022000e+02
# 1    Stationary Fuel Combustion  tonnes  9.771639e+05
# 2          Industrial Processes  tonnes  3.276798e+06
# 3        On-site Transportation  tonnes  2.247158e+04
# 4    Stationary Fuel Combustion  tonnes  2.686400e+04
# ..                          ...     ...           ...
# 967            Leakage / Fuites  tonnes  1.512000e+00
# 968      On-site Transportation  tonnes  1.088594e+04
# 969  Stationary Fuel Combustion  tonnes  3.953728e+04
# 970                       Total  tonnes  1.353246e+05
# 971                       Waste  tonnes  9.192120e+02
#
#                                        comment           main_id  \
# 0                                          NaN  ON-MAIN-eab8c362
# 1                                          NaN  ON-MAIN-eab8c362
# 2                                          NaN  ON-MAIN-eab8c362
# 3                                          NaN  ON-MAIN-eab8c362
# 4                                          NaN  QC-MAIN-52c01ae4
# ..                                         ...               ...
# 967  Aggregated value from multiple facilities              None
# 968  Aggregated value from multiple facilities              None
# 969  Aggregated value from multiple facilities              None
# 970  Aggregated value from multiple facilities              None
# 971  Aggregated value from multiple facilities              None
#
#     facility_group_id    company_id  \
# 0                 NaN  CMP-0f9c0b53
# 1                 NaN  CMP-0f9c0b53
# 2                 NaN  CMP-0f9c0b53
# 3                 NaN  CMP-0f9c0b53
# 4                 NaN  CMP-140e111b
# ..                ...           ...
# 967      GRP-de097f20  CMP-d5f1c66b
# 968      GRP-de097f20  CMP-d5f1c66b
# 969      GRP-de097f20  CMP-d5f1c66b
# 970      GRP-de097f20  CMP-d5f1c66b
# 971      GRP-de097f20  CMP-d5f1c66b
#
#                                              source_id
# 0    https://www.canada.ca/en/environment-climate-c...
# 1    https://www.canada.ca/en/environment-climate-c...
# 2    https://www.canada.ca/en/environment-climate-c...
# 3    https://www.canada.ca/en/environment-climate-c...
# 4    https://www.canada.ca/en/environment-climate-c...
# ..                                                 ...
# 967  https://www.canada.ca/en/environment-climate-c...
# 968  https://www.canada.ca/en/environment-climate-c...
# 969  https://www.canada.ca/en/environment-climate-c...
# 970  https://www.canada.ca/en/environment-climate-c...
# 971  https://www.canada.ca/en/environment-climate-c...
#
# [972 rows x 13 columns]

# %% [markdown]
# # Harmonization of technosphere units

# %%
# Separe energy and material
energy_df = technosphere_table[technosphere_table['flow_type'] == 'Energy']
material_df = technosphere_table[technosphere_table['flow_type'] == 'Material use']

# %% [markdown]
# ## Energy flows

# %%
from utils.conversion_functions import standardize_energy_to_MJ

# %%
# Replace the unit 'kl' to 'm3' for Natural gas to avoid issues during conversion
energy_df.loc[(energy_df['subflow_type'] == 'Natural gas') & (energy_df['unit'] == 'kl'), 'unit'] = 'm3'

# %%
energy_df_sd = standardize_energy_to_MJ(energy_df)

# %%
energy_df_sd[energy_df_sd['value_MJ'].isna()]
# Out:
# Empty DataFrame
# Columns: [technosphere_id, year, flow_type, subflow_type, unit, value, comment, main_id, facility_group_id, company_id, source_id, value_MJ, unit_source, assumption_note, unit_standard, needs_factor]
# Index: []

# %%
# Check the rows where needs_factor is TRUE
energy_df_sd[energy_df_sd['value_MJ'].isna()]
# Out:
# Empty DataFrame
# Columns: [technosphere_id, year, flow_type, subflow_type, unit, value, comment, main_id, facility_group_id, company_id, source_id, value_MJ, unit_source, assumption_note, unit_standard, needs_factor]
# Index: []

# %%
energy_df_sd.to_excel(r'data/MetalliCan/pre_cleaned_data/energy_df.xlsx', index=False)

# %% [markdown]
# ## Material flows

# %%
from utils.conversion_functions import standardize_materials_to_t

# %%
material_df_sd = standardize_materials_to_t(material_df)

# %%
# Check the rows where mass_t is NaN
material_df_sd[material_df_sd['mass_t'].isna()]
# Out:
# Empty DataFrame
# Columns: [technosphere_id, year, flow_type, subflow_type, unit, value, comment, main_id, facility_group_id, company_id, source_id, mass_t, mass_source, mass_note, needs_density]
# Index: []

# %%
material_df_sd.to_excel(r'data/MetalliCan/pre_cleaned_data/material_df.xlsx', index=False)

# %% [markdown]
# # Harmonization of land flows

# %%
# Step 1: Find main_id that have more than one unique source_id
multi_source_main_ids = land_table.groupby('main_id')['source_id'].nunique()
multi_source_main_ids = multi_source_main_ids[multi_source_main_ids > 1].index

# Step 2: Filter the dataframe
land_table = land_table[
    ~land_table['main_id'].isin(multi_source_main_ids) |
    (land_table['source_id'] == "https://www.nature.com/articles/s41597-025-05296-y")
]

# %%
# For each main_id, give the sum of area_km2 associated
land_table = land_table.groupby('main_id')['area_km2'].sum().reset_index()

# %%
land_table = land_table.merge(main_table[['main_id', 'facility_group_id', 'facility_name', 'facility_group_name', 'province', 'facility_type', 'mining_processing_type', 'commodities', 'operation_periods']], on='main_id', how='left')

# %%
#land_table_mining = land_table[land_table['facility_type'] == 'mining']

# %%
# Add a column with area in m2 and
land_table['area_m2'] = land_table['area_km2'] * 1e6
land_table.drop(columns=['area_km2'], inplace=True)

# %%
from utils.data_manipulations import aggregate_land_facility_groups

# %%
land_table = aggregate_land_facility_groups(land_table)

# %%
land_table
# Out:
#               main_id facility_group_id    facility_name facility_group_name  \
# 0    BC-MAIN-23155c25               NaN       Myra Falls                 NaN
# 1    BC-MAIN-3ef4f421               NaN  Avanti Kitsault                 NaN
# 2    BC-MAIN-3f490561               NaN     Mount Polley                 NaN
# 3    BC-MAIN-4724f4ba               NaN              Elk                 NaN
# 4    BC-MAIN-599152a0               NaN  Copper Mountain                 NaN
# ..                ...               ...              ...                 ...
# 126              None      GRP-91aaa60b                                  NaN
# 127              None      GRP-a13779f8                                  NaN
# 128              None      GRP-b48ec279                                  NaN
# 129              None      GRP-dc07540b                                  NaN
# 130              None      GRP-de097f20                                  NaN
#
#              province  facility_type  \
# 0    British Columbia         mining
# 1    British Columbia        project
# 2    British Columbia         mining
# 3    British Columbia         mining
# 4    British Columbia         mining
# ..                ...            ...
# 126      Saskatchewan         mining
# 127          Manitoba         mining
# 128            Quebec  manufacturing
# 129           Ontario         mining
# 130           Ontario         mining
#
#                                 mining_processing_type  \
# 0                                          Underground
# 1                                                  NaN
# 2                               Open-pit, concentrator
# 3                                             Open-pit
# 4                               Open-pit, concentrator
# ..                                                 ...
# 126                          Concentrator, Underground
# 127                          Concentrator, Underground
# 128                                            Smelter
# 129  Underground, Smelter, refinery, plant, Concent...
# 130          Underground, Smelter, plant, Concentrator
#
#                                            commodities  \
# 0                     Zinc, copper, silver, gold, lead
# 1                             Molybdenum, silver, lead
# 2                                 Gold, copper, silver
# 3                                                 Gold
# 4                                 Copper, gold, silver
# ..                                                 ...
# 126                                            Uranium
# 127                         Gold, zinc, copper, silver
# 128      Copper anodes, precious metals, sulfuric acid
# 129  Nickel, copper, platinum group metals, gold, s...
# 130  Nickel, copper, platinum group metals, gold, c...
#
#                    operation_periods       area_m2
# 0    1966–1985; 2002–2015; 2019–open  1.499690e+06
# 1                                NaN  1.396089e+06
# 2                                NaN  7.967835e+06
# 3                                NaN  4.167369e+05
# 4               1884–1958; 2011–open  1.323321e+07
# ..                               ...           ...
# 126                        2015–open  6.013478e+06
# 127  2013–open, 1949–2000; 2021–open  3.104131e+06
# 128                             <NA>  6.630997e+06
# 129                        2014–open  3.338002e+07
# 130  1962–1991; 2007–2009; 2010–open  1.142796e+07
#
# [131 rows x 10 columns]

# %%
land_table.to_excel(r'data/MetalliCan/pre_cleaned_data/land_df.xlsx', index=False)

# %%
# Which ones do not have operation periods?
land_table[land_table['operation_periods'].isna()]
# Out:
#               main_id facility_group_id    facility_name facility_group_name  \
# 1    BC-MAIN-3ef4f421               NaN  Avanti Kitsault                 NaN
# 2    BC-MAIN-3f490561               NaN     Mount Polley                 NaN
# 3    BC-MAIN-4724f4ba               NaN              Elk                 NaN
# 7    BC-MAIN-a505d25d               NaN            Ootsa                 NaN
# 9    BC-MAIN-b1fe389a               NaN      Eskay Creek                 NaN
# ..                ...               ...              ...                 ...
# 121              None      GRP-21eee27d                                  NaN
# 123              None      GRP-2a663492                                  NaN
# 124              None      GRP-677b5973                                  NaN
# 125              None      GRP-7a9ba115                                  NaN
# 128              None      GRP-b48ec279                                  NaN
#
#                       province  facility_type     mining_processing_type  \
# 1             British Columbia        project                        NaN
# 2             British Columbia         mining     Open-pit, concentrator
# 3             British Columbia         mining                   Open-pit
# 7             British Columbia        project                        NaN
# 9             British Columbia        project                        NaN
# ..                         ...            ...                        ...
# 121               Saskatchewan         mining  Concentrator, Underground
# 123  Newfoundland and Labrador         mining                   Open-pit
# 124                     Quebec  manufacturing                   Refinery
# 125                     Quebec  manufacturing       Electric arc furnace
# 128                     Quebec  manufacturing                    Smelter
#
#                                        commodities operation_periods  \
# 1                         Molybdenum, silver, lead               NaN
# 2                             Gold, copper, silver               NaN
# 3                                             Gold               NaN
# 7                 Copper, gold, molybdenum, silver               NaN
# 9                 Gold, Silver, copper, lead, zinc               NaN
# ..                                             ...               ...
# 121                                        Uranium              <NA>
# 123                                           Iron              <NA>
# 124                                        Alumina              <NA>
# 125                                          Steel              <NA>
# 128  Copper anodes, precious metals, sulfuric acid              <NA>
#
#           area_m2
# 1    1.396089e+06
# 2    7.967835e+06
# 3    4.167369e+05
# 7    7.682505e+06
# 9    1.997235e+05
# ..            ...
# 121  1.220954e+07
# 123  1.034080e+07
# 124  1.113482e+06
# 125  1.991940e+06
# 128  6.630997e+06
#
# [77 rows x 10 columns]

# %% [markdown]
# # Carbon stock ecosystems

# %%
carbon_stock_table
# Out:
#      carbon_stock_ecosystems_id  pool   variable   unit      value  \
# 0       carbon_stock-35d0dc71-1  agbc    area_ha     ha  49.315624
# 1       carbon_stock-35d0dc71-2  agbc   mean_act  tC/ha  10.000000
# 2       carbon_stock-35d0dc71-3  agbc  mean_prim  tC/ha  36.000000
# 3       carbon_stock-35d0dc71-4  bgbc    area_ha     ha  49.315624
# 4       carbon_stock-35d0dc71-5  bgbc   mean_act  tC/ha   3.000000
# ...                         ...   ...        ...    ...        ...
# 2425    carbon_stock-e05ed9fe-5  bgbc   mean_act  tC/ha   4.000000
# 2426    carbon_stock-e05ed9fe-6  bgbc  mean_prim  tC/ha   8.000000
# 2427    carbon_stock-e05ed9fe-7   soc    area_ha     ha  37.600693
# 2428    carbon_stock-e05ed9fe-8   soc   mean_act  tC/ha  64.000000
# 2429    carbon_stock-e05ed9fe-9   soc  mean_prim  tC/ha  80.000000
#
#                main_id                            source_id
# 0     AB-MAIN-35d0dc71  https://zenodo.org/records/15777016
# 1     AB-MAIN-35d0dc71  https://zenodo.org/records/15777016
# 2     AB-MAIN-35d0dc71  https://zenodo.org/records/15777016
# 3     AB-MAIN-35d0dc71  https://zenodo.org/records/15777016
# 4     AB-MAIN-35d0dc71  https://zenodo.org/records/15777016
# ...                ...                                  ...
# 2425  YT-MAIN-e05ed9fe  https://zenodo.org/records/15777016
# 2426  YT-MAIN-e05ed9fe  https://zenodo.org/records/15777016
# 2427  YT-MAIN-e05ed9fe  https://zenodo.org/records/15777016
# 2428  YT-MAIN-e05ed9fe  https://zenodo.org/records/15777016
# 2429  YT-MAIN-e05ed9fe  https://zenodo.org/records/15777016
#
# [2430 rows x 7 columns]

# %%
def add_mean_variation(df):
    """
    For each (main_id, pool), add:
        variable = 'mean_variation'
        value    = mean_prim - mean_act

    Also adds:
        pool = 'all' as the sum of mean_variation over pools
        (e.g. AGBC + BGBC + SOC)
    """

    # --- wide format for computation ---
    wide = df.pivot_table(
        index=["main_id", "pool"],
        columns="variable",
        values="value",
        aggfunc="first"
    )

    # --- per-pool variation ---
    wide["mean_variation"] = wide["mean_prim"] - wide["mean_act"]

    per_pool = (
        wide[["mean_variation"]]
        .reset_index()
        .rename(columns={"mean_variation": "value"})
    )

    # --- all-pool variation (sum across pools) ---
    all_pool = (
        per_pool
        .groupby("main_id", as_index=False)["value"]
        .sum()
    )
    all_pool["pool"] = "all"

    # --- harmonize metadata ---
    for df_ in (per_pool, all_pool):
        df_["variable"] = "mean_variation"
        df_["unit"] = "tC/ha"
        df_["source_id"] = "https://zenodo.org/records/15777016"

    # --- append to original ---
    return pd.concat([df, per_pool, all_pool], ignore_index=True)

# %%
carbon_stock_table = add_mean_variation(carbon_stock_table)

# %%
carbon_stock_table
# Out:
#      carbon_stock_ecosystems_id  pool        variable   unit      value  \
# 0       carbon_stock-35d0dc71-1  agbc         area_ha     ha  49.315624
# 1       carbon_stock-35d0dc71-2  agbc        mean_act  tC/ha  10.000000
# 2       carbon_stock-35d0dc71-3  agbc       mean_prim  tC/ha  36.000000
# 3       carbon_stock-35d0dc71-4  bgbc         area_ha     ha  49.315624
# 4       carbon_stock-35d0dc71-5  bgbc        mean_act  tC/ha   3.000000
# ...                         ...   ...             ...    ...        ...
# 3505                        NaN   all  mean_variation  tC/ha  24.000000
# 3506                        NaN   all  mean_variation  tC/ha   2.000000
# 3507                        NaN   all  mean_variation  tC/ha   2.000000
# 3508                        NaN   all  mean_variation  tC/ha   0.000000
# 3509                        NaN   all  mean_variation  tC/ha  30.000000
#
#                main_id                            source_id
# 0     AB-MAIN-35d0dc71  https://zenodo.org/records/15777016
# 1     AB-MAIN-35d0dc71  https://zenodo.org/records/15777016
# 2     AB-MAIN-35d0dc71  https://zenodo.org/records/15777016
# 3     AB-MAIN-35d0dc71  https://zenodo.org/records/15777016
# 4     AB-MAIN-35d0dc71  https://zenodo.org/records/15777016
# ...                ...                                  ...
# 3505  YT-MAIN-752fbcae  https://zenodo.org/records/15777016
# 3506  YT-MAIN-956d050a  https://zenodo.org/records/15777016
# 3507  YT-MAIN-c3105f43  https://zenodo.org/records/15777016
# 3508  YT-MAIN-ca488f19  https://zenodo.org/records/15777016
# 3509  YT-MAIN-e05ed9fe  https://zenodo.org/records/15777016
#
# [3510 rows x 7 columns]

# %%
carbon_stock_table.to_excel(r'data/MetalliCan/pre_cleaned_data/carbon_stock_df.xlsx', index=False)

# %% [markdown]
# # Sanity check for energy flows and GHG emissions

# %%
ef_df = pd.read_excel(r'data/Quality control/Emission_factors.xlsx', sheet_name='data')
ef_mapping_df = pd.read_excel(r'data/Quality control/Emission_factors.xlsx', sheet_name='MAPPING')

# %% [markdown]
# ## Prepare clean GHG and energy dataframes

# %%
# Step 1: Find main_id that have more than one unique source_id
multi_source_main_ids = ghg_df.groupby('main_id')['source_id'].nunique()
multi_source_main_ids = multi_source_main_ids[multi_source_main_ids > 1].index

# Step 2: Filter the dataframe
ghg_df = ghg_df[
    ~ghg_df['main_id'].isin(multi_source_main_ids)|
    (ghg_df['source_id'] == "https://www.canada.ca/en/environment-climate-change/services/environmental-indicators/greenhouse-gas-emissions/large-facilities.html; https://open.canada.ca/data/en/dataset/a8ba14b7-7f23-462a-bdbb-83b0ef629823")
]

# %%
energy_flow_to_check = ['Diesel', 'Gasoline', 'Propane','Natural gas', 'Aviation fuel','Electricity consumption|Generated on-site', 'Explosives', 'Oil', 'Light Fuel & Gasoline', 'Electricity consumption|Non-renewable electricity use', 'Non-renewable fuel use', 'Naphta', 'LPG', 'Petrol', 'Biodiesel', 'ANFO', 'Emulsion ANFO', 'Diesel|Mobile equipment', 'Gasoline|Mobile equipment', 'Diesel|Stationary equipment', 'LPG|Mobile equipment', 'LPG|Stationary equipment', 'Dynamite', 'Emulsions']
energy_df_check = energy_df_sd[energy_df_sd['subflow_type'].isin(energy_flow_to_check)]

# %%
ghg_df = add_site_id(ghg_df)
energy_df_check = add_site_id(energy_df_check)

# %%
ghg_df.to_csv(r'data/Quality control/ghg_flows.csv', index=False)
energy_df_check.to_csv(r'data/Quality control/energy_flows_to_check.csv', index=False)

# %% [markdown]
# ## Check

# %%
# Keep only the total GHG emissions (substance_id = 'NA - GHG')
ghg_df_check = ghg_df[ghg_df['substance_id'] == 'NA - GHG']
ghg_df_check = ghg_df_check[~ghg_df_check['release_pathway'].isin(['Industrial Processes', 'Stationary Fuel Combustion', 'On-site Transportation', 'Waste', 'Wastewater'])]

# %%
from utils.constants import DEFAULT_LHV, DEFAULT_DENSITY
from utils.conversion_functions import convert_energy_to_fuel_units, compute_ghg_from_energy

# %%
energy_df_check["tCO2eq_estimated"] = energy_df_check.apply(
    lambda row: compute_ghg_from_energy(row, ef_mapping_df, ef_df, DEFAULT_LHV),
    axis=1
)

# %%
comparison = (
    energy_df_check.groupby("site_id")["tCO2eq_estimated"].sum()
    .to_frame("tCO2eq_estimated")
    .merge(
        ghg_df_check.groupby("site_id")["value"].sum(),
        left_index=True, right_index=True
    )
)

comparison["difference"] = comparison["tCO2eq_estimated"] - comparison["value"]
comparison["ratio"] = comparison["tCO2eq_estimated"] / comparison["value"]

# %%
comparison.to_excel(r'data/Quality control/ghg_comparison.xlsx', index=True)
