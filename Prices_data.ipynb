# %%
import pandas as pd

# %%
can_export_df = pd.read_csv(r'data/Prices/Canada_export_2013_2023.csv')

# %%
can_export_df
# Out:
#           Period                                          Commodity Province  \
# 0     01/01/2013  2601.11.10 - Iron ores concentrated, non-agglo...   Canada
# 1     01/01/2016  2601.12.00 - Iron ores and concentrates, o/t r...   Canada
# 2     01/01/2018  2601.20.00 - Roasted iron pyrites (pyrites cin...   Canada
# 3     01/01/2019  2620.99.90 - Ash and residues containing metal...   Canada
# 4     01/01/2021     2604.00.90 - Nickel ores and concentrates, nes   Canada
# ...          ...                                                ...      ...
# 3698  01/01/2024            2617.90.00 - Ores and concentrates, nes   Canada
# 3699  01/01/2015  2618.00.00 - Granulated slag (slag sand) from ...   Canada
# 3700  01/01/2018  2618.00.00 - Granulated slag (slag sand) from ...   Canada
# 3701  01/01/2013  2618.00.00 - Granulated slag (slag sand) from ...   Canada
# 3702  01/01/2016  2618.00.00 - Granulated slag (slag sand) from ...   Canada
#
# ...

# %%
import pandas as pd
import numpy as np

def compute_price_per_kg_summary(df):
    """
    Process trade data to compute $/kg ratios and summarize by commodity.

    Parameters
    ----------
    df : pd.DataFrame
        Must contain columns:
        ['Period', 'Commodity', 'Value ($)', 'Quantity', 'Unit of measure']

    Returns
    -------
    df_prices : pd.DataFrame
        Original dataframe with added columns:
        - Quantity_kg
        - Price_per_kg

    summary : pd.DataFrame
        Aggregated by 'Commodity' with columns:
        - mean_price_per_kg
        - std_price_per_kg
        - n_records
        - start_date
        - end_date
        - date_range_comment
    """

    df = df.copy()

    # --- 1. Clean and standardize units ---
    df["Unit of measure"] = df["Unit of measure"].str.strip().str.lower()

    unit_factors = {
        "weight in metric tonne": 1000,
        "weight in kilograms": 1,
        "weight in grams": 0.001,
        "weight in pounds": 0.453592,
    }

    df["Quantity_kg"] = df.apply(
        lambda x: x["Quantity"] * unit_factors.get(x["Unit of measure"], np.nan),
        axis=1
    )

    # --- 2. Convert period to datetime ---
    df["Period"] = pd.to_datetime(df["Period"], errors="coerce", dayfirst=True)

    # --- 3. Filter out invalid values ---
    df = df[(df["Quantity_kg"] > 0) & (~df["Value ($)"].isna())]

    # --- 4. Compute price ratio ---
    df["Price_per_kg"] = df["Value ($)"] / df["Quantity_kg"]

    # --- 5. Summarize by commodity ---
    summary = (
        df.groupby("Commodity")
        .agg(
            mean_price_per_kg=("Price_per_kg", "mean"),
            std_price_per_kg=("Price_per_kg", "std"),
            n_records=("Price_per_kg", "count"),
            start_date=("Period", "min"),
            end_date=("Period", "max"),
        )
        .reset_index()
    )

    summary["date_range_comment"] = summary.apply(
        lambda x: f"{x['start_date'].date()} to {x['end_date'].date()}"
        if pd.notna(x["start_date"]) and pd.notna(x["end_date"])
        else "Unknown",
        axis=1
    )

    # Round for readability
    summary = summary.round({"mean_price_per_kg": 4, "std_price_per_kg": 4})

    return df, summary

# %%
df, summary = compute_price_per_kg_summary(can_export_df)

# %%
# Display the unique 'Commodity' in alphabetic order
unique_commodities = sorted(df['Commodity'].unique())
unique_commodities
# Out:
# ['2601.11.10 - Iron ores concentrated, non-agglomerated, other than roasted iron pyrites',
#  '2601.11.90 - Iron ores not concentrated, non-agglomerated, other than roasted iron pyrites',
#  '2601.12.00 - Iron ores and concentrates, o/t roasted iron pyrites, agglomerated',
#  '2601.20.00 - Roasted iron pyrites (pyrites cinders)',
#  '2602.00.00 - Manganese ores and conc etc',
#  '2603.00.10 - Copper ores and concentrates, copper content',
#  '2603.00.40 - Copper ores and concentrates, silver content',
#  '2603.00.50 - Copper ores and concentrates, gold content',
#  '2603.00.90 - Copper ores and concentrates, nes',
#  '2604.00.40 - Nickel ores and concentrates, nickel content',
#  '2604.00.90 - Nickel ores and concentrates, nes',
#  '2605.00.00 - Cobalt ores and concentrates',
#  '2606.00.00 - Aluminium ores and concentrates',
#  '2607.00.20 - Lead ores and concentrates, lead content',
#  '2607.00.40 - Lead ores and concentrates, silver content',
# ...

# %%
com_to_include = [
'2605.00.00 - Cobalt ores and concentrates',
'2603.00.90 - Copper ores and concentrates, nes',
'2603.00.10 - Copper ores and concentrates, copper content',
'2601.11.10 - Iron ores concentrated, non-agglomerated, other than roasted iron pyrites',
'2601.12.00 - Iron ores and concentrates, o/t roasted iron pyrites, agglomerated',
'2604.00.90 - Nickel ores and concentrates, nes',
'2604.00.40 - Nickel ores and concentrates, nickel content',
'2607.00.90 - Lead ores and concentrates, nes',
'2607.00.20 - Lead ores and concentrates, lead content',
'2613.90.00 - Molybdenum ores and concentrates nes',
'2615.90.00 - Niobium, tantalum and vanadium ores and concentrates',
'2616.90.90 - Precious metal ores and concentrates, nes',
'2616.90.10 - Precious metal ores and concentrates, nes, gold content',
'2616.10.40 - Silver ores and concentrates, silver content',
'2616.10.90 - Silver ores and concentrates, nes',
'2612.10.00 - Uranium ores and concentrates',
'2608.00.90 - Zinc ores and concentrates, nes',
'2608.00.30 - Zinc ores and concentrates, zinc content'
]

# %%
df = df[df['Commodity'].isin(com_to_include)]

# %%
import pandas as pd
import numpy as np
import plotly.express as px

def plot_price_variability_faceted(
    df,
    commodities,
    output_html="data/Prices/price_variability_faceted_exact.html"
):
    """
    Faceted boxplots of $/kg variability by year and region for selected exact commodity names.

    Parameters
    ----------
    df : pd.DataFrame
        Must include ['Period', 'Commodity', 'Country', 'State', 'Value ($)', 'Quantity', 'Unit of measure'].
    commodities : list[str]
        List of exact commodity names to include (case-insensitive exact match).
    output_html : str
        Path to export the interactive HTML file.
    """

    df = df.copy()
    df["Unit of measure"] = df["Unit of measure"].str.strip().str.lower()

    # Treat U.S. states as unique "countries"
    df["Country_full"] = df.apply(
        lambda x: f"{x['Country']} - {x['State']}" if pd.notna(x["State"]) and str(x["State"]).strip() else x["Country"],
        axis=1
    )

    # Convert quantities to kilograms
    unit_factors = {
        "weight in metric tonne": 1000,
        "weight in kilograms": 1,
        "weight in grams": 0.001,
        "weight in pounds": 0.453592,
    }

    df["Quantity_kg"] = df.apply(
        lambda x: x["Quantity"] * unit_factors.get(x["Unit of measure"], np.nan),
        axis=1
    )

    df = df[(df["Quantity_kg"] > 0) & (~df["Value ($)"].isna())]
    df["Price_per_kg"] = df["Value ($)"] / df["Quantity_kg"]

    df["Period"] = pd.to_datetime(df["Period"], errors="coerce", dayfirst=True)
    df["Year"] = df["Period"].dt.year

    # Filter for *exact* matches (case-insensitive)
    commodities_lower = [c.lower().strip() for c in commodities]
    df_sel = df[df["Commodity"].str.lower().isin(commodities_lower)]

    if df_sel.empty:
        raise ValueError("No data found for the selected exact commodities.")

    # Plot faceted boxplots
    fig = px.box(
        df_sel,
        x="Year",
        y="Price_per_kg",
        color="Country_full",
        facet_col="Commodity",
        facet_col_wrap=3,
        points="all",
        hover_data=["Country_full", "Value ($)", "Quantity", "Unit of measure"],
        title="Export Price Variability ($/kg) by Year, Region, and Commodity",
        template="plotly_white"
    )

    # Style
    fig.update_layout(
        paper_bgcolor="rgb(245,245,245)",
        plot_bgcolor="rgb(245,245,245)",
        font=dict(family="Arial", size=12),
        title_font=dict(size=18),
        yaxis=dict(title="Price per kg ($)", gridcolor="rgba(230,230,230,1)")
    )

    # Clean facet labels
    fig.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1]))

    # Save and display
    fig.write_html(output_html)
    print(f"✅ Faceted boxplot saved to {output_html}")
    fig.show()

# %%
plot_price_variability_faceted(
    df,
    commodities=['2603.00.10 - Copper ores and concentrates, copper content',
                 '2603.00.90 - Copper ores and concentrates, nes'],
    output_html="data/Prices/faceted_prices.html"
)
# Out:
# ✅ Faceted boxplot saved to data/Prices/faceted_prices.html

# %%
plot_price_variability_faceted(
    df,
    commodities=['2616.10.40 - Silver ores and concentrates, silver content',
'2616.10.90 - Silver ores and concentrates, nes',],
    output_html="data/Prices/faceted_prices.html"
)
# Out:
# ✅ Faceted boxplot saved to data/Prices/faceted_prices.html

# %%
import plotly.express as px
import pandas as pd
import numpy as np

def plot_price_variability(df, commodity, output_html="data/Prices/price_variability.html"):
    """
    Create a boxplot of $/kg variability by country and year for a selected commodity.

    Parameters
    ----------
    df : pd.DataFrame
        Must include columns ['Period', 'Commodity', 'Country', 'Value ($)', 'Quantity', 'Unit of measure'].
    commodity : str
        Commodity name or substring to filter.
    output_html : str
        File path to export the interactive HTML plot.
    """
    df = df.copy()
    df["Unit of measure"] = df["Unit of measure"].str.strip().str.lower()

    unit_factors = {
        "weight in metric tonne": 1000,
        "weight in kilograms": 1,
        "weight in grams": 0.001,
        "weight in pounds": 0.453592,
    }

    df["Quantity_kg"] = df.apply(
        lambda x: x["Quantity"] * unit_factors.get(x["Unit of measure"], np.nan), axis=1
    )
    df = df[(df["Quantity_kg"] > 0) & (~df["Value ($)"].isna())]
    df["Price_per_kg"] = df["Value ($)"] / df["Quantity_kg"]

    df["Period"] = pd.to_datetime(df["Period"], errors="coerce", dayfirst=True)
    df["Year"] = df["Period"].dt.year

    # Filter for chosen commodity (flexible substring match)
    df_sel = df[df["Commodity"].str.contains(commodity, case=False, na=False)]
    if df_sel.empty:
        raise ValueError(f"No data found for commodity containing '{commodity}'.")

    fig = px.box(
        df_sel,
        x="Year",
        y="Price_per_kg",
        color="Country",
        points="all",
        hover_data=["Country", "Value ($)", "Quantity", "Unit of measure"],
        title=f"Export Price Variability ($/kg) for {commodity}",
        template="plotly_white"
    )

    fig.update_layout(
        paper_bgcolor="rgb(245,245,245)",
        plot_bgcolor="rgb(245,245,245)",
        title_font=dict(size=20),
        yaxis=dict(title="Price per kg ($)", gridcolor="rgba(230,230,230,1)"),
        xaxis=dict(title="Year"),
        font=dict(family="Arial", size=12)
    )

    fig.write_html(output_html)
    print(f"✅ Boxplot saved to {output_html}")
    fig.show()

# %%
plot_price_variability(df, commodity='2603.00.10 - Copper ores and concentrates, copper content', output_html='data/Prices/cu_content_price_variability.html')
# Out:
# ✅ Boxplot saved to data/Prices/cu_content_price_variability.html

# %%
plot_price_variability(df, commodity='2603.00.90 - Copper ores and concentrates, nes', output_html='data/Prices/cu_price_variability.html')
# Out:
# ✅ Boxplot saved to data/Prices/cu_price_variability.html

# %%
df.to_csv(r'prices_df.csv', index=False)

# %%
summary
# Out:
#                                             Commodity  mean_price_per_kg  \
# 0   2601.11.10 - Iron ores concentrated, non-agglo...             0.1351
# 1   2601.11.90 - Iron ores not concentrated, non-a...             0.1750
# 2   2601.12.00 - Iron ores and concentrates, o/t r...             0.1573
# 3   2601.20.00 - Roasted iron pyrites (pyrites cin...             0.2509
# 4            2602.00.00 - Manganese ores and conc etc             6.2380
# 5   2603.00.10 - Copper ores and concentrates, cop...            29.6705
# 6   2603.00.40 - Copper ores and concentrates, sil...           797.3410
# 7   2603.00.50 - Copper ores and concentrates, gol...         62894.6262
# 8      2603.00.90 - Copper ores and concentrates, nes            25.0965
# 9   2604.00.40 - Nickel ores and concentrates, nic...            19.6335
# 10     2604.00.90 - Nickel ores and concentrates, nes          6062.4070
# 11          2605.00.00 - Cobalt ores and concentrates           236.5782
# ...

# %%
summary.to_csv(r'data/Prices/canada_export_price_per_kg_summary.csv', index=False)
