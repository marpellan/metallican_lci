# %%
import pandas as pd

# %%
can_export_df = pd.read_csv(r'data/Prices/Canada_export_2013_2023.csv')

# %%
can_export_df
# Out:
#           Period                                          Commodity Province  \
# 0     01/01/2013  2601.11.10 - Iron ores concentrated, non-agglo...   Canada
# 1     01/01/2016  2601.12.00 - Iron ores and concentrates, o/t r...   Canada
# 2     01/01/2018  2601.20.00 - Roasted iron pyrites (pyrites cin...   Canada
# 3     01/01/2019  2620.99.90 - Ash and residues containing metal...   Canada
# 4     01/01/2021     2604.00.90 - Nickel ores and concentrates, nes   Canada
# ...          ...                                                ...      ...
# 3698  01/01/2024            2617.90.00 - Ores and concentrates, nes   Canada
# 3699  01/01/2015  2618.00.00 - Granulated slag (slag sand) from ...   Canada
# 3700  01/01/2018  2618.00.00 - Granulated slag (slag sand) from ...   Canada
# 3701  01/01/2013  2618.00.00 - Granulated slag (slag sand) from ...   Canada
# 3702  01/01/2016  2618.00.00 - Granulated slag (slag sand) from ...   Canada
#
#                         Country     State  Value ($)   Quantity  \
# 0                United Kingdom       NaN    4877724      42326
# 1                     Australia       NaN         60          0
# 2                       Germany       NaN         19          0
# 3                  Korea, South       NaN          1          0
# 4     South Africa, Republic of       NaN        200          0
# ...                         ...       ...        ...        ...
# 3698                      China       NaN  314316832  248696575
# 3699              United States  Michigan    6676825  280708000
# 3700              United States  Michigan    5887808  280717000
# 3701              United States  Michigan    4272901  288301000
# 3702              United States  Michigan    7334483  303838000
#
#              Unit of measure
# 0     Weight in metric tonne
# 1     Weight in metric tonne
# 2     Weight in metric tonne
# 3        Weight in kilograms
# 4        Weight in kilograms
# ...                      ...
# 3698     Weight in kilograms
# 3699     Weight in kilograms
# 3700     Weight in kilograms
# 3701     Weight in kilograms
# 3702     Weight in kilograms
#
# [3703 rows x 8 columns]

# %%
import pandas as pd
import numpy as np

def compute_price_per_kg_summary(df):
    """
    Process trade data to compute $/kg ratios and summarize by commodity.

    Parameters
    ----------
    df : pd.DataFrame
        Must contain columns:
        ['Period', 'Commodity', 'Value ($)', 'Quantity', 'Unit of measure']

    Returns
    -------
    df_prices : pd.DataFrame
        Original dataframe with added columns:
        - Quantity_kg
        - Price_per_kg

    summary : pd.DataFrame
        Aggregated by 'Commodity' with columns:
        - mean_price_per_kg
        - std_price_per_kg
        - n_records
        - start_date
        - end_date
        - date_range_comment
    """

    df = df.copy()

    # --- 1. Clean and standardize units ---
    df["Unit of measure"] = df["Unit of measure"].str.strip().str.lower()

    unit_factors = {
        "weight in metric tonne": 1000,
        "weight in kilograms": 1,
        "weight in grams": 0.001,
        "weight in pounds": 0.453592,
    }

    df["Quantity_kg"] = df.apply(
        lambda x: x["Quantity"] * unit_factors.get(x["Unit of measure"], np.nan),
        axis=1
    )

    # --- 2. Convert period to datetime ---
    df["Period"] = pd.to_datetime(df["Period"], errors="coerce", dayfirst=True)

    # --- 3. Filter out invalid values ---
    df = df[(df["Quantity_kg"] > 0) & (~df["Value ($)"].isna())]

    # --- 4. Compute price ratio ---
    df["Price_per_kg"] = df["Value ($)"] / df["Quantity_kg"]

    # --- 5. Summarize by commodity ---
    summary = (
        df.groupby("Commodity")
        .agg(
            mean_price_per_kg=("Price_per_kg", "mean"),
            std_price_per_kg=("Price_per_kg", "std"),
            n_records=("Price_per_kg", "count"),
            start_date=("Period", "min"),
            end_date=("Period", "max"),
        )
        .reset_index()
    )

    summary["date_range_comment"] = summary.apply(
        lambda x: f"{x['start_date'].date()} to {x['end_date'].date()}"
        if pd.notna(x["start_date"]) and pd.notna(x["end_date"])
        else "Unknown",
        axis=1
    )

    # Round for readability
    summary = summary.round({"mean_price_per_kg": 4, "std_price_per_kg": 4})

    return df, summary

# %%
df, summary = compute_price_per_kg_summary(can_export_df)

# %%
df
# Out:
#          Period                                          Commodity Province  \
# 0    2013-01-01  2601.11.10 - Iron ores concentrated, non-agglo...   Canada
# 5    2013-01-01  2616.90.90 - Precious metal ores and concentra...   Canada
# 6    2013-01-01  2616.90.90 - Precious metal ores and concentra...   Canada
# 7    2014-01-01  2620.99.90 - Ash and residues containing metal...   Canada
# 8    2015-01-01  2601.20.00 - Roasted iron pyrites (pyrites cin...   Canada
# ...         ...                                                ...      ...
# 3698 2024-01-01            2617.90.00 - Ores and concentrates, nes   Canada
# 3699 2015-01-01  2618.00.00 - Granulated slag (slag sand) from ...   Canada
# 3700 2018-01-01  2618.00.00 - Granulated slag (slag sand) from ...   Canada
# 3701 2013-01-01  2618.00.00 - Granulated slag (slag sand) from ...   Canada
# 3702 2016-01-01  2618.00.00 - Granulated slag (slag sand) from ...   Canada
#
#              Country     State  Value ($)   Quantity         Unit of measure  \
# 0     United Kingdom       NaN    4877724      42326  weight in metric tonne
# 5      United States    Nevada       2737          1     weight in kilograms
# 6        Netherlands       NaN         24          1     weight in kilograms
# 7         Madagascar       NaN         16          1     weight in kilograms
# 8              Chile       NaN         82          1  weight in metric tonne
# ...              ...       ...        ...        ...                     ...
# 3698           China       NaN  314316832  248696575     weight in kilograms
# 3699   United States  Michigan    6676825  280708000     weight in kilograms
# 3700   United States  Michigan    5887808  280717000     weight in kilograms
# 3701   United States  Michigan    4272901  288301000     weight in kilograms
# 3702   United States  Michigan    7334483  303838000     weight in kilograms
#
#       Quantity_kg  Price_per_kg
# 0      42326000.0      0.115242
# 5             1.0   2737.000000
# 6             1.0     24.000000
# 7             1.0     16.000000
# 8          1000.0      0.082000
# ...           ...           ...
# 3698  248696575.0      1.263857
# 3699  280708000.0      0.023786
# 3700  280717000.0      0.020974
# 3701  288301000.0      0.014821
# 3702  303838000.0      0.024139
#
# [3698 rows x 10 columns]

# %%
summary
# Out:
#                                             Commodity  mean_price_per_kg  \
# 0   2601.11.10 - Iron ores concentrated, non-agglo...             0.1351
# 1   2601.11.90 - Iron ores not concentrated, non-a...             0.1750
# 2   2601.12.00 - Iron ores and concentrates, o/t r...             0.1573
# 3   2601.20.00 - Roasted iron pyrites (pyrites cin...             0.2509
# 4            2602.00.00 - Manganese ores and conc etc             6.2380
# 5   2603.00.10 - Copper ores and concentrates, cop...            29.6705
# 6   2603.00.40 - Copper ores and concentrates, sil...           797.3410
# 7   2603.00.50 - Copper ores and concentrates, gol...         62894.6262
# 8      2603.00.90 - Copper ores and concentrates, nes            25.0965
# 9   2604.00.40 - Nickel ores and concentrates, nic...            19.6335
# 10     2604.00.90 - Nickel ores and concentrates, nes          6062.4070
# 11          2605.00.00 - Cobalt ores and concentrates           236.5782
# 12       2606.00.00 - Aluminium ores and concentrates             0.6097
# 13  2607.00.20 - Lead ores and concentrates, lead ...            12.4082
# 14  2607.00.40 - Lead ores and concentrates, silve...           974.1125
# 15  2607.00.50 - Lead ores and concentrates, gold ...         86728.0527
# 16       2607.00.90 - Lead ores and concentrates, nes           202.1570
# 17  2608.00.20 - Zinc ores and concentrates, lead ...             2.0299
# 18  2608.00.30 - Zinc ores and concentrates, zinc ...             3.5510
# 19  2608.00.40 - Zinc ores and concentrates, silve...          1003.9428
# 20       2608.00.90 - Zinc ores and concentrates, nes          3386.4626
# 21             2609.00.00 - Tin ores and concentrates             1.4217
# 22        2610.00.00 - Chromium ores and concentrates             1.4352
# 23        2611.00.00 - Tungsten ores and concentrates           218.3194
# 24         2612.10.00 - Uranium ores and concentrates           118.9593
# 25         2612.20.00 - Thorium ores and concentrates            11.4845
# 26      2613.10.00 - Molybdenum concentrates, roasted           194.5235
# 27  2613.90.00 - Molybdenum ores and concentrates nes            19.1012
# 28        2614.00.00 - Titanium ores and concentrates            14.9043
# 29       2615.10.00 - Zirconium ores and concentrates             7.3554
# 30  2615.90.00 - Niobium, tantalum and vanadium or...            89.0338
# 31  2616.10.40 - Silver ores and concentrates, sil...           523.4822
# 32     2616.10.90 - Silver ores and concentrates, nes          1315.5658
# 33  2616.90.10 - Precious metal ores and concentra...        161540.9037
# 34  2616.90.90 - Precious metal ores and concentra...         25481.2560
# 35  2616.90.90 - Precious metal ores and concentra...           142.4863
# 36        2617.10.00 - Antimony ores and concentrates             4.8990
# 37            2617.90.00 - Ores and concentrates, nes            49.2261
# 38  2618.00.00 - Granulated slag (slag sand) from ...             0.5110
# 39  2619.00.00 - Slag, dross, o/t granulated slag,...             6.4169
# 40  2620.11.00 - Ash and residues containing hard ...             2.5667
# 41  2620.19.00 - Ash and residues containing mainl...           645.4520
# 42  2620.21.00 - Lead gasoline sludges & lead anti...             0.2758
# 43  2620.29.00 - Ash & residues, containing mainly...           109.1300
# 44  2620.30.00 - Ash and residues containing mainl...             5.7151
# 45  2620.40.00 - Ash and residues containing mainl...            29.2743
# 46  2620.60.00 - Ash & residues cont arsenic,mercu...             3.1646
# 47  2620.91.00 - Ash & residues cont antimony, ber...           193.0624
# 48  2620.99.10 - Ash and residues containing mainl...             3.3131
# 49  2620.99.90 - Ash and residues containing metal...           730.9084
# 50  2621.10.00 - Ash and residues from the inciner...             0.4680
# 51  2621.90.00 - Other ash and slag, including sea...             0.2646
#
#     std_price_per_kg  n_records start_date   end_date  \
# 0             0.0970        194 2013-01-01 2024-01-01
# 1             0.1348         95 2013-01-01 2024-01-01
# 2             0.0519        250 2013-01-01 2024-01-01
# 3             0.4451          6 2013-01-01 2019-01-01
# 4            12.3893         15 2014-01-01 2024-01-01
# 5           300.3357        217 2013-01-01 2024-01-01
# 6           208.9266         83 2017-01-01 2024-01-01
# 7         18776.4027         83 2017-01-01 2024-01-01
# 8            22.8053         62 2013-01-01 2024-01-01
# 9             8.2158         46 2014-01-01 2024-01-01
# 10        10575.3619         22 2013-01-01 2024-01-01
# 11          571.4579         12 2014-01-01 2024-01-01
# 12            0.5705         41 2013-01-01 2024-01-01
# 13           42.6099         50 2013-01-01 2024-01-01
# 14          230.3893         15 2017-01-01 2024-01-01
# 15        15103.7723          6 2021-01-01 2024-01-01
# 16          737.7573         29 2013-01-01 2024-01-01
# 17            0.7582         15 2013-01-01 2024-01-01
# 18           16.4475         65 2013-01-01 2024-01-01
# 19          475.6254         19 2018-01-01 2024-01-01
# 20         9316.0951         25 2014-01-01 2024-01-01
# 21            0.0046          7 2013-01-01 2024-01-01
# 22            2.0562         24 2013-01-01 2023-01-01
# 23          865.9016         38 2013-01-01 2024-01-01
# 24          160.7207         17 2013-01-01 2024-01-01
# 25           10.0644          4 2014-01-01 2018-01-01
# 26          606.3752         13 2013-01-01 2023-01-01
# 27           11.3949        101 2013-01-01 2024-01-01
# 28           61.9672         43 2013-01-01 2024-01-01
# 29            9.2792         65 2013-01-01 2024-01-01
# 30          328.2766         62 2013-01-01 2024-01-01
# 31          266.8996          7 2017-01-01 2023-01-01
# 32         5879.9532         27 2013-01-01 2024-01-01
# 33       959359.7388         75 2017-01-01 2024-01-01
# 34        35165.7318         95 2017-01-01 2024-01-01
# 35          552.7608         24 2013-01-01 2016-01-01
# 36            5.4191         22 2013-01-01 2023-01-01
# 37          311.0447        332 2013-01-01 2024-01-01
# 38            0.7255        114 2013-01-01 2024-01-01
# 39           23.3516        144 2013-01-01 2024-01-01
# 40            0.6346         54 2013-01-01 2024-01-01
# 41         3494.4143        181 2013-01-01 2024-01-01
# 42               NaN          1 2024-01-01 2024-01-01
# 43          757.8863         50 2013-01-01 2024-01-01
# 44            3.9102        100 2013-01-01 2024-01-01
# 45          225.9691        139 2013-01-01 2024-01-01
# 46               NaN          1 2019-01-01 2019-01-01
# 47          382.0151         15 2013-01-01 2023-01-01
# 48            3.9660         17 2013-01-01 2021-01-01
# 49         7417.0728        220 2013-01-01 2024-01-01
# 50            0.5321          5 2014-01-01 2021-01-01
# 51            0.3343        351 2013-01-01 2024-01-01
#
#           date_range_comment
# 0   2013-01-01 to 2024-01-01
# 1   2013-01-01 to 2024-01-01
# 2   2013-01-01 to 2024-01-01
# 3   2013-01-01 to 2019-01-01
# 4   2014-01-01 to 2024-01-01
# 5   2013-01-01 to 2024-01-01
# 6   2017-01-01 to 2024-01-01
# 7   2017-01-01 to 2024-01-01
# 8   2013-01-01 to 2024-01-01
# 9   2014-01-01 to 2024-01-01
# 10  2013-01-01 to 2024-01-01
# 11  2014-01-01 to 2024-01-01
# 12  2013-01-01 to 2024-01-01
# 13  2013-01-01 to 2024-01-01
# 14  2017-01-01 to 2024-01-01
# 15  2021-01-01 to 2024-01-01
# 16  2013-01-01 to 2024-01-01
# 17  2013-01-01 to 2024-01-01
# 18  2013-01-01 to 2024-01-01
# 19  2018-01-01 to 2024-01-01
# 20  2014-01-01 to 2024-01-01
# 21  2013-01-01 to 2024-01-01
# 22  2013-01-01 to 2023-01-01
# 23  2013-01-01 to 2024-01-01
# 24  2013-01-01 to 2024-01-01
# 25  2014-01-01 to 2018-01-01
# 26  2013-01-01 to 2023-01-01
# 27  2013-01-01 to 2024-01-01
# 28  2013-01-01 to 2024-01-01
# 29  2013-01-01 to 2024-01-01
# 30  2013-01-01 to 2024-01-01
# 31  2017-01-01 to 2023-01-01
# 32  2013-01-01 to 2024-01-01
# 33  2017-01-01 to 2024-01-01
# 34  2017-01-01 to 2024-01-01
# 35  2013-01-01 to 2016-01-01
# 36  2013-01-01 to 2023-01-01
# 37  2013-01-01 to 2024-01-01
# 38  2013-01-01 to 2024-01-01
# 39  2013-01-01 to 2024-01-01
# 40  2013-01-01 to 2024-01-01
# 41  2013-01-01 to 2024-01-01
# 42  2024-01-01 to 2024-01-01
# 43  2013-01-01 to 2024-01-01
# 44  2013-01-01 to 2024-01-01
# 45  2013-01-01 to 2024-01-01
# 46  2019-01-01 to 2019-01-01
# 47  2013-01-01 to 2023-01-01
# 48  2013-01-01 to 2021-01-01
# 49  2013-01-01 to 2024-01-01
# 50  2014-01-01 to 2021-01-01
# 51  2013-01-01 to 2024-01-01

# %%
summary.to_csv(r'data/Prices/canada_export_price_per_kg_summary.csv', index=False)
