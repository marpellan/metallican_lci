# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from typing import List, Tuple

# %%
# Custom functions
from some_functions import merge_without_suffixes, normalize_by_production, get_info_for_ids, create_sankey_diagram, get_production_data

# %%
metallican_path = r'C:\Users\mp_ma\OneDrive - polymtl\POST_DOC\CODE\metallican_db'

# %% [markdown]
# # Import MetalliCan tables

# %%
main_table = pd.read_csv(metallican_path + r'\database\CSV\main_table.csv')
production_table = pd.read_csv(metallican_path + r'\database\CSV\production_table.csv')
tech_attributes_table = pd.read_csv(metallican_path + r'\database\CSV\tech_attributes_table.csv')
env_table = pd.read_csv(metallican_path + r'\database\CSV\environmental_flows_table.csv')
technosphere_table = pd.read_csv(metallican_path + r'\database\CSV\materials_energy_table.csv')
archetypes_table = pd.read_csv(metallican_path + r'\database\CSV\archetypes_table.csv')
land_table = pd.read_csv(metallican_path + r'\database\CSV\land_occupation_table.csv')
intensity_table = pd.read_csv(metallican_path + r'\database\CSV\intensity_table.csv')
waste_table = pd.read_table(metallican_path + r'\database\CSV\waste_table.csv', sep=',')

# %%
substances_table = pd.read_csv(metallican_path + r'\database\CSV\substances_table.csv')

# %%
intensity_table_nrj = intensity_table[intensity_table['type'] == 'Energy']
intensity_table_nrj = intensity_table_nrj[~intensity_table_nrj['intensity_id'].str.startswith('INT-CMP')]

# %%
# Let's remove ClimateTRACE data
production_table = production_table[~production_table['source_id'].str.startswith('Jolleys, M. et al (2024). Mineral Extraction sector: Mining and Quarrying Emissions from Copper, Iron, Bauxite, Rock and Sand, Hypervine, UK, Climate TRACE Emissions Inventory')]

# %% [markdown]
# # Harmonization of environmental flow units

# %%
# Let's remove ClimateTRACE data
env_table = env_table[~env_table['source_id'].str.startswith('Jolleys, M. et al (2024). Mineral Extraction sector: Mining and Quarrying Emissions from Copper, Iron, Bauxite, Rock and Sand, Hypervine, UK, Climate TRACE Emissions Inventory')]

# %%
env_table
# Out:
#                     env_id  year compartment_name substance_id flow_direction  \
# 28        npri-1568-2023-1  2023              Air      NA - 16       Emission
# 29        npri-1568-2023-2  2023              Air      NA - 02       Emission
# 30        npri-1568-2023-3  2023              Air     630-08-0       Emission
# 31        npri-1568-2023-4  2023              Air      NA - 04       Emission
# 32        npri-1568-2023-5  2023              Air      NA - 05       Emission
# ...                    ...   ...              ...          ...            ...
# 5147   ENV-9de9bb0d-2023-8  2023              Air     NA - M16       Emission
# 5148   ENV-9de9bb0d-2023-9  2023            Water    7732-18-5     Withdrawal
# 5149  ENV-9de9bb0d-2023-10  2023            Water    7732-18-5     Withdrawal
# 5150  ENV-9de9bb0d-2023-11  2023            Water    7732-18-5    Consumption
# 5151  ENV-9de9bb0d-2023-12  2023            Water    7732-18-5     Discharged
#
#       release_pathway    unit     value comment           main_id  \
# 28    Stack Emissions  tonnes     0.636     NaN  ON-MAIN-1f126a43
# 29    Stack Emissions      kg     0.116     NaN  ON-MAIN-1f126a43
# 30    Stack Emissions  tonnes    76.208     NaN  ON-MAIN-1f126a43
# 31    Stack Emissions  tonnes   0.00105     NaN  ON-MAIN-1f126a43
# 32    Stack Emissions      kg      0.18     NaN  ON-MAIN-1f126a43
# ...               ...     ...       ...     ...               ...
# 5147              NaN       t      0.99     NaN  QC-MAIN-9de9bb0d
# 5148              NaN      m3  168115.0     NaN  QC-MAIN-9de9bb0d
# 5149              NaN      m3  168115.0     NaN  QC-MAIN-9de9bb0d
# 5150              NaN      m3   82144.0     NaN  QC-MAIN-9de9bb0d
# 5151              NaN      m3  536420.0     NaN  QC-MAIN-9de9bb0d
#
#      facility_group_id    company_id  \
# 28                 NaN           NaN
# 29                 NaN           NaN
# 30                 NaN           NaN
# 31                 NaN           NaN
# 32                 NaN           NaN
# ...                ...           ...
# 5147               NaN  CMP-3d2c4955
# 5148               NaN  CMP-3d2c4955
# 5149               NaN  CMP-3d2c4955
# 5150               NaN  CMP-3d2c4955
# 5151               NaN  CMP-3d2c4955
#
#                                               source_id
# 28    https://www.canada.ca/en/environment-climate-c...
# 29    https://www.canada.ca/en/environment-climate-c...
# 30    https://www.canada.ca/en/environment-climate-c...
# 31    https://www.canada.ca/en/environment-climate-c...
# 32    https://www.canada.ca/en/environment-climate-c...
# ...                                                 ...
# 5147       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables
# 5148       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables
# 5149       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables
# 5150       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables
# 5151       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables
#
# [5124 rows x 13 columns]

# %%
# How many different unit per substance_id, make a df with substance_id and number of different units
test = env_table.groupby('substance_id')['unit'].nunique().sort_values(ascending=False).reset_index()
test
# Out:
#    substance_id  unit
# 0     7732-18-5     5
# 1      NA - M10     3
# 2      NA - M09     3
# 3      NA - M16     3
# 4      630-08-0     3
# ..          ...   ...
# 94     224-42-0     1
# 95     218-01-9     1
# 96     208-96-8     1
# 97     207-08-9     1
# 98      75-15-0     1
#
# [99 rows x 2 columns]

# %%
env_table.groupby('substance_id')['unit'].unique().reset_index()
# Out:
#         substance_id      unit
# 0           100-41-4  [tonnes]
# 1           100-42-5  [tonnes]
# 2         10024-97-2  [tCO2eq]
# 3         10102-44-0       [t]
# 4           107-21-1  [tonnes]
# ..               ...       ...
# 94          NA - P/H      [kg]
# 95          NA - PAH       [t]
# 96         NA - PFCs  [tCO2eq]
# 97  NA - Particulate       [t]
# 98          NA - SOx   [t, kg]
#
# [99 rows x 2 columns]

# %%
unit_mapping = {
'7732-18-5' : 'm3',
'NA - M10' : 'tonnes',
'NA - M09' : 'tonnes',
'NA - M16' : 'tonnes',
'630-08-0' : 'tonnes',
'NA - NOx' : 'tonnes',
'NA - 08' : 'kg',
'NA - 10' : 'tonnes',
'NA - 02' : 'kg',
'NA - M08' : 'tonnes',
'NA - GHG' : 'tCO2eq',
'NA - 12': 'kg',
'NA - SOx': 'tonnes'
}

# %%
conversion_factors = {
    ('kg', 'tonnes'): 1/1000,
    ('kg', 't'): 1/1000,
    ('tonnes', 'kg'): 1000,
    ('t', 'kg'): 1000,
    ('tonnes', 't'): 1,
    ('t', 'tonnes'): 1,
    ('ML', 'm3'): 1000,
    ('m3', 'ML'): 1/1000,
    ('L', 'm3'): 1/1000,
    ('m3', 'L'): 1000,
    ('Mm3', 'm3'): 1000000,
    ('km3', 'm3'): 1000,
    ('ktCO2eq', 'tCO2eq'): 1000,
    ('tCO2eq', 'ktCO2eq'): 1/1000
}

# %%
def update_units_and_values(row):
    substance_id = row['substance_id']
    current_unit = row['unit']
    value = row['value']

    if substance_id in unit_mapping:
        target_unit = unit_mapping[substance_id]

        if current_unit != target_unit:
            conversion_key = (current_unit, target_unit)
            if conversion_key in conversion_factors:
                value = value * conversion_factors[conversion_key]
            # Si la conversion n'est pas définie, la valeur reste inchangée

        current_unit = target_unit  # Mettre à jour l'unité

    return pd.Series({'unit': current_unit, 'value': value})


env_table['value'] = pd.to_numeric(env_table['value'], errors='coerce')
mask = env_table['substance_id'].isin(unit_mapping.keys())
env_table.loc[mask, ['unit', 'value']] = env_table.loc[mask].apply(update_units_and_values, axis=1)

# %%
env_table.groupby('substance_id')['unit'].nunique().sort_values(ascending=False).reset_index()
# Out:
#    substance_id  unit
# 0      100-41-4     1
# 1       NA - 09     1
# 2       NA - 07     1
# 3       NA - 06     1
# 4       NA - 05     1
# ..          ...   ...
# 94     224-42-0     1
# 95     218-01-9     1
# 96     208-96-8     1
# 97     207-08-9     1
# 98     NA - SOx     1
#
# [99 rows x 2 columns]

# %% [markdown]
# # Harmonization of technosphere units

# %%
# Separe energy and material
energy_df = technosphere_table[technosphere_table['flow_type'] == 'Energy']
material_df = technosphere_table[technosphere_table['flow_type'] == 'Material use']

# %% [markdown]
# ## Energy flows

# %%
## New version
# --- Direct energy units → MJ ---
UNIT_TO_MJ = {
    'mj':   1.0,
    'gj':   1_000.0,
    'tj':   1_000_000.0,
    'j':    1e-6,
    'wh':   0.0036,
    'kwh':  3.6,
    'mwh':  3_600.0,
    'gwh':  3_600_000.0,
}

# --- Volume unit multipliers (to liters) ---
VOLUME_TO_L = {
    'l': 1.0, 'liter': 1.0, 'litre': 1.0, 'liters': 1.0, 'litres': 1.0,
    'kl': 1_000.0, 'kiloliter': 1_000.0, 'kilolitre': 1_000.0,
    'ml': 1_000_000.0, 'megaliter': 1_000_000.0, 'megalitre': 1_000_000.0,
    'gallon': 3.78541, 'gallons': 3.78541,
}

CUBIC_M_TO_M3 = {'m3': 1.0, 'm^3': 1.0, 'cubicmeter': 1.0, 'cubicmeters': 1.0}

# --- Default LHVs (edit with site/company data whenever you can) ---
DEFAULT_LHV = {
    'diesel':      {'MJ/kg': 43.0, 'MJ/L': 38.6, 'density_kg_per_L': 0.835},
    'gasoline':    {'MJ/kg': 44.0, 'MJ/L': 34.2, 'density_kg_per_L': 0.745},
    'heavy_fuel_oil': {'MJ/kg': 40.5, 'MJ/L': 39.69, 'density_kg_per_L': 0.98},
    'coal':        {'MJ/kg': 25.0},
    'natural_gas': {'MJ/m3': 38.0, 'MJ/L': 22.5, 'density_kg_per_L': 0.7},
    'propane':     {'MJ/kg': 46.4, 'MJ/L': 25.3, 'density_kg_per_L': 0.493},
    'electricity': {'MJ/kWh': 3.6},
    'explosives':  {'MJ/kg': 4.0},
    'coke':        {'MJ/kg': 28.0},
    'wood':        {'MJ/kg': 16.0},
}


# --- Subflow canonicalization (aliases + strip pipe suffixes) ---
SUBFLOW_ALIASES = {
    'petrol': 'gasoline',
    'heavy fuel oil': 'heavy_fuel_oil',
    'hfo': 'heavy_fuel_oil',
    'natural gas': 'natural_gas',
    'explosive': 'explosives',
    'lpg': 'propane',
    'surface/underground_emulsion_&_anfo': 'explosives',
    'grinding_media': 'explosives',
    'total_blasting_agents_used_e.g._anfo': 'explosives'
}

def _norm_unit(x):
    if pd.isna(x): return None
    #n = str(x).strip().lower().replace(' ', '')
    #print(f"Original unit: '{x}', Normalized: '{n}'")  # Debug line
    #return n
    return str(x).strip().lower().replace(' ', '')

def _canon_subflow(x):
    if pd.isna(x): return None
    s = str(x).strip().lower()
    if '|' in s:
        s = s.split('|', 1)[0].strip()
    s = SUBFLOW_ALIASES.get(s, s)
    s_us = s.replace(' ', '_')
    #print(f"Original: '{x}', Normalized: '{s_us}'")  # Debug line
    return s_us

def standardize_energy_to_MJ(
    df,
    subflow_col='subflow_type',
    unit_col='unit',
    value_col='value',
    lhv_table=None
):
    """
    Convert energy/fuel rows to MJ.
    """
    lhv = (lhv_table or DEFAULT_LHV).copy()
    out = df.copy()

    # Normalize
    out['_unit_n'] = out[unit_col].map(_norm_unit)
    out['_subflow_n'] = out[subflow_col].map(_canon_subflow)
    out[value_col] = pd.to_numeric(out[value_col], errors='coerce')

    # 1) Direct energy units
    direct_mask = out['_unit_n'].isin(UNIT_TO_MJ)
    out.loc[direct_mask, 'value_MJ'] = (
        out.loc[direct_mask, value_col] *
        out.loc[direct_mask, '_unit_n'].map(UNIT_TO_MJ)
    )
    out.loc[direct_mask, 'unit_source'] = 'direct_unit'
    out.loc[direct_mask, 'assumption_note'] = (
        out.loc[direct_mask, '_unit_n'].map(lambda u: f"{u}→MJ factor={UNIT_TO_MJ[u]}")
    )

    # 2) Fuels via LHV
    fuel_rows = ~direct_mask & out['_subflow_n'].notna() & out[value_col].notna()
    for idx in out.index[fuel_rows]:
        sub = out.at[idx, '_subflow_n']
        unit = out.at[idx, '_unit_n']
        val  = out.at[idx, value_col]
        lhv_data = lhv.get(sub)

        if not lhv_data:
            out.at[idx, 'unit_source'] = 'missing_factor'
            out.at[idx, 'assumption_note'] = f"No LHV for subflow={sub}"
            continue

        converted = False

        # A) Mass units (kg, t, lbs)
        if unit in ('kg', 'kilogram', 'kilograms', 't', 'tonne', 'tonnes',
                    'metricton', 'ton', 'lb', 'lbs', 'pound', 'pounds'):
            # Determine multiplier to convert mass unit to kg
            mult_kg = 1.0
            if unit.startswith('t'):
                mult_kg = 1000.0
            elif unit in ('lb', 'lbs', 'pound', 'pounds'):
                mult_kg = 0.453592 # lbs to kg

            factor_kg = lhv_data.get('MJ/kg')
            if factor_kg:
                out.at[idx, 'value_MJ'] = val * mult_kg * factor_kg
                out.at[idx, 'unit_source'] = 'lhv_factor'
                out.at[idx, 'assumption_note'] = f"{sub} MJ/kg={factor_kg} (from {unit})"
                converted = True

        # B) Volume units (L, kL, ML, Gallons)
        elif unit in VOLUME_TO_L:
            mult_L = VOLUME_TO_L[unit]
            factor_l = lhv_data.get('MJ/L')
            if factor_l is None and lhv_data.get('density_kg_per_L') and lhv_data.get('MJ/kg'):
                dens = lhv_data.get('density_kg_per_L')
                factor_kg = lhv_data.get('MJ/kg')
                mass_kg = val * mult_L * dens
                out.at[idx, 'value_MJ'] = mass_kg * factor_kg
                out.at[idx, 'unit_source'] = 'lhv+density'
                out.at[idx, 'assumption_note'] = f"{sub} L→kg via {dens} kg/L; MJ/kg={factor_kg}"
                converted = True
            elif factor_l:
                out.at[idx, 'value_MJ'] = val * mult_L * factor_l
                out.at[idx, 'unit_source'] = 'lhv_factor'
                out.at[idx, 'assumption_note'] = f"{sub} MJ/L={factor_l}"
                converted = True

        # C) Volume units (m3)
        elif unit in CUBIC_M_TO_M3:
            factor_m3 = lhv_data.get('MJ/m3')
            if factor_m3:
                out.at[idx, 'value_MJ'] = val * CUBIC_M_TO_M3[unit] * factor_m3
                out.at[idx, 'unit_source'] = 'lhv_factor'
                out.at[idx, 'assumption_note'] = f"{sub} MJ/m3={factor_m3}"
                converted = True

        if not converted:
            out.at[idx, 'unit_source'] = 'missing_factor'
            out.at[idx, 'assumption_note'] = f"No conversion rule for subflow={sub}, unit={unit}"

    # Final flags
    out['unit_standard'] = np.where(out['value_MJ'].notna(), 'MJ', None)
    out['needs_factor'] = out['value_MJ'].isna() & out[value_col].notna()
    out = out.drop(columns=['_unit_n', '_subflow_n'], errors='ignore')
    return out

# %%
energy_df_sd = standardize_energy_to_MJ(energy_df)

# %%
energy_df_sd
# Out:
#           technosphere_id  year flow_type  \
# 0    TECH-857b7b89-2023-1  2023    Energy
# 1    TECH-857b7b89-2023-2  2023    Energy
# 2    TECH-857b7b89-2023-3  2023    Energy
# 3    TECH-857b7b89-2023-4  2023    Energy
# 4    TECH-857b7b89-2023-5  2023    Energy
# ..                    ...   ...       ...
# 226  TECH-7607a50e-2023-3  2023    Energy
# 227  TECH-7607a50e-2023-4  2023    Energy
# 228  TECH-7607a50e-2023-5  2023    Energy
# 229  TECH-7607a50e-2023-6  2023    Energy
# 230  TECH-7607a50e-2023-7  2023    Energy
#
#                              subflow_type unit          value  \
# 0                               Acetylene   GJ      18.475651
# 1                           Aviation fuel   GJ   72676.110790
# 2                                  Diesel   GJ  287042.447232
# 3                                Gasoline   GJ   13568.450000
# 4                                 Propane   GJ   42071.041300
# ..                                    ...  ...            ...
# 226                                Diesel   GJ  140100.000000
# 227                              Gasoline   GJ    2124.000000
# 228                                Naphta   GJ    6344.000000
# 229                           Natural gas   GJ  221612.000000
# 230  Total blasting agents used e.g. ANFO    t    2599.500000
#
#                                        comment           main_id  \
# 0                                          NaN  BC-MAIN-857b7b89
# 1                                          NaN  BC-MAIN-857b7b89
# 2                                          NaN  BC-MAIN-857b7b89
# 3                                          NaN  BC-MAIN-857b7b89
# 4                                          NaN  BC-MAIN-857b7b89
# ..                                         ...               ...
# 226                                        NaN  ON-MAIN-7607a50e
# 227                                        NaN  ON-MAIN-7607a50e
# 228                                        NaN  ON-MAIN-7607a50e
# 229                                        NaN  ON-MAIN-7607a50e
# 230  Explosives, treated as energy consumption  ON-MAIN-7607a50e
#
#     facility_group_id    company_id  \
# 0                 NaN  CMP-4a434d72
# 1                 NaN  CMP-4a434d72
# 2                 NaN  CMP-4a434d72
# 3                 NaN  CMP-4a434d72
# 4                 NaN  CMP-4a434d72
# ..                ...           ...
# 226               NaN  CMP-3a4ccc7f
# 227               NaN  CMP-3a4ccc7f
# 228               NaN  CMP-3a4ccc7f
# 229               NaN  CMP-3a4ccc7f
# 230               NaN  CMP-3a4ccc7f
#
#                                         source_id      value_MJ  \
# 0    SRC_NewmontCorporation_2023-Performance-data  1.847565e+04
# 1    SRC_NewmontCorporation_2023-Performance-data  7.267611e+07
# 2    SRC_NewmontCorporation_2023-Performance-data  2.870424e+08
# 3    SRC_NewmontCorporation_2023-Performance-data  1.356845e+07
# 4    SRC_NewmontCorporation_2023-Performance-data  4.207104e+07
# ..                                            ...           ...
# 226                   SRC_AlamosGoldInc_Data_2023  1.401000e+08
# 227                   SRC_AlamosGoldInc_Data_2023  2.124000e+06
# 228                   SRC_AlamosGoldInc_Data_2023  6.344000e+06
# 229                   SRC_AlamosGoldInc_Data_2023  2.216120e+08
# 230                   SRC_AlamosGoldInc_Data_2023           NaN
#
#         unit_source                                    assumption_note  \
# 0       direct_unit                                gj→MJ factor=1000.0
# 1       direct_unit                                gj→MJ factor=1000.0
# 2       direct_unit                                gj→MJ factor=1000.0
# 3       direct_unit                                gj→MJ factor=1000.0
# 4       direct_unit                                gj→MJ factor=1000.0
# ..              ...                                                ...
# 226     direct_unit                                gj→MJ factor=1000.0
# 227     direct_unit                                gj→MJ factor=1000.0
# 228     direct_unit                                gj→MJ factor=1000.0
# 229     direct_unit                                gj→MJ factor=1000.0
# 230  missing_factor  No LHV for subflow=total_blasting_agents_used_...
#
#     unit_standard  needs_factor
# 0              MJ         False
# 1              MJ         False
# 2              MJ         False
# 3              MJ         False
# 4              MJ         False
# ..            ...           ...
# 226            MJ         False
# 227            MJ         False
# 228            MJ         False
# 229            MJ         False
# 230          None          True
#
# [182 rows x 16 columns]

# %%
# Check the rows that could not be converted
energy_df_sd[energy_df_sd['needs_factor']]['subflow_type']
# Out:
# 17       Surface/underground emulsion & ANFO
# 38                            Grinding media
# 70       Surface/underground emulsion & ANFO
# 109    Electricity consumption|Not specified
# 110                                   Diesel
# 111                               Explosives
# 112                                 Gasoline
# 113                                  Propane
# 119                           Grinding media
# 148                           Grinding media
# 230     Total blasting agents used e.g. ANFO
# Name: subflow_type, dtype: object

# %% [markdown]
# ## Material flows

# %%
# liters prefixes → L
VOLUME_TO_L = {
    'l': 1.0, 'liter': 1.0, 'litre': 1.0, 'liters': 1.0, 'litres': 1.0,
    'kl': 1_000.0, 'kiloliter': 1_000.0, 'kilolitre': 1_000.0,
    'ml': 1_000_000.0, 'megaliter': 1_000_000.0, 'megalitre': 1_000_000.0,
}

# Default densities (kg/L) – please override with site-specific values when you have them
DEFAULT_DENSITY = {
    # Oils & lubricants family
    'lubricants': 0.88,
    'hydraulic oil': 0.88,
    'transmission oil': 0.88,
    'motor oil': 0.88,
    'drill oil': 0.88,
    'compressor oil': 0.88,

    # Acids (typical commercial concentrations)
    'sulfuric acid (h2so4)': 1.84,    # ~98%
    'hydrochloric acid (hcl)': 1.19,  # ~37%
    'nitric acid (hno3)': 1.51,       # ~68–70%

    # If you have aqueous reagents (e.g., “sodium cyanide solution”) add their conc/density here.
}

# Canonicalize names (left part before '|', lowercased)
ALIASES = {
    'petrol': 'gasoline',
    'grindingmedia': 'grinding media',
    '3/4\'\'balls': 'grinding media',
    '2\'\'balls': 'grinding media',
    '2.5\'\'balls': 'grinding media',
    '5.5\'\'balls': 'grinding media',
    'polyfrothh57': 'polyfroth h57',
    'antiscalant': 'anti-scalant',
}

def _norm_text(x):
    if pd.isna(x): return None
    return str(x).strip()

def _canon_subflow(s):
    if s is None: return None
    # take leftmost token before a pipe and lowercase
    base = s.split('|', 1)[0].strip().lower()
    # strip extra spaces and collapse doubles
    base = ' '.join(base.split())
    return ALIASES.get(base.replace(' ', ''), base)

def standardize_materials_to_t(df, subflow_col='subflow_type', unit_col='unit', value_col='value',
                               density_table=None):
    """
    Convert 'material' rows to tonnes.
    Adds:
      - mass_t : numeric mass in tonnes
      - mass_source : 't','kg→t','L×density→t','missing_density','unknown_unit'
      - mass_note : short note on the assumption used
      - needs_density : True when a volume row had no density mapping
    """
    den = {k.lower(): v for k, v in (density_table or DEFAULT_DENSITY).items()}
    out = df.copy()

    out['_unit_n'] = out[unit_col].astype(str).str.strip().str.lower().str.replace(' ', '', regex=False)
    out['_subflow_n'] = out[subflow_col].map(_canon_subflow)
    out[value_col] = pd.to_numeric(out[value_col], errors='coerce')

    # direct tonnes
    mask_t = out['_unit_n'].isin({'t','tonne','tonnes','metricton','ton'})
    out.loc[mask_t, 'mass_t'] = out.loc[mask_t, value_col].astype(float)
    out.loc[mask_t, 'mass_source'] = 't'
    out.loc[mask_t, 'mass_note'] = 'reported in tonnes'

    # kg → t
    mask_kg = out['_unit_n'].isin({'kg','kilogram','kilograms'})
    out.loc[mask_kg, 'mass_t'] = out.loc[mask_kg, value_col] / 1000.0
    out.loc[mask_kg, 'mass_source'] = 'kg→t'
    out.loc[mask_kg, 'mass_note'] = 'kg/1000'

    # liters family → t using density (kg/L)
    mask_L = out['_unit_n'].isin(VOLUME_TO_L)
    if mask_L.any():
        multL = out.loc[mask_L, '_unit_n'].map(VOLUME_TO_L)
        # find density per row from mapping on canonical subflow
        dens = out.loc[mask_L, '_subflow_n'].map(lambda s: den.get(s if s else '', np.nan))
        mass_t = (out.loc[mask_L, value_col] * multL * dens) / 1000.0
        out.loc[mask_L, 'mass_t'] = mass_t
        out.loc[mask_L, 'mass_source'] = np.where(dens.notna(), 'L×density→t', 'missing_density')
        out.loc[mask_L, 'mass_note'] = np.where(
            dens.notna(),
            (out.loc[mask_L, '_unit_n'].map(str) + f"→L × density kg/L; density=" + dens.map(lambda x: f"{x:g}")),
            "volume reported; no density mapping for this subflow"
        )

    # mark unknown units
    mask_done = mask_t | mask_kg | mask_L
    out.loc[~mask_done & out[value_col].notna(), 'mass_source'] = 'unknown_unit'
    out.loc[~mask_done & out[value_col].notna(), 'mass_note'] = 'no rule for this unit'

    out['needs_density'] = (out['mass_source'] == 'missing_density')

    # clean temp
    out = out.drop(columns=['_unit_n','_subflow_n'])
    return out

# %%
material_df_sd = standardize_materials_to_t(material_df)

# %%
material_df_sd
# Out:
#                technosphere_id  year     flow_type  \
# 35        TECH-6dc537e6-2023-2  2023  Material use
# 39        TECH-6dc537e6-2023-6  2023  Material use
# 40        TECH-6dc537e6-2023-7  2023  Material use
# 41        TECH-6dc537e6-2023-8  2023  Material use
# 43       TECH-6dc537e6-2023-10  2023  Material use
# 44       TECH-6dc537e6-2023-11  2023  Material use
# 45       TECH-6dc537e6-2023-12  2023  Material use
# 65        TECH-687b8c8d-2023-6  2023  Material use
# 66        TECH-687b8c8d-2023-7  2023  Material use
# 116       TECH-fefeaee4-2023-3  2023  Material use
# 120       TECH-fefeaee4-2023-7  2023  Material use
# 121       TECH-fefeaee4-2023-8  2023  Material use
# 122       TECH-fefeaee4-2023-9  2023  Material use
# 124      TECH-fefeaee4-2023-11  2023  Material use
# 126      TECH-fefeaee4-2023-13  2023  Material use
# 131       TECH-aa76f6f2-2023-3  2023  Material use
# 132       TECH-aa76f6f2-2023-4  2023  Material use
# 133       TECH-aa76f6f2-2023-5  2023  Material use
# 136       TECH-aa76f6f2-2023-8  2023  Material use
# 138      TECH-aa76f6f2-2023-10  2023  Material use
# 140      TECH-aa76f6f2-2023-12  2023  Material use
# 142      TECH-aa76f6f2-2023-14  2023  Material use
# 144   TECH-GRP-0d911886-2023-2  2023  Material use
# 149   TECH-GRP-0d911886-2023-7  2023  Material use
# 150   TECH-GRP-0d911886-2023-8  2023  Material use
# 151   TECH-GRP-0d911886-2023-9  2023  Material use
# 153  TECH-GRP-0d911886-2023-11  2023  Material use
# 155  TECH-GRP-0d911886-2023-13  2023  Material use
# 156  TECH-GRP-0d911886-2023-14  2023  Material use
# 157  TECH-GRP-0d911886-2023-15  2023  Material use
# 160       TECH-0aadf28f-2023-2  2023  Material use
# 161       TECH-0aadf28f-2023-3  2023  Material use
# 162       TECH-0aadf28f-2023-4  2023  Material use
# 163       TECH-0aadf28f-2023-5  2023  Material use
# 164       TECH-0aadf28f-2023-6  2023  Material use
# 167       TECH-0aadf28f-2023-9  2023  Material use
# 169      TECH-0aadf28f-2023-11  2023  Material use
# 206       TECH-02884fb5-2023-3  2023  Material use
# 207       TECH-02884fb5-2023-4  2023  Material use
# 208       TECH-02884fb5-2023-5  2023  Material use
# 209       TECH-02884fb5-2023-6  2023  Material use
# 210       TECH-02884fb5-2023-7  2023  Material use
# 214      TECH-02884fb5-2023-11  2023  Material use
# 216      TECH-02884fb5-2023-13  2023  Material use
# 217      TECH-02884fb5-2023-14  2023  Material use
# 218      TECH-02884fb5-2023-15  2023  Material use
# 219      TECH-02884fb5-2023-16  2023  Material use
# 222      TECH-02884fb5-2023-19  2023  Material use
# 223      TECH-02884fb5-2023-20  2023  Material use
# 231       TECH-7607a50e-2023-8  2023  Material use
#
#                              subflow_type unit          value comment  \
# 35                                 Cement    t   27374.000000     NaN
# 39                                   Lime    t    2229.000000     NaN
# 40                             Lubricants   kl     380.687000     NaN
# 41                     Nitric acid (HNO3)    l   26575.000000     NaN
# 43                  Sodium cyanide (NaCN)    t     838.800000     NaN
# 44                  Sulfuric acid (H2SO4)    l      73.960000     NaN
# 45                                  Tires    t     241.250567     NaN
# 65              Total sodium cyanide used    t     245.000000     NaN
# 66   Total blasting agents used e.g. ANFO    t     486.300000     NaN
# 116                                Cement    t    9417.600000     NaN
# 120               Hydrochloric acid (HCL)   kl      57.200000     NaN
# 121                                  Lime    t     924.081000     NaN
# 122                            Lubricants   kl     336.521000     NaN
# 124                 Sodium cyanide (NaCN)    t     390.003000     NaN
# 126                                 Tires    t     100.705343     NaN
# 131                             2'' balls    t     980.000000     NaN
# 132                           3/4'' balls    t     179.000000     NaN
# 133                          Anti-scalant   kg   38000.000000     NaN
# 136                            Flocculant    t     192.000000     NaN
# 138                                  Lime    t    2724.000000     NaN
# 140                         Polyfroth h57    t      55.000000     NaN
# 142                         S60 SAG Balls    t     583.000000     NaN
# 144                                Cement    t   12578.000000     NaN
# 149               Hydrochloric acid (HCL)   kl       2.255000     NaN
# 150                                  Lime    t    4346.921000     NaN
# 151                            Lubricants   kl     619.366000     NaN
# 153                    Nitric acid (HNO3)    l     175.000000     NaN
# 155                 Sodium cyanide (NaCN)    t     734.521000     NaN
# 156                 Sulfuric acid (H2SO4)    l       5.000000     NaN
# 157                                 Tires    t     626.983580     NaN
# 160                           2.5'' balls    t    5977.020000     NaN
# 161                           5.5'' balls    t    2819.390000     NaN
# 162                          Anti-scalant   kg  231239.820000     NaN
# 163                          Caustic soda    t     526.210000     NaN
# 164                               Cyanide    t    2269.570000     NaN
# 167                            Flocculant    t     149.100000     NaN
# 169                                  Lime    t    6390.400000     NaN
# 206                          Anti-scalant    t      35.400000     NaN
# 207                                Carbon    t      60.400000     NaN
# 208                          Caustic soda    t      86.600000     NaN
# 209                        Compressor oil    t       1.500000     NaN
# 210                               Cyanide    t     399.300000     NaN
# 214                            Flocculant    t      46.200000     NaN
# 216                                Grease    t       4.500000     NaN
# 217                         Hydraulic oil    t     200.200000     NaN
# 218                                  Lime    t    5069.300000     NaN
# 219                       Motor/drill oil    t      18.900000     NaN
# 222                        Sulfur dioxide    t     539.000000     NaN
# 223                      Transmission oil    t       8.100000     NaN
# 231             Total sodium cyanide used    t    1955.700000     NaN
#
#               main_id facility_group_id    company_id  \
# 35   QC-MAIN-6dc537e6               NaN  CMP-4a434d72
# 39   QC-MAIN-6dc537e6               NaN  CMP-4a434d72
# 40   QC-MAIN-6dc537e6               NaN  CMP-4a434d72
# 41   QC-MAIN-6dc537e6               NaN  CMP-4a434d72
# 43   QC-MAIN-6dc537e6               NaN  CMP-4a434d72
# 44   QC-MAIN-6dc537e6               NaN  CMP-4a434d72
# 45   QC-MAIN-6dc537e6               NaN  CMP-4a434d72
# 65   ON-MAIN-687b8c8d               NaN  CMP-3a4ccc7f
# 66   ON-MAIN-687b8c8d               NaN  CMP-3a4ccc7f
# 116  ON-MAIN-fefeaee4               NaN  CMP-4a434d72
# 120  ON-MAIN-fefeaee4               NaN  CMP-4a434d72
# 121  ON-MAIN-fefeaee4               NaN  CMP-4a434d72
# 122  ON-MAIN-fefeaee4               NaN  CMP-4a434d72
# 124  ON-MAIN-fefeaee4               NaN  CMP-4a434d72
# 126  ON-MAIN-fefeaee4               NaN  CMP-4a434d72
# 131  BC-MAIN-aa76f6f2               NaN  CMP-d94be190
# 132  BC-MAIN-aa76f6f2               NaN  CMP-d94be190
# 133  BC-MAIN-aa76f6f2               NaN  CMP-d94be190
# 136  BC-MAIN-aa76f6f2               NaN  CMP-d94be190
# 138  BC-MAIN-aa76f6f2               NaN  CMP-d94be190
# 140  BC-MAIN-aa76f6f2               NaN  CMP-d94be190
# 142  BC-MAIN-aa76f6f2               NaN  CMP-d94be190
# 144               NaN      GRP-0d911886  CMP-4a434d72
# 149               NaN      GRP-0d911886  CMP-4a434d72
# 150               NaN      GRP-0d911886  CMP-4a434d72
# 151               NaN      GRP-0d911886  CMP-4a434d72
# 153               NaN      GRP-0d911886  CMP-4a434d72
# 155               NaN      GRP-0d911886  CMP-4a434d72
# 156               NaN      GRP-0d911886  CMP-4a434d72
# 157               NaN      GRP-0d911886  CMP-4a434d72
# 160  ON-MAIN-0aadf28f               NaN  CMP-d94be190
# 161  ON-MAIN-0aadf28f               NaN  CMP-d94be190
# 162  ON-MAIN-0aadf28f               NaN  CMP-d94be190
# 163  ON-MAIN-0aadf28f               NaN  CMP-d94be190
# 164  ON-MAIN-0aadf28f               NaN  CMP-d94be190
# 167  ON-MAIN-0aadf28f               NaN  CMP-d94be190
# 169  ON-MAIN-0aadf28f               NaN  CMP-d94be190
# 206  QC-MAIN-02884fb5               NaN  CMP-3d0a95b7
# 207  QC-MAIN-02884fb5               NaN  CMP-3d0a95b7
# 208  QC-MAIN-02884fb5               NaN  CMP-3d0a95b7
# 209  QC-MAIN-02884fb5               NaN  CMP-3d0a95b7
# 210  QC-MAIN-02884fb5               NaN  CMP-3d0a95b7
# 214  QC-MAIN-02884fb5               NaN  CMP-3d0a95b7
# 216  QC-MAIN-02884fb5               NaN  CMP-3d0a95b7
# 217  QC-MAIN-02884fb5               NaN  CMP-3d0a95b7
# 218  QC-MAIN-02884fb5               NaN  CMP-3d0a95b7
# 219  QC-MAIN-02884fb5               NaN  CMP-3d0a95b7
# 222  QC-MAIN-02884fb5               NaN  CMP-3d0a95b7
# 223  QC-MAIN-02884fb5               NaN  CMP-3d0a95b7
# 231  ON-MAIN-7607a50e               NaN  CMP-3a4ccc7f
#
#                                              source_id        mass_t  \
# 35   SRC_NewmontCorporation_Newmont-2023-Performanc...  27374.000000
# 39   SRC_NewmontCorporation_Newmont-2023-Performanc...   2229.000000
# 40   SRC_NewmontCorporation_Newmont-2023-Performanc...    335.004560
# 41   SRC_NewmontCorporation_Newmont-2023-Performanc...     40.128250
# 43   SRC_NewmontCorporation_Newmont-2023-Performanc...    838.800000
# 44   SRC_NewmontCorporation_Newmont-2023-Performanc...      0.136086
# 45   SRC_NewmontCorporation_Newmont-2023-Performanc...    241.250567
# 65                         SRC_AlamosGoldInc_Data_2023    245.000000
# 66                         SRC_AlamosGoldInc_Data_2023    486.300000
# 116  SRC_NewmontCorporation_Newmont-2023-Performanc...   9417.600000
# 120  SRC_NewmontCorporation_Newmont-2023-Performanc...     68.068000
# 121  SRC_NewmontCorporation_Newmont-2023-Performanc...    924.081000
# 122  SRC_NewmontCorporation_Newmont-2023-Performanc...    296.138480
# 124  SRC_NewmontCorporation_Newmont-2023-Performanc...    390.003000
# 126  SRC_NewmontCorporation_Newmont-2023-Performanc...    100.705343
# 131     SRC_NewGoldInc_2023-New-Gold-ESG-Data-Factbook    980.000000
# 132     SRC_NewGoldInc_2023-New-Gold-ESG-Data-Factbook    179.000000
# 133     SRC_NewGoldInc_2023-New-Gold-ESG-Data-Factbook     38.000000
# 136     SRC_NewGoldInc_2023-New-Gold-ESG-Data-Factbook    192.000000
# 138     SRC_NewGoldInc_2023-New-Gold-ESG-Data-Factbook   2724.000000
# 140     SRC_NewGoldInc_2023-New-Gold-ESG-Data-Factbook     55.000000
# 142     SRC_NewGoldInc_2023-New-Gold-ESG-Data-Factbook    583.000000
# 144  SRC_NewmontCorporation_Newmont-2023-Performanc...  12578.000000
# 149  SRC_NewmontCorporation_Newmont-2023-Performanc...      2.683450
# 150  SRC_NewmontCorporation_Newmont-2023-Performanc...   4346.921000
# 151  SRC_NewmontCorporation_Newmont-2023-Performanc...    545.042080
# 153  SRC_NewmontCorporation_Newmont-2023-Performanc...      0.264250
# 155  SRC_NewmontCorporation_Newmont-2023-Performanc...    734.521000
# 156  SRC_NewmontCorporation_Newmont-2023-Performanc...      0.009200
# 157  SRC_NewmontCorporation_Newmont-2023-Performanc...    626.983580
# 160     SRC_NewGoldInc_2023-New-Gold-ESG-Data-Factbook   5977.020000
# 161     SRC_NewGoldInc_2023-New-Gold-ESG-Data-Factbook   2819.390000
# 162     SRC_NewGoldInc_2023-New-Gold-ESG-Data-Factbook    231.239820
# 163     SRC_NewGoldInc_2023-New-Gold-ESG-Data-Factbook    526.210000
# 164     SRC_NewGoldInc_2023-New-Gold-ESG-Data-Factbook   2269.570000
# 167     SRC_NewGoldInc_2023-New-Gold-ESG-Data-Factbook    149.100000
# 169     SRC_NewGoldInc_2023-New-Gold-ESG-Data-Factbook   6390.400000
# 206  SRC_IAMGOLDCorporation_2023_iamgold-esg-perfor...     35.400000
# 207  SRC_IAMGOLDCorporation_2023_iamgold-esg-perfor...     60.400000
# 208  SRC_IAMGOLDCorporation_2023_iamgold-esg-perfor...     86.600000
# 209  SRC_IAMGOLDCorporation_2023_iamgold-esg-perfor...      1.500000
# 210  SRC_IAMGOLDCorporation_2023_iamgold-esg-perfor...    399.300000
# 214  SRC_IAMGOLDCorporation_2023_iamgold-esg-perfor...     46.200000
# 216  SRC_IAMGOLDCorporation_2023_iamgold-esg-perfor...      4.500000
# 217  SRC_IAMGOLDCorporation_2023_iamgold-esg-perfor...    200.200000
# 218  SRC_IAMGOLDCorporation_2023_iamgold-esg-perfor...   5069.300000
# 219  SRC_IAMGOLDCorporation_2023_iamgold-esg-perfor...     18.900000
# 222  SRC_IAMGOLDCorporation_2023_iamgold-esg-perfor...    539.000000
# 223  SRC_IAMGOLDCorporation_2023_iamgold-esg-perfor...      8.100000
# 231                        SRC_AlamosGoldInc_Data_2023   1955.700000
#
#      mass_source                          mass_note  needs_density
# 35             t                 reported in tonnes          False
# 39             t                 reported in tonnes          False
# 40   L×density→t  kl→L × density kg/L; density=0.88          False
# 41   L×density→t   l→L × density kg/L; density=1.51          False
# 43             t                 reported in tonnes          False
# 44   L×density→t   l→L × density kg/L; density=1.84          False
# 45             t                 reported in tonnes          False
# 65             t                 reported in tonnes          False
# 66             t                 reported in tonnes          False
# 116            t                 reported in tonnes          False
# 120  L×density→t  kl→L × density kg/L; density=1.19          False
# 121            t                 reported in tonnes          False
# 122  L×density→t  kl→L × density kg/L; density=0.88          False
# 124            t                 reported in tonnes          False
# 126            t                 reported in tonnes          False
# 131            t                 reported in tonnes          False
# 132            t                 reported in tonnes          False
# 133         kg→t                            kg/1000          False
# 136            t                 reported in tonnes          False
# 138            t                 reported in tonnes          False
# 140            t                 reported in tonnes          False
# 142            t                 reported in tonnes          False
# 144            t                 reported in tonnes          False
# 149  L×density→t  kl→L × density kg/L; density=1.19          False
# 150            t                 reported in tonnes          False
# 151  L×density→t  kl→L × density kg/L; density=0.88          False
# 153  L×density→t   l→L × density kg/L; density=1.51          False
# 155            t                 reported in tonnes          False
# 156  L×density→t   l→L × density kg/L; density=1.84          False
# 157            t                 reported in tonnes          False
# 160            t                 reported in tonnes          False
# 161            t                 reported in tonnes          False
# 162         kg→t                            kg/1000          False
# 163            t                 reported in tonnes          False
# 164            t                 reported in tonnes          False
# 167            t                 reported in tonnes          False
# 169            t                 reported in tonnes          False
# 206            t                 reported in tonnes          False
# 207            t                 reported in tonnes          False
# 208            t                 reported in tonnes          False
# 209            t                 reported in tonnes          False
# 210            t                 reported in tonnes          False
# 214            t                 reported in tonnes          False
# 216            t                 reported in tonnes          False
# 217            t                 reported in tonnes          False
# 218            t                 reported in tonnes          False
# 219            t                 reported in tonnes          False
# 222            t                 reported in tonnes          False
# 223            t                 reported in tonnes          False
# 231            t                 reported in tonnes          False

# %%
# Check the ones that need density
material_df_sd[material_df_sd['needs_density']]
# Out:
# Empty DataFrame
# Columns: [technosphere_id, year, flow_type, subflow_type, unit, value, comment, main_id, facility_group_id, company_id, source_id, mass_t, mass_source, mass_note, needs_density]
# Index: []

# %% [markdown]
# # Normalization of technosphere and biosphere flows by production values

# %% [markdown]
# ## Check production_data_available

# %%
# To get the reference points available
production_data_available = production_table.groupby(['main_id', 'facility_group_id'], dropna=False).agg(
     commodities=('commodity', lambda x: x.unique().tolist()),
     reference_points=('reference_point', lambda x: x.unique().tolist()),
     material_types=('material_type', lambda x: x.unique().tolist())
 ).reset_index()

# %%
production_data_available
# Out:
#              main_id facility_group_id                  commodities  \
# 0   AB-MAIN-d3a4aba9               NaN             [Cobalt, Nickel]
# 1   BC-MAIN-3bb6b7cd               NaN                       [Zinc]
# 2   BC-MAIN-3f490561               NaN          [Copper, Gold, Ore]
# 3   BC-MAIN-4724f4ba               NaN                       [Gold]
# 4   BC-MAIN-599152a0               NaN  [Copper, Gold, Ore, Silver]
# ..               ...               ...                          ...
# 78               NaN      GRP-14bfbb82                       [Gold]
# 79               NaN      GRP-21eee27d                    [Uranium]
# 80               NaN      GRP-2a663492                       [Iron]
# 81               NaN      GRP-7a9ba115                      [Steel]
# 82               NaN      GRP-dc07540b             [Copper, Nickel]
#
#                              reference_points  \
# 0                    [Refined metal produced]
# 1                    [Refined metal produced]
# 2                     [Usable ore, Crude ore]
# 3   [Total extraction, Crude ore, Usable ore]
# 4   [Usable ore, Crude ore, Total extraction]
# ..                                        ...
# 78  [Crude ore, Total extraction, Usable ore]
# 79                    [Usable ore, Crude ore]
# 80                         [Total extraction]
# 81                   [Refined metal produced]
# 82                   [Refined metal produced]
#
#                                        material_types
# 0                               [Refinery production]
# 1                               [Refinery production]
# 2   [Concentrate, Contained metal in concentrate, ...
# 3   [Ore mined, Ore delivered, Contained metal in ...
# 4   [Concentrate, Contained metal in concentrate, ...
# ..                                                ...
# 78  [Ore milled, Ore mined, Contained metal in con...
# 79    [Contained metal in concentrate, Ore processed]
# 80                                        [Ore mined]
# 81                       [Long/wire rod, bars, slabs]
# 82                              [Refinery production]
#
# [83 rows x 5 columns]

# %%
# Extract all the rows from the production_data_available that have a non NaN main_id
prod_f = production_data_available[production_data_available['main_id'].notna()]
prod_f = prod_f.merge(main_table[['main_id', 'facility_name', 'facility_type', 'mining_processing_type']], on='main_id', how='left').drop_duplicates(subset=['main_id'], keep='first')

# %%
# Extract all the rows from the production_data_available that have a NaN main_id and non NaN facility_group_id
prod_fg = production_data_available[production_data_available['main_id'].isna() & production_data_available['facility_group_id'].notna()]
prod_fg = prod_fg.merge(main_table[['facility_group_id', 'facility_group_name', 'facility_type', 'mining_processing_type']], on='facility_group_id', how='left').drop_duplicates(subset=['facility_group_id'], keep='first')

# %%
# Ensure all desired columns are present in both DataFrames before concatenation
cols_to_keep = ['main_id', 'facility_name', 'facility_group_id', 'facility_group_name', 'facility_type', 'mining_processing_type', 'commodities', 'reference_points', 'material_types']

# Add missing columns to merged_f
for col in cols_to_keep:
    if col not in prod_f.columns:
        prod_f[col] = None
# Add missing columns to merged_fg
for col in cols_to_keep:
    if col not in prod_fg.columns:
        prod_fg[col] = None

# Reorder columns
prod_f = prod_f[cols_to_keep]
prod_fg = prod_fg[cols_to_keep]

# Combine the two results
production_data_available = pd.concat([prod_f, prod_fg])

# %%
production_data_available
# Out:
#              main_id                     facility_name facility_group_id  \
# 0   AB-MAIN-d3a4aba9  The Cobalt Refinery Company Inc.               NaN
# 1   BC-MAIN-3bb6b7cd                             Trail               NaN
# 2   BC-MAIN-3f490561                      Mount Polley               NaN
# 3   BC-MAIN-4724f4ba                               Elk               NaN
# 4   BC-MAIN-599152a0                   Copper Mountain               NaN
# ..               ...                               ...               ...
# 7                NaN                              None      GRP-14bfbb82
# 9                NaN                              None      GRP-21eee27d
# 11               NaN                              None      GRP-2a663492
# 13               NaN                              None      GRP-7a9ba115
# 15               NaN                              None      GRP-dc07540b
#
#           facility_group_name  facility_type    mining_processing_type  \
# 0                        None  manufacturing                  Refinery
# 1                        None  manufacturing  Smelter, refinery, plant
# 2                        None         mining    Open-pit, concentrator
# 3                        None         mining                  Open-pit
# 4                        None         mining    Open-pit, concentrator
# ..                        ...            ...                       ...
# 7       Seabee Gold Operation         mining               Underground
# 9   Key Lake + McArthur River         mining              Concentrator
# 11                        DSO         mining                  Open-pit
# 13                Contrecoeur  manufacturing      Electric arc furnace
# 15          Sudbury Operation         mining              Concentrator
#
#                     commodities                           reference_points  \
# 0              [Cobalt, Nickel]                   [Refined metal produced]
# 1                        [Zinc]                   [Refined metal produced]
# 2           [Copper, Gold, Ore]                    [Usable ore, Crude ore]
# 3                        [Gold]  [Total extraction, Crude ore, Usable ore]
# 4   [Copper, Gold, Ore, Silver]  [Usable ore, Crude ore, Total extraction]
# ..                          ...                                        ...
# 7                        [Gold]  [Crude ore, Total extraction, Usable ore]
# 9                     [Uranium]                    [Usable ore, Crude ore]
# 11                       [Iron]                         [Total extraction]
# 13                      [Steel]                   [Refined metal produced]
# 15             [Copper, Nickel]                   [Refined metal produced]
#
#                                        material_types
# 0                               [Refinery production]
# 1                               [Refinery production]
# 2   [Concentrate, Contained metal in concentrate, ...
# 3   [Ore mined, Ore delivered, Contained metal in ...
# 4   [Concentrate, Contained metal in concentrate, ...
# ..                                                ...
# 7   [Ore milled, Ore mined, Contained metal in con...
# 9     [Contained metal in concentrate, Ore processed]
# 11                                        [Ore mined]
# 13                       [Long/wire rod, bars, slabs]
# 15                              [Refinery production]
#
# [83 rows x 9 columns]

# %%
production_data_available.to_excel(r'data/MetalliCan/production_data_available.xlsx', index=False)

# %%
# def prepare_normalization_data(df):
#     '''
#     Fonction pour nettoyer le DataFrame en vue de la normalisation.
#     Règles :
#     1) Pour chaque (main_id, facility_group_id), garder uniquement les lignes avec data_type = 'Production'.
#     2) Pour chaque (main_id, facility_group_id), garder la ligne avec le reference_point le plus prioritaire.
#        Si plusieurs commodities, les agréger (somme des valeurs, concaténation des commodities).
#     3) Ordre de priorité : 'Crude ore' > 'Total extraction' > 'Intermediate metal produced' > 'Refined metal produced' > 'Usable ore'.
#     Return :
#     cleaned_df : DataFrame nettoyé avec les mêmes colonnes.
#     '''
#     # 1. Filtrer pour ne garder que les lignes avec data_type = 'Production'
#     df_filtered = df[df['data_type'] == 'Production'].copy()
#
#     # 2. Définition des priorités (plus le chiffre est bas, plus la priorité est haute)
#     priority_order = {
#         'Crude ore': 1,
#         'Total extraction': 2,
#         'Intermediate metal produced': 3,
#         'Refined metal produced': 4,
#         'Usable ore': 5
#     }
#
#     # 3. Préparation des clés de groupe
#     df_filtered['facility_group_id'] = df_filtered['facility_group_id'].fillna('NA_ID')
#     id_cols = ['main_id', 'facility_group_id', 'year', 'geography']
#
#     # 4. Créer la colonne de priorité
#     df_filtered['priority'] = df_filtered['reference_point'].map(priority_order).fillna(99)
#
#     # 5. Trier le DataFrame par priorité pour identifier le meilleur niveau
#     df_sorted = df_filtered.sort_values(by=id_cols + ['priority'], ascending=[True] * len(id_cols) + [True])
#
#     # 6. Identification du Meilleur Niveau de Priorité (pour tout le groupe)
#     best_priority_levels = df_sorted.groupby(id_cols)['priority'].min().reset_index().rename(
#         columns={'priority': 'best_priority_level'}
#     )
#
#     # 7. Filtrage pour l'agrégation
#     df_merged = df_sorted.merge(best_priority_levels, on=id_cols, how='left')
#     df_to_sum = df_merged[df_merged['priority'] == df_merged['best_priority_level']].copy()
#
#     # 8. Assurer que les colonnes sont numériques pour la somme
#     df_to_sum['value'] = pd.to_numeric(df_to_sum['value'], errors='coerce')
#     df_to_sum['value_tonnes'] = pd.to_numeric(df_to_sum['value_tonnes'], errors='coerce')
#
#     # 9. Agrégation (Somme des valeurs et concaténation des commodities)
#     aggregated_data = df_to_sum.groupby(id_cols).agg(
#         value_sum=('value', 'sum'),
#         value_tonnes_sum=('value_tonnes', 'sum'),
#         commodity_agg=('commodity', lambda x: ', '.join(sorted(x.unique())))
#     ).reset_index()
#
#     # 10. Extraction des Métadonnées et Fusion
#     metadata_cols = [col for col in df_sorted.columns if col not in ['value', 'value_tonnes', 'priority']]
#     cleaned_df = df_sorted.drop_duplicates(subset=id_cols, keep='first')[metadata_cols]
#
#     # 11. Fusionner les métadonnées avec les valeurs agrégées
#     cleaned_df = cleaned_df.merge(aggregated_data, on=id_cols, how='left')
#
#     # 12. Remplacer les colonnes de valeur et de commodity avec les valeurs agrégées
#     cleaned_df['value'] = cleaned_df['value_sum']
#     cleaned_df['value_tonnes'] = cleaned_df['value_tonnes_sum']
#     cleaned_df['commodity'] = cleaned_df['commodity_agg']
#
#     # 13. Nettoyage Final et Restauration
#     cleaned_df['facility_group_id'] = cleaned_df['facility_group_id'].replace('NA_ID', None)
#
#     # 14. Rétablir l'ordre original des colonnes du DF d'entrée
#     original_cols = df.columns.tolist()
#     cols_to_drop = ['best_priority_level', 'value_sum', 'value_tonnes_sum', 'commodity_agg', 'priority']
#     cleaned_df = cleaned_df.drop(columns=[col for col in cols_to_drop if col in cleaned_df.columns])
#
#     return cleaned_df[original_cols]

# %%
def prepare_normalization_data(df):
    '''
    Fonction pour nettoyer le DataFrame en vue de la normalisation.
    Règles :
    1) Pour chaque (main_id, facility_group_id), garder uniquement les lignes avec data_type = 'Production'.
    2) Pour chaque (main_id, facility_group_id), garder la ligne avec le reference_point le plus prioritaire.
       Si plusieurs commodities, les agréger (somme des valeurs, concaténation des commodities).
    3) Ordre de priorité : 'Crude ore' > 'Total extraction' > 'Intermediate metal produced' > 'Refined metal produced' > 'Usable ore'.
    Return :
    cleaned_df : DataFrame nettoyé avec les mêmes colonnes.
    '''
    # 1. Filtrer pour ne garder que les lignes avec data_type = 'Production'
    df_filtered = df[df['data_type'] == 'Production'].copy()

    # 2. Définition des priorités (plus le chiffre est bas, plus la priorité est haute)
    priority_order = {
        'Crude ore': 1,
        'Total extraction': 2,
        'Intermediate metal produced': 3,
        'Refined metal produced': 4,
        'Usable ore': 5
    }

    # 3. Préparation des clés de groupe : remplir NaN pour main_id et facility_group_id
    df_filtered['main_id'] = df_filtered['main_id'].fillna('NA_ID')
    df_filtered['facility_group_id'] = df_filtered['facility_group_id'].fillna('NA_ID')
    id_cols = ['main_id', 'facility_group_id', 'year', 'geography']

    # 4. Créer la colonne de priorité
    df_filtered['priority'] = df_filtered['reference_point'].map(priority_order).fillna(99)

    # 5. Trier le DataFrame par priorité pour identifier le meilleur niveau
    df_sorted = df_filtered.sort_values(by=id_cols + ['priority'], ascending=[True] * len(id_cols) + [True])

    # 6. Identification du Meilleur Niveau de Priorité (pour tout le groupe)
    best_priority_levels = df_sorted.groupby(id_cols)['priority'].min().reset_index().rename(
        columns={'priority': 'best_priority_level'}
    )

    # 7. Filtrage pour l'agrégation
    df_merged = df_sorted.merge(best_priority_levels, on=id_cols, how='left')
    df_to_sum = df_merged[df_merged['priority'] == df_merged['best_priority_level']].copy()

    # 8. Assurer que les colonnes sont numériques pour la somme
    df_to_sum['value'] = pd.to_numeric(df_to_sum['value'], errors='coerce')
    df_to_sum['value_tonnes'] = pd.to_numeric(df_to_sum['value_tonnes'], errors='coerce')

    # 9. Agrégation (Somme des valeurs et concaténation des commodities)
    aggregated_data = df_to_sum.groupby(id_cols).agg(
        value_sum=('value', 'sum'),
        value_tonnes_sum=('value_tonnes', 'sum'),
        commodity_agg=('commodity', lambda x: ', '.join(sorted(x.unique())))
    ).reset_index()

    # 10. Extraction des Métadonnées et Fusion
    metadata_cols = [col for col in df_sorted.columns if col not in ['value', 'value_tonnes', 'priority']]
    cleaned_df = df_sorted.drop_duplicates(subset=id_cols, keep='first')[metadata_cols]

    # 11. Fusionner les métadonnées avec les valeurs agrégées
    cleaned_df = cleaned_df.merge(aggregated_data, on=id_cols, how='left')

    # 12. Remplacer les colonnes de valeur et de commodity avec les valeurs agrégées
    cleaned_df['value'] = cleaned_df['value_sum']
    cleaned_df['value_tonnes'] = cleaned_df['value_tonnes_sum']
    cleaned_df['commodity'] = cleaned_df['commodity_agg']

    # 13. Nettoyage Final et Restauration
    cleaned_df['main_id'] = cleaned_df['main_id'].replace('NA_ID', None)
    cleaned_df['facility_group_id'] = cleaned_df['facility_group_id'].replace('NA_ID', None)

    # 14. Rétablir l'ordre original des colonnes du DF d'entrée
    original_cols = [col for col in df.columns if col in cleaned_df.columns]
    cols_to_drop = ['best_priority_level', 'value_sum', 'value_tonnes_sum', 'commodity_agg', 'priority']
    cleaned_df = cleaned_df.drop(columns=[col for col in cols_to_drop if col in cleaned_df.columns])

    return cleaned_df[original_cols]

# %%
normalization_production_df = prepare_normalization_data(production_table)
# Let's remove usable ore for main_id = YT-MAIN-44857446
normalization_production_df = normalization_production_df[~((normalization_production_df['main_id'] == 'YT-MAIN-44857446') & (normalization_production_df['reference_point'] == 'Usable ore'))]

# %%
normalization_production_df
# Out:
#                  prod_id  year geography       commodity  \
# 0   PROD-d3a4aba9-2022-1  2022    Canada  Cobalt, Nickel
# 1   PROD-3bb6b7cd-2024-1  2024    Canada            Zinc
# 2   PROD-3f490561-2023-3  2023    Canada             Ore
# 3   PROD-4724f4ba-2024-2  2024    Canada            Gold
# 4   PROD-599152a0-2023-4  2023    Canada             Ore
# ..                   ...   ...       ...             ...
# 73  PROD-f9e41c2a-2023-2  2023    Canada            Gold
# 74  PROD-26b9aaf3-2021-1  2021    Canada           Steel
# 75  PROD-60ba74c4-2022-1  2022    Canada         Uranium
# 76  PROD-91cf5448-2023-2  2023    Canada         Uranium
# 78  PROD-44857446-2024-1  2024    Canada             Ore
#
#                 reference_point                   material_type   data_type  \
# 0        Refined metal produced             Refinery production  Production
# 1        Refined metal produced             Refinery production  Production
# 2                     Crude ore                      Ore milled  Production
# 3                     Crude ore                   Ore delivered  Production
# 4                     Crude ore                      Ore milled  Production
# ..                          ...                             ...         ...
# 73                    Crude ore                      Ore milled  Production
# 74  Intermediate metal produced                  EAF production  Production
# 75                   Usable ore  Contained metal in concentrate  Production
# 76                    Crude ore                   Ore processed  Production
# 78                    Crude ore                       Mill feed  Production
#
#     unit         value  value_tonnes  \
# 0      t  3.563600e+04  3.563600e+04
# 1     kt  2.560000e+02  2.560000e+05
# 2      t  5.948239e+06  5.948239e+06
# 3      t  3.324500e+04  3.324500e+04
# 4      t  6.862152e+06  6.862152e+06
# ..   ...           ...           ...
# 73     t  8.384190e+05  8.384190e+05
# 74    kt  8.280000e+02  8.280000e+05
# 75  mlbs  1.800000e+01  8.164656e+03
# 76  mlbs  9.640129e+01  4.372686e+04
# 78     t  1.273070e+05  1.273070e+05
#
#                                               comment           main_id  \
# 0   Deducted as the difference and verified in the SR  AB-MAIN-d3a4aba9
# 1                                                 NaN  BC-MAIN-3bb6b7cd
# 2                                                 NaN  BC-MAIN-3f490561
# 3                                                 NaN  BC-MAIN-4724f4ba
# 4   "As Copper Mountain was acquired on June 20, 2...  BC-MAIN-599152a0
# ..                                                ...               ...
# 73                                                NaN  QC-MAIN-f9e41c2a
# 74                                                NaN  SK-MAIN-26b9aaf3
# 75  Process the high-grade uranium ore which is su...  SK-MAIN-60ba74c4
# 76  Calculated based on a 15,87% ore grade and 98,...  SK-MAIN-91cf5448
# 78                                                NaN  YT-MAIN-44857446
#
#    facility_group_id    company_id  \
# 0               None  CMP-2ef1f553
# 1               None  CMP-06e20c6e
# 2               None  CMP-0dfcd91e
# 3               None  CMP-d726df1c
# 4               None  CMP-12afc634
# ..               ...           ...
# 73              None  CMP-64d60fd7
# 74              None  CMP-28720916
# 75              None  CMP-43299e17
# 76              None  CMP-cadb529a
# 78              None  CMP-7e360a1f
#
#                                             source_id
# 0   SRC_SherrittInternationalCorporationandGeneral...
# 1         SRC_TeckResourcesLimited_2024_Annual_report
# 2           SRC_ImperialMetalsCorporation_2024-Q4-MDA
# 3   SRC_GoldMountainMiningCorp_gold-mountain-repor...
# 4                         SRC_HudbayMineralsInc_MDA25
# ..                                                ...
# 73                              SRC_EldoradoGold_Data
# 74  SRC_EVRAZNorthAmericaInc_Evraz_Regina_Steel_plant
# 75              SRC_OranoCanadaInc_mining-and-milling
# 76                   SRC_CamecoCorporation_cigar-lake
# 78           SRC_HeclaMiningCompany_TR_Keno_Hill_2024
#
# [78 rows x 15 columns]

# %%
normalization_production_df.to_csv(r'normalization_production_df.csv', index=False)

# %% [markdown]
# ## Work on the production table

# %%
def normalize_by_production(df, production_df, value_col='value', prod_col='value_tonnes', prod_agg='sum'):

    df = df.copy()
    # ensure numeric
    df[value_col] = pd.to_numeric(df[value_col], errors='coerce')
    prod = production_df.copy()
    prod[prod_col] = pd.to_numeric(prod[prod_col], errors='coerce')

    # aggregate to unique per key
    main_prod = (prod.dropna(subset=['main_id'])
                    .groupby('main_id', as_index=False)[prod_col]
                    .agg(prod_agg)
                    .rename(columns={prod_col: 'value_tonnes_main'}))
    group_prod = (prod.dropna(subset=['facility_group_id'])
                     .groupby('facility_group_id', as_index=False)[prod_col]
                     .agg(prod_agg)
                     .rename(columns={prod_col: 'value_tonnes_group'}))

    # safe 1:1 merges
    out = df.merge(main_prod, on='main_id', how='left').merge(group_prod, on='facility_group_id', how='left')

    # prefer main_id match, fallback to facility_group_id
    out['value_tonnes_match'] = out['value_tonnes_main'].combine_first(out['value_tonnes_group'])
    out['value_normalized'] = out[value_col] / out['value_tonnes_match']

    # diagnostics
    out['normalization_key'] = None
    out.loc[out['value_tonnes_main'].notna(), 'normalization_key'] = 'main_id'
    out.loc[out['value_tonnes_main'].isna() & out['value_tonnes_group'].notna(), 'normalization_key'] = 'facility_group_id'
    return out

# %% [markdown]
# ## Technosphere flows

# %%
energy_df_sd_norm = normalize_by_production(energy_df_sd, normalization_production_df, value_col='value_MJ', prod_col='value_tonnes')

# %%
material_df_sd_norm = normalize_by_production(material_df_sd, normalization_production_df, value_col='mass_t', prod_col='value_tonnes')

# %% [markdown]
# ## Biosphere flows

# %%
biosphere_df_norm = normalize_by_production(env_table, normalization_production_df, value_col='value', prod_col='value_tonnes')

# %%
biosphere_df_norm
# Out:
#                     env_id  year compartment_name substance_id flow_direction  \
# 0         npri-1568-2023-1  2023              Air      NA - 16       Emission
# 1         npri-1568-2023-2  2023              Air      NA - 02       Emission
# 2         npri-1568-2023-3  2023              Air     630-08-0       Emission
# 3         npri-1568-2023-4  2023              Air      NA - 04       Emission
# 4         npri-1568-2023-5  2023              Air      NA - 05       Emission
# ...                    ...   ...              ...          ...            ...
# 5119   ENV-9de9bb0d-2023-8  2023              Air     NA - M16       Emission
# 5120   ENV-9de9bb0d-2023-9  2023            Water    7732-18-5     Withdrawal
# 5121  ENV-9de9bb0d-2023-10  2023            Water    7732-18-5     Withdrawal
# 5122  ENV-9de9bb0d-2023-11  2023            Water    7732-18-5    Consumption
# 5123  ENV-9de9bb0d-2023-12  2023            Water    7732-18-5     Discharged
#
#       release_pathway    unit         value comment           main_id  \
# 0     Stack Emissions  tonnes       0.63600     NaN  ON-MAIN-1f126a43
# 1     Stack Emissions      kg       0.11600     NaN  ON-MAIN-1f126a43
# 2     Stack Emissions  tonnes      76.20800     NaN  ON-MAIN-1f126a43
# 3     Stack Emissions  tonnes       0.00105     NaN  ON-MAIN-1f126a43
# 4     Stack Emissions      kg       0.18000     NaN  ON-MAIN-1f126a43
# ...               ...     ...           ...     ...               ...
# 5119              NaN  tonnes       0.99000     NaN  QC-MAIN-9de9bb0d
# 5120              NaN      m3  168115.00000     NaN  QC-MAIN-9de9bb0d
# 5121              NaN      m3  168115.00000     NaN  QC-MAIN-9de9bb0d
# 5122              NaN      m3   82144.00000     NaN  QC-MAIN-9de9bb0d
# 5123              NaN      m3  536420.00000     NaN  QC-MAIN-9de9bb0d
#
#      facility_group_id    company_id  \
# 0                  NaN           NaN
# 1                  NaN           NaN
# 2                  NaN           NaN
# 3                  NaN           NaN
# 4                  NaN           NaN
# ...                ...           ...
# 5119               NaN  CMP-3d2c4955
# 5120               NaN  CMP-3d2c4955
# 5121               NaN  CMP-3d2c4955
# 5122               NaN  CMP-3d2c4955
# 5123               NaN  CMP-3d2c4955
#
#                                               source_id  value_tonnes_main  \
# 0     https://www.canada.ca/en/environment-climate-c...           441588.0
# 1     https://www.canada.ca/en/environment-climate-c...           441588.0
# 2     https://www.canada.ca/en/environment-climate-c...           441588.0
# 3     https://www.canada.ca/en/environment-climate-c...           441588.0
# 4     https://www.canada.ca/en/environment-climate-c...           441588.0
# ...                                                 ...                ...
# 5119       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables           191148.0
# 5120       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables           191148.0
# 5121       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables           191148.0
# 5122       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables           191148.0
# 5123       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables           191148.0
#
#       value_tonnes_group  value_tonnes_match  value_normalized  \
# 0                    NaN            441588.0      1.440257e-06
# 1                    NaN            441588.0      2.626883e-07
# 2                    NaN            441588.0      1.725772e-04
# 3                    NaN            441588.0      2.377782e-09
# 4                    NaN            441588.0      4.076198e-07
# ...                  ...                 ...               ...
# 5119                 NaN            191148.0      5.179233e-06
# 5120                 NaN            191148.0      8.795017e-01
# 5121                 NaN            191148.0      8.795017e-01
# 5122                 NaN            191148.0      4.297403e-01
# 5123                 NaN            191148.0      2.806307e+00
#
#      normalization_key
# 0              main_id
# 1              main_id
# 2              main_id
# 3              main_id
# 4              main_id
# ...                ...
# 5119           main_id
# 5120           main_id
# 5121           main_id
# 5122           main_id
# 5123           main_id
#
# [5124 rows x 18 columns]

# %%
biosphere_df_norm['unit_normalized'] = biosphere_df_norm['unit'] + '/t'

# %% [markdown]
# # Export normalized technosphere and biosphere flows

# %%
energy_df_sd_norm.to_excel(r'data/MetalliCan/energy_df_sd_norm.xlsx', index=False)
material_df_sd_norm.to_excel(r'data/MetalliCan/material_df_sd_norm.xlsx', index=False)
biosphere_df_norm.to_excel(r'data/MetalliCan/biosphere_df_norm.xlsx', index=False)
