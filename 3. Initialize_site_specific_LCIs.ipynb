# %%
import pandas as pd
import os
import sys

# %% [markdown]
# # Import cleaned MetalliCan data

# %%
from some_functions import get_info_for_ids

# %%
substances_table = pd.read_csv(r'C:\Users\mp_ma\OneDrive - polymtl\POST_DOC\CODE\metallican_db\database\CSV\substances_table.csv')

# %%
main_table = pd.read_csv(r'C:\Users\mp_ma\OneDrive - polymtl\POST_DOC\CODE\metallican_db\database\CSV\main_table.csv')
ta_table = pd.read_csv(r'C:\Users\mp_ma\OneDrive - polymtl\POST_DOC\CODE\metallican_db\database\CSV\tech_attributes_table.csv')
energy_table = pd.read_excel(r'data/MetalliCan/cleaned_data/energy_df_sd_norm.xlsx')
material_table = pd.read_excel(r'data/MetalliCan/cleaned_data/material_df_sd_norm.xlsx')
biosphere_table = pd.read_excel(r'data/MetalliCan/cleaned_data/biosphere_df_norm.xlsx')
land_table = pd.read_excel(r'data/MetalliCan/cleaned_data/land_table_mining.xlsx')

# %%
biosphere_table.merge(substances_table[['substance_id', 'substance_name']], how='left', on='substance_id')
# Out:
#                     env_id  year compartment_name substance_id flow_direction  \
# 0         npri-1568-2023-1  2023              Air      NA - 16       Emission
# 1         npri-1568-2023-2  2023              Air      NA - 02       Emission
# 2         npri-1568-2023-3  2023              Air     630-08-0       Emission
# 3         npri-1568-2023-4  2023              Air      NA - 04       Emission
# 4         npri-1568-2023-5  2023              Air      NA - 05       Emission
# ...                    ...   ...              ...          ...            ...
# 5119   ENV-9de9bb0d-2023-8  2023              Air     NA - M16       Emission
# 5120   ENV-9de9bb0d-2023-9  2023            Water    7732-18-5     Withdrawal
# 5121  ENV-9de9bb0d-2023-10  2023            Water    7732-18-5     Withdrawal
# 5122  ENV-9de9bb0d-2023-11  2023            Water    7732-18-5    Consumption
# 5123  ENV-9de9bb0d-2023-12  2023            Water    7732-18-5     Discharged
#
# ...

# %% [markdown]
# # Separating when we have only biosphere flows or both technosphere and biosphere flows

# %%
ids_energy = set(energy_table[['main_id', 'facility_group_id']].apply(tuple, axis=1))
ids_material = set(material_table[['main_id', 'facility_group_id']].apply(tuple, axis=1))
ids_biosphere = set(biosphere_table[['main_id', 'facility_group_id']].apply(tuple, axis=1))
ids_land = set(land_table[['main_id', 'facility_group_id']].apply(tuple, axis=1))

# %%
best_ids = ids_energy & ids_material & ids_biosphere & ids_land
best_ids
# Out:
# {('BC-MAIN-aa76f6f2', nan),
#  ('ON-MAIN-0aadf28f', nan),
#  ('ON-MAIN-7607a50e', nan),
#  ('ON-MAIN-fefeaee4', nan),
#  ('QC-MAIN-02884fb5', nan),
#  ('QC-MAIN-6dc537e6', nan)}

# %%
second_best_ids = ids_energy & ids_material & ids_biosphere
second_best_ids
# Out:
# {('BC-MAIN-aa76f6f2', nan),
#  ('ON-MAIN-0aadf28f', nan),
#  ('ON-MAIN-687b8c8d', nan),
#  ('ON-MAIN-7607a50e', nan),
#  ('ON-MAIN-fefeaee4', nan),
#  ('QC-MAIN-02884fb5', nan),
#  ('QC-MAIN-6dc537e6', nan),
#  (nan, 'GRP-0d911886')}

# %%
second_best_ids - best_ids
# Out:
# {('ON-MAIN-687b8c8d', nan), (nan, 'GRP-0d911886')}

# %%
main_df = get_info_for_ids(main_table, best_ids)
main_df = main_df[['main_id', 'facility_name', 'province', 'mining_processing_type', 'commodities']]
main_df
# Out:
#               main_id   facility_name          province  \
# 14   ON-MAIN-7607a50e  Young-Davidson           Ontario
# 127  QC-MAIN-02884fb5  Westwood-Doyon            Quebec
# 160  BC-MAIN-aa76f6f2       New Afton  British Columbia
# 161  ON-MAIN-0aadf28f     Rainy River           Ontario
# 167  ON-MAIN-fefeaee4     Musselwhite           Ontario
# 170  QC-MAIN-6dc537e6        Éléonore            Quebec
#
#                   mining_processing_type           commodities
# 14             Underground, concentrator                  Gold
# 127            Underground, concentrator          Gold, silver
# 160            Underground, concentrator  Gold, copper, silver
# 161  Open-pit, underground, concentrator          Gold, silver
# 167            Underground, concentrator          Gold, silver
# 170            Underground, concentrator                  Gold

# %%
energy_df = get_info_for_ids(energy_table, best_ids)
energy_df = energy_df[['main_id', 'facility_name', 'commodities', 'subflow_type', 'value_normalized']]
energy_df['unit'] = 'MJ'
energy_df
# Out:
#               main_id   facility_name           commodities  \
# 34   QC-MAIN-6dc537e6        Éléonore                  Gold
# 35   QC-MAIN-6dc537e6        Éléonore                  Gold
# 36   QC-MAIN-6dc537e6        Éléonore                  Gold
# 37   QC-MAIN-6dc537e6        Éléonore                  Gold
# 38   QC-MAIN-6dc537e6        Éléonore                  Gold
# 39   QC-MAIN-6dc537e6        Éléonore                  Gold
# 40   QC-MAIN-6dc537e6        Éléonore                  Gold
# 105  ON-MAIN-fefeaee4     Musselwhite          Gold, silver
# 106  ON-MAIN-fefeaee4     Musselwhite          Gold, silver
# 107  ON-MAIN-fefeaee4     Musselwhite          Gold, silver
# 108  ON-MAIN-fefeaee4     Musselwhite          Gold, silver
# 109  ON-MAIN-fefeaee4     Musselwhite          Gold, silver
# 110  ON-MAIN-fefeaee4     Musselwhite          Gold, silver
# 111  ON-MAIN-fefeaee4     Musselwhite          Gold, silver
# 112  ON-MAIN-fefeaee4     Musselwhite          Gold, silver
# ...

# %%
material_df = get_info_for_ids(material_table, best_ids)
material_df = material_df[['main_id', 'facility_name', 'commodities', 'subflow_type', 'value_normalized']]
material_df['unit'] = 't'
material_df
# Out:
#              main_id   facility_name           commodities  \
# 0   QC-MAIN-6dc537e6        Éléonore                  Gold
# 1   QC-MAIN-6dc537e6        Éléonore                  Gold
# 2   QC-MAIN-6dc537e6        Éléonore                  Gold
# 3   QC-MAIN-6dc537e6        Éléonore                  Gold
# 4   QC-MAIN-6dc537e6        Éléonore                  Gold
# 5   QC-MAIN-6dc537e6        Éléonore                  Gold
# 6   QC-MAIN-6dc537e6        Éléonore                  Gold
# 9   ON-MAIN-fefeaee4     Musselwhite          Gold, silver
# 10  ON-MAIN-fefeaee4     Musselwhite          Gold, silver
# 11  ON-MAIN-fefeaee4     Musselwhite          Gold, silver
# 12  ON-MAIN-fefeaee4     Musselwhite          Gold, silver
# 13  ON-MAIN-fefeaee4     Musselwhite          Gold, silver
# 14  ON-MAIN-fefeaee4     Musselwhite          Gold, silver
# 15  BC-MAIN-aa76f6f2       New Afton  Gold, copper, silver
# 16  BC-MAIN-aa76f6f2       New Afton  Gold, copper, silver
# ...

# %%
biosphere_df = get_info_for_ids(biosphere_table, best_ids)

# %%
biosphere_df = biosphere_df[['main_id', 'facility_name', 'substance_name', 'commodities', 'subflow_type', 'value_normalized']]

# %%
biosphere_df
# Out:
#                     env_id  year compartment_name substance_id  \
# 51       npri-26132-2023-1  2023              Air      NA - 01
# 53       npri-26132-2023-2  2023              Air      NA - 02
# 55       npri-26132-2023-3  2023              Air      NA - 03
# 56       npri-26132-2023-4  2023              Air      75-15-0
# 58       npri-26132-2023-5  2023              Air     630-08-0
# ...                    ...   ...              ...          ...
# 5033  ENV-fefeaee4-2023-13  2023              Air     NA - M16
# 5034  ENV-fefeaee4-2023-14  2023            Water    7732-18-5
# 5035  ENV-fefeaee4-2023-15  2023            Water    7732-18-5
# 5036  ENV-fefeaee4-2023-16  2023            Water    7732-18-5
# 5037  ENV-fefeaee4-2023-17  2023             Land          NaN
#
#                      flow_direction  release_pathway    unit         value  \
# 51                         Emission  Stack Emissions  tonnes  7.000000e-06
# ...

# %% [markdown]
# # Map MetalliCan flows to EI and RI flows

# %% [markdown]
# # LCI creation

# %% [markdown]
# ## Create LCI activities

# %%
def build_lci_entries(df, facility_col, site_id_col, db_name='MetalliCan'):
    lcis = {}
    for _, row in df.iterrows():
        name = f"{row['mining_processing_type']} {row['commodity']} {row['facility_type']}, {row[facility_col]}".strip()
        location = CA_provinces.get(row['province'], 'CA')
        site_id = row[site_id_col]
        key = (db_name, name)
        lcis[key] = {
            'name': name,
            'unit': 'kilogram',
            'location': location,
            'exchanges': [],
            'type': 'process',
            'description': f"This is a site-specific LCI drawn from the MetalliCan database. Site ID is {site_id}."
        }
    return lcis

# %%
# Create LCI metadata from both facility and facility_group
facility_lcis = build_lci_entries(facility_df, "facility_name", "main_id")
facility_group_lcis = build_lci_entries(facility_group_df, "facility_group_name", "facility_group_id")

# %%
metallican_db.write(facility_lcis)
# Out:
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 07/29/2025 14:41:53
#   Finished: 07/29/2025 14:41:53
#   Total time elapsed: 00:00:00
#   CPU %: 104.20
#   Memory %: 1.16

# %%
metallican_db.write(facility_group_lcis)
# Out:
# Writing activities to SQLite3 database:
# 0% [########] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 07/29/2025 14:41:21
#   Finished: 07/29/2025 14:41:21
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 1.16

# %% [markdown]
# ## Populate the LCIs with MetalliCan entries

# %%
def populate_lci_with_exchanges(lcis, data_table, mapping_table, site_id_column='site_id'):
    """
    Populates each LCI entry in `lcis` with exchanges from `data_table`, using `mapping_table`.

    Parameters:
        lcis (dict): Dictionary of LCI entries keyed by (database_name, process_name).
        data_table (pd.DataFrame): Raw data table with flow values and site IDs.
        mapping_table (pd.DataFrame): Table with mapping: internal name -> (db, code, unit, type).
        site_id_column (str): Column in data_table that links to each site ID.
    """
    for key, process in lcis.items():
        # Extract site ID from the process description or a metadata field you added earlier
        site_id = None
        if 'description' in process and 'Site ID is ' in process['description']:
            site_id = process['description'].split('Site ID is ')[-1].strip('. ')

        if site_id is None:
            continue

        # Filter data for this specific site
        site_data = data_table[data_table[site_id_column] == site_id]

        # Build exchanges
        for _, row in site_data.iterrows():
            internal_name = row['flow_name']  # or column that matches your mapping
            amount = row['amount']

            # Find mapping
            try:
                mapped = mapping_table[mapping_table['internal_name'] == internal_name].iloc[0]
            except IndexError:
                continue  # skip if not found

            exchange = {
                'input': (mapped['database'], mapped['code']),
                'amount': amount,
                'unit': mapped['unit'],
                'type': mapped['flow_type']
            }

            process['exchanges'].append(exchange)
