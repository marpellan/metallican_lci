# %%
import pandas as pd

# %% [markdown]
# # Import cleaned MetalliCan data

# %%
from core.data_manipulations import get_info_for_ids, merge_main_and_group

# %%
# Raw MetalliCan tables
main_table = pd.read_csv(r'C:\Users\mp_ma\OneDrive - polymtl\POST_DOC\CODE\metallican_db\database\CSV\main_table.csv')
substances_table = pd.read_csv(r'C:\Users\mp_ma\OneDrive - polymtl\POST_DOC\CODE\metallican_db\database\CSV\substances_table.csv')

# %%
# Pre-processed production table
production_table = pd.read_excel(r'data/MetalliCan/sites_for_lci.xlsx', sheet_name='prod_data')

# %%
def build_activity_name(row):
    # ---- 1️⃣ Déterminer le type d’opération ----
    mpt = str(row.get("mining_processing_type", "")).lower()
    parts = []

    if "open-pit" in mpt and "underground" in mpt:
        parts.append("OP and UG mining")
    elif "open-pit" in mpt:
        parts.append("OP mining")
    elif "underground" in mpt:
        parts.append("UG mining")

    if "concentrator" in mpt:
        parts.append("and beneficiation")

    op = " ".join(parts)

    # ---- 2️⃣ Déterminer les commodities ----
    commodities = []
    for col in production_table.columns:
        if col.endswith("_t") and col != "ore_processed_t":
            if pd.notna(row[col]) and row[col] != 0:
                commodities.append(col.replace("_t", ""))
    commodities_str = " and ".join(commodities)

    # ---- 3️⃣ Choisir le nom de site ----
    facility = row.get("facility_name") if pd.notna(row.get("facility_name")) else row.get("facility_group_name", "")

    # ---- 4️⃣ Construire la chaîne finale ----
    if commodities_str and op and facility:
        return f"{commodities_str}, {op}, {facility}"
    elif commodities_str and op:
        return f"{commodities_str}, {op}"
    elif commodities_str and facility:
        return f"{commodities_str}, {facility}"
    else:
        return None

# %%
production_table["activity_name_lci"] = production_table.apply(build_activity_name, axis=1)

# %%
# Normalized MetalliCan tables
energy_table = pd.read_csv(r'data/MetalliCan/cleaned_data/energy_df.csv')
material_table = pd.read_csv(r'data/MetalliCan/cleaned_data/material_df.csv')
biosphere_table = pd.read_csv(r'data/MetalliCan/cleaned_data/biosphere_df.csv')
#land_table = pd.read_csv(r'data/MetalliCan/cleaned_data/land_table_mining.xlsx')

# %%
biosphere_table = biosphere_table.merge(substances_table[['substance_id', 'substance_name']], how='left', on='substance_id')

# %%
# Removing rows with value_normalized is NaN and divide it by 10e6 to have values per kg
energy_table = energy_table[~energy_table['value_normalized'].isna()]
energy_table['value_normalized'] = energy_table['value_normalized'] / 1e6

# %%
material_table = material_table[~material_table['value_normalized'].isna()]
material_table['value_normalized'] = material_table['value_normalized'] / 1e6

# %%
# Removing rows with value_normalized is NaN and divide it by 10e6 to have values per kg
biosphere_table = biosphere_table[~biosphere_table['value_normalized'].isna()]
biosphere_table['value_normalized'] = biosphere_table['value_normalized'] / 1e6

# %% [markdown]
# # Keeping only relevant columns

# %%
energy_df = energy_table[['main_id', 'facility_group_id', 'subflow_type', 'value_normalized']]
energy_df['unit'] = 'MJ'
# Out:
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_10740\335451116.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df['unit'] = 'MJ'

# %%
material_df = material_table[['main_id', 'facility_group_id', 'subflow_type', 'value_normalized']]
material_df['unit'] = 't'
# Out:
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_10740\2691601530.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   material_df['unit'] = 't'

# %%
# Put energy_df and material_df together in a single dataframe and add the province from the main_df to specify electricity location later
technosphere_df = pd.concat([energy_df, material_df], ignore_index=True)
technosphere_df = technosphere_df.merge(production_table[['main_id', 'facility_group_id', 'province']], on=['main_id', 'facility_group_id'], how='left')
technosphere_df
# Out:
#               main_id facility_group_id               subflow_type  \
# 0    BC-MAIN-857b7b89               NaN                  Acetylene
# 1    BC-MAIN-857b7b89               NaN              Aviation fuel
# 2    BC-MAIN-857b7b89               NaN                     Diesel
# 3    BC-MAIN-857b7b89               NaN                   Gasoline
# 4    BC-MAIN-857b7b89               NaN                    Propane
# ..                ...               ...                        ...
# 210  QC-MAIN-02884fb5               NaN                       Lime
# 211  QC-MAIN-02884fb5               NaN            Motor/drill oil
# 212  QC-MAIN-02884fb5               NaN             Sulfur dioxide
# 213  QC-MAIN-02884fb5               NaN           Transmission oil
# 214  ON-MAIN-7607a50e               NaN  Total sodium cyanide used
#
#      value_normalized unit          province
# 0        1.112991e-07   MJ  British Columbia
# 1        4.378079e-04   MJ  British Columbia
# 2        1.729171e-03   MJ  British Columbia
# 3        8.173765e-05   MJ  British Columbia
# 4        2.534400e-04   MJ  British Columbia
# ..                ...  ...               ...
# 210      4.902611e-09    t            Quebec
# 211      1.827853e-11    t            Quebec
# 212      5.212766e-10    t            Quebec
# 213      7.833656e-12    t            Quebec
# 214      6.795233e-10    t           Ontario
#
# [215 rows x 6 columns]

# %%
biosphere_df = biosphere_table[['main_id', 'facility_group_id', 'substance_name', 'unit', 'value_normalized']]
biosphere_df = biosphere_df.merge(production_table[['main_id', 'facility_group_id', 'province']], on=['main_id', 'facility_group_id'], how='left')
biosphere_df
# Out:
#                main_id facility_group_id                 substance_name  \
# 0     ON-MAIN-1f126a43               NaN                Ammonia (total)
# 1     ON-MAIN-1f126a43               NaN    Arsenic (and its compounds)
# 2     ON-MAIN-1f126a43               NaN                Carbon monoxide
# 3     ON-MAIN-1f126a43               NaN   Chromium (and its compounds)
# 4     ON-MAIN-1f126a43               NaN     Cobalt (and its compounds)
# ...                ...               ...                            ...
# 1284               NaN      GRP-a13779f8  Manganese (and its compounds)
# 1285               NaN      GRP-a13779f8       Zinc (and its compounds)
# 1286               NaN      GRP-a13779f8       Zinc (and its compounds)
# 1287               NaN      GRP-a13779f8                Ammonia (total)
# 1288               NaN      GRP-a13779f8                Ammonia (total)
#
#         unit  value_normalized  province
# 0     tonnes      1.440257e-12   Ontario
# 1         kg      2.626883e-13   Ontario
# 2     tonnes      1.725772e-10   Ontario
# 3     tonnes      2.377782e-15   Ontario
# 4         kg      4.076198e-13   Ontario
# ...      ...               ...       ...
# 1284  tonnes      0.000000e+00  Manitoba
# 1285  tonnes      9.152123e-14  Manitoba
# 1286  tonnes      0.000000e+00  Manitoba
# 1287  tonnes      9.866373e-11  Manitoba
# 1288  tonnes      0.000000e+00  Manitoba
#
# [1289 rows x 6 columns]

# %% [markdown]
# # Map MetalliCan flows to EI and RI flows

# %%
from core.conversion_functions import map_technosphere_to_ecoinvent, map_biosphere_to_ecoinvent
from core.constants import CA_provinces

# %% [markdown]
# ## Technosphere flows

# %%
mapping_technosphere = pd.read_excel(r'data/Mappings/MAPPINGS_RI.xlsx', sheet_name='technosphere')

# %%
mapping_technosphere
# Out:
#         Type                            MetalliCan MetalliCan_unit  \
# 0     Energy                             Acetylene              MJ
# 1     Energy                      Ammonium nitrate              MJ
# 2     Energy                                  ANFO              MJ
# 3     Energy                         Aviation fuel              MJ
# 4     Energy                             Biodiesel              MJ
# ..       ...                                   ...             ...
# 70  Material                 Sulfuric acid (H2SO4)               t
# 71  Material                                 Tires               t
# 72  Material  Total blasting agents used e.g. ANFO               t
# 73  Material             Total sodium cyanide used               t
# 74  Material                      Transmission oil               t
#
#       DB_to_map Reference product                                Flow name  \
# 0   Regioinvent         acetylene         consumption market for acetylene
# 1   Regioinvent  ammonium nitrate  consumption market for ammonium nitrate
# 2   Regioinvent  explosive, tovex  consumption market for explosive, tovex
# 3   Regioinvent          kerosene          consumption market for kerosene
# 4   Regioinvent            biogas            consumption market for biogas
# ..          ...               ...                                      ...
# 70  Regioinvent     sulfuric acid     consumption market for sulfuric acid
# 71  Regioinvent  synthetic rubber  consumption market for synthetic rubber
# 72  Regioinvent  explosive, tovex  consumption market for explosive, tovex
# 73  Regioinvent    sodium cyanide    consumption market for sodium cyanide
# 74  Regioinvent   lubricating oil   consumption market for lubricating oil
#
#    Location         Unit                                            Comment
# 0        CA     kilogram                                                NaN
# 1        CA     kilogram  Precursor to ANFO; not burned on its own, usua...
# 2        CA     kilogram        Or consumption market for ammonium nitrate?
# 3        CA     kilogram                                                NaN
# 4        CA  cubic meter                       No biodiesel inventory found
# ..      ...          ...                                                ...
# 70       CA     kilogram                                                NaN
# 71       CA     kilogram                                                NaN
# 72       CA     kilogram        Or consumption market for ammonium nitrate?
# 73       CA     kilogram                           Same as Lai et al (2025)
# 74       CA     kilogram                                                NaN
#
# [75 rows x 9 columns]

# %%
# Apply the function
mapped_technosphere_df = map_technosphere_to_ecoinvent(technosphere_df, mapping_technosphere, CA_provinces)
# Out:
# Index(['main_id', 'facility_group_id', 'subflow_type', 'value_normalized',
#        'unit', 'province', 'Type', 'MetalliCan', 'MetalliCan_unit',
#        'DB_to_map', 'Reference product', 'Flow name', 'Location', 'Unit',
#        'Comment'],
#       dtype='object')
# ⚠️ Les flux suivants n'ont pas trouvé de correspondance dans Ecoinvent:
#  - Energy use
#  - Other
# ⚠️ Pas de conversion définie pour MJ → kilogram (flux: Acetylene)
# ⚠️ Pas de conversion définie pour MJ → kilogram (flux: Used oil)
# ⚠️ Pas de conversion définie pour MJ → kg (flux: Electricity consumption|Generated on-site)
# ℹ️ Conversion explosive par défaut utilisée (3.0 MJ/kg) pour: Explosives
# ℹ️ Conversion explosive par défaut utilisée (3.0 MJ/kg) pour: Explosives
# ℹ️ Conversion explosive par défaut utilisée (3.0 MJ/kg) pour: Explosives
# ℹ️ Conversion explosive par défaut utilisée (3.0 MJ/kg) pour: Explosives
# ⚠️ Pas de conversion définie pour MJ → kg (flux: Electricity consumption|Generated on-site)
# ⚠️ Pas de conversion définie pour MJ → kg (flux: Electricity consumption|Generated on-site)
# ℹ️ Conversion explosive par défaut utilisée (3.0 MJ/kg) pour: Explosives
# ℹ️ Conversion explosive par défaut utilisée (3.0 MJ/kg) pour: Explosives
# ⚠️ Pas de conversion définie pour MJ → kg (flux: Electricity consumption|Non-renewable electricity use)
# ⚠️ Pas de conversion définie pour MJ → kilogram (flux: Non-renewable fuel use)
# ⚠️ Pas de conversion définie pour MJ → kg (flux: Electricity consumption|Generated on-site)
# ℹ️ Conversion explosive par défaut utilisée (3.0 MJ/kg) pour: Explosives
# ℹ️ Conversion explosive par défaut utilisée (3.0 MJ/kg) pour: Explosives
# ⚠️ Pas de conversion définie pour MJ → kg (flux: Electricity consumption|Generated on-site)
# ⚠️ Pas de conversion définie pour MJ → kilogram (flux: Petrol)
# ⚠️ Pas de conversion définie pour MJ → kilogram (flux: LPG|Mobile equipment)
# ⚠️ Pas de conversion définie pour MJ → kilogram (flux: LPG|Stationary equipment)
# ℹ️ Conversion explosive par défaut utilisée (3.0 MJ/kg) pour: Explosives
# ℹ️ Conversion explosive par défaut utilisée (3.0 MJ/kg) pour: Explosives
# ℹ️ Conversion explosive par défaut utilisée (3.0 MJ/kg) pour: Explosives
# ℹ️ Conversion explosive par défaut utilisée (3.0 MJ/kg) pour: Explosives
# ⚠️ Pas de conversion définie pour MJ → kg (flux: Electricity consumption|Generated on-site)
# ℹ️ Conversion explosive par défaut utilisée (3.0 MJ/kg) pour: Explosives
# ℹ️ Conversion explosive par défaut utilisée (3.0 MJ/kg) pour: Explosives
# ⚠️ Pas de conversion définie pour MJ → kilogram (flux: Lubricating Oils & Greases)
# ⚠️ Pas de conversion définie pour MJ → kg (flux: Electricity consumption|Generated on-site)
# ℹ️ Conversion explosive par défaut utilisée (3.0 MJ/kg) pour: Explosives
# ℹ️ Conversion explosive par défaut utilisée (3.0 MJ/kg) pour: Explosives
# ⚠️ Pas de conversion définie pour MJ → kg (flux: Electricity consumption|Generated on-site)
# ⚠️ Pas de conversion définie pour MJ → kg (flux: Electricity consumption|Generated on-site)
# ℹ️ Conversion explosive par défaut utilisée (3.0 MJ/kg) pour: Explosives
# ℹ️ Conversion explosive par défaut utilisée (3.0 MJ/kg) pour: Explosives
# ⚠️ Pas de conversion définie pour MJ → kg (flux: Electricity consumption|Generated on-site)
# ℹ️ Conversion explosive par défaut utilisée (3.0 MJ/kg) pour: Explosives
# ℹ️ Conversion explosive par défaut utilisée (3.0 MJ/kg) pour: Explosives
# ⚠️ Pas de conversion définie pour MJ → kg (flux: Electricity consumption|Generated on-site)
# ⚠️ Pas de conversion définie pour MJ → kilogram (flux: Acetylene)
# ⚠️ Pas de conversion définie pour MJ → kilogram (flux: LPG)
# ⚠️ Pas de conversion définie pour MJ → kilogram (flux: Oil)
# ⚠️ Pas de conversion définie pour MJ → kg (flux: Electricity consumption|Generated on-site)
# ⚠️ Pas de conversion définie pour MJ → kilogram (flux: Ammonium nitrate)
# ⚠️ Pas de conversion définie pour MJ → kilogram (flux: Dynamite)
# ℹ️ Conversion explosive par défaut utilisée (3.0 MJ/kg) pour: Explosives
# ℹ️ Conversion explosive par défaut utilisée (3.0 MJ/kg) pour: Explosives
# ⚠️ Pas de conversion définie pour MJ → kg (flux: Electricity consumption|Generated on-site)

# %%
# Drop rows where ecoinvent_flow_name is "No mapping" and Amount is NaN for now
mapped_technosphere_df = mapped_technosphere_df[
    (mapped_technosphere_df["Activity"] != "No mapping") &
    (~mapped_technosphere_df["Amount"].isna())
]

# %%
mapped_technosphere_df = mapped_technosphere_df[['main_id', 'facility_group_id', 'Amount', 'Activity', 'Product', 'Unit', 'Location', 'Database']]

# %%
mapped_technosphere_df
# Out:
#               main_id facility_group_id        Amount  \
# 0    BC-MAIN-857b7b89               NaN  1.112991e-07
# 1    BC-MAIN-857b7b89               NaN  1.015796e-05
# 2    BC-MAIN-857b7b89               NaN  4.021329e-05
# 3    BC-MAIN-857b7b89               NaN  1.840938e-06
# 4    BC-MAIN-857b7b89               NaN  5.462069e-06
# ..                ...               ...           ...
# 229  QC-MAIN-02884fb5               NaN  4.902611e-06
# 230  QC-MAIN-02884fb5               NaN  1.827853e-08
# 231  QC-MAIN-02884fb5               NaN  5.212766e-07
# 232  QC-MAIN-02884fb5               NaN  7.833656e-09
# 233  ON-MAIN-7607a50e               NaN  6.795233e-07
#
#                                           Activity                 Product  \
# 0                 consumption market for acetylene               acetylene
# 1                  consumption market for kerosene                kerosene
# 2                    consumption market for diesel                  diesel
# 3                    consumption market for diesel                  diesel
# 4                   consumption market for propane                 propane
# ..                                             ...                     ...
# 229                    consumption market for lime                    lime
# 230         consumption market for lubricating oil         lubricating oil
# 231  consumption market for sulfur dioxide, liquid  sulfur dioxide, liquid
# 232         consumption market for lubricating oil         lubricating oil
# 233          consumption market for sodium cyanide          sodium cyanide
#
#          Unit Location     Database
# 0    kilogram       CA  Regioinvent
# 1    kilogram       CA  Regioinvent
# 2          kg       CA  Regioinvent
# 3          kg       CA  Regioinvent
# 4    kilogram       CA  Regioinvent
# ..        ...      ...          ...
# 229  kilogram       CA  Regioinvent
# 230  kilogram       CA  Regioinvent
# 231  kilogram       CA  Regioinvent
# 232  kilogram       CA  Regioinvent
# 233  kilogram       CA  Regioinvent
#
# [232 rows x 8 columns]

# %% [markdown]
# ## Biosphere flows mapping

# %%
mapping_biosphere = pd.read_excel(r'data/Mappings/MAPPINGS_RI.xlsx', sheet_name='biosphere')
mapping_biosphere
# Out:
#                     Type substance_id                  substance_name  \
# 0    Environmental_flows      95-63-6          1,2,4-Trimethylbenzene
# 1    Environmental_flows      57-97-6  7,12-Dimethylbenz[a]anthracene
# 2    Environmental_flows     194-59-2        7H-Dibenzo[c,g]carbazole
# 3    Environmental_flows      83-32-9                    Acenaphthene
# 4    Environmental_flows      83-32-9                    Acenaphthene
# ..                   ...          ...                             ...
# 413  Environmental_flows      NA - 14        Zinc (and its compounds)
# 414  Environmental_flows      NA - 14        Zinc (and its compounds)
# 415  Environmental_flows      NA - 14        Zinc (and its compounds)
# 416  Environmental_flows      NA - 14        Zinc (and its compounds)
# 417  Environmental_flows      NA - 14        Zinc (and its compounds)
#
#     compartment_name     release_pathway flow_direction MetalliCan_unit  \
# 0                Air               Other       Emission          tonnes
# 1                Air  Fugitive Emissions       Emission             NaN
# 2                Air     Stack Emissions       Emission              kg
# 3                Air  Fugitive Emissions       Emission              kg
# 4                Air     Stack Emissions       Emission              kg
# ..               ...                 ...            ...             ...
# 413              Air  Storage / Handling       Emission          tonnes
# 414             Land               Other       Emission          tonnes
# 415             Land              Spills       Emission          tonnes
# 416            Water    Direct Discharge       Emission          tonnes
# 417            Water           Waterbody       Emission          tonnes
#
#       DB_to_map                              Flow name  \
# 0    biosphere3                 2,2,4-Trimethylpentane
# 1    biosphere3                  Dibenz(a,h)anthracene
# 2    biosphere3  PAH, polycyclic aromatic hydrocarbons
# 3    biosphere3                           Acenaphthene
# 4    biosphere3                           Acenaphthene
# ..          ...                                    ...
# 413  biosphere3                                Zinc II
# 414  biosphere3                                Zinc II
# 415  biosphere3                                Zinc II
# 416  biosphere3                                Zinc II
# 417  biosphere3                                Zinc II
#
#                Compartments      Unit                                Comment
# 0                  ('air',)  kilogram                                    NaN
# 1                  ('air',)  kilogram                                    NaN
# 2                  ('air',)  kilogram  Polycyclic Aromatic Hydrocarbon (PAH)
# 3                  ('air',)  kilogram                                    NaN
# 4                  ('air',)  kilogram                                    NaN
# ..                      ...       ...                                    ...
# 413                ('air',)  kilogram                                    NaN
# 414  ('soil', 'industrial')  kilogram                                    NaN
# 415  ('soil', 'industrial')  kilogram                                    NaN
# 416              ('water',)  kilogram                                    NaN
# 417              ('water',)  kilogram                                    NaN
#
# [418 rows x 12 columns]

# %%
biosphere_df
# Out:
#                main_id facility_group_id                 substance_name  \
# 0     ON-MAIN-1f126a43               NaN                Ammonia (total)
# 1     ON-MAIN-1f126a43               NaN    Arsenic (and its compounds)
# 2     ON-MAIN-1f126a43               NaN                Carbon monoxide
# 3     ON-MAIN-1f126a43               NaN   Chromium (and its compounds)
# 4     ON-MAIN-1f126a43               NaN     Cobalt (and its compounds)
# ...                ...               ...                            ...
# 1284               NaN      GRP-a13779f8  Manganese (and its compounds)
# 1285               NaN      GRP-a13779f8       Zinc (and its compounds)
# 1286               NaN      GRP-a13779f8       Zinc (and its compounds)
# 1287               NaN      GRP-a13779f8                Ammonia (total)
# 1288               NaN      GRP-a13779f8                Ammonia (total)
#
#         unit  value_normalized  province
# 0     tonnes      1.440257e-12   Ontario
# 1         kg      2.626883e-13   Ontario
# 2     tonnes      1.725772e-10   Ontario
# 3     tonnes      2.377782e-15   Ontario
# 4         kg      4.076198e-13   Ontario
# ...      ...               ...       ...
# 1284  tonnes      0.000000e+00  Manitoba
# 1285  tonnes      9.152123e-14  Manitoba
# 1286  tonnes      0.000000e+00  Manitoba
# 1287  tonnes      9.866373e-11  Manitoba
# 1288  tonnes      0.000000e+00  Manitoba
#
# [1289 rows x 6 columns]

# %%
mapped_biosphere_df = map_biosphere_to_ecoinvent(biosphere_df, mapping_biosphere, CA_provinces)
# Out:
# Index(['main_id', 'facility_group_id', 'substance_name', 'unit',
#        'value_normalized', 'province', 'Type', 'substance_id',
#        'compartment_name', 'release_pathway', 'flow_direction',
#        'MetalliCan_unit', 'DB_to_map', 'Flow name', 'Compartments', 'Unit',
#        'Comment'],
#       dtype='object')
# ⚠️ 6 biosphere flows could not be mapped to Ecoinvent:
#    - 1-Nitropyrene
#    - Quinoline
#    - Ethylene glycol
#    - Water
#    - nan
#    - PFCs
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for kg → nan (flow: 1-Nitropyrene)
# ⚠️ No conversion defined for g teq → kilogram (flow: Dioxins and furans - total)
# ⚠️ No conversion defined for g teq → kilogram (flow: Dioxins and furans - total)
# ⚠️ No conversion defined for grams → kilogram (flow: Hexachlorobenzene)
# ⚠️ No conversion defined for grams → kilogram (flow: Hexachlorobenzene)
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for kg → nan (flow: Quinoline)
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for g teq → kilogram (flow: Dioxins and furans - total)
# ⚠️ No conversion defined for g teq → kilogram (flow: Dioxins and furans - total)
# ⚠️ No conversion defined for grams → kilogram (flow: Hexachlorobenzene)
# ⚠️ No conversion defined for grams → kilogram (flow: Hexachlorobenzene)
# ⚠️ No conversion defined for g teq → kilogram (flow: Dioxins and furans - total)
# ⚠️ No conversion defined for g teq → kilogram (flow: Dioxins and furans - total)
# ⚠️ No conversion defined for grams → kilogram (flow: Hexachlorobenzene)
# ⚠️ No conversion defined for grams → kilogram (flow: Hexachlorobenzene)
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → nan (flow: Ethylene glycol)
# ⚠️ No conversion defined for tonnes → nan (flow: Ethylene glycol)
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: CO2)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: CH4)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: CO2)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: N2O)
# ⚠️ No conversion defined for tco2eq → nan (flow: PFCs)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: CO2)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: CH4)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: CO2)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: N2O)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tonnes → nan (flow: Ethylene glycol)
# ⚠️ No conversion defined for tonnes → nan (flow: Ethylene glycol)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ✅ Mapped 7051 biosphere flows (68 unique flows).

# %%
mapped_biosphere_df
# Out:
#                main_id facility_group_id   substance_name  province  \
# 0     ON-MAIN-1f126a43               NaN  Ammonia (total)   Ontario
# 1     ON-MAIN-1f126a43               NaN  Ammonia (total)   Ontario
# 2     ON-MAIN-1f126a43               NaN  Ammonia (total)   Ontario
# 3     ON-MAIN-1f126a43               NaN  Ammonia (total)   Ontario
# 4     ON-MAIN-1f126a43               NaN  Ammonia (total)   Ontario
# ...                ...               ...              ...       ...
# 7046               NaN      GRP-a13779f8  Ammonia (total)  Manitoba
# 7047               NaN      GRP-a13779f8  Ammonia (total)  Manitoba
# 7048               NaN      GRP-a13779f8  Ammonia (total)  Manitoba
# 7049               NaN      GRP-a13779f8  Ammonia (total)  Manitoba
# 7050               NaN      GRP-a13779f8  Ammonia (total)  Manitoba
#
#            Flow Name                                 Compartments  \
# 0     Ammonia, CA-ON  ('air', 'low population density long term')
# 1     Ammonia, CA-ON  ('air', 'low population density long term')
# 2     Ammonia, CA-ON  ('air', 'low population density long term')
# 3            Ammonia                       ('soil', 'industrial')
# 4           Ammonium                                   ('water',)
# ...              ...                                          ...
# 7046  Ammonia, CA-MB  ('air', 'low population density long term')
# 7047  Ammonia, CA-MB  ('air', 'low population density long term')
# 7048  Ammonia, CA-MB  ('air', 'low population density long term')
# 7049         Ammonia                       ('soil', 'industrial')
# 7050        Ammonium                                   ('water',)
#
#             Amount    unit      Unit                      Database
# 0     1.440257e-09  tonnes  kilogram  biosphere3_spatialized_flows
# 1     1.440257e-09  tonnes  kilogram  biosphere3_spatialized_flows
# 2     1.440257e-09  tonnes  kilogram  biosphere3_spatialized_flows
# 3     1.440257e-09  tonnes  kilogram                    biosphere3
# 4     1.440257e-09  tonnes  kilogram                    biosphere3
# ...            ...     ...       ...                           ...
# 7046  0.000000e+00  tonnes  kilogram  biosphere3_spatialized_flows
# 7047  0.000000e+00  tonnes  kilogram  biosphere3_spatialized_flows
# 7048  0.000000e+00  tonnes  kilogram  biosphere3_spatialized_flows
# 7049  0.000000e+00  tonnes  kilogram                    biosphere3
# 7050  0.000000e+00  tonnes  kilogram                    biosphere3
#
# [7051 rows x 10 columns]

# %%
# Drop rows where ecoinvent_flow_name is "No mapping" and Amount is NaN for now
mapped_biosphere_df = mapped_biosphere_df[
    (mapped_biosphere_df["Flow Name"] != "No mapping") &
    (~mapped_biosphere_df["Amount"].isna())
]

# %%
mapped_biosphere_df
# Out:
#                main_id facility_group_id   substance_name  province  \
# 0     ON-MAIN-1f126a43               NaN  Ammonia (total)   Ontario
# 1     ON-MAIN-1f126a43               NaN  Ammonia (total)   Ontario
# 2     ON-MAIN-1f126a43               NaN  Ammonia (total)   Ontario
# 3     ON-MAIN-1f126a43               NaN  Ammonia (total)   Ontario
# 4     ON-MAIN-1f126a43               NaN  Ammonia (total)   Ontario
# ...                ...               ...              ...       ...
# 7046               NaN      GRP-a13779f8  Ammonia (total)  Manitoba
# 7047               NaN      GRP-a13779f8  Ammonia (total)  Manitoba
# 7048               NaN      GRP-a13779f8  Ammonia (total)  Manitoba
# 7049               NaN      GRP-a13779f8  Ammonia (total)  Manitoba
# 7050               NaN      GRP-a13779f8  Ammonia (total)  Manitoba
#
#            Flow Name                                 Compartments  \
# 0     Ammonia, CA-ON  ('air', 'low population density long term')
# 1     Ammonia, CA-ON  ('air', 'low population density long term')
# 2     Ammonia, CA-ON  ('air', 'low population density long term')
# 3            Ammonia                       ('soil', 'industrial')
# 4           Ammonium                                   ('water',)
# ...              ...                                          ...
# 7046  Ammonia, CA-MB  ('air', 'low population density long term')
# 7047  Ammonia, CA-MB  ('air', 'low population density long term')
# 7048  Ammonia, CA-MB  ('air', 'low population density long term')
# 7049         Ammonia                       ('soil', 'industrial')
# 7050        Ammonium                                   ('water',)
#
#             Amount    unit      Unit                      Database
# 0     1.440257e-09  tonnes  kilogram  biosphere3_spatialized_flows
# 1     1.440257e-09  tonnes  kilogram  biosphere3_spatialized_flows
# 2     1.440257e-09  tonnes  kilogram  biosphere3_spatialized_flows
# 3     1.440257e-09  tonnes  kilogram                    biosphere3
# 4     1.440257e-09  tonnes  kilogram                    biosphere3
# ...            ...     ...       ...                           ...
# 7046  0.000000e+00  tonnes  kilogram  biosphere3_spatialized_flows
# 7047  0.000000e+00  tonnes  kilogram  biosphere3_spatialized_flows
# 7048  0.000000e+00  tonnes  kilogram  biosphere3_spatialized_flows
# 7049  0.000000e+00  tonnes  kilogram                    biosphere3
# 7050  0.000000e+00  tonnes  kilogram                    biosphere3
#
# [6928 rows x 10 columns]

# %%
mapped_biosphere_df = mapped_biosphere_df[['main_id', 'facility_group_id', 'Amount', 'Unit', 'Flow Name', 'Compartments', 'Database']]

# %%
production_table
# Out:
#              main_id facility_group_id              facility_name  \
# 0   BC-MAIN-857b7b89               NaN                  Brucejack
# 1   QC-MAIN-e7e6a960               NaN          Canadian Malartic
# 2   NL-MAIN-dd723db4               NaN                 Carol Lake
# 3   QC-MAIN-b86f7d07               NaN               Casa Berardi
# 4   BC-MAIN-599152a0               NaN            Copper Mountain
# 5   ON-MAIN-aeafbb59               NaN                Detour Lake
# 6   ON-MAIN-cb85213a               NaN                Eagle River
# 7   QC-MAIN-6dc537e6               NaN                   Éléonore
# 8   BC-MAIN-6b4800fe               NaN                  Gibraltar
# 9   QC-MAIN-c0660aec               NaN                     Goldex
# 10  ON-MAIN-6e9be24e               NaN           Hemlo (Williams)
# 11  ON-MAIN-687b8c8d               NaN                     Island
# 12  YT-MAIN-44857446               NaN  Keno Hill Silver District
# 13  QC-MAIN-9de9bb0d               NaN                      Kiena
# 14  ON-MAIN-a3c56a83               NaN               Lac des Iles
# 15  QC-MAIN-f9e41c2a               NaN                    Lamaque
# 16  QC-MAIN-e51eda66               NaN                    LaRonde
# 17  ON-MAIN-1f126a43               NaN                    Macassa
# 18  NU-MAIN-8b0264c9               NaN                  Meliadine
# 19  BC-MAIN-ed23117f               NaN             Mount Milligan
# 20  ON-MAIN-fefeaee4               NaN                Musselwhite
# 21  BC-MAIN-aa76f6f2               NaN                  New Afton
# 22  ON-MAIN-0aadf28f               NaN                Rainy River
# 23  BC-MAIN-8eb8be0d               NaN                  Red Chris
# 24  ON-MAIN-7f050560               NaN                   Red Lake
# 25  NL-MAIN-b64bae7a               NaN                     Scully
# 26  QC-MAIN-02884fb5               NaN             Westwood-Doyon
# 27  ON-MAIN-7607a50e               NaN             Young-Davidson
# 28               NaN      GRP-0a2c0d69                        NaN
# 29               NaN      GRP-0d911886                        NaN
# 30               NaN      GRP-147b3123                        NaN
# 31               NaN      GRP-14bfbb82                        NaN
# 32               NaN      GRP-a13779f8                        NaN
#
#       facility_group_name                   province facility_type  \
# 0                     NaN           British Columbia        mining
# 1                     NaN                     Quebec        mining
# 2                     NaN  Newfoundland and Labrador        mining
# 3                     NaN                     Quebec        mining
# 4                     NaN           British Columbia        mining
# 5                     NaN                    Ontario        mining
# 6                     NaN                    Ontario        mining
# 7                     NaN                     Quebec        mining
# 8                     NaN           British Columbia        mining
# 9                     NaN                     Quebec        mining
# 10                    NaN                    Ontario        mining
# 11                    NaN                    Ontario        mining
# 12                    NaN                      Yukon        mining
# 13                    NaN                     Quebec        mining
# 14                    NaN                    Ontario        mining
# 15                    NaN                     Quebec        mining
# 16                    NaN                     Quebec        mining
# 17                    NaN                    Ontario        mining
# 18                    NaN                    Nunavut        mining
# 19                    NaN           British Columbia        mining
# 20                    NaN                    Ontario        mining
# 21                    NaN           British Columbia        mining
# 22                    NaN                    Ontario        mining
# 23                    NaN           British Columbia        mining
# 24                    NaN                    Ontario        mining
# 25                    NaN  Newfoundland and Labrador        mining
# 26                    NaN                     Quebec        mining
# 27                    NaN                    Ontario        mining
# 28     Meadowbank complex                    Nunavut        mining
# 29      Porcupine complex                    Ontario        mining
# 30      Timmins Operation                    Ontario        mining
# 31  Seabee Gold Operation               Saskatchewan        mining
# 32              Snow Lake                   Manitoba        mining
#
#                  mining_processing_type  \
# 0             Underground, concentrator
# 1                Open-pit, concentrator
# 2                Open-pit, concentrator
# 3   Open-pit, underground, concentrator
# 4                Open-pit, concentrator
# 5                Open-pit, concentrator
# 6             Underground, concentrator
# 7             Underground, concentrator
# 8                Open-pit, concentrator
# 9             Underground, concentrator
# 10  Open-pit, underground, concentrator
# 11            Underground, concentrator
# 12            Underground, concentrator
# 13               Open-pit, concentrator
# 14  Open-pit, underground, concentrator
# 15            Underground, concentrator
# 16            Underground, concentrator
# 17            Underground, concentrator
# 18  Open-pit, underground, concentrator
# 19               Open-pit, concentrator
# 20            Underground, concentrator
# 21            Underground, concentrator
# 22  Open-pit, underground, concentrator
# 23               Open-pit, concentrator
# 24            Underground, concentrator
# 25               Open-pit, concentrator
# 26            Underground, concentrator
# 27            Underground, concentrator
# 28                Open-pit, underground
# 29                Open-pit, underground
# 30            Underground, concentrator
# 31            Underground, concentrator
# 32            Underground, concentrator
#
#                                           commodities  ore_processed_t  \
# 0                                        Gold, silver     1.660000e+05
# 1                                        Gold, silver     1.959493e+07
# 2                                                Iron     1.788000e+07
# 3                                        Gold, silver     1.361450e+06
# 4                                Copper, gold, silver     6.862152e+06
# 5                                                Gold     2.543485e+07
# 6                                                Gold     2.226270e+05
# 7                                                Gold     1.661000e+06
# 8                          Copper, molybdenum, silver     3.000000e+07
# 9                                        Gold, silver     2.886927e+06
# 10                                               Gold     1.266009e+06
# 11                                               Gold     4.390080e+05
# 12                                 Silver, zinc, lead     1.273070e+05
# 13                                               Gold     1.911480e+05
# 14  Platinum group metals, gold, nickel, copper, c...     1.024800e+07
# 15                                               Gold     8.384190e+05
# 16                Gold, zinc, copper, silver, cadmium     2.658396e+06
# 17                                       Gold, silver     4.415880e+05
# 18                                               Gold     1.918143e+06
# 19                               Copper, gold, silver     2.168000e+07
# 20                                       Gold, silver     1.028000e+06
# 21                               Gold, copper, silver     3.065000e+06
# 22                                       Gold, silver     8.764000e+06
# 23                               Gold, copper, silver     1.139000e+06
# 24                                       Gold, silver     8.410000e+05
# 25                                               Iron     3.560000e+06
# 26                                       Gold, silver     1.034000e+06
# 27                                               Gold     2.878047e+06
# 28                                               Gold     3.842649e+06
# 29                                               Gold     2.911000e+06
# 30                                               Gold     1.574000e+06
# 31                                               Gold     1.220000e+05
# 32                         Gold, zinc, copper, silver     1.562479e+06
#
#          Au_t       Ag_t          Cu_t  Ni_t        Mo_t          Zn_t  \
# 0    0.902002        NaN           NaN   NaN         NaN           NaN
# 1   21.294700   9.642085           NaN   NaN         NaN           NaN
# 2         NaN        NaN           NaN   NaN         NaN           NaN
# 3    2.693563   0.752705           NaN   NaN         NaN           NaN
# 4    0.275204   6.789334  19050.000000   NaN         NaN           NaN
# 5   21.070942   2.457177           NaN   NaN         NaN           NaN
# 6    2.720530        NaN           NaN   NaN         NaN           NaN
# 7    7.216012        NaN           NaN   NaN         NaN           NaN
# 8         NaN        NaN  55610.379200   NaN  545.217584           NaN
# 9    4.385051   0.062207           NaN   NaN         NaN     39.036758
# 10   4.386993        NaN           NaN   NaN         NaN           NaN
# 11   4.087000        NaN           NaN   NaN         NaN           NaN
# 12        NaN  46.735404           NaN   NaN         NaN   1339.000000
# 13   1.105325        NaN           NaN   NaN         NaN           NaN
# 14        NaN        NaN           NaN   NaN         NaN           NaN
# 15   5.507466        NaN           NaN   NaN         NaN           NaN
# 16   9.537841  18.288858   7702.438517   NaN         NaN   2577.960375
# 17   7.108238        NaN           NaN   NaN         NaN           NaN
# 18  11.326060   0.839794           NaN   NaN         NaN           NaN
# 19   4.802100        NaN  28060.108304   NaN         NaN           NaN
# 20   5.598630        NaN           NaN   NaN         NaN           NaN
# 21   2.097402        NaN  21500.260800   NaN         NaN           NaN
# 22   7.892358        NaN           NaN   NaN         NaN           NaN
# 23   0.155518        NaN   3628.736000   NaN         NaN           NaN
# 24   3.505364        NaN           NaN   NaN         NaN           NaN
# 25        NaN        NaN           NaN   NaN         NaN           NaN
# 26   2.892625        NaN           NaN   NaN         NaN           NaN
# 27   5.757258        NaN           NaN   NaN         NaN           NaN
# 28  13.426312   3.887938           NaN   NaN         NaN           NaN
# 29   8.086910        NaN           NaN   NaN         NaN           NaN
# 30   4.133655   0.497656           NaN   NaN         NaN           NaN
# 31   1.205478        NaN           NaN   NaN         NaN           NaN
# 32   5.827645  26.491566  12154.000000   NaN         NaN  34642.000000
#
#       Pb_t       Fe_t       Pt_t  \
# 0      NaN        NaN        NaN
# 1      NaN        NaN        NaN
# 2      NaN  4497892.8        NaN
# 3      NaN        NaN        NaN
# 4      NaN        NaN        NaN
# 5      NaN        NaN        NaN
# 6      NaN        NaN        NaN
# 7      NaN        NaN        NaN
# 8      NaN        NaN        NaN
# 9      NaN        NaN        NaN
# 10     NaN        NaN        NaN
# 11     NaN        NaN        NaN
# 12  1225.0        NaN        NaN
# 13     NaN        NaN        NaN
# 14     NaN        NaN  38.319512
# 15     NaN        NaN        NaN
# 16     NaN        NaN        NaN
# 17     NaN        NaN        NaN
# 18     NaN        NaN        NaN
# 19     NaN        NaN        NaN
# 20     NaN        NaN        NaN
# 21     NaN        NaN        NaN
# 22     NaN        NaN        NaN
# 23     NaN        NaN        NaN
# 24     NaN        NaN        NaN
# 25     NaN   895553.6        NaN
# 26     NaN        NaN        NaN
# 27     NaN        NaN        NaN
# 28     NaN        NaN        NaN
# 29     NaN        NaN        NaN
# 30     NaN        NaN        NaN
# 31     NaN        NaN        NaN
# 32     NaN        NaN        NaN
#
#                                     activity_name_lci
# 0          Au, UG mining and beneficiation, Brucejack
# 1   Au and Ag, OP mining and beneficiation, Canadi...
# 2         Fe, OP mining and beneficiation, Carol Lake
# 3   Au and Ag, OP and UG mining and beneficiation,...
# 4   Au and Ag and Cu, OP mining and beneficiation,...
# 5   Au and Ag, OP mining and beneficiation, Detour...
# 6        Au, UG mining and beneficiation, Eagle River
# 7           Au, UG mining and beneficiation, Éléonore
# 8   Cu and Mo, OP mining and beneficiation, Gibraltar
# 9   Au and Ag and Zn, UG mining and beneficiation,...
# 10  Au, OP and UG mining and beneficiation, Hemlo ...
# 11            Au, UG mining and beneficiation, Island
# 12  Ag and Zn and Pb, UG mining and beneficiation,...
# 13             Au, OP mining and beneficiation, Kiena
# 14  Pt, OP and UG mining and beneficiation, Lac de...
# 15           Au, UG mining and beneficiation, Lamaque
# 16  Au and Ag and Cu and Zn, UG mining and benefic...
# 17           Au, UG mining and beneficiation, Macassa
# 18  Au and Ag, OP and UG mining and beneficiation,...
# 19  Au and Cu, OP mining and beneficiation, Mount ...
# 20       Au, UG mining and beneficiation, Musselwhite
# 21  Au and Cu, UG mining and beneficiation, New Afton
# 22  Au, OP and UG mining and beneficiation, Rainy ...
# 23  Au and Cu, OP mining and beneficiation, Red Chris
# 24          Au, UG mining and beneficiation, Red Lake
# 25            Fe, OP mining and beneficiation, Scully
# 26    Au, UG mining and beneficiation, Westwood-Doyon
# 27    Au, UG mining and beneficiation, Young-Davidson
# 28    Au and Ag, OP and UG mining, Meadowbank complex
# 29            Au, OP and UG mining, Porcupine complex
# 30  Au and Ag, UG mining and beneficiation, Timmin...
# 31  Au, UG mining and beneficiation, Seabee Gold O...
# 32  Au and Ag and Cu and Zn, UG mining and benefic...

# %% [markdown]
# # LCI creation

# %%
mapped_technosphere_df.to_csv(r'data/MetalliCan/data_for_lci_initialization/mapped_technosphere_df.csv', index=False)
mapped_biosphere_df.to_csv(r'data/MetalliCan/data_for_lci_initialization/mapped_biosphere_df.csv', index=False)
production_table.to_csv(r'data/MetalliCan/data_for_lci_initialization/production_table.csv', index=False)

# %%
def add_site_id(
    df: pd.DataFrame,
    main_col: str = "main_id",
    group_col: str = "facility_group_id",
    out_col: str = "site_id",
) -> pd.DataFrame:
    """
    Create a single canonical site_id column:
    - Prefer `main_id` when present, otherwise `facility_group_id`
    - Normalize to uppercase, strip whitespace
    """
    # copy to avoid mutating caller
    df = df.copy()

    # make sure both columns exist even if missing
    if main_col not in df.columns:
        df[main_col] = pd.NA
    if group_col not in df.columns:
        df[group_col] = pd.NA

    # unify true missing values
    df[main_col] = df[main_col].replace({None: pd.NA, "": pd.NA, "nan": pd.NA})
    df[group_col] = df[group_col].replace({None: pd.NA, "": pd.NA, "nan": pd.NA})

    # prefer main_id, fallback to facility_group_id
    site = df[main_col].fillna(df[group_col])

    # normalize: string, strip, uppercase
    site = site.astype(str).str.strip()
    site = site.mask(site.eq("nan"), pd.NA)  # undo string "nan"
    site = site.fillna(pd.NA)
    #site = site.str.upper()

    df[out_col] = site
    return df

# %%
mapped_technosphere_df = add_site_id(mapped_technosphere_df)
mapped_biosphere_df = add_site_id(mapped_biosphere_df)
production_table = add_site_id(production_table)

# %%
from core.lci_database_builder import LCIDatabaseBuilder

# %%
# Step 1 — initialize the builder
builder = LCIDatabaseBuilder(
    db_name='metallican_lci_',
    project_name='metallican'
)
# Out:
# 📂 Active Brightway project: metallican
# ✅ Using existing database 'metallican_lci_'.

# %%
# Step 2 — create the activity shells from the main dataframe
builder.build_lci_entries(df=production_table)
print(len(builder.lcis))
# Out:
# ✅ Created 33 base LCI activities with production exchanges.
# 33

# %%
# Step 3a — Populate with the technosphere exchanges
builder.populate_technosphere_exchanges(technosphere_df=mapped_technosphere_df)
# Out:
# ⚙️ Populating technosphere exchanges
#    ✅ Cached 218246 activities from Regioinvent
#    ✅ Cached 20769 activities from ecoinvent-3.10-cutoff regionalized
# ✅ Added 232 technosphere exchanges.

# %%
# Step 3b — Populate with the biosphere exchanges
builder.populate_biosphere_exchanges(biosphere_df=mapped_biosphere_df)
# Out:
# 🌱 Populating biosphere exchanges
#    ✅ Cached 110559 biosphere flows from biosphere3_spatialized_flows
#    ✅ Cached 4362 biosphere flows from biosphere3
# ✅ Added 6891 biosphere exchanges.
# ⚠️ 37 biosphere flows could not be matched:
#    - ('soil',) (emission, biosphere3)
#    - ('soil',) (emission, biosphere3)
#    - ('soil',) (emission, biosphere3)
#    - ('soil',) (emission, biosphere3)
#    - ('soil',) (emission, biosphere3)
#    - ('soil',) (emission, biosphere3)
#    - ('soil',) (emission, biosphere3)
#    - ('soil',) (emission, biosphere3)
#    - ('soil',) (emission, biosphere3)
#    - ('soil',) (emission, biosphere3)
#    ... and 27 more.

# %%
# Step 4 - Consolidate duplicate flows
builder.consolidate_exchanges()
# Out:
# 🧮 Consolidation: 7156 → 768 exchanges (summed duplicates).

# %%
builder.write_to_database()
# Out:
# 🧱 Writing 33 activities to database 'metallican_lci_'...
# ♻️ Overwriting existing activity: Au, UG mining and beneficiation, Brucejack
# C:\Users\mp_ma\anaconda3\envs\lca\lib\site-packages\bw2data\backends\peewee\database.py:328: UserWarning:
#             Please use `del databases['metallican_lci_']` instead.
#             Otherwise, the metadata and database get out of sync.
#             Call `.delete(warn=False)` to skip this message in the future.
#
#   warnings.warn(MESSAGE.format(self.name), UserWarning)
# ✅ Database 'metallican_lci_' processed successfully with 33 activities.
