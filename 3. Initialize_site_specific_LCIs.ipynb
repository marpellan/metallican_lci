# %%
import pandas as pd
import plotly.graph_objects as go

# %% [markdown]
# # Plot selected sites

# %%
production_df = pd.read_excel(r'data/MetalliCan/sites_for_lci.xlsx', sheet_name='prod_data')

# %%
import plotly.graph_objects as go
import pandas as pd
import numpy as np
import plotly.express as px

def plot_sankey_hierarchy(
        df,
        columns,
        html_output="sankey_generic.html",
        undefined_label="Undefined"
    ):
    """
    Create a Sankey diagram from an arbitrary list of hierarchical columns.
    Missing values are replaced with distinct undefined labels per level
    but DISPLAYED as 'Undefined'.

    Colors are assigned automatically per level.
    """

    df = df.copy()

    # ---------------------------------------------------------------
    # 1. Create DISTINCT undefined names internally per level
    # ---------------------------------------------------------------
    undefined_values = {
        col: f"{undefined_label}_{i+1}"
        for i, col in enumerate(columns)
    }

    for col in columns:
        df[col] = df[col].fillna(undefined_values[col])

    # ---------------------------------------------------------------
    # 2. Build levels and internal labels
    # ---------------------------------------------------------------
    levels = [df[col].unique().tolist() for col in columns]
    internal_labels = [lab for lvl in levels for lab in lvl]

    idx = {label: i for i, label in enumerate(internal_labels)}

    # ---------------------------------------------------------------
    # 3. Build displayed labels (merge all Undefined_* into "Undefined")
    # ---------------------------------------------------------------
    display_labels = [
        undefined_label if lab.startswith(undefined_label + "_") else lab
        for lab in internal_labels
    ]

    # ---------------------------------------------------------------
    # 4. Build links between each level
    # ---------------------------------------------------------------
    sources, targets, values = [], [], []

    for i in range(len(columns) - 1):
        c1, c2 = columns[i], columns[i + 1]
        pairs = df[[c1, c2]].drop_duplicates()

        for _, row in pairs.iterrows():
            v1, v2 = row[c1], row[c2]
            count = df[(df[c1] == v1) & (df[c2] == v2)].shape[0]

            sources.append(idx[v1])
            targets.append(idx[v2])
            values.append(count)

    # ---------------------------------------------------------------
    # 5. Horizontal node positions
    # ---------------------------------------------------------------
    num_levels = len(levels)
    x_positions = []
    for i, lvl in enumerate(levels):
        x_positions.extend([i / (num_levels - 1)] * len(lvl))

    # ---------------------------------------------------------------
    # 6. Generate colors per level
    # ---------------------------------------------------------------
    color_scales = [
        px.colors.qualitative.Plotly,
        px.colors.qualitative.Set2,
        px.colors.qualitative.Pastel,
        px.colors.qualitative.Set3,
        px.colors.qualitative.Bold,
        px.colors.qualitative.Prism
    ]

    node_colors = []
    for lvl_index, lvl in enumerate(levels):
        palette = color_scales[lvl_index % len(color_scales)]
        for j, _ in enumerate(lvl):
            node_colors.append(palette[j % len(palette)])

    # ---------------------------------------------------------------
    # 7. Build the Sankey diagram
    # ---------------------------------------------------------------
    fig = go.Figure(go.Sankey(
        arrangement="snap",
        node=dict(
            label=display_labels,
            pad=10,
            thickness=18,
            color=node_colors,
            x=x_positions,
            y=None
        ),
        link=dict(
            source=sources,
            target=targets,
            value=values,
            color="rgba(140,140,140,0.35)"
        )
    ))

    # ---------------------------------------------------------------
    # 8. Layout (white background, black text)
    # ---------------------------------------------------------------
    fig.update_layout(
        width=2000,
        height=1100,
        font=dict(color="black", size=22),
        paper_bgcolor="white",
        plot_bgcolor="white",
        margin=dict(l=10, r=10, t=10, b=10)
    )

    fig.write_html(html_output)
    print(f"✓ Sankey exported to: {html_output}")

    return fig

# %%
production_df.columns
# Out:
# Index(['main_id', 'facility_group_id', 'facility_name', 'facility_group_name',
#        'province', 'facility_type', 'mining_processing_type', 'archetypes',
#        'biosphere_data?', 'technosphere_data?', 'land_data?', 'commodities',
#        'ore_processed_t', 'Au_t', 'Ag_t', 'Cu_t', 'Ni_t', 'Co_t', 'Mo_t',
#        'Zn_t', 'Pb_t', 'Fe_t', 'Pt_t', 'Pd_t', 'U_t', 'Nb_t', 'Au_$', 'Ag_$',
#        'Cu_$', 'Ni_$', 'Co_$', 'Mo_$', 'Zn_$', 'Pb_$', 'Fe_$', 'Pt_$', 'U_$',
#        'N_$', 'Sum', '%Au', '%Cu', 'Main_product'],
#       dtype='object')

# %%
columns_to_plot = [
    #"mining_processing_type",
    "archetypes",
    "Main_product",
    #"biosphere_data?",
    "technosphere_data?",
    #"Main_product"
]

# %%
plot_sankey_hierarchy(production_df, columns_to_plot, html_output="data/MetalliCan/sites_for_lci_archetypes.html")
# Out:
# ✓ Sankey exported to: data/MetalliCan/sites_for_lci_archetypes.html

# %% [markdown]
# # Import cleaned MetalliCan data

# %%
from utils.data_manipulations import build_activity_name, add_site_id

# %%
# Pre-processed production table
production_df = pd.read_excel(r'data/MetalliCan/sites_for_lci.xlsx', sheet_name='prod_data')

# %%
# Add activitiy_name to production_df and site_id
production_df['activity_name'] = production_df.apply(lambda row: build_activity_name(row, production_df), axis=1)
production_df = add_site_id(production_df)

# %%
production_df['mining_processing_type'].unique()
# Out:
# array(['Open-pit', 'Underground, concentrator', 'Refinery',
#        'Open-pit, concentrator', 'Open-pit, underground, concentrator',
#        'Underground', 'Smelter, refinery, plant', 'Smelter',
#        'Underground, Concentrator', 'Concentrator', 'Convertor',
#        'Smelter, plant', 'Open-pit, underground'], dtype=object)

# %%
production_df.to_csv(r'test.csv', index=False)

# %%
# Normalized MetalliCan tables per ore processed
energy_ore_df = pd.read_csv(r'data/MetalliCan/data_for_lci_initialization/ore_normalization/energy_df.csv')
material_ore_df = pd.read_csv(r'data/MetalliCan/data_for_lci_initialization/ore_normalization/material_df.csv')
biosphere_ore_df = pd.read_csv(r'data/MetalliCan/data_for_lci_initialization/ore_normalization/biosphere_df.csv')

# %%
# Normalized MetalliCan tables per metal, economic allocation
energy_econ_df = pd.read_csv(r'data/MetalliCan/data_for_lci_initialization/economic_allocation/energy_df.csv')
material_econ_df = pd.read_csv(r'data/MetalliCan/data_for_lci_initialization/economic_allocation/material_df.csv')
biosphere_econ_df = pd.read_csv(r'data/MetalliCan/data_for_lci_initialization/economic_allocation/biosphere_df.csv')

# %%
# Removing rows with value_normalized is NaN in the biosphere dfs
biosphere_ore_df = biosphere_ore_df[~biosphere_ore_df['value_normalized'].isna()]
biosphere_econ_df['value_normalized'] = biosphere_econ_df['value_normalized'] / 1e6

# %%
# For all the dfs, multiply the value_normalized to 10e6 to have values per kg
energy_ore_df['value_normalized'] = energy_ore_df['value_normalized'] / 1e6
material_ore_df['value_normalized'] = material_ore_df['value_normalized'] / 1e6
biosphere_ore_df['value_normalized'] = biosphere_ore_df['value_normalized'] / 1e6
energy_econ_df['value_normalized'] = energy_econ_df['value_normalized'] / 1e6
material_econ_df['value_normalized'] = material_econ_df['value_normalized'] / 1e6
biosphere_econ_df['value_normalized'] = biosphere_econ_df['value_normalized'] / 1e6

# %% [markdown]
# # Keeping only relevant columns

# %%
technosphere_col = ['activity_name', 'functional_unit', 'site_id', 'subflow_type', 'value_normalized']
biosphere_col = ['activity_name', 'functional_unit', 'site_id', 'substance_name', 'value_normalized', 'unit']

# %%
energy_ore_df = energy_ore_df[technosphere_col]
material_ore_df = material_ore_df[technosphere_col]
biosphere_ore_df = biosphere_ore_df[biosphere_col]
energy_econ_df = energy_econ_df[technosphere_col]
material_econ_df = material_econ_df[technosphere_col]
biosphere_econ_df = biosphere_econ_df[biosphere_col]

# %%
# Add units to technosphere dfs
energy_ore_df['unit'] = 'MJ'
material_ore_df['unit'] = 't'
energy_econ_df['unit'] = 'MJ'
material_econ_df['unit'] = 't'

# %%
# Put energy_df and material_df together
technosphere_ore_df = pd.concat([energy_ore_df, material_ore_df], ignore_index=True)
technosphere_econ_df = pd.concat([energy_econ_df, material_econ_df], ignore_index=True)

# %%
# Add the province from the main_df to specify electricity location later
technosphere_ore_df = technosphere_ore_df.merge(production_df[['site_id', 'province']], on=['site_id'], how='left')
technosphere_econ_df = technosphere_econ_df.merge(production_df[['site_id', 'province']], on=['site_id'], how='left')
biosphere_ore_df = biosphere_ore_df.merge(production_df[['site_id', 'province']], on=['site_id'], how='left')
biosphere_econ_df = biosphere_econ_df.merge(production_df[['site_id', 'province']], on=['site_id'], how='left')

# %%
#technosphere_ore_df.to_csv(r'technosphere_ore_df.csv', index=False)

# %% [markdown]
# # Map MetalliCan flows to EI and RI flows

# %%
from utils.conversion_functions import map_technosphere_to_ecoinvent, map_biosphere_to_ecoinvent
from utils.constants import CA_provinces

# %% [markdown]
# ## Technosphere flows

# %%
mapping_technosphere = pd.read_excel(r'data/Mappings/MAPPINGS_RI.xlsx', sheet_name='technosphere')

# %%
technosphere_ore_df
# Out:
#                                          activity_name functional_unit  \
# 0    Au, Underground mining and beneficiation at Br...   Ore processed
# 1    Au, Underground mining and beneficiation at Br...   Ore processed
# 2    Au, Underground mining and beneficiation at Br...   Ore processed
# 3    Au, Underground mining and beneficiation at Br...   Ore processed
# 4    Au, Underground mining and beneficiation at Br...   Ore processed
# ..                                                 ...             ...
# 228  Au and Ag, Underground mining and beneficiatio...   Ore processed
# 229  Au and Ag, Underground mining and beneficiatio...   Ore processed
# 230  Au and Ag, Underground mining and beneficiatio...   Ore processed
# 231  Au, Underground mining and beneficiation at Yo...   Ore processed
# 232  Au, Underground mining and beneficiation at Yo...   Ore processed
#
#               site_id                               subflow_type  \
# 0    BC-MAIN-857b7b89                                  Acetylene
# 1    BC-MAIN-857b7b89                              Aviation fuel
# 2    BC-MAIN-857b7b89                                     Diesel
# 3    BC-MAIN-857b7b89  Electricity consumption|Generated on-site
# 4    BC-MAIN-857b7b89   Electricity consumption|Grid electricity
# ..                ...                                        ...
# 228  QC-MAIN-02884fb5                            Motor/drill oil
# 229  QC-MAIN-02884fb5                             Sulfur dioxide
# 230  QC-MAIN-02884fb5                           Transmission oil
# 231  ON-MAIN-7607a50e       Total blasting agents used e.g. ANFO
# 232  ON-MAIN-7607a50e                  Total sodium cyanide used
#
#      value_normalized unit          province
# 0        1.112991e-07   MJ  British Columbia
# 1        4.378079e-04   MJ  British Columbia
# 2        1.729171e-03   MJ  British Columbia
# 3        5.194284e-04   MJ  British Columbia
# 4        3.427769e-03   MJ  British Columbia
# ..                ...  ...               ...
# 228      1.827853e-11    t            Quebec
# 229      5.212766e-10    t            Quebec
# 230      7.833656e-12    t            Quebec
# 231      9.032167e-10    t           Ontario
# 232      6.795233e-10    t           Ontario
#
# [233 rows x 7 columns]

# %%
# Apply the function
mapped_technosphere_ore_df = map_technosphere_to_ecoinvent(technosphere_ore_df, mapping_technosphere, CA_provinces)
mapped_technosphere_econ_df = map_technosphere_to_ecoinvent(technosphere_econ_df, mapping_technosphere, CA_provinces)
# Out:
# ⚠️ Les flux suivants n'ont pas trouvé de correspondance dans Ecoinvent:
#  - Energy use
#  - Other
#  - Surface/underground emulsion & ANFO
# ⚠️ Pas de conversion définie pour MJ → kilogram (flux: Ammonium nitrate)
# ⚠️ Pas de conversion définie pour MJ → kilogram (flux: Dynamite)
# ⚠️ Les flux suivants n'ont pas trouvé de correspondance dans Ecoinvent:
#  - Surface/underground emulsion & ANFO
# ⚠️ Pas de conversion définie pour MJ → kilogram (flux: Ammonium nitrate)
# ⚠️ Pas de conversion définie pour MJ → kilogram (flux: Dynamite)

# %%
# Drop rows where ecoinvent_flow_name is "No mapping" and Amount is NaN for now
mapped_technosphere_ore_df = mapped_technosphere_ore_df[(mapped_technosphere_ore_df["Activity"] != "No mapping") & (~mapped_technosphere_ore_df["Amount"].isna())]
mapped_technosphere_econ_df = mapped_technosphere_econ_df[(mapped_technosphere_econ_df["Activity"] != "No mapping") & (~mapped_technosphere_econ_df["Amount"].isna())]

# %%
mapped_technosphere_econ_df
# Out:
#                                          activity_name functional_unit  \
# 0    Au, Underground mining and beneficiation at Br...  Au, usable ore
# 1    Au, Underground mining and beneficiation at Br...  Au, usable ore
# 2    Au, Underground mining and beneficiation at Br...  Au, usable ore
# 3    Au, Underground mining and beneficiation at Br...  Au, usable ore
# 4    Au, Underground mining and beneficiation at Br...  Au, usable ore
# ..                                                 ...             ...
# 421  Au and Ag, Underground mining and beneficiatio...  Au, usable ore
# 422  Au and Ag, Underground mining and beneficiatio...  Ag, usable ore
# 423  Au, Underground mining and beneficiation at Yo...  Au, usable ore
# 424  Au, Underground mining and beneficiation at Yo...  Au, usable ore
# 425  Au, Underground mining and beneficiation at Yo...  Au, usable ore
#
#               site_id                               subflow_type  \
# 0    BC-MAIN-857b7b89                                  Acetylene
# 1    BC-MAIN-857b7b89                              Aviation fuel
# 2    BC-MAIN-857b7b89                                     Diesel
# 3    BC-MAIN-857b7b89  Electricity consumption|Generated on-site
# 4    BC-MAIN-857b7b89   Electricity consumption|Grid electricity
# ..                ...                                        ...
# 421  QC-MAIN-02884fb5                           Transmission oil
# 422  QC-MAIN-02884fb5                           Transmission oil
# 423  ON-MAIN-7607a50e       Total blasting agents used e.g. ANFO
# 424  ON-MAIN-7607a50e       Total blasting agents used e.g. ANFO
# 425  ON-MAIN-7607a50e                  Total sodium cyanide used
#
#                                     Activity                      Product  \
# 0           consumption market for acetylene                    acetylene
# 1            consumption market for kerosene                     kerosene
# 2              consumption market for diesel                       diesel
# 3              consumption market for diesel                       diesel
# 4     market for electricity, medium voltage  electricity, medium voltage
# ..                                       ...                          ...
# 421   consumption market for lubricating oil              lubricating oil
# 422   consumption market for lubricating oil              lubricating oil
# 423  consumption market for explosive, tovex             explosive, tovex
# 424  consumption market for explosive, tovex             explosive, tovex
# 425    consumption market for sodium cyanide               sodium cyanide
#
#      value_normalized unit      Amount           Unit Location  \
# 0        2.048295e-02   MJ    0.000427       kilogram       CA
# 1        8.057205e+01   MJ    1.869421       kilogram       CA
# 2        3.182283e+02   MJ    7.400659       kilogram       CA
# 3        9.559310e+01   MJ    2.223095       kilogram       CA
# 4        6.308300e+02   MJ  175.230689  kilowatt hour    CA-BC
# ..                ...  ...         ...            ...      ...
# 421      2.785936e-06    t    0.002786       kilogram       CA
# 422      3.615366e-08    t    0.000036       kilogram       CA
# 423      4.515170e-04    t    0.451517       kilogram       CA
# 424      4.515170e-04    t    0.451517       kilogram       CA
# 425      3.396930e-04    t    0.339693       kilogram       CA
#
#              province                            Database
# 0    British Columbia                         Regioinvent
# 1    British Columbia                         Regioinvent
# 2    British Columbia                         Regioinvent
# 3    British Columbia                         Regioinvent
# 4    British Columbia  ecoinvent-3.10-cutoff regionalized
# ..                ...                                 ...
# 421            Quebec                         Regioinvent
# 422            Quebec                         Regioinvent
# 423           Ontario                         Regioinvent
# 424           Ontario                         Regioinvent
# 425           Ontario                         Regioinvent
#
# [418 rows x 13 columns]

# %%
technosphere_col_for_lci = ['site_id', 'activity_name', 'functional_unit', 'Amount', 'Activity', 'Product', 'Unit', 'Location', 'Database']

# %%
mapped_technosphere_ore_df = mapped_technosphere_ore_df[technosphere_col_for_lci]
mapped_technosphere_econ_df = mapped_technosphere_econ_df[technosphere_col_for_lci]

# %% [markdown]
# ## Biosphere flows mapping

# %%
mapping_biosphere = pd.read_excel(r'data/Mappings/MAPPINGS_RI.xlsx', sheet_name='biosphere')

# %%
mapped_biosphere_ore_df = map_biosphere_to_ecoinvent(biosphere_ore_df, mapping_biosphere, CA_provinces)
mapped_biosphere_econ_df = map_biosphere_to_ecoinvent(biosphere_econ_df, mapping_biosphere, CA_provinces)
# Out:
# Index(['activity_name', 'functional_unit', 'site_id', 'substance_name',
#        'value_normalized', 'unit', 'province', 'Type', 'substance_id',
#        'compartment_name', 'release_pathway', 'flow_direction',
#        'MetalliCan_unit', 'DB_to_map', 'Flow name', 'Compartments', 'Unit',
#        'Comment', 'Alternatives'],
#       dtype='object')
# ⚠️ 6 biosphere flows could not be mapped to Ecoinvent:
#    - 1-Nitropyrene
#    - Quinoline
#    - Ethylene glycol
#    - nan
#    - N2O
#    - PFCs
# ⚠️ No conversion defined for g teq → kilogram (flow: Dioxins and furans - total)
# ⚠️ No conversion defined for g teq → kilogram (flow: Dioxins and furans - total)
# ⚠️ No conversion defined for kg → nan (flow: 1-Nitropyrene)
# ⚠️ No conversion defined for g teq → kilogram (flow: Dioxins and furans - total)
# ⚠️ No conversion defined for g teq → kilogram (flow: Dioxins and furans - total)
# ⚠️ No conversion defined for kg → nan (flow: Quinoline)
# ⚠️ No conversion defined for g teq → kilogram (flow: Dioxins and furans - total)
# ⚠️ No conversion defined for g teq → kilogram (flow: Dioxins and furans - total)
# ⚠️ No conversion defined for g teq → kilogram (flow: Dioxins and furans - total)
# ⚠️ No conversion defined for g teq → kilogram (flow: Dioxins and furans - total)
# ⚠️ No conversion defined for g teq → kilogram (flow: Dioxins and furans - total)
# ⚠️ No conversion defined for g teq → kilogram (flow: Dioxins and furans - total)
# ⚠️ No conversion defined for tonnes → nan (flow: Ethylene glycol)
# ⚠️ No conversion defined for tonnes → nan (flow: Ethylene glycol)
# ⚠️ No conversion defined for tonnes → nan (flow: Ethylene glycol)
# ⚠️ No conversion defined for tonnes → nan (flow: Ethylene glycol)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for tco2eq → nan (flow: N2O)
# ⚠️ No conversion defined for tco2eq → nan (flow: PFCs)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for tco2eq → nan (flow: N2O)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for tonnes → nan (flow: Ethylene glycol)
# ⚠️ No conversion defined for tonnes → nan (flow: Ethylene glycol)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ✅ Mapped 11682 biosphere flows (91 unique flows).
# Index(['activity_name', 'functional_unit', 'site_id', 'substance_name',
#        'value_normalized', 'unit', 'province', 'Type', 'substance_id',
#        'compartment_name', 'release_pathway', 'flow_direction',
#        'MetalliCan_unit', 'DB_to_map', 'Flow name', 'Compartments', 'Unit',
#        'Comment', 'Alternatives'],
#       dtype='object')
# ⚠️ 4 biosphere flows could not be mapped to Ecoinvent:
#    - Ethylene glycol
#    - nan
#    - N2O
#    - PFCs
# ⚠️ No conversion defined for g teq → kilogram (flow: Dioxins and furans - total)
# ⚠️ No conversion defined for g teq → kilogram (flow: Dioxins and furans - total)
# ⚠️ No conversion defined for g teq → kilogram (flow: Dioxins and furans - total)
# ⚠️ No conversion defined for g teq → kilogram (flow: Dioxins and furans - total)
# ⚠️ No conversion defined for g teq → kilogram (flow: Dioxins and furans - total)
# ⚠️ No conversion defined for g teq → kilogram (flow: Dioxins and furans - total)
# ⚠️ No conversion defined for g teq → kilogram (flow: Dioxins and furans - total)
# ⚠️ No conversion defined for g teq → kilogram (flow: Dioxins and furans - total)
# ⚠️ No conversion defined for g teq → kilogram (flow: Dioxins and furans - total)
# ⚠️ No conversion defined for g teq → kilogram (flow: Dioxins and furans - total)
# ⚠️ No conversion defined for g teq → kilogram (flow: Dioxins and furans - total)
# ⚠️ No conversion defined for g teq → kilogram (flow: Dioxins and furans - total)
# ⚠️ No conversion defined for tonnes → nan (flow: Ethylene glycol)
# ⚠️ No conversion defined for tonnes → nan (flow: Ethylene glycol)
# ⚠️ No conversion defined for tonnes → nan (flow: Ethylene glycol)
# ⚠️ No conversion defined for tonnes → nan (flow: Ethylene glycol)
# ⚠️ No conversion defined for tonnes → nan (flow: Ethylene glycol)
# ⚠️ No conversion defined for tonnes → nan (flow: Ethylene glycol)
# ⚠️ No conversion defined for tonnes → nan (flow: Ethylene glycol)
# ⚠️ No conversion defined for tonnes → nan (flow: Ethylene glycol)
# ⚠️ No conversion defined for tonnes → nan (flow: Ethylene glycol)
# ⚠️ No conversion defined for tonnes → nan (flow: Ethylene glycol)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for tco2eq → nan (flow: N2O)
# ⚠️ No conversion defined for tco2eq → nan (flow: PFCs)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for tco2eq → nan (flow: N2O)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for tonnes → nan (flow: Ethylene glycol)
# ⚠️ No conversion defined for tonnes → nan (flow: Ethylene glycol)
# ⚠️ No conversion defined for tonnes → nan (flow: Ethylene glycol)
# ⚠️ No conversion defined for tonnes → nan (flow: Ethylene glycol)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ✅ Mapped 25548 biosphere flows (87 unique flows).

# %%
# Drop rows where ecoinvent_flow_name is "No mapping" and Amount is NaN for now
mapped_biosphere_ore_df = mapped_biosphere_ore_df[(mapped_biosphere_ore_df["Flow Name"] != "No mapping") & (~mapped_biosphere_ore_df["Amount"].isna())]
mapped_biosphere_econ_df = mapped_biosphere_econ_df[(mapped_biosphere_econ_df["Flow Name"] != "No mapping") & (~mapped_biosphere_econ_df["Amount"].isna())]

# %%
biosphere_col_for_lci = ['site_id', 'activity_name', 'functional_unit', 'Amount', 'Unit', 'Flow Name', 'Compartments', 'Database']

# %%
mapped_biosphere_ore_df = mapped_biosphere_ore_df[biosphere_col_for_lci]
mapped_biosphere_econ_df = mapped_biosphere_econ_df[biosphere_col_for_lci]

# %%
production_df.to_csv(r'data/MetalliCan/data_for_lci_initialization/production_df.csv', index=False)

# %%
mapped_biosphere_ore_df.to_csv(r'data/MetalliCan/data_for_lci_initialization/biosphere_ore_df.csv', index=False)
mapped_biosphere_econ_df.to_csv(r'data/MetalliCan/data_for_lci_initialization/biosphere_econ_df.csv', index=False)

# %%
mapped_technosphere_ore_df.to_csv(r'data/MetalliCan/data_for_lci_initialization/technosphere_ore_df.csv', index=False)
mapped_technosphere_econ_df.to_csv(r'data/MetalliCan/data_for_lci_initialization/technosphere_econ_df.csv', index=False)

# %%
# Add province and commodities from NRCan to production table
mapped_biosphere_ore_df = mapped_biosphere_ore_df.merge(production_df[['site_id', 'province', 'commodities']], on=['site_id'], how='left')
mapped_biosphere_econ_df = mapped_biosphere_econ_df.merge(production_df[['site_id', 'province', 'commodities']], on=['site_id'], how='left')

# %%
mapped_technosphere_econ_df
# Out:
#               site_id                                      activity_name  \
# 0    BC-MAIN-857b7b89  Au, Underground mining and beneficiation at Br...
# 1    BC-MAIN-857b7b89  Au, Underground mining and beneficiation at Br...
# 2    BC-MAIN-857b7b89  Au, Underground mining and beneficiation at Br...
# 3    BC-MAIN-857b7b89  Au, Underground mining and beneficiation at Br...
# 4    BC-MAIN-857b7b89  Au, Underground mining and beneficiation at Br...
# ..                ...                                                ...
# 421  QC-MAIN-02884fb5  Au and Ag, Underground mining and beneficiatio...
# 422  QC-MAIN-02884fb5  Au and Ag, Underground mining and beneficiatio...
# 423  ON-MAIN-7607a50e  Au, Underground mining and beneficiation at Yo...
# 424  ON-MAIN-7607a50e  Au, Underground mining and beneficiation at Yo...
# 425  ON-MAIN-7607a50e  Au, Underground mining and beneficiation at Yo...
#
#     functional_unit      Amount                                 Activity  \
# 0    Au, usable ore    0.000427         consumption market for acetylene
# 1    Au, usable ore    1.869421          consumption market for kerosene
# 2    Au, usable ore    7.400659            consumption market for diesel
# 3    Au, usable ore    2.223095            consumption market for diesel
# 4    Au, usable ore  175.230689   market for electricity, medium voltage
# ..              ...         ...                                      ...
# 421  Au, usable ore    0.002786   consumption market for lubricating oil
# 422  Ag, usable ore    0.000036   consumption market for lubricating oil
# 423  Au, usable ore    0.451517  consumption market for explosive, tovex
# 424  Au, usable ore    0.451517  consumption market for explosive, tovex
# 425  Au, usable ore    0.339693    consumption market for sodium cyanide
#
#                          Product           Unit Location  \
# 0                      acetylene       kilogram       CA
# 1                       kerosene       kilogram       CA
# 2                         diesel       kilogram       CA
# 3                         diesel       kilogram       CA
# 4    electricity, medium voltage  kilowatt hour    CA-BC
# ..                           ...            ...      ...
# 421              lubricating oil       kilogram       CA
# 422              lubricating oil       kilogram       CA
# 423             explosive, tovex       kilogram       CA
# 424             explosive, tovex       kilogram       CA
# 425               sodium cyanide       kilogram       CA
#
#                                Database
# 0                           Regioinvent
# 1                           Regioinvent
# 2                           Regioinvent
# 3                           Regioinvent
# 4    ecoinvent-3.10-cutoff regionalized
# ..                                  ...
# 421                         Regioinvent
# 422                         Regioinvent
# 423                         Regioinvent
# 424                         Regioinvent
# 425                         Regioinvent
#
# [418 rows x 9 columns]

# %% [markdown]
# # LCI creation

# %%
from core.lci_database_builder import LCIDatabaseBuilder

# %% [markdown]
# ## Ore processed basis

# %%
# Step 1 — initialize the builder
builder_op = LCIDatabaseBuilder(db_name='metallican_lci', project_name='metallican')
# Out:
# 📂 Active Brightway project: metallican
# ✅ Using existing database 'metallican_lci'.

# %%
# Step 2 — create the activity shells from the main dataframe
builder_op.build_lci_entries(df=mapped_biosphere_ore_df)
print(len(builder_op.lcis))
# Out:
# ✅ Created 52 base LCI activities with production exchanges.
# 52

# %%
# Step 3a — Populate with the technosphere exchanges
builder_op.populate_technosphere_exchanges(technosphere_df=mapped_technosphere_ore_df)
# Out:
# ⚙️ Populating technosphere exchanges
#    ✅ Cached 218246 activities from Regioinvent
#    ✅ Cached 20769 activities from ecoinvent-3.10-cutoff regionalized
# ✅ Added 246 technosphere exchanges.

# %%
# Step 3b — Populate with the biosphere exchanges
builder_op.populate_biosphere_exchanges(biosphere_df=mapped_biosphere_ore_df)
# Out:
# 🌱 Populating biosphere exchanges
#    ✅ Cached 110559 biosphere flows from biosphere3_spatialized_flows
#    ✅ Cached 4362 biosphere flows from biosphere3
# ✅ Added 7889 biosphere exchanges.

# %%
# Step 4 - Consolidate duplicate flows
builder_op.consolidate_exchanges()
# Out:
# 🧮 Consolidation: 8168 → 849 exchanges (summed duplicates).

# %%
builder_op.write_to_database()
# Out:
# 🧱 Writing 33 activities to database 'metallican_lci'...
# ✅ Database 'metallican_lci' processed successfully with 33 activities.

# %% [markdown]
# ## Usable ore or metal basis

# %%
# Step 1 — initialize the builder
builder_uo = LCIDatabaseBuilder(db_name='metallican_lci', project_name='metallican')
# Out:
# 📂 Active Brightway project: metallican
# ✅ Using existing database 'metallican_lci'.

# %%
# Step 2 — create the activity shells from the main dataframe
builder_uo.build_lci_entries(df=mapped_biosphere_econ_df)
print(len(builder_uo.lcis))
# Out:
# ✅ Created 80 base LCI activities with production exchanges.
# 80

# %%
# Step 3a — Populate with the technosphere exchanges
builder_uo.populate_technosphere_exchanges(technosphere_df=mapped_technosphere_econ_df)
# Out:
# ⚙️ Populating technosphere exchanges
#    ✅ Cached 218246 activities from Regioinvent
#    ✅ Cached 20769 activities from ecoinvent-3.10-cutoff regionalized
# ✅ Added 418 technosphere exchanges.

# %%
# Step 3b — Populate with the biosphere exchanges
builder_uo.populate_biosphere_exchanges(biosphere_df=mapped_biosphere_econ_df)
# Out:
# 🌱 Populating biosphere exchanges
#    ✅ Cached 4362 biosphere flows from biosphere3
#    ✅ Cached 110559 biosphere flows from biosphere3_spatialized_flows
# ✅ Added 16952 biosphere exchanges.

# %%
# Step 4 - Consolidate duplicate flows
builder_uo.consolidate_exchanges()
# Out:
# 🧮 Consolidation: 17450 → 1772 exchanges (summed duplicates).

# %%
builder_uo.write_to_database()
# Out:
# 🧱 Writing 80 activities to database 'metallican_lci'...
# ✅ Database 'metallican_lci' processed successfully with 80 activities.
