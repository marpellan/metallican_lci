# %%
import pandas as pd

# %% [markdown]
# # Import cleaned MetalliCan data

# %%
from core.data_manipulations import get_info_for_ids

# %%
substances_table = pd.read_csv(r'C:\Users\mp_ma\OneDrive - polymtl\POST_DOC\CODE\metallican_db\database\CSV\substances_table.csv')

# %%
main_table = pd.read_csv(r'C:\Users\mp_ma\OneDrive - polymtl\POST_DOC\CODE\metallican_db\database\CSV\main_table.csv')
ta_table = pd.read_csv(r'C:\Users\mp_ma\OneDrive - polymtl\POST_DOC\CODE\metallican_db\database\CSV\tech_attributes_table.csv')
energy_table = pd.read_excel(r'data/MetalliCan/cleaned_data/energy_df_sd_norm.xlsx')
material_table = pd.read_excel(r'data/MetalliCan/cleaned_data/material_df_sd_norm.xlsx')
biosphere_table = pd.read_excel(r'data/MetalliCan/cleaned_data/biosphere_df_norm.xlsx')
land_table = pd.read_excel(r'data/MetalliCan/cleaned_data/land_table_mining.xlsx')

# %%
biosphere_table = biosphere_table.merge(substances_table[['substance_id', 'substance_name']], how='left', on='substance_id')

# %%
# Remove the '/t' at the end in the unit_normalized column
biosphere_table['unit_normalized'] = biosphere_table['unit_normalized'].str.replace('/t', '', regex=False)

# %% [markdown]
# # Separating when we have only biosphere flows or both technosphere and biosphere flows

# %%
ids_energy = set(energy_table[['main_id', 'facility_group_id']].apply(tuple, axis=1))
ids_material = set(material_table[['main_id', 'facility_group_id']].apply(tuple, axis=1))
ids_biosphere = set(biosphere_table[['main_id', 'facility_group_id']].apply(tuple, axis=1))
ids_land = set(land_table[['main_id', 'facility_group_id']].apply(tuple, axis=1))

# %%
# Facilities with at least technosphere and biosphere flows
best_ids = ids_energy & ids_material & ids_biosphere
best_ids
# Out:
# {('BC-MAIN-aa76f6f2', nan),
#  ('ON-MAIN-0aadf28f', nan),
#  ('ON-MAIN-687b8c8d', nan),
#  ('ON-MAIN-7607a50e', nan),
#  ('ON-MAIN-fefeaee4', nan),
#  ('QC-MAIN-02884fb5', nan),
#  ('QC-MAIN-6dc537e6', nan),
#  (nan, 'GRP-0d911886')}

# %%
# Facilities with only biosphere flows
other_ids = ids_biosphere - best_ids
other_ids
# Out:
# {('AB-MAIN-9fed34a8', nan),
#  ('AB-MAIN-d3a4aba9', nan),
#  ('BC-MAIN-23155c25', nan),
#  ('BC-MAIN-3bb6b7cd', nan),
#  ('BC-MAIN-3f490561', nan),
#  ('BC-MAIN-599152a0', nan),
#  ('BC-MAIN-6b4800fe', nan),
#  ('BC-MAIN-857b7b89', nan),
#  ('BC-MAIN-8eb8be0d', nan),
#  ('BC-MAIN-bf503b6b', nan),
#  ('BC-MAIN-e34feb4d', nan),
#  ('BC-MAIN-ed23117f', nan),
#  ('MB-MAIN-0898e255', 'GRP-a13779f8'),
#  ('MB-MAIN-b4ca1426', nan),
#  ('MB-MAIN-da0b5c3d', 'GRP-a13779f8'),
#  ('MB-MAIN-e0a6250e', nan),
#  ('NL-MAIN-2d8801d6', nan),
#  ('NL-MAIN-842ba1b4', nan),
#  ('NL-MAIN-b64bae7a', nan),
#  ('NL-MAIN-c139de6d', nan),
#  ('NL-MAIN-d9036091', nan),
#  ('NL-MAIN-dd723db4', nan),
#  ('NL-MAIN-e09881ff', 'GRP-2a663492'),
#  ('NT-MAIN-0ec39ce0', nan),
#  ('NT-MAIN-6c1d6ee6', nan),
#  ('NT-MAIN-94e652a5', nan),
#  ('NU-MAIN-5154702a', nan),
#  ('NU-MAIN-730aefe3', 'GRP-0a2c0d69'),
#  ('NU-MAIN-8b0264c9', nan),
#  ('ON-MAIN-020a683c', nan),
#  ('ON-MAIN-1c674cd0', 'GRP-0d911886'),
#  ('ON-MAIN-1f126a43', nan),
#  ('ON-MAIN-21b6ab35', nan),
#  ('ON-MAIN-28f3f0fc', 'GRP-dc07540b'),
#  ('ON-MAIN-2e13aaa0', nan),
#  ('ON-MAIN-387b06fe', nan),
#  ('ON-MAIN-3b3e5365', nan),
#  ('ON-MAIN-40ce0593', 'GRP-de097f20'),
#  ('ON-MAIN-48fe2205', 'GRP-dc07540b'),
#  ('ON-MAIN-4c35e094', nan),
#  ('ON-MAIN-4e0734b5', nan),
#  ('ON-MAIN-52224e1e', 'GRP-dc07540b'),
#  ('ON-MAIN-63b394c3', 'GRP-dc07540b'),
#  ('ON-MAIN-6664e89b', nan),
#  ('ON-MAIN-6bd6cc80', nan),
#  ('ON-MAIN-6e9b2449', 'GRP-dc07540b'),
#  ('ON-MAIN-6e9be24e', nan),
#  ('ON-MAIN-7001a391', nan),
#  ('ON-MAIN-7f050560', nan),
#  ('ON-MAIN-8825d90d', nan),
#  ('ON-MAIN-9a34108c', nan),
#  ('ON-MAIN-a3c56a83', nan),
#  ('ON-MAIN-aeafbb59', nan),
#  ('ON-MAIN-b2e5c9bb', nan),
#  ('ON-MAIN-bddeaef0', nan),
#  ('ON-MAIN-bfbcd72e', 'GRP-147b3123'),
#  ('ON-MAIN-cb85213a', nan),
#  ('ON-MAIN-de2f9639', 'GRP-dc07540b'),
#  ('ON-MAIN-e928d96a', nan),
#  ('ON-MAIN-eab8c362', nan),
#  ('ON-MAIN-ed85ac94', 'GRP-de097f20'),
#  ('ON-MAIN-f080c409', 'GRP-dc07540b'),
#  ('ON-MAIN-f3e6ff08', 'GRP-147b3123'),
#  ('ON-MAIN-f8313ebd', nan),
#  ('ON-MAIN-fc6f1a44', nan),
#  ('ON-MAIN-fcb287a4', 'GRP-de097f20'),
#  ('QC-MAIN-01c1e81f', 'GRP-677b5973'),
#  ('QC-MAIN-084bd95c', 'GRP-1402249f'),
#  ('QC-MAIN-089f3c60', nan),
#  ('QC-MAIN-1eee4ace', 'GRP-7a9ba115'),
#  ('QC-MAIN-3032c251', nan),
#  ('QC-MAIN-30c1828c', 'GRP-b48ec279'),
#  ('QC-MAIN-33c09b8b', 'GRP-1402249f'),
#  ('QC-MAIN-3aa117d8', 'GRP-677b5973'),
#  ('QC-MAIN-3e146840', 'GRP-25483238'),
#  ('QC-MAIN-529c96b4', 'GRP-b48ec279'),
#  ('QC-MAIN-52c01ae4', nan),
#  ('QC-MAIN-5398dfac', nan),
#  ('QC-MAIN-5ce331b8', nan),
#  ('QC-MAIN-844dcc47', 'GRP-7a9ba115'),
#  ('QC-MAIN-8d6616b4', 'GRP-677b5973'),
#  ('QC-MAIN-92628f16', 'GRP-677b5973'),
#  ('QC-MAIN-9de9bb0d', nan),
#  ('QC-MAIN-a555d9b9', nan),
#  ('QC-MAIN-a97821c0', nan),
#  ('QC-MAIN-b86f7d07', nan),
#  ('QC-MAIN-c0660aec', nan),
#  ('QC-MAIN-c0e3a48b', 'GRP-677b5973'),
#  ('QC-MAIN-c1c7eb99', 'GRP-677b5973'),
#  ('QC-MAIN-c1cc9f7c', nan),
#  ('QC-MAIN-c8966bdc', nan),
#  ('QC-MAIN-dc1a16f9', nan),
#  ('QC-MAIN-e25eed27', 'GRP-1402249f'),
#  ('QC-MAIN-e51eda66', nan),
#  ('QC-MAIN-e7e6a960', nan),
#  ('QC-MAIN-eac5a52b', nan),
#  ('QC-MAIN-f9e41c2a', nan),
#  ('SK-MAIN-26b9aaf3', nan),
#  ('SK-MAIN-29afbdb5', 'GRP-14bfbb82'),
#  ('SK-MAIN-60ba74c4', nan),
#  ('SK-MAIN-91cf5448', nan),
#  ('SK-MAIN-bb89158f', 'GRP-21eee27d'),
#  ('SK-MAIN-d3c471e8', 'GRP-21eee27d'),
#  ('YT-MAIN-44857446', nan),
#  ('YT-MAIN-e05ed9fe', nan),
#  (nan, 'GRP-0a2c0d69'),
#  (nan, 'GRP-147b3123'),
#  (nan, 'GRP-14bfbb82'),
#  (nan, 'GRP-a13779f8')}

# %% [markdown]
# ## Facilities with both technosphere and biosphere flows

# %%
main_df = get_info_for_ids(main_table, best_ids)
main_df = main_df[['main_id', 'facility_name', 'province', 'mining_processing_type', 'commodities']]
main_df
# Out:
#               main_id   facility_name          province  \
# 13   ON-MAIN-687b8c8d          Island           Ontario
# 14   ON-MAIN-7607a50e  Young-Davidson           Ontario
# 127  QC-MAIN-02884fb5  Westwood-Doyon            Quebec
# 160  BC-MAIN-aa76f6f2       New Afton  British Columbia
# 161  ON-MAIN-0aadf28f     Rainy River           Ontario
# 162  ON-MAIN-1c674cd0          Borden           Ontario
# 165  ON-MAIN-8629a493       Hollinger           Ontario
# 166  ON-MAIN-538513cd      Hoyle Pond           Ontario
# 167  ON-MAIN-fefeaee4     Musselwhite           Ontario
# 170  QC-MAIN-6dc537e6        Éléonore            Quebec
#
#                   mining_processing_type           commodities
# 13             Underground, concentrator                  Gold
# 14             Underground, concentrator                  Gold
# 127            Underground, concentrator          Gold, silver
# 160            Underground, concentrator  Gold, copper, silver
# 161  Open-pit, underground, concentrator          Gold, silver
# 162                Open-pit, underground                  Gold
# 165                             Open-pit                  Gold
# 166                          Underground                  Gold
# 167            Underground, concentrator          Gold, silver
# 170            Underground, concentrator                  Gold

# %%
energy_df = get_info_for_ids(energy_table, best_ids)
energy_df = energy_df[['main_id', 'facility_name', 'commodities', 'subflow_type', 'value_normalized']]
energy_df['unit'] = 'MJ'

# %%
energy_df
# Out:
#               main_id   facility_name           commodities  \
# 34   QC-MAIN-6dc537e6        Éléonore                  Gold
# 35   QC-MAIN-6dc537e6        Éléonore                  Gold
# 36   QC-MAIN-6dc537e6        Éléonore                  Gold
# 37   QC-MAIN-6dc537e6        Éléonore                  Gold
# 38   QC-MAIN-6dc537e6        Éléonore                  Gold
# 39   QC-MAIN-6dc537e6        Éléonore                  Gold
# 40   QC-MAIN-6dc537e6        Éléonore                  Gold
# 53   ON-MAIN-687b8c8d          Island                  Gold
# 54   ON-MAIN-687b8c8d          Island                  Gold
# 55   ON-MAIN-687b8c8d          Island                  Gold
# 56   ON-MAIN-687b8c8d          Island                  Gold
# 57   ON-MAIN-687b8c8d          Island                  Gold
# 105  ON-MAIN-fefeaee4     Musselwhite          Gold, silver
# 106  ON-MAIN-fefeaee4     Musselwhite          Gold, silver
# 107  ON-MAIN-fefeaee4     Musselwhite          Gold, silver
# 108  ON-MAIN-fefeaee4     Musselwhite          Gold, silver
# 109  ON-MAIN-fefeaee4     Musselwhite          Gold, silver
# 110  ON-MAIN-fefeaee4     Musselwhite          Gold, silver
# 111  ON-MAIN-fefeaee4     Musselwhite          Gold, silver
# 112  ON-MAIN-fefeaee4     Musselwhite          Gold, silver
# 113  ON-MAIN-fefeaee4     Musselwhite          Gold, silver
# 114  BC-MAIN-aa76f6f2       New Afton  Gold, copper, silver
# 115  BC-MAIN-aa76f6f2       New Afton  Gold, copper, silver
# 116  BC-MAIN-aa76f6f2       New Afton  Gold, copper, silver
# 117  BC-MAIN-aa76f6f2       New Afton  Gold, copper, silver
# 118  BC-MAIN-aa76f6f2       New Afton  Gold, copper, silver
# 119  BC-MAIN-aa76f6f2       New Afton  Gold, copper, silver
# 120  BC-MAIN-aa76f6f2       New Afton  Gold, copper, silver
# 121               NaN      Hoyle Pond                  Gold
# 122               NaN      Hoyle Pond                  Gold
# 123               NaN      Hoyle Pond                  Gold
# 124               NaN      Hoyle Pond                  Gold
# 125               NaN      Hoyle Pond                  Gold
# 126               NaN      Hoyle Pond                  Gold
# 127               NaN      Hoyle Pond                  Gold
# 128               NaN      Hoyle Pond                  Gold
# 129  ON-MAIN-0aadf28f     Rainy River          Gold, silver
# 130  ON-MAIN-0aadf28f     Rainy River          Gold, silver
# 131  ON-MAIN-0aadf28f     Rainy River          Gold, silver
# 132  ON-MAIN-0aadf28f     Rainy River          Gold, silver
# 133  ON-MAIN-0aadf28f     Rainy River          Gold, silver
# 167  QC-MAIN-02884fb5  Westwood-Doyon          Gold, silver
# 168  QC-MAIN-02884fb5  Westwood-Doyon          Gold, silver
# 169  QC-MAIN-02884fb5  Westwood-Doyon          Gold, silver
# 170  QC-MAIN-02884fb5  Westwood-Doyon          Gold, silver
# 171  QC-MAIN-02884fb5  Westwood-Doyon          Gold, silver
# 172  QC-MAIN-02884fb5  Westwood-Doyon          Gold, silver
# 173  QC-MAIN-02884fb5  Westwood-Doyon          Gold, silver
# 174  QC-MAIN-02884fb5  Westwood-Doyon          Gold, silver
# 175  ON-MAIN-7607a50e  Young-Davidson                  Gold
# 176  ON-MAIN-7607a50e  Young-Davidson                  Gold
# 177  ON-MAIN-7607a50e  Young-Davidson                  Gold
# 178  ON-MAIN-7607a50e  Young-Davidson                  Gold
# 179  ON-MAIN-7607a50e  Young-Davidson                  Gold
# 180  ON-MAIN-7607a50e  Young-Davidson                  Gold
# 181  ON-MAIN-7607a50e  Young-Davidson                  Gold
#
#                                   subflow_type  value_normalized unit
# 34                               Aviation fuel         13.041601   MJ
# 35                                      Diesel        231.985429   MJ
# 36                                    Gasoline          6.031377   MJ
# 37                              Grinding media               NaN   MJ
# 38                                     Propane         85.727378   MJ
# 39    Electricity consumption|Grid electricity        537.164329   MJ
# 40   Electricity consumption|Generated on-site          2.125892   MJ
# 53   Electricity consumption|Generated on-site          1.633228   MJ
# 54    Electricity consumption|Grid electricity        761.213919   MJ
# 55                                      Diesel        481.330636   MJ
# 56                                    Gasoline         32.814892   MJ
# 57                                     Propane        164.031179   MJ
# 105                              Aviation fuel         26.900028   MJ
# 106                                  Biodiesel         11.449776   MJ
# 107                                     Diesel        300.208882   MJ
# 108                                   Gasoline          5.289528   MJ
# 109                             Grinding media               NaN   MJ
# 110                                    Propane        223.630223   MJ
# 111                                      Solar          1.442802   MJ
# 112  Electricity consumption|Generated on-site          3.705238   MJ
# 113   Electricity consumption|Grid electricity        496.001556   MJ
# 114  Electricity consumption|Generated on-site         18.406093   MJ
# 115   Electricity consumption|Grid electricity         56.112504   MJ
# 116                                     Diesel         59.966644   MJ
# 117                                 Explosives          0.682023   MJ
# 118                                   Gasoline          1.332499   MJ
# 119                                Natural gas         19.314192   MJ
# 120                                    Propane          0.256298   MJ
# 121                                  Biodiesel          8.081222   MJ
# 122                                     Diesel        214.023315   MJ
# 123  Electricity consumption|Generated on-site         31.269489   MJ
# 124                                   Gasoline          5.907196   MJ
# 125                             Grinding media               NaN   MJ
# 126                                Natural gas         57.267262   MJ
# 127                                    Propane          2.176592   MJ
# 128   Electricity consumption|Grid electricity        248.700515   MJ
# 129                    Electricity consumption        333.092424   MJ
# 130                                     Diesel        186.649489   MJ
# 131                                 Explosives          6.757475   MJ
# 132                                   Gasoline          4.476712   MJ
# 133                                    Propane         10.656407   MJ
# 167   Electricity consumption|Grid electricity        508.652515   MJ
# 168                                       ANFO          1.480561   MJ
# 169                                     Diesel        200.141199   MJ
# 170                              Emulsion ANFO          4.120503   MJ
# 171                                 Explosives          5.738491   MJ
# 172                                   Gasoline          3.240619   MJ
# 173                                Natural gas         61.855222   MJ
# 174                                    Propane          0.031915   MJ
# 175  Electricity consumption|Generated on-site          0.165042   MJ
# 176   Electricity consumption|Grid electricity        333.819427   MJ
# 177                                     Diesel         48.678844   MJ
# 178                                   Gasoline          0.738000   MJ
# 179                                     Naphta          2.204273   MJ
# 180                                Natural gas         77.000827   MJ
# 181       Total blasting agents used e.g. ANFO               NaN   MJ

# %%
material_df = get_info_for_ids(material_table, best_ids)
material_df = material_df[['main_id', 'facility_name', 'commodities', 'subflow_type', 'value_normalized']]
material_df['unit'] = 't'

# %%
# Put energy_df and material_df together in a single dataframe and add the province from the main_df to specify electricity location later
technosphere_df = pd.concat([energy_df, material_df], ignore_index=True)
technosphere_df = technosphere_df.merge(main_df[['main_id', 'province']], on=['main_id'], how='left')
technosphere_df
# Out:
#               main_id   facility_name   commodities  \
# 0    QC-MAIN-6dc537e6        Éléonore          Gold
# 1    QC-MAIN-6dc537e6        Éléonore          Gold
# 2    QC-MAIN-6dc537e6        Éléonore          Gold
# 3    QC-MAIN-6dc537e6        Éléonore          Gold
# 4    QC-MAIN-6dc537e6        Éléonore          Gold
# ..                ...             ...           ...
# 101  QC-MAIN-02884fb5  Westwood-Doyon  Gold, silver
# 102  QC-MAIN-02884fb5  Westwood-Doyon  Gold, silver
# 103  QC-MAIN-02884fb5  Westwood-Doyon  Gold, silver
# 104  QC-MAIN-02884fb5  Westwood-Doyon  Gold, silver
# 105  ON-MAIN-7607a50e  Young-Davidson          Gold
#
#                   subflow_type  value_normalized unit province
# 0                Aviation fuel         13.041601   MJ   Quebec
# 1                       Diesel        231.985429   MJ   Quebec
# 2                     Gasoline          6.031377   MJ   Quebec
# 3               Grinding media               NaN   MJ   Quebec
# 4                      Propane         85.727378   MJ   Quebec
# ..                         ...               ...  ...      ...
# 101                       Lime          0.004903    t   Quebec
# 102            Motor/drill oil          0.000018    t   Quebec
# 103             Sulfur dioxide          0.000521    t   Quebec
# 104           Transmission oil          0.000008    t   Quebec
# 105  Total sodium cyanide used          0.000680    t  Ontario
#
# [106 rows x 7 columns]

# %%
biosphere_df = get_info_for_ids(biosphere_table, best_ids)

# %%
biosphere_df = biosphere_df[['main_id', 'facility_name', 'commodities', 'substance_name', 'unit_normalized', 'value_normalized']]
biosphere_df = biosphere_df.merge(main_df[['main_id', 'province']], on=['main_id'], how='left')
biosphere_df
# Out:
#               main_id   facility_name commodities  \
# 0    ON-MAIN-687b8c8d          Island        Gold
# 1    ON-MAIN-7607a50e  Young-Davidson        Gold
# 2    ON-MAIN-687b8c8d          Island        Gold
# 3    ON-MAIN-7607a50e  Young-Davidson        Gold
# 4    ON-MAIN-687b8c8d          Island        Gold
# ..                ...             ...         ...
# 499               NaN      Hoyle Pond        Gold
# 500               NaN      Hoyle Pond        Gold
# 501               NaN      Hoyle Pond        Gold
# 502               NaN      Hoyle Pond        Gold
# 503               NaN      Hoyle Pond        Gold
#
#                    substance_name unit_normalized  value_normalized province
# 0                 Ammonia (total)          tonnes      1.100208e-06  Ontario
# 1    Antimony (and its compounds)          tonnes      2.432205e-12  Ontario
# 2     Arsenic (and its compounds)              kg      4.151405e-06  Ontario
# 3     Arsenic (and its compounds)              kg      1.134033e-08  Ontario
# 4     Cadmium (and its compounds)              kg      3.143451e-08  Ontario
# ..                            ...             ...               ...      ...
# 499                           SOx          tonnes      1.511508e-07      NaN
# 500                         Water              m3      1.825518e+00      NaN
# 501                         Water              m3      3.150320e+00      NaN
# 502                         Water              m3      1.685956e+00      NaN
# 503                           NaN              ha      9.564514e-04      NaN
#
# [504 rows x 7 columns]

# %% [markdown]
# ## Facilities with only biosphere flows

# %%
main_df_other = get_info_for_ids(main_table, other_ids)
main_df_other = main_df_other[['main_id', 'facility_name', 'province', 'facility_type', 'mining_processing_type', 'commodities']]
main_df_other

# %%
biosphere_df_other = get_info_for_ids(biosphere_table, best_ids)
biosphere_df_other = biosphere_df[
    ['main_id', 'facility_name', 'commodities', 'substance_name', 'unit_normalized', 'value_normalized']]
biosphere_df_other = biosphere_df.merge(main_df[['main_id', 'province']], on=['main_id'], how='left')
biosphere_df_other

# %% [markdown]
# # Map MetalliCan flows to EI and RI flows

# %% [markdown]
# ## Technosphere flows

# %%
mapping_technosphere = pd.read_excel(r'data/Mappings/MAPPINGS_RI.xlsx', sheet_name='technosphere')

# %%
from core.conversion_functions import map_technosphere_to_ecoinvent, map_biosphere_to_ecoinvent
from core.constants import CA_provinces

# %%
# Apply the function
mapped_technosphere_df = map_technosphere_to_ecoinvent(technosphere_df, mapping_technosphere, CA_provinces)
# Out:
# Index(['main_id', 'facility_name', 'commodities', 'subflow_type',
#        'value_normalized', 'unit', 'province', 'Type', 'MetalliCan',
#        'MetalliCan_unit', 'DB_to_map', 'Reference product', 'Flow name',
#        'Location', 'Unit', 'Comment'],
#       dtype='object')
# ⚠️ Les flux suivants n'ont pas trouvé de correspondance dans Ecoinvent:
#  - Grinding media
#  - Electricity consumption|Generated on-site
#  - Solar
#  - Total blasting agents used e.g. ANFO
#  - Tires
#  - Polyfroth h57
# ℹ️ Conversion explosive par défaut utilisée (3.0 MJ/kg) pour: Explosives
# ℹ️ Conversion explosive par défaut utilisée (3.0 MJ/kg) pour: Explosives
# ℹ️ Conversion explosive par défaut utilisée (3.0 MJ/kg) pour: Explosives
# ℹ️ Conversion explosive par défaut utilisée (3.0 MJ/kg) pour: Explosives
# ℹ️ Conversion explosive par défaut utilisée (3.0 MJ/kg) pour: Explosives
# ℹ️ Conversion explosive par défaut utilisée (3.0 MJ/kg) pour: Explosives

# %%
# Drop rows where ecoinvent_flow_name is "No mapping" and Amount is NaN for now
mapped_technosphere_df = mapped_technosphere_df[
    (mapped_technosphere_df["Activity"] != "No mapping") &
    (~mapped_technosphere_df["Amount"].isna())
]

# %%
mapped_technosphere_df = mapped_technosphere_df[['main_id', 'facility_name', 'Amount', 'Activity', 'Product', 'Unit', 'Location', 'Database']]

# %%
mapped_technosphere_df
# Out:
#               main_id   facility_name      Amount  \
# 0    QC-MAIN-6dc537e6        Éléonore    0.302589
# 1    QC-MAIN-6dc537e6        Éléonore    5.395010
# 2    QC-MAIN-6dc537e6        Éléonore    0.135842
# 5    QC-MAIN-6dc537e6        Éléonore    1.847573
# 6    QC-MAIN-6dc537e6        Éléonore  149.212433
# ..                ...             ...         ...
# 109  QC-MAIN-02884fb5  Westwood-Doyon    4.902611
# 110  QC-MAIN-02884fb5  Westwood-Doyon    0.018279
# 111  QC-MAIN-02884fb5  Westwood-Doyon    0.521277
# 112  QC-MAIN-02884fb5  Westwood-Doyon    0.007834
# 113  ON-MAIN-7607a50e  Young-Davidson    0.679523
#
#                                           Activity  \
# 0                  consumption market for kerosene
# 1                    consumption market for diesel
# 2                    consumption market for diesel
# 5                   consumption market for propane
# 6           market for electricity, medium voltage
# ..                                             ...
# 109                    consumption market for lime
# 110         consumption market for lubricating oil
# 111  consumption market for sulfur dioxide, liquid
# 112         consumption market for lubricating oil
# 113          consumption market for sodium cyanide
#
#                          Product           Unit Location  \
# 0                       kerosene       kilogram       CA
# 1                         diesel             kg       CA
# 2                         diesel             kg       CA
# 5                        propane       kilogram       CA
# 6    electricity, medium voltage  kilowatt hour    CA-QC
# ..                           ...            ...      ...
# 109                         lime       kilogram       CA
# 110              lubricating oil       kilogram       CA
# 111       sulfur dioxide, liquid       kilogram       CA
# 112              lubricating oil       kilogram       CA
# 113               sodium cyanide       kilogram       CA
#
#                                Database
# 0                           Regioinvent
# 1                           Regioinvent
# 2                           Regioinvent
# 5                           Regioinvent
# 6    ecoinvent-3.10-cutoff regionalized
# ..                                  ...
# 109                         Regioinvent
# 110                         Regioinvent
# 111                         Regioinvent
# 112                         Regioinvent
# 113                         Regioinvent
#
# [88 rows x 8 columns]

# %% [markdown]
# ## Biosphere flows mapping

# %%
mapping_biosphere = pd.read_excel(r'data/Mappings/MAPPINGS_RI.xlsx', sheet_name='biosphere')
mapping_biosphere
# Out:
#                     Type substance_id                  substance_name  \
# 0    Environmental_flows      95-63-6          1,2,4-Trimethylbenzene
# 1    Environmental_flows      57-97-6  7,12-Dimethylbenz[a]anthracene
# 2    Environmental_flows     194-59-2        7H-Dibenzo[c,g]carbazole
# 3    Environmental_flows      83-32-9                    Acenaphthene
# 4    Environmental_flows      83-32-9                    Acenaphthene
# ..                   ...          ...                             ...
# 413  Environmental_flows      NA - 14        Zinc (and its compounds)
# 414  Environmental_flows      NA - 14        Zinc (and its compounds)
# 415  Environmental_flows      NA - 14        Zinc (and its compounds)
# 416  Environmental_flows      NA - 14        Zinc (and its compounds)
# 417  Environmental_flows      NA - 14        Zinc (and its compounds)
#
#     compartment_name     release_pathway flow_direction MetalliCan_unit  \
# 0                Air               Other       Emission          tonnes
# 1                Air  Fugitive Emissions       Emission             NaN
# 2                Air     Stack Emissions       Emission              kg
# 3                Air  Fugitive Emissions       Emission              kg
# 4                Air     Stack Emissions       Emission              kg
# ..               ...                 ...            ...             ...
# 413              Air  Storage / Handling       Emission          tonnes
# 414             Land               Other       Emission          tonnes
# 415             Land              Spills       Emission          tonnes
# 416            Water    Direct Discharge       Emission          tonnes
# 417            Water           Waterbody       Emission          tonnes
#
#       DB_to_map                              Flow name  \
# 0    biosphere3                 2,2,4-Trimethylpentane
# 1    biosphere3                  Dibenz(a,h)anthracene
# 2    biosphere3  PAH, polycyclic aromatic hydrocarbons
# 3    biosphere3                           Acenaphthene
# 4    biosphere3                           Acenaphthene
# ..          ...                                    ...
# 413  biosphere3                                Zinc II
# 414  biosphere3                                Zinc II
# 415  biosphere3                                Zinc II
# 416  biosphere3                                Zinc II
# 417  biosphere3                                Zinc II
#
#                Compartments      Unit                                Comment
# 0                  ('air',)  kilogram                                    NaN
# 1                  ('air',)  kilogram                                    NaN
# 2                  ('air',)  kilogram  Polycyclic Aromatic Hydrocarbon (PAH)
# 3                  ('air',)  kilogram                                    NaN
# 4                  ('air',)  kilogram                                    NaN
# ..                      ...       ...                                    ...
# 413                ('air',)  kilogram                                    NaN
# 414  ('soil', 'industrial')  kilogram                                    NaN
# 415  ('soil', 'industrial')  kilogram                                    NaN
# 416              ('water',)  kilogram                                    NaN
# 417              ('water',)  kilogram                                    NaN
#
# [418 rows x 12 columns]

# %%
mapped_biosphere_df = map_biosphere_to_ecoinvent(biosphere_df, mapping_biosphere, CA_provinces)
# Out:
# Index(['main_id', 'facility_name', 'commodities', 'substance_name',
#        'unit_normalized', 'value_normalized', 'province', 'Type',
#        'substance_id', 'compartment_name', 'release_pathway', 'flow_direction',
#        'MetalliCan_unit', 'DB_to_map', 'Flow name', 'Compartments', 'Unit',
#        'Comment'],
#       dtype='object')
# ⚠️ 4 biosphere flows could not be mapped to Ecoinvent:
#    - N2O
#    - PFCs
#    - Water
#    - nan
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tonnes → kilo becquerel (flow: Manganese (and its compounds))
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: CO2)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: CH4)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: CO2)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → nan (flow: N2O)
# ⚠️ No conversion defined for tco2eq → nan (flow: PFCs)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: CO2)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: CH4)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: CO2)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → nan (flow: N2O)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for tco2eq → kilogram (flow: GHG)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for m3 → nan (flow: Water)
# ⚠️ No conversion defined for ha → nan (flow: nan)
# ✅ Mapped 2866 biosphere flows (44 unique flows).

# %%
mapped_biosphere_df
# Out:
#                main_id facility_name commodities   substance_name province  \
# 0     ON-MAIN-687b8c8d        Island        Gold  Ammonia (total)  Ontario
# 1     ON-MAIN-687b8c8d        Island        Gold  Ammonia (total)  Ontario
# 2     ON-MAIN-687b8c8d        Island        Gold  Ammonia (total)  Ontario
# 3     ON-MAIN-687b8c8d        Island        Gold  Ammonia (total)  Ontario
# 4     ON-MAIN-687b8c8d        Island        Gold  Ammonia (total)  Ontario
# ...                ...           ...         ...              ...      ...
# 2861               NaN    Hoyle Pond        Gold              SOx      NaN
# 2862               NaN    Hoyle Pond        Gold            Water      NaN
# 2863               NaN    Hoyle Pond        Gold            Water      NaN
# 2864               NaN    Hoyle Pond        Gold            Water      NaN
# 2865               NaN    Hoyle Pond        Gold              NaN      NaN
#
#            Flow Name                                       Compartments  \
# 0     Ammonia, CA-ON        ('air', 'low population density long term')
# 1     Ammonia, CA-ON        ('air', 'low population density long term')
# 2     Ammonia, CA-ON        ('air', 'low population density long term')
# 3            Ammonia                             ('soil', 'industrial')
# 4           Ammonium                                         ('water',)
# ...              ...                                                ...
# 2861  Sulfur dioxide  ('air', 'lower stratosphere + upper troposphere')
# 2862      No mapping                                         No mapping
# 2863      No mapping                                         No mapping
# 2864      No mapping                                         No mapping
# 2865      No mapping                                         No mapping
#
#         Amount      Unit                      Database
# 0     0.001100  kilogram  biosphere3_spatialized_flows
# 1     0.001100  kilogram  biosphere3_spatialized_flows
# 2     0.001100  kilogram  biosphere3_spatialized_flows
# 3     0.001100  kilogram                    biosphere3
# 4     0.001100  kilogram                    biosphere3
# ...        ...       ...                           ...
# 2861  0.000151  kilogram                    biosphere3
# 2862  1.825518       NaN                    biosphere3
# 2863  3.150320       NaN                    biosphere3
# 2864  1.685956       NaN                    biosphere3
# 2865  0.000956       NaN                    biosphere3
#
# [2866 rows x 10 columns]

# %%
# Drop rows where ecoinvent_flow_name is "No mapping" and Amount is NaN for now
mapped_biosphere_df = mapped_biosphere_df[
    (mapped_biosphere_df["Flow Name"] != "No mapping") &
    (~mapped_biosphere_df["Amount"].isna())
]

# %%
mapped_biosphere_df = mapped_biosphere_df[['main_id', 'facility_name', 'Amount', 'Unit', 'Flow Name', 'Compartments', 'Database']]

# %%
mapped_biosphere_df
# Out:
#                main_id facility_name    Amount      Unit  \
# 0     ON-MAIN-687b8c8d        Island  0.001100  kilogram
# 1     ON-MAIN-687b8c8d        Island  0.001100  kilogram
# 2     ON-MAIN-687b8c8d        Island  0.001100  kilogram
# 3     ON-MAIN-687b8c8d        Island  0.001100  kilogram
# 4     ON-MAIN-687b8c8d        Island  0.001100  kilogram
# ...                ...           ...       ...       ...
# 2857               NaN    Hoyle Pond  0.004720  kilogram
# 2858               NaN    Hoyle Pond  0.004720  kilogram
# 2859               NaN    Hoyle Pond  0.004720  kilogram
# 2860               NaN    Hoyle Pond  0.004720  kilogram
# 2861               NaN    Hoyle Pond  0.000151  kilogram
#
#                                 Flow Name  \
# 0                          Ammonia, CA-ON
# 1                          Ammonia, CA-ON
# 2                          Ammonia, CA-ON
# 3                                 Ammonia
# 4                                Ammonium
# ...                                   ...
# 2857  Particulate Matter, < 2.5 um, CA-xx
# 2858  Particulate Matter, < 2.5 um, CA-xx
# 2859  Particulate Matter, < 2.5 um, CA-xx
# 2860  Particulate Matter, < 2.5 um, CA-xx
# 2861                       Sulfur dioxide
#
#                                            Compartments  \
# 0           ('air', 'low population density long term')
# 1           ('air', 'low population density long term')
# 2           ('air', 'low population density long term')
# 3                                ('soil', 'industrial')
# 4                                            ('water',)
# ...                                                 ...
# 2857        ('air', 'low population density long term')
# 2858        ('air', 'low population density long term')
# 2859        ('air', 'low population density long term')
# 2860        ('air', 'low population density long term')
# 2861  ('air', 'lower stratosphere + upper troposphere')
#
#                           Database
# 0     biosphere3_spatialized_flows
# 1     biosphere3_spatialized_flows
# 2     biosphere3_spatialized_flows
# 3                       biosphere3
# 4                       biosphere3
# ...                            ...
# 2857  biosphere3_spatialized_flows
# 2858  biosphere3_spatialized_flows
# 2859  biosphere3_spatialized_flows
# 2860  biosphere3_spatialized_flows
# 2861                    biosphere3
#
# [1925 rows x 7 columns]

# %% [markdown]
# # LCI creation

# %%
from core.lci_database_builder import LCIDatabaseBuilder

# %%
# Step 1 — initialize the builder
builder = LCIDatabaseBuilder(
    db_name='metallican_lci',
    project_name='metallican'
)
# Out:
# 📂 Active Brightway project: metallican
# ✅ Using existing database 'metallican_lci'.

# %%
# Step 2 — create the activity shells from the main dataframe
builder.build_lci_entries(
    df=main_df,
    facility_col="facility_name",
    site_id_col="main_id"
)

# You can check what was created:
print(len(builder.lcis))
list(builder.lcis.keys())[:5]
# Out:
# ✅ Created 10 base LCI activities with production exchanges.
# 10
# [('metallican_lci', 'Underground, concentrator Gold, Island'),
#  ('metallican_lci', 'Underground, concentrator Gold, Young-Davidson'),
#  ('metallican_lci', 'Underground, concentrator Gold, silver, Westwood-Doyon'),
#  ('metallican_lci',
#   'Underground, concentrator Gold, copper, silver, New Afton'),
#  ('metallican_lci',
#   'Open-pit, underground, concentrator Gold, silver, Rainy River')]

# %%
# Step 3a — Populate with the technosphere exchanges
builder.populate_technosphere_exchanges(
    technosphere_df=mapped_technosphere_df,
    site_id_column="main_id"
)
# Out:
# Populating biosphere exchanges
#    ✅ Cached 218246 activities from Regioinvent
#    ✅ Cached 20769 activities from ecoinvent-3.10-cutoff regionalized
# ✅ Added 78 technosphere exchanges.

# %%
# Step 3b — Populate with the biosphere exchanges
builder.populate_biosphere_exchanges(
    biosphere_df=mapped_biosphere_df,
    site_id_column="main_id"
)
# Out:
# 🌱 Populating biosphere exchanges
#    ✅ Cached 110559 biosphere flows from biosphere3_spatialized_flows
#    ✅ Cached 4362 biosphere flows from biosphere3
# ✅ Added 1868 biosphere exchanges.
# ⚠️ 11 flows could not be matched to biosphere3:
#    - ('soil',) (emission, biosphere3)
#    - ('soil',) (emission, biosphere3)
#    - ('soil',) (emission, biosphere3)
#    - ('soil',) (emission, biosphere3)
#    - ('soil',) (emission, biosphere3)
#    - ('soil',) (emission, biosphere3)
#    - ('soil',) (emission, biosphere3)
#    - ('soil',) (emission, biosphere3)
#    - ('soil',) (emission, biosphere3)
#    - ('soil',) (emission, biosphere3)
#    ... and 1 more.

# %%
# Step 4 - Consolidate duplicate flows
builder.consolidate_exchanges()
# Out:
# 🧮 Consolidation: 1956 → 226 exchanges (summed duplicates).

# %%
builder.write_to_database()
# Out:
# 🧱 Writing 10 activities to database 'metallican_lci'...
# ♻️ Overwriting existing activity: Underground, concentrator Gold, Young-Davidson
# C:\Users\mp_ma\anaconda3\envs\lca\lib\site-packages\bw2data\backends\peewee\database.py:328: UserWarning:
#             Please use `del databases['metallican_lci']` instead.
#             Otherwise, the metadata and database get out of sync.
#             Call `.delete(warn=False)` to skip this message in the future.
#
#   warnings.warn(MESSAGE.format(self.name), UserWarning)
# ✅ Database 'metallican_lci' processed successfully with 9 activities.
