# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# %%
from typing import List, Tuple

# %%
# Custom functions
from some_functions import get_info_for_ids, create_sankey_diagram, get_production_data

# %%
metallican_path = r'C:\Users\mp_ma\OneDrive - polymtl\POST_DOC\CODE\metallican_db'

# %% [markdown]
# # MetalliCan data availability

# %%
df = pd.read_csv(r'C:\Users\mp_ma\OneDrive - polymtl\POST_DOC\CODE\metallican_db\results\data_coverage\data_coverage_per_table.csv')

# %%
import pandas as pd
import plotly.graph_objects as go
from collections import defaultdict

def generate_sankey_from_data(df):
    # Filtrer les données pour exclure les installations de type "advanced project"
    filtered_data = df[df['facility_type'] != 'advanced project'].copy()

    # Catégoriser les flux comme "Non" ou "Oui" pour chaque table
    filtered_data['Production'] = filtered_data['Production table'].apply(lambda x: 'Oui' if x > 0 else 'Non')
    filtered_data['Materials and energy'] = filtered_data['Materials and energy table'].apply(lambda x: 'Oui' if x > 0 else 'Non')
    filtered_data['Environmental flows'] = filtered_data['Environmental flows table'].apply(lambda x: 'Oui' if x > 0 else 'Non')
    filtered_data['Land occupation'] = filtered_data['Land occupation table'].apply(lambda x: 'Oui' if x > 0 else 'Non')

    # Liste des étapes dans l'ordre
    targets = ['facility_type', 'Production', 'Materials and energy', 'Environmental flows', 'Land occupation']

    # Créer un dictionnaire pour compter les transitions
    transition_counts = defaultdict(int)

    # Compter les transitions
    for _, row in filtered_data.iterrows():
        path = [str(row[target]) for target in targets]
        for i in range(len(path) - 1):
            transition = (f"{targets[i]}: {path[i]}", f"{targets[i+1]}: {path[i+1]}")
            transition_counts[transition] += 1

    # Extraire les labels uniques en tant que chaînes de caractères
    all_labels = sorted(set(item for transition in transition_counts.keys() for item in transition))
    label_to_index = {label: index for index, label in enumerate(all_labels)}

    # Préparer les données pour le Sankey
    source_indices = []
    target_indices = []
    values = []

    for (source, target), count in transition_counts.items():
        source_indices.append(label_to_index[source])
        target_indices.append(label_to_index[target])
        values.append(count)

    # Couleurs des nœuds : gris clair pour tous
    node_colors = ['lightgrey'] * len(all_labels)

    # Couleurs des liens : vert clair si la cible est "Oui", rouge clair si "Non"
    link_colors = []
    for (source, target) in transition_counts.keys():
        if target.endswith("Oui"):
            link_colors.append('rgba(144, 238, 144, 0.7)')  # Vert clair
        else:
            link_colors.append('rgba(255, 182, 193, 0.7)')  # Rouge clair

    # Créer le diagramme de Sankey
    fig = go.Figure(go.Sankey(
        arrangement="fixed",
        node=dict(
            pad=50,
            thickness=20,
            line=dict(color="black", width=0.5),
            label=all_labels,
            color=node_colors,
        ),
        link=dict(
            source=source_indices,
            target=target_indices,
            value=values,
            color=link_colors
        )
    ))

    fig.update_layout(title_text="Diagramme de Sankey des flux de données", font_size=12)
    fig.show()

# Exemple d'utilisation
# data = pd.read_csv('data_coverage_per_table.csv')
# generate_sankey_from_data(data)

# Exemple d'utilisation
# data = pd.read_csv('data_coverage_per_table.csv')
generate_sankey_from_data(df)

# %% [markdown]
# # Define functions

# %%
def abbreviate_metals(s, metal_map):
    """Replace metal names with abbreviations in a comma-separated string. Case-insensitive."""
    if not isinstance(s, str):
        return s
    parts = [p.strip() for p in s.split(",")]
    abbr_parts = [metal_map.get(p.lower(), p) for p in parts]  # lowercase lookup
    return ", ".join(abbr_parts)

# %% [markdown]
# # Import MetalliCan tables

# %%
main_table = pd.read_csv(metallican_path + r'\database\CSV\main_table.csv')
tech_attributes_table = pd.read_csv(metallican_path + r'\database\CSV\tech_attributes_table.csv')
archetypes_table = pd.read_csv(metallican_path + r'\database\CSV\archetypes_table.csv')
land_table = pd.read_csv(metallican_path + r'\database\CSV\land_occupation_table.csv')

# %%
substances_table = pd.read_csv(metallican_path + r'\database\CSV\substances_table.csv')

# %%
# Normalized tables, after cleaning
biosphere_df = pd.read_excel(r'data\MetalliCan\biosphere_df_norm.xlsx')
material_df = pd.read_excel(r'data\MetalliCan\material_df_sd_norm.xlsx')
energy_df = pd.read_excel(r'data\MetalliCan\energy_df_sd_norm.xlsx')

# %%
energy_df
# Out:
#           technosphere_id  year flow_type  \
# 0    TECH-857b7b89-2023-1  2023    Energy
# 1    TECH-857b7b89-2023-2  2023    Energy
# 2    TECH-857b7b89-2023-3  2023    Energy
# 3    TECH-857b7b89-2023-4  2023    Energy
# 4    TECH-857b7b89-2023-5  2023    Energy
# ..                    ...   ...       ...
# 177  TECH-7607a50e-2023-3  2023    Energy
# 178  TECH-7607a50e-2023-4  2023    Energy
# 179  TECH-7607a50e-2023-5  2023    Energy
# 180  TECH-7607a50e-2023-6  2023    Energy
# 181  TECH-7607a50e-2023-7  2023    Energy
#
#                              subflow_type unit          value  \
# 0                               Acetylene   GJ      18.475651
# 1                           Aviation fuel   GJ   72676.110790
# 2                                  Diesel   GJ  287042.447232
# 3                                Gasoline   GJ   13568.450000
# 4                                 Propane   GJ   42071.041300
# ..                                    ...  ...            ...
# 177                                Diesel   GJ  140100.000000
# 178                              Gasoline   GJ    2124.000000
# 179                                Naphta   GJ    6344.000000
# 180                           Natural gas   GJ  221612.000000
# 181  Total blasting agents used e.g. ANFO    t    2599.500000
#
#                                        comment           main_id  \
# 0                                          NaN  BC-MAIN-857b7b89
# 1                                          NaN  BC-MAIN-857b7b89
# 2                                          NaN  BC-MAIN-857b7b89
# 3                                          NaN  BC-MAIN-857b7b89
# 4                                          NaN  BC-MAIN-857b7b89
# ..                                         ...               ...
# 177                                        NaN  ON-MAIN-7607a50e
# 178                                        NaN  ON-MAIN-7607a50e
# 179                                        NaN  ON-MAIN-7607a50e
# 180                                        NaN  ON-MAIN-7607a50e
# 181  Explosives, treated as energy consumption  ON-MAIN-7607a50e
#
#     facility_group_id    company_id  ... needs_factor  value_tonnes_main  \
# 0                 NaN  CMP-4a434d72  ...        False           166000.0
# 1                 NaN  CMP-4a434d72  ...        False           166000.0
# 2                 NaN  CMP-4a434d72  ...        False           166000.0
# 3                 NaN  CMP-4a434d72  ...        False           166000.0
# 4                 NaN  CMP-4a434d72  ...        False           166000.0
# ..                ...           ...  ...          ...                ...
# 177               NaN  CMP-3a4ccc7f  ...        False          2878047.0
# 178               NaN  CMP-3a4ccc7f  ...        False          2878047.0
# 179               NaN  CMP-3a4ccc7f  ...        False          2878047.0
# 180               NaN  CMP-3a4ccc7f  ...        False          2878047.0
# 181               NaN  CMP-3a4ccc7f  ...         True          2878047.0
#
#     value_tonnes_group value_tonnes_match value_normalized  normalization_key  \
# 0                  NaN           166000.0         0.111299            main_id
# 1                  NaN           166000.0       437.807896            main_id
# 2                  NaN           166000.0      1729.171369            main_id
# 3                  NaN           166000.0        81.737651            main_id
# 4                  NaN           166000.0       253.440008            main_id
# ..                 ...                ...              ...                ...
# 177                NaN          2878047.0        48.678844            main_id
# 178                NaN          2878047.0         0.738000            main_id
# 179                NaN          2878047.0         2.204273            main_id
# 180                NaN          2878047.0        77.000827            main_id
# 181                NaN          2878047.0              NaN            main_id
#
#       facility_name  facility_group_name     mining_processing_type  \
# 0         Brucejack                  NaN  Underground, concentrator
# 1         Brucejack                  NaN  Underground, concentrator
# 2         Brucejack                  NaN  Underground, concentrator
# 3         Brucejack                  NaN  Underground, concentrator
# 4         Brucejack                  NaN  Underground, concentrator
# ..              ...                  ...                        ...
# 177  Young-Davidson                  NaN  Underground, concentrator
# 178  Young-Davidson                  NaN  Underground, concentrator
# 179  Young-Davidson                  NaN  Underground, concentrator
# 180  Young-Davidson                  NaN  Underground, concentrator
# 181  Young-Davidson                  NaN  Underground, concentrator
#
#       commodities
# 0    Gold, silver
# 1    Gold, silver
# 2    Gold, silver
# 3    Gold, silver
# 4    Gold, silver
# ..            ...
# 177          Gold
# 178          Gold
# 179          Gold
# 180          Gold
# 181          Gold
#
# [182 rows x 25 columns]

# %%
# Remove the rows where value_normalized is NaN for the 3 dfs
biosphere_df = biosphere_df.dropna(subset=['value_normalized'])
material_df = material_df.dropna(subset=['value_normalized'])
energy_df = energy_df.dropna(subset=['value_normalized'])

# %%
def convert_to_percent(row):
    if row['unit'] == 'g/t':
        row['value'] = row['value'] / 10000  # 1 g/t = 0.0001%
        row['unit'] = '%'
    # For '%' or any other unit, do nothing
    return row


tech_attributes_table = tech_attributes_table.apply(convert_to_percent, axis=1)
mapping = {
    "Head grade": "Grade",
    "Ore grade": "Grade",
    "Mill ore grade": "Grade",
    "Mill grade": "Grade",
    "Mill feed grade": "Grade",
    "Recovery rate": "Recovery rate",
    "Mill recovery rate": "Recovery rate",
    "Copper recovery rate": "Recovery rate",
    "Strip ratio": "Strip ratio",
    "Concentrate grade": "Concentrate grade",
}

tech_attributes_table['material_type'] = tech_attributes_table['material_type'].replace(mapping)

# %% [markdown]
# # Energy consumption exploration

# %% [markdown]
# ## By energy type

# %%
from constants import nrj_subflow

# %%
# Add a subflow_type_agg column to the energy_std_norm DataFrame based on the dictionnary
energy_df_agg = energy_df.copy()
energy_df_agg['subflow_type_agg'] = energy_df_agg['subflow_type'].map(nrj_subflow).fillna(energy_df_agg['subflow_type'])

# %%
energy_df_agg = (energy_df_agg.groupby(['main_id', 'facility_name', 'facility_group_id', 'facility_group_name', 'company_id','year', 'mining_processing_type', 'commodities', 'flow_type', 'subflow_type_agg'], dropna=False, as_index=False)
                 .agg(value_normalized_sum=('value_normalized', 'sum'))
)

# %%
energy_df_agg
# Out:
#               main_id    facility_name facility_group_id facility_group_name  \
# 0    BC-MAIN-599152a0  Copper Mountain               NaN                 NaN
# 1    BC-MAIN-599152a0  Copper Mountain               NaN                 NaN
# 2    BC-MAIN-599152a0  Copper Mountain               NaN                 NaN
# 3    BC-MAIN-599152a0  Copper Mountain               NaN                 NaN
# 4    BC-MAIN-6b4800fe        Gibraltar               NaN                 NaN
# ..                ...              ...               ...                 ...
# 143               NaN     Timmins West      GRP-147b3123   Timmins Operation
# 144               NaN     Timmins West      GRP-147b3123   Timmins Operation
# 145               NaN     Timmins West      GRP-147b3123   Timmins Operation
# 146               NaN     Timmins West      GRP-147b3123   Timmins Operation
# 147               NaN     Timmins West      GRP-147b3123   Timmins Operation
#
#        company_id  year  mining_processing_type                 commodities  \
# 0    CMP-12afc634  2023  Open-pit, concentrator        Copper, gold, silver
# 1    CMP-12afc634  2023  Open-pit, concentrator        Copper, gold, silver
# 2    CMP-12afc634  2023  Open-pit, concentrator        Copper, gold, silver
# 3    CMP-12afc634  2023  Open-pit, concentrator        Copper, gold, silver
# 4    CMP-e35f138c  2023  Open-pit, concentrator  Copper, molybdenum, silver
# ..            ...   ...                     ...                         ...
# 143  CMP-48a36546  2023             Underground                        Gold
# 144  CMP-48a36546  2023             Underground                        Gold
# 145  CMP-48a36546  2023             Underground                        Gold
# 146  CMP-48a36546  2023             Underground                        Gold
# 147  CMP-48a36546  2023             Underground                        Gold
#
#     flow_type subflow_type_agg  value_normalized_sum
# 0      Energy           Diesel             11.798048
# 1      Energy      Electricity            286.790500
# 2      Energy         Gasoline              0.053627
# 3      Energy      LPG-Propane              1.474756
# 4      Energy           Diesel             56.121767
# ..        ...              ...                   ...
# 143    Energy           Diesel            244.145997
# 144    Energy      Electricity            469.013215
# 145    Energy       Explosives              4.407116
# 146    Energy         Gasoline              1.871728
# 147    Energy      Natural gas            101.223379
#
# [148 rows x 11 columns]

# %%
from visualisation_functions import plot_stacked_energy_by_site

# %%
plot_stacked_energy_by_site(energy_df_agg, export_path='data/Parametrization/nrj_by_type.html')

# %%
energy_df_agg.to_csv(r'energy_df_agg.csv', index=False)

# %%
df = energy_df_agg.copy()

# %%
df
# Out:
#           technosphere_id  year flow_type  \
# 0    TECH-857b7b89-2023-1  2023    Energy
# 1    TECH-857b7b89-2023-2  2023    Energy
# 2    TECH-857b7b89-2023-3  2023    Energy
# 3    TECH-857b7b89-2023-4  2023    Energy
# 4    TECH-857b7b89-2023-5  2023    Energy
# ..                    ...   ...       ...
# 176  TECH-7607a50e-2023-2  2023    Energy
# 177  TECH-7607a50e-2023-3  2023    Energy
# 178  TECH-7607a50e-2023-4  2023    Energy
# 179  TECH-7607a50e-2023-5  2023    Energy
# 180  TECH-7607a50e-2023-6  2023    Energy
#
#                                  subflow_type unit          value comment  \
# 0                                   Acetylene   GJ      18.475651     NaN
# 1                               Aviation fuel   GJ   72676.110790     NaN
# 2                                      Diesel   GJ  287042.447232     NaN
# 3                                    Gasoline   GJ   13568.450000     NaN
# 4                                     Propane   GJ   42071.041300     NaN
# ..                                        ...  ...            ...     ...
# 176  Electricity consumption|Grid electricity   GJ  960748.000000     NaN
# 177                                    Diesel   GJ  140100.000000     NaN
# 178                                  Gasoline   GJ    2124.000000     NaN
# 179                                    Naphta   GJ    6344.000000     NaN
# 180                               Natural gas   GJ  221612.000000     NaN
#
#               main_id facility_group_id    company_id  ... value_tonnes_main  \
# 0    BC-MAIN-857b7b89               NaN  CMP-4a434d72  ...          166000.0
# 1    BC-MAIN-857b7b89               NaN  CMP-4a434d72  ...          166000.0
# 2    BC-MAIN-857b7b89               NaN  CMP-4a434d72  ...          166000.0
# 3    BC-MAIN-857b7b89               NaN  CMP-4a434d72  ...          166000.0
# 4    BC-MAIN-857b7b89               NaN  CMP-4a434d72  ...          166000.0
# ..                ...               ...           ...  ...               ...
# 176  ON-MAIN-7607a50e               NaN  CMP-3a4ccc7f  ...         2878047.0
# 177  ON-MAIN-7607a50e               NaN  CMP-3a4ccc7f  ...         2878047.0
# 178  ON-MAIN-7607a50e               NaN  CMP-3a4ccc7f  ...         2878047.0
# 179  ON-MAIN-7607a50e               NaN  CMP-3a4ccc7f  ...         2878047.0
# 180  ON-MAIN-7607a50e               NaN  CMP-3a4ccc7f  ...         2878047.0
#
#      value_tonnes_group value_tonnes_match value_normalized normalization_key  \
# 0                   NaN           166000.0         0.111299           main_id
# 1                   NaN           166000.0       437.807896           main_id
# 2                   NaN           166000.0      1729.171369           main_id
# 3                   NaN           166000.0        81.737651           main_id
# 4                   NaN           166000.0       253.440008           main_id
# ..                  ...                ...              ...               ...
# 176                 NaN          2878047.0       333.819427           main_id
# 177                 NaN          2878047.0        48.678844           main_id
# 178                 NaN          2878047.0         0.738000           main_id
# 179                 NaN          2878047.0         2.204273           main_id
# 180                 NaN          2878047.0        77.000827           main_id
#
#       facility_name  facility_group_name     mining_processing_type  \
# 0         Brucejack                  NaN  Underground, concentrator
# 1         Brucejack                  NaN  Underground, concentrator
# 2         Brucejack                  NaN  Underground, concentrator
# 3         Brucejack                  NaN  Underground, concentrator
# 4         Brucejack                  NaN  Underground, concentrator
# ..              ...                  ...                        ...
# 176  Young-Davidson                  NaN  Underground, concentrator
# 177  Young-Davidson                  NaN  Underground, concentrator
# 178  Young-Davidson                  NaN  Underground, concentrator
# 179  Young-Davidson                  NaN  Underground, concentrator
# 180  Young-Davidson                  NaN  Underground, concentrator
#
#       commodities  subflow_type_agg
# 0    Gold, silver       LPG-Propane
# 1    Gold, silver     Aviation fuel
# 2    Gold, silver            Diesel
# 3    Gold, silver          Gasoline
# 4    Gold, silver       LPG-Propane
# ..            ...               ...
# 176          Gold       Electricity
# 177          Gold            Diesel
# 178          Gold          Gasoline
# 179          Gold           Naphtha
# 180          Gold       Natural gas
#
# [171 rows x 26 columns]

# %%
import pandas as pd

def summarize_clusters_by_subflow(
    df,
    cluster_cols,       # List of columns to create clusters
    subflow_col,        # Column to group by within clusters (e.g., 'subflow_type')
    value_col,          # Column to compute statistics
    id_cols=None,       # Optional: list of columns to count unique IDs per cluster and subflow
    stats=['min', 'max', 'mean', 'std', 'count']
):
    """
    Summarize statistics for clusters and subflow types in a DataFrame.
    Includes unique ID counts per cluster and per subflow.
    """
    # Create cluster identifier
    df['cluster'] = df[cluster_cols].astype(str).agg(' | '.join, axis=1)

    # Group by cluster and subflow_col, then compute statistics
    result = df.groupby(['cluster', subflow_col])[value_col].agg(stats).reset_index()

    # Count unique IDs per subflow
    if id_cols:
        for col in id_cols:
            result[f'num_unique_{col}'] = df.groupby(['cluster', subflow_col])[col].nunique().values

    # Count unique IDs per cluster
    if id_cols:
        for col in id_cols:
            cluster_unique_counts = df.groupby('cluster')[col].nunique().reset_index()
            cluster_unique_counts = cluster_unique_counts.rename(columns={col: f'num_unique_{col}_in_cluster'})
            result = result.merge(cluster_unique_counts, on='cluster', how='left')

    # Add cluster_id for easier reference
    result['cluster_id'] = result.groupby('cluster').ngroup() + 1

    return result

# Example usage:
cluster_stats = summarize_clusters_by_subflow(
     df, cluster_cols=['mining_processing_type', 'commodities'],
     subflow_col='subflow_type_agg', value_col='value_normalized',
     id_cols=['main_id', 'facility_group_id']
)

# %%
cluster_stats
# Out:
#                                               cluster subflow_type_agg  \
# 0                                 Concentrator | Gold           Diesel
# 1                                 Concentrator | Gold      Electricity
# 2                                 Concentrator | Gold       Explosives
# 3                                 Concentrator | Gold         Gasoline
# 4                                 Concentrator | Gold      LPG-Propane
# ..                                                ...              ...
# 85  Underground, concentrator | Gold, zinc, copper...      Natural gas
# 86     Underground, concentrator | Silver, zinc, lead           Diesel
# 87     Underground, concentrator | Silver, zinc, lead      Electricity
# 88     Underground, concentrator | Silver, zinc, lead         Gasoline
# 89     Underground, concentrator | Silver, zinc, lead      LPG-Propane
#
#            min          max         mean         std  count  \
# 0   934.482175  1079.139344  1006.810760  102.288065      2
# 1    13.360574  1583.811856   583.913818  868.810693      3
# 2    11.793427    11.793427    11.793427         NaN      1
# 3    13.313992    13.313992    13.313992         NaN      1
# 4     0.061156   329.319672   164.690414  232.820930      2
# ..         ...          ...          ...         ...    ...
# 85  111.885138   111.885138   111.885138         NaN      1
# 86  470.340613   470.340613   470.340613         NaN      1
# 87  497.564131   497.564131   497.564131         NaN      1
# 88   68.294307    68.294307    68.294307         NaN      1
# 89  317.930531   317.930531   317.930531         NaN      1
#
#     num_unique_main_id  num_unique_facility_group_id  \
# 0                    0                             2
# 1                    0                             2
# 2                    0                             1
# 3                    0                             1
# 4                    0                             2
# ..                 ...                           ...
# 85                   1                             0
# 86                   1                             0
# 87                   1                             0
# 88                   1                             0
# 89                   1                             0
#
#     num_unique_main_id_in_cluster  num_unique_facility_group_id_in_cluster  \
# 0                               0                                        2
# 1                               0                                        2
# 2                               0                                        2
# 3                               0                                        2
# 4                               0                                        2
# ..                            ...                                      ...
# 85                              1                                        0
# 86                              1                                        0
# 87                              1                                        0
# 88                              1                                        0
# 89                              1                                        0
#
#     cluster_id
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ..         ...
# 85          16
# 86          17
# 87          17
# 88          17
# 89          17
#
# [90 rows x 12 columns]

# %%
cluster_stats.to_csv(r'data/Parametrization/cluster_nrj.csv', index=False)

# %% [markdown]
# ## Total energy

# %%
energy_table = energy_df.groupby(['main_id', 'facility_group_id'], dropna=False)['value_normalized'].sum().reset_index()

# %%
energy_table.rename(columns={'value_normalized': 'energy_MJ'}, inplace=True)

# %%
# Extract all the rows from the production_data_available that have a non NaN main_id
energy_table_f = energy_table[energy_table['main_id'].notna()]
energy_table_f = energy_table_f.merge(main_table[['main_id', 'facility_name', 'facility_type', 'province', 'mining_processing_type', 'commodities']], on='main_id', how='left').drop_duplicates(subset=['main_id'], keep='first')

# %%
# Extract all the rows from the production_data_available that have a NaN main_id and non NaN facility_group_id
energy_table_fg = energy_table[energy_table['main_id'].isna() & energy_table['facility_group_id'].notna()]
energy_table_fg = energy_table_fg.merge(main_table[['facility_group_id', 'facility_group_name', 'facility_type', 'province', 'mining_processing_type', 'commodities']], on='facility_group_id', how='left').drop_duplicates(subset=['facility_group_id'], keep='first')

# %%
# Ensure all desired columns are present in both DataFrames before concatenation
cols_to_keep = ['main_id', 'facility_name', 'facility_group_id', 'facility_group_name', 'facility_type', 'province', 'mining_processing_type', 'commodities', 'energy_MJ']

# Add missing columns to merged_f
for col in cols_to_keep:
    if col not in energy_table_f.columns:
        energy_table_f[col] = None
# Add missing columns to merged_fg
for col in cols_to_keep:
    if col not in energy_table_fg.columns:
        energy_table_fg[col] = None

# Reorder columns
energy_table_f = energy_table_f[cols_to_keep]
energy_table_fg = energy_table_fg[cols_to_keep]

# Combine the two results
energy_table = pd.concat([energy_table_f, energy_table_fg])

# %%
energy_table['energy_GJ'] = energy_table['energy_MJ'] / 1000

# %%
from constants import metal_map
metal_map_lower = {k.lower(): v for k, v in metal_map.items()}
energy_table['commodities'] = energy_table['commodities'].apply(lambda x: abbreviate_metals(x, metal_map_lower))

# %%
from visualisation_functions import plot_2axes_by_commodity

# %%
fig_nrj_html = plot_2axes_by_commodity(energy_table, x_label=' ', y_label='MJ/t ore processed', export_path='data/Parametrization/nrj.html', export_format='html')

# %% [markdown]
# # Environmental flows exploration

# %%
# Let's keep rows for source_id = https://www.canada.ca/en/environment-climate-change/services/national-pollutant-release-inventory/tools-resources-data/exploredata.html or https://www.canada.ca/en/environment-climate-change/services/environmental-indicators/greenhouse-gas-emissions/large-facilities.html
biosphere_df = biosphere_df[biosphere_df['source_id'].isin([
    'https://www.canada.ca/en/environment-climate-change/services/national-pollutant-release-inventory/tools-resources-data/exploredata.html',
    'https://www.canada.ca/en/environment-climate-change/services/environmental-indicators/greenhouse-gas-emissions/large-facilities.html'
])]

# %%
# Merge to add the main_table information and the substance name
biosphere_df =biosphere_df.merge(main_table[['main_id', 'province', 'facility_type']], on='main_id', how='left')
biosphere_df = biosphere_df.merge(substances_table[['substance_id', 'substance_name']], on='substance_id', how='left')

# %%
biosphere_df
# Out:
#                 env_id  year compartment_name substance_id flow_direction  \
# 0     npri-1568-2023-1  2023              Air      NA - 16       Emission
# 1     npri-1568-2023-2  2023              Air      NA - 02       Emission
# 2     npri-1568-2023-3  2023              Air     630-08-0       Emission
# 3     npri-1568-2023-4  2023              Air      NA - 04       Emission
# 4     npri-1568-2023-5  2023              Air      NA - 05       Emission
# ...                ...   ...              ...          ...            ...
# 2710  GHG-10791-2023-1  2023              Air     NA - GHG       Emission
# 2711  GHG-11730-2023-1  2023              Air     NA - GHG       Emission
# 2712  GHG-11765-2023-1  2023              Air     NA - GHG       Emission
# 2713  GHG-11989-2023-1  2023              Air     NA - GHG       Emission
# 2714  GHG-12298-2023-1  2023              Air     NA - GHG       Emission
#
#       release_pathway    unit         value comment           main_id  ...  \
# 0     Stack Emissions  tonnes       0.63600     NaN  ON-MAIN-1f126a43  ...
# 1     Stack Emissions      kg       0.11600     NaN  ON-MAIN-1f126a43  ...
# 2     Stack Emissions  tonnes      76.20800     NaN  ON-MAIN-1f126a43  ...
# 3     Stack Emissions  tonnes       0.00105     NaN  ON-MAIN-1f126a43  ...
# 4     Stack Emissions      kg       0.18000     NaN  ON-MAIN-1f126a43  ...
# ...               ...     ...           ...     ...               ...  ...
# 2710      Unspecified  tCO2eq  104880.00000     NaN  QC-MAIN-c1c7eb99  ...
# 2711      Unspecified  tCO2eq  406650.00000     NaN  QC-MAIN-92628f16  ...
# 2712      Unspecified  tCO2eq   15600.00000     NaN  ON-MAIN-4c35e094  ...
# 2713      Unspecified  tCO2eq  952950.00000     NaN  QC-MAIN-1eee4ace  ...
# 2714      Unspecified  tCO2eq  325430.00000     NaN  ON-MAIN-63b394c3  ...
#
#      value_normalized  normalization_key unit_normalized  \
# 0        1.440257e-06            main_id        tonnes/t
# 1        2.626883e-07            main_id            kg/t
# 2        1.725772e-04            main_id        tonnes/t
# 3        2.377782e-09            main_id        tonnes/t
# 4        4.076198e-07            main_id            kg/t
# ...               ...                ...             ...
# 2710     6.096276e-01            main_id        tCO2eq/t
# 2711     2.921744e-01            main_id        tCO2eq/t
# 2712     5.032258e-03            main_id        tCO2eq/t
# 2713     5.015526e-01  facility_group_id        tCO2eq/t
# 2714     3.386368e+00  facility_group_id        tCO2eq/t
#
#               facility_name                 facility_group_name  \
# 0                   Macassa                                 NaN
# 1                   Macassa                                 NaN
# 2                   Macassa                                 NaN
# 3                   Macassa                                 NaN
# 4                   Macassa                                 NaN
# ...                     ...                                 ...
# 2710                 Arvida  Saguenay–Lac-Saint-Jean Operations
# 2711              Vaudreuil  Saguenay–Lac-Saint-Jean Operations
# 2712  ArcelorMittal Dofasco                                 NaN
# 2713        Contrecœur East                         Contrecoeur
# 2714   Copper Cliff Complex                   Sudbury Operation
#
#                           mining_processing_type  \
# 0                      Underground, concentrator
# 1                      Underground, concentrator
# 2                      Underground, concentrator
# 3                      Underground, concentrator
# 4                      Underground, concentrator
# ...                                          ...
# 2710                                     Smelter
# 2711                                    Refinery
# 2712  Basic oxygen furnace, electric arc furnace
# 2713                        Electric arc furnace
# 2714                    Smelter, refinery, plant
#
#                                             commodities province  \
# 0                                          Gold, silver  Ontario
# 1                                          Gold, silver  Ontario
# 2                                          Gold, silver  Ontario
# 3                                          Gold, silver  Ontario
# 4                                          Gold, silver  Ontario
# ...                                                 ...      ...
# 2710  Aluminum (pure or alloyed), alumina, aluminum ...   Quebec
# 2711                                            Alumina   Quebec
# 2712                                              Steel  Ontario
# 2713                                              Steel   Quebec
# 2714  Nickel (oxide sinter, pellets, powder, sulfide...  Ontario
#
#       facility_type                substance_name
# 0            mining               Ammonia (total)
# 1            mining   Arsenic (and its compounds)
# 2            mining               Carbon monoxide
# 3            mining  Chromium (and its compounds)
# 4            mining    Cobalt (and its compounds)
# ...             ...                           ...
# 2710  manufacturing                           GHG
# 2711  manufacturing                           GHG
# 2712  manufacturing                           GHG
# 2713  manufacturing                           GHG
# 2714  manufacturing                           GHG
#
# [2715 rows x 26 columns]

# %%
biosphere_df['commodities'] = biosphere_df['commodities'].apply(lambda x: abbreviate_metals(x, metal_map_lower))

# %%
biosphere_mining_df = biosphere_df[biosphere_df['facility_type'] == 'mining']
biosphere_man_df = biosphere_df[biosphere_df['facility_type'] == 'manufacturing']

# %%
biosphere_df
# Out:
#                 env_id  year compartment_name substance_id flow_direction  \
# 0     npri-1568-2023-1  2023              Air      NA - 16       Emission
# 1     npri-1568-2023-2  2023              Air      NA - 02       Emission
# 2     npri-1568-2023-3  2023              Air     630-08-0       Emission
# 3     npri-1568-2023-4  2023              Air      NA - 04       Emission
# 4     npri-1568-2023-5  2023              Air      NA - 05       Emission
# ...                ...   ...              ...          ...            ...
# 2710  GHG-10791-2023-1  2023              Air     NA - GHG       Emission
# 2711  GHG-11730-2023-1  2023              Air     NA - GHG       Emission
# 2712  GHG-11765-2023-1  2023              Air     NA - GHG       Emission
# 2713  GHG-11989-2023-1  2023              Air     NA - GHG       Emission
# 2714  GHG-12298-2023-1  2023              Air     NA - GHG       Emission
#
#       release_pathway    unit         value comment           main_id  ...  \
# 0     Stack Emissions  tonnes       0.63600     NaN  ON-MAIN-1f126a43  ...
# 1     Stack Emissions      kg       0.11600     NaN  ON-MAIN-1f126a43  ...
# 2     Stack Emissions  tonnes      76.20800     NaN  ON-MAIN-1f126a43  ...
# 3     Stack Emissions  tonnes       0.00105     NaN  ON-MAIN-1f126a43  ...
# 4     Stack Emissions      kg       0.18000     NaN  ON-MAIN-1f126a43  ...
# ...               ...     ...           ...     ...               ...  ...
# 2710      Unspecified  tCO2eq  104880.00000     NaN  QC-MAIN-c1c7eb99  ...
# 2711      Unspecified  tCO2eq  406650.00000     NaN  QC-MAIN-92628f16  ...
# 2712      Unspecified  tCO2eq   15600.00000     NaN  ON-MAIN-4c35e094  ...
# 2713      Unspecified  tCO2eq  952950.00000     NaN  QC-MAIN-1eee4ace  ...
# 2714      Unspecified  tCO2eq  325430.00000     NaN  ON-MAIN-63b394c3  ...
#
#      value_normalized  normalization_key unit_normalized  \
# 0        1.440257e-06            main_id        tonnes/t
# 1        2.626883e-07            main_id            kg/t
# 2        1.725772e-04            main_id        tonnes/t
# 3        2.377782e-09            main_id        tonnes/t
# 4        4.076198e-07            main_id            kg/t
# ...               ...                ...             ...
# 2710     6.096276e-01            main_id        tCO2eq/t
# 2711     2.921744e-01            main_id        tCO2eq/t
# 2712     5.032258e-03            main_id        tCO2eq/t
# 2713     5.015526e-01  facility_group_id        tCO2eq/t
# 2714     3.386368e+00  facility_group_id        tCO2eq/t
#
#               facility_name                 facility_group_name  \
# 0                   Macassa                                 NaN
# 1                   Macassa                                 NaN
# 2                   Macassa                                 NaN
# 3                   Macassa                                 NaN
# 4                   Macassa                                 NaN
# ...                     ...                                 ...
# 2710                 Arvida  Saguenay–Lac-Saint-Jean Operations
# 2711              Vaudreuil  Saguenay–Lac-Saint-Jean Operations
# 2712  ArcelorMittal Dofasco                                 NaN
# 2713        Contrecœur East                         Contrecoeur
# 2714   Copper Cliff Complex                   Sudbury Operation
#
#                           mining_processing_type  \
# 0                      Underground, concentrator
# 1                      Underground, concentrator
# 2                      Underground, concentrator
# 3                      Underground, concentrator
# 4                      Underground, concentrator
# ...                                          ...
# 2710                                     Smelter
# 2711                                    Refinery
# 2712  Basic oxygen furnace, electric arc furnace
# 2713                        Electric arc furnace
# 2714                    Smelter, refinery, plant
#
#                                             commodities province  \
# 0                                                Au, Ag  Ontario
# 1                                                Au, Ag  Ontario
# 2                                                Au, Ag  Ontario
# 3                                                Au, Ag  Ontario
# 4                                                Au, Ag  Ontario
# ...                                                 ...      ...
# 2710  Aluminum (pure or alloyed), alumina, aluminum ...   Quebec
# 2711                                            Alumina   Quebec
# 2712                                              Steel  Ontario
# 2713                                              Steel   Quebec
# 2714  Nickel (oxide sinter, pellets, powder, sulfide...  Ontario
#
#       facility_type                substance_name
# 0            mining               Ammonia (total)
# 1            mining   Arsenic (and its compounds)
# 2            mining               Carbon monoxide
# 3            mining  Chromium (and its compounds)
# 4            mining    Cobalt (and its compounds)
# ...             ...                           ...
# 2710  manufacturing                           GHG
# 2711  manufacturing                           GHG
# 2712  manufacturing                           GHG
# 2713  manufacturing                           GHG
# 2714  manufacturing                           GHG
#
# [2715 rows x 26 columns]

# %%
from visualisation_functions import plot_biosphere

# %%
fig_min = plot_biosphere(
    biosphere_df=biosphere_mining_df,
    x_col='commodities',
    y_col='value_normalized',
    color_col='province',
    symbol_col='mining_processing_type',
    hover_name_cols=['facility_name', 'facility_group_name'],
    y_unit_col='unit_normalized',
    save_path="data/Parametrization/npri_min.html"
)

# %%
fig_man = plot_biosphere(
    biosphere_df=biosphere_man_df,
    x_col='commodities',
    y_col='value_normalized',
    color_col='province',
    symbol_col='mining_processing_type',
    hover_name_cols=['facility_name', 'facility_group_name'],
    y_unit_col='unit_normalized',
    save_path="data/Parametrization/npri_man.html"
)

# %% [markdown]
# # Land occupation exploration

# %%
land_table
# Out:
#     land_occupation_id  area_km2  \
# 0                45954  2.622800
# 1                45955  0.441869
# 2                 7631  0.209038
# 3                 7641  0.113569
# 4                 7633  0.213592
# ..                 ...       ...
# 789     QC-LI-219a2e44  2.926809
# 790     BC-LI-9c3aa818  0.122644
# 791     ON-LI-1a9a061c  4.202254
# 792     QC-LI-94bd8222  6.202897
# 793     MB-LI-3e566fc3  0.409644
#
#                                               geometry  distance_km  \
# 0    POLYGON Z ((-62.920418000502096 44.98665598524...     0.000000
# 1    POLYGON Z ((-62.92612599959345 44.991678995543...     1.186584
# 2    POLYGON Z ((-53.8260233402639 47.4043112260747...     0.811781
# 3    POLYGON Z ((-53.7468445297622 47.4086824659858...     4.647047
# 4    POLYGON Z ((-53.81396413042625 47.413655936064...     0.000000
# ..                                                 ...          ...
# 789  MULTIPOLYGON Z (((-79.08481557072447 48.229685...          NaN
# 790  POLYGON Z ((-130.49619675383414 56.64850845409...          NaN
# 791  MULTIPOLYGON Z (((-81.36899483562593 48.678821...          NaN
# 792  POLYGON Z ((-79.22195784417586 49.574666146450...          NaN
# 793  MULTIPOLYGON Z (((-101.09514443341307 56.81934...          NaN
#
#               main_id  tailing_id  \
# 0    NS-MAIN-c9c77a59         NaN
# 1    NS-MAIN-c9c77a59         NaN
# 2    NL-MAIN-d9036091         NaN
# 3    NL-MAIN-d9036091         NaN
# 4    NL-MAIN-d9036091         NaN
# ..                ...         ...
# 789  QC-MAIN-30c1828c         NaN
# 790  BC-MAIN-b1fe389a         NaN
# 791  ON-MAIN-f8313ebd         NaN
# 792  QC-MAIN-b86f7d07         NaN
# 793  MB-MAIN-6fca9d6d         NaN
#
#                                              source_id
# 0           https://doi.org/10.1038/s43247-023-00805-6
# 1           https://doi.org/10.1038/s43247-023-00805-6
# 2           https://doi.org/10.1038/s43247-023-00805-6
# 3           https://doi.org/10.1038/s43247-023-00805-6
# 4           https://doi.org/10.1038/s43247-023-00805-6
# ..                                                 ...
# 789  https://www.nature.com/articles/s41597-025-052...
# 790  https://www.nature.com/articles/s41597-025-052...
# 791  https://www.nature.com/articles/s41597-025-052...
# 792  https://www.nature.com/articles/s41597-025-052...
# 793  https://www.nature.com/articles/s41597-025-052...
#
# [794 rows x 7 columns]

# %%
# Step 1: Find main_id that have more than one unique source_id
multi_source_main_ids = land_table.groupby('main_id')['source_id'].nunique()
multi_source_main_ids = multi_source_main_ids[multi_source_main_ids > 1].index

# Step 2: Filter the dataframe
land_table = land_table[
    ~land_table['main_id'].isin(multi_source_main_ids) |
    (land_table['source_id'] == "https://www.nature.com/articles/s41597-025-05296-y")
]

# %%
land_table
# Out:
#     land_occupation_id  area_km2  \
# 0                45954  2.622800
# 1                45955  0.441869
# 2                 7631  0.209038
# 3                 7641  0.113569
# 4                 7633  0.213592
# ..                 ...       ...
# 789     QC-LI-219a2e44  2.926809
# 790     BC-LI-9c3aa818  0.122644
# 791     ON-LI-1a9a061c  4.202254
# 792     QC-LI-94bd8222  6.202897
# 793     MB-LI-3e566fc3  0.409644
#
#                                               geometry  distance_km  \
# 0    POLYGON Z ((-62.920418000502096 44.98665598524...     0.000000
# 1    POLYGON Z ((-62.92612599959345 44.991678995543...     1.186584
# 2    POLYGON Z ((-53.8260233402639 47.4043112260747...     0.811781
# 3    POLYGON Z ((-53.7468445297622 47.4086824659858...     4.647047
# 4    POLYGON Z ((-53.81396413042625 47.413655936064...     0.000000
# ..                                                 ...          ...
# 789  MULTIPOLYGON Z (((-79.08481557072447 48.229685...          NaN
# 790  POLYGON Z ((-130.49619675383414 56.64850845409...          NaN
# 791  MULTIPOLYGON Z (((-81.36899483562593 48.678821...          NaN
# 792  POLYGON Z ((-79.22195784417586 49.574666146450...          NaN
# 793  MULTIPOLYGON Z (((-101.09514443341307 56.81934...          NaN
#
#               main_id  tailing_id  \
# 0    NS-MAIN-c9c77a59         NaN
# 1    NS-MAIN-c9c77a59         NaN
# 2    NL-MAIN-d9036091         NaN
# 3    NL-MAIN-d9036091         NaN
# 4    NL-MAIN-d9036091         NaN
# ..                ...         ...
# 789  QC-MAIN-30c1828c         NaN
# 790  BC-MAIN-b1fe389a         NaN
# 791  ON-MAIN-f8313ebd         NaN
# 792  QC-MAIN-b86f7d07         NaN
# 793  MB-MAIN-6fca9d6d         NaN
#
#                                              source_id
# 0           https://doi.org/10.1038/s43247-023-00805-6
# 1           https://doi.org/10.1038/s43247-023-00805-6
# 2           https://doi.org/10.1038/s43247-023-00805-6
# 3           https://doi.org/10.1038/s43247-023-00805-6
# 4           https://doi.org/10.1038/s43247-023-00805-6
# ..                                                 ...
# 789  https://www.nature.com/articles/s41597-025-052...
# 790  https://www.nature.com/articles/s41597-025-052...
# 791  https://www.nature.com/articles/s41597-025-052...
# 792  https://www.nature.com/articles/s41597-025-052...
# 793  https://www.nature.com/articles/s41597-025-052...
#
# [664 rows x 7 columns]

# %%
# For each main_id, give me the sum of area_km2 associated
land_table = land_table.groupby('main_id')['area_km2'].sum().reset_index()

# %%
land_table = land_table.merge(main_table[['main_id', 'facility_group_id', 'facility_name', 'facility_group_name', 'province', 'facility_type', 'mining_processing_type', 'commodities']], on='main_id', how='left')

# %%
land_table
# Out:
#               main_id   area_km2 facility_group_id              facility_name  \
# 0    BC-MAIN-23155c25   1.499690               NaN                 Myra Falls
# 1    BC-MAIN-3ef4f421   1.396089               NaN            Avanti Kitsault
# 2    BC-MAIN-3f490561   7.967835               NaN               Mount Polley
# 3    BC-MAIN-4724f4ba   0.416737               NaN                        Elk
# 4    BC-MAIN-599152a0  13.233210               NaN            Copper Mountain
# ..                ...        ...               ...                        ...
# 111  SK-MAIN-9dd2b7f8   4.345047               NaN            Horseshoe-Raven
# 112  SK-MAIN-bb89158f  10.235647      GRP-21eee27d                   Key Lake
# 113  SK-MAIN-d3c471e8   1.973892      GRP-21eee27d             McArthur River
# 114  YT-MAIN-44857446   5.293594               NaN  Keno Hill Silver District
# 115  YT-MAIN-752fbcae   3.418676               NaN                      Minto
#
#            facility_group_name          province facility_type  \
# 0                          NaN  British Columbia        mining
# 1                          NaN  British Columbia       project
# 2                          NaN  British Columbia        mining
# 3                          NaN  British Columbia        mining
# 4                          NaN  British Columbia        mining
# ..                         ...               ...           ...
# 111                        NaN      Saskatchewan       project
# 112  Key Lake + McArthur River      Saskatchewan        mining
# 113  Key Lake + McArthur River      Saskatchewan        mining
# 114                        NaN             Yukon        mining
# 115                        NaN             Yukon        mining
#
#                   mining_processing_type                       commodities
# 0                            Underground  Zinc, copper, silver, gold, lead
# 1                                    NaN          Molybdenum, silver, lead
# 2                 Open-pit, concentrator              Gold, copper, silver
# 3                               Open-pit                              Gold
# 4                 Open-pit, concentrator              Copper, gold, silver
# ..                                   ...                               ...
# 111                                  NaN                           Uranium
# 112                         Concentrator                           Uranium
# 113                          Underground                           Uranium
# 114            Underground, concentrator                Silver, zinc, lead
# 115  Open-pit, underground, concentrator              Copper, gold, silver
#
# [116 rows x 9 columns]

# %%
land_table_mining = land_table[land_table['facility_type'] == 'mining']

# %%
land_table_mining['commodities'] = land_table_mining['commodities'].apply(lambda x: abbreviate_metals(x, metal_map_lower))
# Out:
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_7996\3042316127.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
land_mining_plot = plot_2axes_by_commodity(land_table_mining, y_col='area_km2',x_label=' ', y_label='km2', export_path='data/Parametrization/land.html', export_format='html')

# %%
ta_grade = tech_attributes_table[tech_attributes_table['material_type'] == 'Grade']
ta_strip = tech_attributes_table[tech_attributes_table['material_type'] == 'Strip ratio']

# %%
ta_grade_ids = set(tech_attributes_table[['main_id', 'facility_group_id']].apply(tuple, axis=1))
ta_strip_ids = set(tech_attributes_table[['main_id', 'facility_group_id']].apply(tuple, axis=1))
ta_common_ids = ta_grade_ids.intersection(ta_strip_ids)

# %% [markdown]
# ## Prepare dfs

# %%
biosphere_param_df = get_info_for_ids(biosphere_df, ta_grade_ids)
biosphere_param_df
# Out:
#                  env_id  year compartment_name substance_id flow_direction  \
# 18    npri-25188-2023-1  2023              Air     630-08-0       Emission
# 19    npri-25188-2023-2  2023              Air   11104-93-1       Emission
# 20    npri-25188-2023-3  2023              Air     NA - M09       Emission
# 21    npri-25188-2023-4  2023              Air     NA - M10       Emission
# 22    npri-25188-2023-5  2023              Air     NA - M08       Emission
# ...                 ...   ...              ...          ...            ...
# 2695   GHG-11894-2023-1  2023              Air     NA - GHG       Emission
# 2696   GHG-11951-2023-1  2023              Air     NA - GHG       Emission
# 2697   GHG-12304-2023-1  2023              Air     NA - GHG       Emission
# 2698   GHG-12553-2023-1  2023              Air     NA - GHG       Emission
# 2702   GHG-10119-2023-1  2023              Air     NA - GHG       Emission
#
#       release_pathway    unit      value comment           main_id  ...  \
# 18    Stack Emissions  tonnes       3.03     NaN  QC-MAIN-e7e6a960  ...
# 19    Stack Emissions  tonnes       9.03     NaN  QC-MAIN-e7e6a960  ...
# 20    Stack Emissions  tonnes       1.73     NaN  QC-MAIN-e7e6a960  ...
# 21    Stack Emissions  tonnes       0.61     NaN  QC-MAIN-e7e6a960  ...
# 22    Stack Emissions  tonnes       7.86     NaN  QC-MAIN-e7e6a960  ...
# ...               ...     ...        ...     ...               ...  ...
# 2695      Unspecified  tCO2eq   70400.00     NaN  BC-MAIN-599152a0  ...
# 2696      Unspecified  tCO2eq   26800.00     NaN  ON-MAIN-7f050560  ...
# 2697      Unspecified  tCO2eq   12400.00     NaN  ON-MAIN-cb85213a  ...
# 2698      Unspecified  tCO2eq   95700.00     NaN  BC-MAIN-8eb8be0d  ...
# 2702      Unspecified  tCO2eq  305170.00     NaN  AB-MAIN-d3a4aba9  ...
#
#      value_tonnes_match value_normalized normalization_key  unit_normalized  \
# 18           19594928.0     1.546319e-07           main_id         tonnes/t
# 19           19594928.0     4.608335e-07           main_id         tonnes/t
# 20           19594928.0     8.828815e-08           main_id         tonnes/t
# 21           19594928.0     3.113050e-08           main_id         tonnes/t
# 22           19594928.0     4.011242e-07           main_id         tonnes/t
# ...                 ...              ...               ...              ...
# 2695          6862152.0     1.025917e-02           main_id         tCO2eq/t
# 2696           841000.0     3.186683e-02           main_id         tCO2eq/t
# 2697           222627.0     5.569855e-02           main_id         tCO2eq/t
# 2698          1139000.0     8.402107e-02           main_id         tCO2eq/t
# 2702            35636.0     8.563531e+00           main_id         tCO2eq/t
#
#                          facility_name          province  facility_type  \
# 18                   Canadian Malartic            Quebec         mining
# 19                   Canadian Malartic            Quebec         mining
# 20                   Canadian Malartic            Quebec         mining
# 21                   Canadian Malartic            Quebec         mining
# 22                   Canadian Malartic            Quebec         mining
# ...                                ...               ...            ...
# 2695                   Copper Mountain  British Columbia         mining
# 2696                          Red Lake           Ontario         mining
# 2697                       Eagle River           Ontario         mining
# 2698                         Red Chris  British Columbia         mining
# 2702  The Cobalt Refinery Company Inc.           Alberta  manufacturing
#
#          mining_processing_type                               commodities  \
# 18       Open-pit, concentrator                                    Au, Ag
# 19       Open-pit, concentrator                                    Au, Ag
# 20       Open-pit, concentrator                                    Au, Ag
# 21       Open-pit, concentrator                                    Au, Ag
# 22       Open-pit, concentrator                                    Au, Ag
# ...                         ...                                       ...
# 2695     Open-pit, concentrator                                Cu, Au, Ag
# 2696  Underground, concentrator                                    Au, Ag
# 2697  Underground, concentrator                                        Au
# 2698     Open-pit, concentrator                                Au, Cu, Ag
# 2702                   Refinery  Ni, Co, copper sulfide, ammonium sulfate
#
#                                        substance_name
# 18                                    Carbon monoxide
# 19    Nitrogen oxides (expressed as nitrogen dioxide)
# 20        PM10 - Particulate Matter <= 10 Micrometers
# 21      PM2.5 - Particulate Matter <= 2.5 Micrometers
# 22                           Total particulate matter
# ...                                               ...
# 2695                                              GHG
# 2696                                              GHG
# 2697                                              GHG
# 2698                                              GHG
# 2702                                              GHG
#
# [1031 rows x 25 columns]

# %%
# Extract all the rows from the production_data_available that have a non NaN main_id
biosphere_param_df_f = biosphere_param_df[biosphere_param_df['main_id'].notna()]
biosphere_param_df_f = biosphere_param_df_f.merge(main_table[['main_id', 'facility_name', 'facility_type', 'province', 'mining_processing_type', 'commodities']], on='main_id', how='left').drop_duplicates(subset=['main_id'], keep='first')

# %%
# Extract all the rows from the production_data_available that have a NaN main_id and non NaN facility_group_id
biosphere_param_df_fg = biosphere_param_df[biosphere_param_df['main_id'].isna() & biosphere_param_df['facility_group_id'].notna()]
biosphere_param_df_fg = biosphere_param_df_fg.merge(main_table[['facility_group_id', 'facility_group_name', 'facility_type', 'province', 'mining_processing_type', 'commodities']], on='facility_group_id', how='left').drop_duplicates(subset=['facility_group_id'], keep='first')

# %%
biosphere_param_df_f.columns
# Out:
# Index(['env_id', 'year', 'compartment_name', 'substance_id', 'flow_direction',
#        'release_pathway', 'unit', 'value', 'comment', 'main_id',
#        'facility_group_id', 'company_id', 'source_id', 'value_tonnes_main',
#        'value_tonnes_group', 'value_tonnes_match', 'value_normalized',
#        'normalization_key', 'unit_normalized', 'facility_name_x', 'province_x',
#        'facility_type_x', 'mining_processing_type_x', 'commodities_x',
#        'substance_name', 'facility_name_y', 'facility_type_y', 'province_y',
#        'mining_processing_type_y', 'commodities_y'],
#       dtype='object')

# %%
biosphere_param_df_fg.columns
# Out:
# Index(['env_id', 'year', 'compartment_name', 'substance_id', 'flow_direction',
#        'release_pathway', 'unit', 'value', 'comment', 'main_id',
#        'facility_group_id', 'company_id', 'source_id', 'value_tonnes_main',
#        'value_tonnes_group', 'value_tonnes_match', 'value_normalized',
#        'normalization_key', 'unit_normalized', 'facility_name', 'province_x',
#        'facility_type_x', 'mining_processing_type_x', 'commodities_x',
#        'substance_name', 'facility_group_name', 'facility_type_y',
#        'province_y', 'mining_processing_type_y', 'commodities_y'],
#       dtype='object')

# %%
# Ensure all desired columns are present in both DataFrames before concatenation
cols_to_keep = ['main_id', 'facility_name', 'facility_group_id', 'facility_group_name', 'facility_type', 'province', 'mining_processing_type', 'commodities', 'energy_MJ']

# Add missing columns to merged_f
for col in cols_to_keep:
    if col not in energy_table_f.columns:
        energy_table_f[col] = None
# Add missing columns to merged_fg
for col in cols_to_keep:
    if col not in energy_table_fg.columns:
        energy_table_fg[col] = None

# Reorder columns
energy_table_f = energy_table_f[cols_to_keep]
energy_table_fg = energy_table_fg[cols_to_keep]

# Combine the two results
energy_table = pd.concat([energy_table_f, energy_table_fg])

# %%
biosphere_param_df.to_excel(r'data/Parametrization/param_biosphere.xlsx', index=False)

# %%
energy_param_df = get_info_for_ids(energy_df, ta_grade_ids)
energy_param_df
# Out:
#           technosphere_id  year flow_type  \
# 0    TECH-857b7b89-2023-1  2023    Energy
# 1    TECH-857b7b89-2023-2  2023    Energy
# 2    TECH-857b7b89-2023-3  2023    Energy
# 3    TECH-857b7b89-2023-4  2023    Energy
# 4    TECH-857b7b89-2023-5  2023    Energy
# ..                    ...   ...       ...
# 176  TECH-7607a50e-2023-2  2023    Energy
# 177  TECH-7607a50e-2023-3  2023    Energy
# 178  TECH-7607a50e-2023-4  2023    Energy
# 179  TECH-7607a50e-2023-5  2023    Energy
# 180  TECH-7607a50e-2023-6  2023    Energy
#
#                                  subflow_type unit          value comment  \
# 0                                   Acetylene   GJ      18.475651     NaN
# 1                               Aviation fuel   GJ   72676.110790     NaN
# 2                                      Diesel   GJ  287042.447232     NaN
# 3                                    Gasoline   GJ   13568.450000     NaN
# 4                                     Propane   GJ   42071.041300     NaN
# ..                                        ...  ...            ...     ...
# 176  Electricity consumption|Grid electricity   GJ  960748.000000     NaN
# 177                                    Diesel   GJ  140100.000000     NaN
# 178                                  Gasoline   GJ    2124.000000     NaN
# 179                                    Naphta   GJ    6344.000000     NaN
# 180                               Natural gas   GJ  221612.000000     NaN
#
#               main_id facility_group_id    company_id  ...      value_MJ  \
# 0    BC-MAIN-857b7b89               NaN  CMP-4a434d72  ...  1.847565e+04
# 1    BC-MAIN-857b7b89               NaN  CMP-4a434d72  ...  7.267611e+07
# 2    BC-MAIN-857b7b89               NaN  CMP-4a434d72  ...  2.870424e+08
# 3    BC-MAIN-857b7b89               NaN  CMP-4a434d72  ...  1.356845e+07
# 4    BC-MAIN-857b7b89               NaN  CMP-4a434d72  ...  4.207104e+07
# ..                ...               ...           ...  ...           ...
# 176  ON-MAIN-7607a50e               NaN  CMP-3a4ccc7f  ...  9.607480e+08
# 177  ON-MAIN-7607a50e               NaN  CMP-3a4ccc7f  ...  1.401000e+08
# 178  ON-MAIN-7607a50e               NaN  CMP-3a4ccc7f  ...  2.124000e+06
# 179  ON-MAIN-7607a50e               NaN  CMP-3a4ccc7f  ...  6.344000e+06
# 180  ON-MAIN-7607a50e               NaN  CMP-3a4ccc7f  ...  2.216120e+08
#
#      unit_source      assumption_note unit_standard needs_factor  \
# 0    direct_unit  gj→MJ factor=1000.0            MJ        False
# 1    direct_unit  gj→MJ factor=1000.0            MJ        False
# 2    direct_unit  gj→MJ factor=1000.0            MJ        False
# 3    direct_unit  gj→MJ factor=1000.0            MJ        False
# 4    direct_unit  gj→MJ factor=1000.0            MJ        False
# ..           ...                  ...           ...          ...
# 176  direct_unit  gj→MJ factor=1000.0            MJ        False
# 177  direct_unit  gj→MJ factor=1000.0            MJ        False
# 178  direct_unit  gj→MJ factor=1000.0            MJ        False
# 179  direct_unit  gj→MJ factor=1000.0            MJ        False
# 180  direct_unit  gj→MJ factor=1000.0            MJ        False
#
#      value_tonnes_main  value_tonnes_group  value_tonnes_match  \
# 0             166000.0                 NaN            166000.0
# 1             166000.0                 NaN            166000.0
# 2             166000.0                 NaN            166000.0
# 3             166000.0                 NaN            166000.0
# 4             166000.0                 NaN            166000.0
# ..                 ...                 ...                 ...
# 176          2878047.0                 NaN           2878047.0
# 177          2878047.0                 NaN           2878047.0
# 178          2878047.0                 NaN           2878047.0
# 179          2878047.0                 NaN           2878047.0
# 180          2878047.0                 NaN           2878047.0
#
#      value_normalized  normalization_key
# 0            0.111299            main_id
# 1          437.807896            main_id
# 2         1729.171369            main_id
# 3           81.737651            main_id
# 4          253.440008            main_id
# ..                ...                ...
# 176        333.819427            main_id
# 177         48.678844            main_id
# 178          0.738000            main_id
# 179          2.204273            main_id
# 180         77.000827            main_id
#
# [150 rows x 21 columns]

# %% [markdown]
# ## NRJ

# %%
nrj_param = pd.read_excel(r'data/Parametrization/energy_parametrization.xlsx', sheet_name='RECAP')

# %%
# Make sure garde is numeric
nrj_param ['Grade'] = pd.to_numeric(nrj_param ['Grade'], errors='coerce')
nrj_param ['energy_MJ'] = pd.to_numeric(nrj_param ['energy_MJ'], errors='coerce')

# %%
# Apply
nrj_param ['commodities'] = nrj_param['commodities'].apply(lambda x: abbreviate_metals(x, metal_map_lower))

# %%
nrj_param
# Out:
#              main_id              facility_name facility_group_id  \
# 0   BC-MAIN-599152a0            Copper Mountain               NaN
# 1   BC-MAIN-6b4800fe                  Gibraltar               NaN
# 2   BC-MAIN-857b7b89                  Brucejack               NaN
# 3   BC-MAIN-8eb8be0d                  Red Chris               NaN
# 4   BC-MAIN-aa76f6f2                  New Afton               NaN
# 5   NL-MAIN-b64bae7a                     Scully               NaN
# 6   NL-MAIN-dd723db4                 Carol Lake               NaN
# 7   NU-MAIN-8b0264c9                  Meliadine               NaN
# 8   ON-MAIN-0aadf28f                Rainy River               NaN
# 9   ON-MAIN-1f126a43                    Macassa               NaN
# 10  ON-MAIN-687b8c8d                     Island               NaN
# 11  ON-MAIN-6e9be24e           Hemlo (Williams)               NaN
# 12  ON-MAIN-7607a50e             Young-Davidson               NaN
# 13  ON-MAIN-7f050560                   Red Lake               NaN
# 14  ON-MAIN-a3c56a83               Lac des Iles               NaN
# 15  ON-MAIN-aeafbb59                Detour Lake               NaN
# 16  ON-MAIN-cb85213a                Eagle River               NaN
# 17  ON-MAIN-fefeaee4                Musselwhite               NaN
# 18  QC-MAIN-02884fb5             Westwood-Doyon               NaN
# 19  QC-MAIN-6dc537e6                   Éléonore               NaN
# 20  QC-MAIN-9de9bb0d                      Kiena               NaN
# 21  QC-MAIN-b86f7d07               Casa Berardi               NaN
# 22  QC-MAIN-c0660aec                     Goldex               NaN
# 23  QC-MAIN-e51eda66                    LaRonde               NaN
# 24  QC-MAIN-e7e6a960          Canadian Malartic               NaN
# 25  QC-MAIN-f9e41c2a                    Lamaque               NaN
# 26  YT-MAIN-44857446  Keno Hill Silver District               NaN
# 27               NaN                        NaN      GRP-0a2c0d69
# 28               NaN                        NaN      GRP-0d911886
# 29               NaN                        NaN      GRP-147b3123
# 30               NaN                        NaN      GRP-14bfbb82
# 31               NaN                        NaN      GRP-a13779f8
#
#       facility_group_name facility_type                   province  \
# 0                     NaN        mining           British Columbia
# 1                     NaN        mining           British Columbia
# 2                     NaN        mining           British Columbia
# 3                     NaN        mining           British Columbia
# 4                     NaN        mining           British Columbia
# 5                     NaN        mining  Newfoundland and Labrador
# 6                     NaN        mining  Newfoundland and Labrador
# 7                     NaN        mining                    Nunavut
# 8                     NaN        mining                    Ontario
# 9                     NaN        mining                    Ontario
# 10                    NaN        mining                    Ontario
# 11                    NaN        mining                    Ontario
# 12                    NaN        mining                    Ontario
# 13                    NaN        mining                    Ontario
# 14                    NaN        mining                    Ontario
# 15                    NaN        mining                    Ontario
# 16                    NaN        mining                    Ontario
# 17                    NaN        mining                    Ontario
# 18                    NaN        mining                     Quebec
# 19                    NaN        mining                     Quebec
# 20                    NaN        mining                     Quebec
# 21                    NaN        mining                     Quebec
# 22                    NaN        mining                     Quebec
# 23                    NaN        mining                     Quebec
# 24                    NaN        mining                     Quebec
# 25                    NaN        mining                     Quebec
# 26                    NaN        mining                      Yukon
# 27     Meadowbank complex        mining                    Nunavut
# 28      Porcupine complex        mining                    Ontario
# 29      Timmins Operation        mining                    Ontario
# 30  Seabee Gold Operation        mining               Saskatchewan
# 31              Snow Lake        mining                   Manitoba
#
#                  mining_processing_type           commodities    energy_MJ  \
# 0                Open-pit, concentrator            Cu, Au, Ag   300.116931
# 1                Open-pit, concentrator            Cu, Mo, Ag   120.184633
# 2             Underground, concentrator                Au, Ag  6463.585853
# 3                Open-pit, concentrator            Au, Cu, Ag  2518.230578
# 4             Underground, concentrator            Au, Cu, Ag   156.070253
# 5                Open-pit, concentrator                    Fe   768.539326
# 6                Open-pit, concentrator                    Fe   834.563758
# 7   Open-pit, underground, concentrator                    Au  1274.879784
# 8   Open-pit, underground, concentrator                Au, Ag   541.632505
# 9             Underground, concentrator                Au, Ag  2639.074911
# 10            Underground, concentrator                    Au  1441.023854
# 11  Open-pit, underground, concentrator                    Au   726.693096
# 12            Underground, concentrator                    Au   462.606413
# 13            Underground, concentrator                Au, Ag  1596.673150
# 14  Open-pit, underground, concentrator  PGMs, Au, Ni, Cu, Co   168.091706
# 15               Open-pit, concentrator                    Au   285.352781
# 16            Underground, concentrator                    Au  2032.580055
# 17            Underground, concentrator                Au, Ag  1068.628033
# 18            Underground, concentrator                Au, Ag   785.261025
# 19            Underground, concentrator                    Au   876.076006
# 20               Open-pit, concentrator                    Au  1241.701718
# 21  Open-pit, underground, concentrator                Au, Ag   711.466658
# 22            Underground, concentrator                Au, Ag   302.120969
# 23            Underground, concentrator    Au, Zn, Cu, Ag, Cd   899.934796
# 24               Open-pit, concentrator                Au, Ag   265.028858
# 25            Underground, concentrator                    Au   655.055527
# 26            Underground, concentrator            Ag, Zn, Pb  1354.129582
# 27                Open-pit, underground                    Au  1116.122369
# 28                Open-pit, underground                    Au   567.425590
# 29            Underground, concentrator                    Au   820.661435
# 30                          Underground                    Au  3089.869151
# 31                          Underground        Au, Zn, Cu, Ag   388.889320
#
#     energy_GJ     Grade  Concentrate grade  Strip ratio  Recovery rate  \
# 0    0.300117  0.350000               23.1     3.820000           79.7
# 1    0.120185  0.250000                NaN     1.300000           82.6
# 2    6.463586  0.000568                NaN          NaN           96.0
# 3    2.518231       NaN                NaN          NaN           54.2
# 4    0.156070       NaN                NaN     0.187133           90.0
# 5    0.768539       NaN                NaN          NaN            NaN
# 6    0.834564       NaN                NaN          NaN            NaN
# 7    1.274880  0.000611                NaN     3.148294           96.6
# 8    0.541633       NaN                NaN     3.472590           91.0
# 9    2.639075       NaN                NaN          NaN            NaN
# 10   1.441024  0.000948                NaN     0.167682           97.0
# 11   0.726693       NaN                NaN     1.208527            NaN
# 12   0.462606  0.000220                NaN     0.156803           90.0
# 13   1.596673       NaN                NaN     1.181059            NaN
# 14   0.168092  0.000388                NaN          NaN            NaN
# 15   0.285353       NaN                NaN     4.327581            NaN
# 16   2.032580  0.001260                NaN     0.649378           96.6
# 17   1.068628  0.000570                NaN     0.682115            NaN
# 18   0.785261  0.000303                NaN     2.343911           93.0
# 19   0.876076  0.000478                NaN     0.361706           91.0
# 20   1.241702  0.000590                NaN     0.848296           98.3
# 21   0.711467       NaN                NaN          NaN            NaN
# 22   0.302121       NaN                NaN          NaN            NaN
# 23   0.899935  0.000523                NaN     1.467090           93.5
# 24   0.265029  0.000117                NaN     1.000141           92.8
# 25   0.655056  0.000676                NaN          NaN           97.1
# 26   1.354130  0.094400                NaN          NaN            NaN
# 27   1.116122  0.000386                NaN     9.553805           90.6
# 28   0.567426  0.000302                NaN          NaN           91.4
# 29   0.820661  0.000270                NaN          NaN            NaN
# 30   3.089869  0.001014                NaN          NaN           97.0
# 31   0.388889  0.000345                NaN          NaN           64.8
#
#                                               Comment
# 0                      Assumed Cu is the main product
# 1                               Only available for Cu
# 2                                                 Ore
# 3                      Assumed Au is the main product
# 4                      Assumed Au is the main product
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8          Assumed Au is the main product (for grade)
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                 Only PGM available
# 15                                                NaN
# 16                                                NaN
# 17                                                Ore
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                     Assumed Au is the main product
# 24                                                NaN
# 25                                                NaN
# 26                     Assumed Si is the main product
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31  Assumed Au is the main product, taken values f...

# %%
def plot_energy_vs_grade(
    df,
    x_col='Grade',
    y_col='energy_MJ',
    color_col='commodities',
    symbol_col='mining_processing_type',
    hover_name_cols=['facility_name', 'facility_group_name'],
    x_label='Grade (%)',
    y_label='MJ/t ore processed',
    x_log=False,
    font_color="#333333",
    size_marker=10,
    save_path=None
):
    """
    Scatter plot of energy vs grade.
    Color = commodities
    Symbol = mining/processing type
    Fixed mapping for symbols to match the legend
    """
    df = df.copy()

    # Build hover_name
    if hover_name_cols and all(col in df.columns for col in hover_name_cols):
        df['hover_name'] = (
            df[hover_name_cols[0]].astype(str)
            + " (" + df[hover_name_cols[1]].astype(str) + ")"
        )
    else:
        df['hover_name'] = df[hover_name_cols[0]] if hover_name_cols else None

    # Prepare color and symbol sequences
    color_sequence = px.colors.qualitative.Plotly
    symbol_sequence = [
        "circle", "square", "diamond", "cross", "x",
        "triangle-up", "triangle-down", "triangle-left", "triangle-right",
        "star", "hexagon", "pentagon"
    ]

    # Create symbol map for unique values
    unique_symbols = df[symbol_col].dropna().unique()
    symbol_map = {sym: symbol_sequence[i % len(symbol_sequence)] for i, sym in enumerate(unique_symbols)}

    # Create color map for unique commodities
    unique_colors = df[color_col].dropna().unique()
    color_map = {col: color_sequence[i % len(color_sequence)] for i, col in enumerate(unique_colors)}

    # Apply the mappings
    df['marker_symbol'] = df[symbol_col].map(symbol_map)
    df['marker_color'] = df[color_col].map(color_map)

    # Initialize figure
    fig = go.Figure()

    # Scatter trace
    fig.add_trace(
        go.Scatter(
            x=df[x_col],
            y=df[y_col],
            mode='markers',
            marker=dict(
                size=size_marker,
                color=df['marker_color'],
                symbol=df['marker_symbol']
            ),
            text=df['hover_name'],
            hovertemplate='%{text}<br>%{x:.4f} ' + x_col + '<br>%{y:.2f} ' + y_col + '<extra></extra>',
            showlegend=False
        )
    )

    # Add dummy traces for color legend
    for col, col_color in color_map.items():
        fig.add_trace(
            go.Scatter(
                x=[None], y=[None], mode='markers',
                marker=dict(symbol="circle", size=size_marker, color=col_color),
                legendgroup="Color",
                showlegend=True,
                name=str(col)
            )
        )

    # Add dummy traces for symbol legend
    for sym, sym_marker in symbol_map.items():
        fig.add_trace(
            go.Scatter(
                x=[None], y=[None], mode='markers',
                marker=dict(symbol=sym_marker, size=size_marker, color="grey"),
                legendgroup="Symbol",
                showlegend=True,
                name=str(sym)
            )
        )

    # Layout
    fig.update_layout(
        xaxis_title=x_label if x_label else x_col.replace('_', ' ').title(),
        yaxis_title=y_label if y_label else y_col.replace('_', ' ').title(),
        font=dict(color=font_color, size=14),
        template="plotly_white",
        legend=dict(tracegroupgap=20, itemsizing='constant'),
        height=600
    )

    if x_log:
        fig.update_xaxes(type="log")

    if save_path:
        fig.write_html(save_path, include_plotlyjs='cdn')

    fig.show()
    return fig

# %%
fig_log = plot_energy_vs_grade(
    nrj_param,
    x_col='Grade',
    y_col='energy_MJ',
    color_col='commodities',
    symbol_col='mining_processing_type',
    x_log=True,
    font_color='black',
    save_path=r'data/Parametrization/param_nrj_log.html'
)

# Filtered grades < 0.01
df_filtered = nrj_param[nrj_param['Grade'] < 0.01]
fig_filtered = plot_energy_vs_grade(
    df_filtered,
    x_col='Grade',
    y_col='energy_MJ',
    color_col='commodities',
    symbol_col='mining_processing_type',
    font_color='black',
    save_path=r'data/Parametrization/param_nrj.html'
)

# %% [markdown]
# ## Environmental flows

# %%
biosphere_param = pd.read_excel(r'data/Parametrization/biosphere_parametrization.xlsx')

# %%
biosphere_param
# Out:
#                        env_id  year compartment_name substance_id  \
# 0            npri-2132-2023-1  2023              Air      NA - 16
# 1            npri-2132-2023-2  2023              Air     630-08-0
# 2            npri-2132-2023-3  2023              Air   11104-93-1
# 3            npri-2132-2023-4  2023              Air     NA - M09
# 4            npri-2132-2023-5  2023              Air     NA - M10
# ...                       ...   ...              ...          ...
# 1284  ENV-GRP-14bfbb82-2023-1  2023              Air     NA - GHG
# 1285  ENV-GRP-14bfbb82-2023-2  2023              Air     NA - GHG
# 1286  ENV-GRP-14bfbb82-2023-3  2023            Water    7732-18-5
# 1287  ENV-GRP-14bfbb82-2023-4  2023            Water    7732-18-5
# 1288  ENV-GRP-14bfbb82-2023-5  2023            Water    7732-18-5
#
#      flow_direction  release_pathway    unit       value comment  \
# 0          Emission  Stack Emissions  tonnes     127.312     NaN
# 1          Emission  Stack Emissions  tonnes     189.137     NaN
# 2          Emission  Stack Emissions  tonnes    1099.925     NaN
# 3          Emission  Stack Emissions  tonnes      43.701     NaN
# 4          Emission  Stack Emissions  tonnes       8.343     NaN
# ...             ...              ...     ...         ...     ...
# 1284       Emission              NaN  tCO2eq   14002.000     NaN
# 1285       Emission              NaN  tCO2eq   30057.000     NaN
# 1286     Withdrawal              NaN      m3  183118.000     NaN
# 1287     Discharged              NaN      m3   25131.000     NaN
# 1288    Consumption              NaN      m3  147624.000     NaN
#
#                main_id  ... Recovery rate  \
# 0     AB-MAIN-d3a4aba9  ...          83.5
# 1     AB-MAIN-d3a4aba9  ...          83.5
# 2     AB-MAIN-d3a4aba9  ...          83.5
# 3     AB-MAIN-d3a4aba9  ...          83.5
# 4     AB-MAIN-d3a4aba9  ...          83.5
# ...                ...  ...           ...
# 1284               NaN  ...          97.0
# 1285               NaN  ...          97.0
# 1286               NaN  ...          97.0
# 1287               NaN  ...          97.0
# 1288               NaN  ...          97.0
#
#                                                 Comment    company_id  \
# 0     Assumed Ni is the main product (Co also included)           NaN
# 1                                                   NaN           NaN
# 2                                                   NaN           NaN
# 3                                                   NaN           NaN
# 4                                                   NaN           NaN
# ...                                                 ...           ...
# 1284                                                NaN  CMP-4a73c5f8
# 1285                                                NaN  CMP-4a73c5f8
# 1286                                                NaN  CMP-4a73c5f8
# 1287                                                NaN  CMP-4a73c5f8
# 1288                                                NaN  CMP-4a73c5f8
#
#                                               source_id  value_tonnes_main  \
# 0     https://www.canada.ca/en/environment-climate-c...            35636.0
# 1     https://www.canada.ca/en/environment-climate-c...            35636.0
# 2     https://www.canada.ca/en/environment-climate-c...            35636.0
# 3     https://www.canada.ca/en/environment-climate-c...            35636.0
# 4     https://www.canada.ca/en/environment-climate-c...            35636.0
# ...                                                 ...                ...
# 1284                          SRC_SSRMiningInc_ESG_2023                NaN
# 1285                          SRC_SSRMiningInc_ESG_2023                NaN
# 1286                          SRC_SSRMiningInc_ESG_2023                NaN
# 1287                          SRC_SSRMiningInc_ESG_2023                NaN
# 1288                          SRC_SSRMiningInc_ESG_2023                NaN
#
#      value_tonnes_group value_tonnes_match value_normalized  \
# 0                   NaN            35636.0         0.003573
# 1                   NaN            35636.0         0.005307
# 2                   NaN            35636.0         0.030866
# 3                   NaN            35636.0         0.001226
# 4                   NaN            35636.0         0.000234
# ...                 ...                ...              ...
# 1284           122000.0           122000.0         0.114770
# 1285           122000.0           122000.0         0.246369
# 1286           122000.0           122000.0         1.500967
# 1287           122000.0           122000.0         0.205992
# 1288           122000.0           122000.0         1.210033
#
#       normalization_key  unit_normalized
# 0               main_id         tonnes/t
# 1               main_id         tonnes/t
# 2               main_id         tonnes/t
# 3               main_id         tonnes/t
# 4               main_id         tonnes/t
# ...                 ...              ...
# 1284  facility_group_id         tCO2eq/t
# 1285  facility_group_id         tCO2eq/t
# 1286  facility_group_id             m3/t
# 1287  facility_group_id             m3/t
# 1288  facility_group_id             m3/t
#
# [1289 rows x 24 columns]

# %%
# Make sure garde is numeric
biosphere_param['Grade'] = pd.to_numeric(biosphere_param['Grade'], errors='coerce')
biosphere_param['Strip ratio'] = pd.to_numeric(biosphere_param['Strip ratio'], errors='coerce')
biosphere_param['Recovery rate'] = pd.to_numeric(biosphere_param['Recovery rate'], errors='coerce')
biosphere_param['value_normalized'] = pd.to_numeric(biosphere_param['value_normalized'], errors='coerce')

# %%
# Apply
biosphere_param['commodities'] = biosphere_param['commodities'].apply(lambda x: abbreviate_metals(x, metal_map_lower))

# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px

def plot_energy_vs_grade_by_substance(
    df,
    x_col='Grade',
    y_col='value',
    substance_col='substance_id',
    color_col='commodities',
    symbol_col='mining_processing_type',
    hover_name_cols=['facility_name', 'facility_group_name'],
    x_label='Grade (%)',
    y_label='MJ/t ore processed',
    x_log=False,
    font_color="#333333",
    size_marker=10,
    save_path=None
):
    """
    Scatter plot of energy vs grade, with dropdown by substance_id.
    Color = commodities
    Symbol = mining/processing type
    Dropdown allows filtering by substance_id.
    """

    df = df.copy()

    # Build hover_name
    if hover_name_cols and all(col in df.columns for col in hover_name_cols):
        df['hover_name'] = (
            df[hover_name_cols[0]].astype(str)
            + " (" + df[hover_name_cols[1]].astype(str) + ")"
        )
    else:
        df['hover_name'] = df[hover_name_cols[0]] if hover_name_cols else None

    # --- Filter for unique substances ---
    substances = df[substance_col].dropna().unique()
    substances = sorted(substances, key=lambda x: str(x))

    # Prepare color and symbol sequences
    color_sequence = px.colors.qualitative.Plotly
    symbol_sequence = [
        "circle", "square", "diamond", "cross", "x",
        "triangle-up", "triangle-down", "triangle-left", "triangle-right",
        "star", "hexagon", "pentagon"
    ]

    # Create symbol map for unique values
    unique_symbols = df[symbol_col].dropna().unique()
    symbol_map = {sym: symbol_sequence[i % len(symbol_sequence)] for i, sym in enumerate(unique_symbols)}

    # Create color map for unique commodities
    unique_colors = df[color_col].dropna().unique()
    color_map = {col: color_sequence[i % len(color_sequence)] for i, col in enumerate(unique_colors)}

    # Initialize figure
    fig = go.Figure()

    # --- Add one trace per substance ---
    for i, substance in enumerate(substances):
        df_sub = df[df[substance_col] == substance]
        df_sub = df_sub.dropna(subset=[x_col, y_col])
        visible = True if i == 0 else False

        fig.add_trace(
            go.Scatter(
                x=df_sub[x_col],
                y=df_sub[y_col],
                mode='markers',
                marker=dict(
                    size=size_marker,
                    color=df_sub[color_col].map(color_map),
                    symbol=df_sub[symbol_col].map(symbol_map)
                ),
                text=df_sub['hover_name'],
                hovertemplate='%{text}<br>%{x:.4f} ' + x_col + '<br>%{y:.2f} ' + y_label + '<extra></extra>',
                name=str(substance),
                visible=visible,
                showlegend=False
            )
        )

    # --- Add dummy traces for color legend ---
    for col, col_color in color_map.items():
        fig.add_trace(
            go.Scatter(
                x=[None], y=[None], mode='markers',
                marker=dict(symbol="circle", size=size_marker, color=col_color),
                legendgroup="Color",
                showlegend=True,
                name=str(col)
            )
        )

    # --- Add dummy traces for symbol legend ---
    for sym, sym_marker in symbol_map.items():
        fig.add_trace(
            go.Scatter(
                x=[None], y=[None], mode='markers',
                marker=dict(symbol=sym_marker, size=size_marker, color="grey"),
                legendgroup="Symbol",
                showlegend=True,
                name=str(sym)
            )
        )

    # --- Dropdown buttons ---
    buttons = []
    for i, substance in enumerate(substances):
        visibility = [False]*len(substances) + [True]*(len(color_map)+len(symbol_map))
        visibility[i] = True
        buttons.append(
            dict(
                label=str(substance),
                method="update",
                args=[{"visible": visibility},
                      {"title": f"Energy vs Grade – {substance}"}]
            )
        )

    # Layout
    fig.update_layout(
        updatemenus=[dict(buttons=buttons, direction="down", showactive=True)],
        xaxis_title=x_label if x_label else x_col.replace('_', ' ').title(),
        yaxis_title=y_label if y_label else y_col.replace('_', ' ').title(),
        font=dict(color=font_color, size=14),
        template="plotly_white",
        legend=dict(tracegroupgap=20, itemsizing='constant'),
        height=600,
        title=f"Energy vs Grade – {substances[0]}"
    )

    if x_log:
        fig.update_xaxes(type="log")

    if save_path:
        fig.write_html(save_path, include_plotlyjs='cdn')

    fig.show()
    return fig

# %%
plot_energy_vs_grade_by_substance(
    biosphere_param,
    x_col='Grade',            # ou autre colonne quantitative
    y_col='value_normalized', # par exemple
    substance_col='substance_id',
    color_col='commodities',
    symbol_col='mining_processing_type',
    y_label='MJ/t ore processed'
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\lca\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'facility_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 plot_energy_vs_grade_by_substance(
#       2     biosphere_param,
#       3     x_col='Grade',            # ou autre colonne quantitative
#       4     y_col='value_normalized', # par exemple
#       5     substance_col='substance_id',
#       6     color_col='commodities',
#       7     symbol_col='mining_processing_type',
#       8     y_label='MJ/t ore processed'
#       9 )
#
# Cell In[51], line 36, in plot_energy_vs_grade_by_substance(df, x_col, y_col, substance_col, color_col, symbol_col, hover_name_cols, x_label, y_label, x_log, font_color, size_marker, save_path)
#      31     df['hover_name'] = (
#      32         df[hover_name_cols[0]].astype(str)
#      33         + " (" + df[hover_name_cols[1]].astype(str) + ")"
#      34     )
#      35 else:
# ---> 36     df['hover_name'] = df[hover_name_cols[0]] if hover_name_cols else None
#      38 # --- Filter for unique substances ---
#      39 substances = df[substance_col].dropna().unique()
#
# File ~\anaconda3\envs\lca\lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\envs\lca\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'facility_name'

# %% [markdown]
# ## Land occupation
